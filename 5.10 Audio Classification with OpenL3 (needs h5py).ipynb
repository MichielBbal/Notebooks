# %% [markdown]
# # Audio with OpenL3

# %% [markdown]
# ## 0. Install packages

# %%
# !pip install pysoundfile
# Out:
# Collecting pysoundfile
#   Downloading PySoundFile-0.9.0.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (671 kB)
# Requirement already satisfied: cffi>=0.6 in c:\users\31653\anaconda3\lib\site-packages (from pysoundfile) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\31653\anaconda3\lib\site-packages (from cffi>=0.6->pysoundfile) (2.20)
# Installing collected packages: pysoundfile
# Successfully installed pysoundfile-0.9.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### installing h5py
#
# The h5py package provides both a high- and low-level interface to the HDF5 library from Python.
# HDF5 lets you store huge amounts of numerical data, and easily manipulate that data from NumPy.
# - source: https://pypi.org/project/h5py/
# - installation: https://docs.h5py.org/en/latest/index.html
#
# Or try 'conda install h5py' => this took me >15 minutes

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\michiel\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\michiel\anaconda3\lib\site-packages (from h5py) (1.21.5)

# %%
# !pip install openl3
# Out:
# Collecting openl3
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Michiel\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Michiel\\AppData\\Local\\Temp\\pip-install-ix0str9m\\h5py_2e7fa06e5354475bb6e8d8b777835865\\setup.py'"'"'; __file__='"'"'C:\\Users\\Michiel\\AppData\\Local\\Temp\\pip-install-ix0str9m\\h5py_2e7fa06e5354475bb6e8d8b777835865\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Michiel\AppData\Local\Temp\pip-wheel-3y8_5ui6'
#        cwd: C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\
#   Complete output (1328 lines):
#   C:\Users\Michiel\anaconda3\lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running bdist_wheel
#   Using cached openl3-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: soundfile>=0.9.0.post1 in c:\users\michiel\appdata\roaming\python\python39\site-packages (from openl3) (0.10.3.post1)
# Requirement already satisfied: scikit-image>=0.14.3librosa>=0.7.2 in c:\users\michiel\anaconda3\lib\site-packages (from openl3) (0.19.2)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\michiel\anaconda3\lib\site-packages (from openl3) (1.21.5)
# Collecting h5py<3.0.0,>=2.7.0
#   Using cached h5py-2.10.0.tar.gz (301 kB)
# Collecting moviepy>=1.0.0
#   Using cached moviepy-1.0.3-py3-none-any.whl
# Requirement already satisfied: resampy<0.3.0,>=0.2.1 in c:\users\michiel\anaconda3\lib\site-packages (from openl3) (0.2.2)
# Collecting tensorflow>=2.0.0
#   Using cached tensorflow-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\michiel\anaconda3\lib\site-packages (from openl3) (1.7.3)
# Collecting kapre>=0.3.5
#   Using cached kapre-0.3.7-py3-none-any.whl
# Requirement already satisfied: six in c:\users\michiel\anaconda3\lib\site-packages (from h5py<3.0.0,>=2.7.0->openl3) (1.16.0)
# Requirement already satisfied: librosa>=0.7.2 in c:\users\michiel\appdata\roaming\python\python39\site-packages (from kapre>=0.3.5->openl3) (0.9.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\michiel\anaconda3\lib\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (1.0.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\michiel\anaconda3\lib\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (5.1.1)
# Requirement already satisfied: numba>=0.45.1 in c:\users\michiel\anaconda3\lib\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (0.55.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\michiel\anaconda3\lib\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (21.3)
# Requirement already satisfied: joblib>=0.14 in c:\users\michiel\anaconda3\lib\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (1.1.0)
# Requirement already satisfied: pooch>=1.0 in c:\users\michiel\appdata\roaming\python\python39\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (1.6.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\michiel\appdata\roaming\python\python39\site-packages (from librosa>=0.7.2->kapre>=0.3.5->openl3) (2.1.9)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\michiel\anaconda3\lib\site-packages (from moviepy>=1.0.0->openl3) (4.64.0)
# Collecting decorator>=4.0.10
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting imageio-ffmpeg>=0.2.0
#   Using cached imageio_ffmpeg-0.4.7-py3-none-win_amd64.whl (22.6 MB)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\michiel\anaconda3\lib\site-packages (from moviepy>=1.0.0->openl3) (2.9.0)
# Collecting proglog<=1.0.0
#   Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\michiel\anaconda3\lib\site-packages (from moviepy>=1.0.0->openl3) (2.27.1)
# Requirement already satisfied: pillow in c:\users\michiel\anaconda3\lib\site-packages (from imageio<3.0,>=2.5->moviepy>=1.0.0->openl3) (9.0.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\michiel\anaconda3\lib\site-packages (from numba>=0.45.1->librosa>=0.7.2->kapre>=0.3.5->openl3) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\michiel\anaconda3\lib\site-packages (from numba>=0.45.1->librosa>=0.7.2->kapre>=0.3.5->openl3) (61.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\michiel\anaconda3\lib\site-packages (from packaging>=20.0->librosa>=0.7.2->kapre>=0.3.5->openl3) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\michiel\anaconda3\lib\site-packages (from pooch>=1.0->librosa>=0.7.2->kapre>=0.3.5->openl3) (1.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->openl3) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\michiel\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->openl3) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michiel\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->openl3) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michiel\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->openl3) (2021.10.8)
# Requirement already satisfied: networkx>=2.2 in c:\users\michiel\anaconda3\lib\site-packages (from scikit-image>=0.14.3librosa>=0.7.2->openl3) (2.7.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\michiel\anaconda3\lib\site-packages (from scikit-image>=0.14.3librosa>=0.7.2->openl3) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\michiel\anaconda3\lib\site-packages (from scikit-image>=0.14.3librosa>=0.7.2->openl3) (2021.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa>=0.7.2->kapre>=0.3.5->openl3) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\michiel\anaconda3\lib\site-packages (from soundfile>=0.9.0.post1->openl3) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\michiel\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0.post1->openl3) (2.21)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (3.3.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (2.9.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (14.0.1)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (4.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (1.12.1)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (1.42.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (0.26.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (3.19.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\michiel\anaconda3\lib\site-packages (from tensorflow>=2.0.0->openl3) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\michiel\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->openl3) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\michiel\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (1.33.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\michiel\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\michiel\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\michiel\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\michiel\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0->openl3) (3.2.0)
# Requirement already satisfied: colorama in c:\users\michiel\anaconda3\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy>=1.0.0->openl3) (0.4.4)
# Building wheels for collected packages: h5py
#   Building wheel for h5py (setup.py): started
#   Building wheel for h5py (setup.py): finished with status 'error'
#   Running setup.py clean for h5py
# Failed to build h5py
# Installing collected packages: h5py, google-pasta, gast, flatbuffers, decorator, astunparse, tensorflow, proglog, imageio-ffmpeg, moviepy, kapre, openl3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.6.0
#     Uninstalling h5py-3.6.0:
#       Successfully uninstalled h5py-3.6.0
#     Running setup.py install for h5py: started
#     Running setup.py install for h5py: finished with status 'error'
#   Rolling back uninstall of h5py
#   Moving to c:\users\michiel\anaconda3\lib\site-packages\h5py-3.6.0.dist-info\
#    from C:\Users\Michiel\anaconda3\Lib\site-packages\~5py-3.6.0.dist-info
#   Moving to c:\users\michiel\anaconda3\lib\site-packages\h5py\
#    from C:\Users\Michiel\anaconda3\Lib\site-packages\~5py
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\h5py
#   copying h5py\h5py_warnings.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\highlevel.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\ipy_completer.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\version.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\__init__.py -> build\lib.win-amd64-3.9\h5py
#   creating build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\attrs.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\base.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\compat.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\dataset.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\datatype.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\dims.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\files.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\filters.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\group.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\selections.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\selections2.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\vds.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\__init__.py -> build\lib.win-amd64-3.9\h5py\_hl
#   creating build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\common.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attribute_create.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attrs.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attrs_data.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_base.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_completions.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset_getitem.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset_swmr.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_datatype.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_deprecation.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dimension_scales.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dims_dimensionproxy.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dtype.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file2.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file_image.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_filters.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_group.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5d_direct_chunk.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5f.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5p.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5pl.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5t.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_objects.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_selections.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_slicing.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_threads.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\__init__.py -> build\lib.win-amd64-3.9\h5py\tests
#   creating build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_highlevel_vds.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_lowlevel_vds.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_virtual_source.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\__init__.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   running build_ext
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
# ...
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#     warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#     warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#     warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#     warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#     warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#     warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#     warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#     warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#     warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#     warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#     warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#     warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#     warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#     warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#     warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#     warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#     warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#     warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#     warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#     warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     Loading library to get version: hdf5.dll
#     Autodetected HDF5 1.10.6
#     ********************************************************************************
#                            Summary of the h5py configuration
#
#         Path to HDF5: None
#         HDF5 Version: '1.10.6'
#          MPI Enabled: False
#     Rebuild Required: True
#
#     ********************************************************************************
#     Executing cythonize()
#     [ 1/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\_conv.pyx
#     [ 2/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\_errors.pyx
#     [ 3/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\_objects.pyx
#     [ 4/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\_proxy.pyx
#     [ 5/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\defs.pyx
#     [ 6/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5.pyx
#     [ 7/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5a.pyx
#     [ 8/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5ac.pyx
#     [ 9/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5d.pyx
#     [10/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5ds.pyx
#     [11/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5f.pyx
#     [12/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5fd.pyx
#     [13/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5g.pyx
#     [14/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5i.pyx
#     [15/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5l.pyx
#     [16/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5o.pyx
#     [17/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5p.pyx
#     [18/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5pl.pyx
#     [19/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5r.pyx
#     [20/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5s.pyx
#     [21/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5t.pyx
#     [22/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\h5z.pyx
#     [23/23] Cythonizing C:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\utils.pyx
#     building 'h5py.defs' extension
#     creating build\temp.win-amd64-3.9
#     creating build\temp.win-amd64-3.9\Release
#     creating build\temp.win-amd64-3.9\Release\Users
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local\Temp
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865
#     creating build\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py
#     "C:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\BIN\x86_amd64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DH5_USE_16_API -D_HDF5USEDLL_ -DH5_BUILT_AS_DYNAMIC_LIB -I.\h5py -IC:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\lzf -IC:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\windows -IC:\Users\Michiel\anaconda3\lib\site-packages\numpy\core\include -IC:\Users\Michiel\anaconda3\include -IC:\Users\Michiel\anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\INCLUDE" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.10240.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\8.1\include\shared" "-IC:\Program Files (x86)\Windows Kits\8.1\include\um" "-IC:\Program Files (x86)\Windows Kits\8.1\include\winrt" /TcC:\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\defs.c /Fobuild\temp.win-amd64-3.9\Release\Users\Michiel\AppData\Local\Temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\defs.obj
#     defs.c
#     c:\users\michiel\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#     c:\users\michiel\appdata\local\temp\pip-install-ix0str9m\h5py_2e7fa06e5354475bb6e8d8b777835865\h5py\api_compat.h(27): fatal error C1083: Cannot open include file: 'hdf5.h': No such file or directory
#     error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit code 2
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Michiel\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Michiel\\AppData\\Local\\Temp\\pip-install-ix0str9m\\h5py_2e7fa06e5354475bb6e8d8b777835865\\setup.py'"'"'; __file__='"'"'C:\\Users\\Michiel\\AppData\\Local\\Temp\\pip-install-ix0str9m\\h5py_2e7fa06e5354475bb6e8d8b777835865\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Michiel\AppData\Local\Temp\pip-record-ym_soi0g\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Michiel\anaconda3\Include\h5py' Check the logs for full command output.

# %%
import glob
wav_files=glob.glob('*.wav')
print(wav_files)
# Out:
# ['11k16bitpcm.wav', 'claxon_1m.wav', 'claxon_close.wav', 'claxon_freesound.wav', 'claxon_iphone.wav', 'claxon_michiel.wav', 'converted.wav', 'example.wav', 'file.wav', 'loudness.wav', 'miaow_16k.wav', 'my-audio.wav', 'my_test.wav', 'my_wav.wav', 'new_file.wav', 'noise_add.wav', 'out.wav', 'output.wav', 'piano_c.wav', 'robot0.wav', 'robot1.wav', 'robot2.wav', 'robot3.wav', 'silence.wav', 'speech_whistling2.wav', 'test.wav', 'test2.wav', 'test3.wav', 'tone_220.wav', 'welcome.wav']

# %%
import soundfile as sf

data, samplerate = sf.read('test3.wav')
sf.write('new_file.ogg', data, samplerate)
samplerate
# Out:
# 16000

# %%
#source: https://openl3.readthedocs.io/en/latest/tutorial.html
import openl3
import soundfile as sf

audio, sr = sf.read('test3.wav')
emb, ts = openl3.get_audio_embedding(audio, sr)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 import openl3
#       2 import soundfile as sf
#       4 audio, sr = sf.read('test3.wav')
#
# ModuleNotFoundError: No module named 'openl3'
