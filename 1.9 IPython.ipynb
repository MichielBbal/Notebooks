# %% [markdown]
# # Some examples of IPython
#
# ## Contents
# 0. Install packages
# 1. Youtube video
# 2. image
# 3. video

# %% [markdown]
# ## 0. Install packages

# %%
pip install IPython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('Cgxsv1riJhI')

# %%
from IPython import display
#IPython.display.Image(data=None, url=None, filename=None, format=None, embed=None, width=None, height=None, retina=False, unconfined=False, metadata=None)

IPython.display.Image(filename="insecten.png", width=300, height=300)

# %%
import IPython
#from IPython import display
IPython.display.Video(filename='camera_detected_video.avi')

#(data=None, url=None, filename=None, embed=False, mimetype=None, width=None, height=None, html_attributes='controls')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-83260479432a> in <module>
#       1 import IPython
#       2 #from IPython import display
# ----> 3 IPython.display.Video(filename='camera_detected_video.avi')
#       4
#       5 #(data=None, url=None, filename=None, embed=False, mimetype=None, width=None, height=None, html_attributes='controls')
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1391             url = data
#    1392             data = None
# -> 1393         elif os.path.exists(data):
#    1394             filename = data
#    1395             data = None
#
# ~\Anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
# ...
