# %% [markdown]
# # Time Series database with InfluxDB InfluxDB
#
# #### Links
# - Readthedocs : https://influxdb-python.readthedocs.io/en/latest/api-documentation.html
# - Pypi:https://pypi.org/project/influxdb/
# - GitHub: https://github.com/influxdata/influxdb-python
#
# This Notebook is for InfluxDB 1.8.
# November 2021.

# %% [markdown]
# ## Contents
# 0. Install packages
# 1. Some basic scripts with InfluxDBClient
# 2. Some basic scripts with DataframeClient

# %% [markdown]
# ## 0. Install packages

# %%
# %pip install influxdb
# Out:
# Collecting influxdb
#   Downloading influxdb-5.3.1-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: python-dateutil>=2.6.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2.8.1)
# Requirement already satisfied: msgpack in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (1.0.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (1.15.0)
# Requirement already satisfied: requests>=2.17.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2.25.1)
# Requirement already satisfied: pytz in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2020.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (1.26.4)
# Installing collected packages: influxdb
# Successfully installed influxdb-5.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.23.0-py3-none-any.whl (522 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (1.26.7)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: pytz>=2019.1 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2021.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (58.2.0)
# Requirement already satisfied: six>=1.10 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (1.16.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2021.10.8)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.23.0 rx-3.2.0

# %% [markdown]
# ## 1. Some basic scripts with InfluxDBclient

# %%
import notebooks_config
red_rpi_ip =notebooks_config.red_rpi_ip
print(red_rpi_ip)
# Out:
# 192.168.178.50

# %%
#check connection with the Influxdb on the raspberry
from influxdb import InfluxDBClient
client = InfluxDBClient(host= red_rpi_ip, port=8086) # rry ip on a local network
pong = client.ping()
print(pong)
# Out:
# 1.8.10

# %% [markdown]
# ### 1.1 Getting, creating and deleting users

# %%
# get a list of users
from influxdb import InfluxDBClient
client = InfluxDBClient(host='192.168.178.50', port=8086)
users = client.get_list_users()
print(users)
# Out:
# []

# %%
# create a new user called Henk
client.create_user('Henk', 'henkspw', admin=False)
users = client.get_list_users()
print(users)
# Out:
# [{'user': 'Henk', 'admin': False}]

# %%
# drop Henk again
client.drop_user('Henk')
users = client.get_list_users()
print(users)
# Out:
# []

# %% [markdown]
# ### 1.2 Getting, creating and deleting databases

# %%
#also working
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING'}]

# %%
#create a new database and check it 
client.create_database('example2')
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING2'}, {'name': 'SNORING'}, {'name': 'example'}, {'name': 'example2'}]

# %%
# delete a database and check it
client.drop_database('example2')
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING2'}, {'name': 'SNORING'}]

# %%
# switch to database
client.switch_database('SNORING')

# %% [markdown]
# ### 1.3 Get measurements and series

# %%
#when switched to a database you can get a list of measurements
msmts = client.get_list_measurements()
print(msmts)
# Out:
# [{'name': 'my_snoring'}]

# %%
series = client.get_list_series(database=None, measurement=None, tags=None)
series
# Out:
# ['my_snoring']

# %% [markdown]
# ### 1.4 Queries

# %%
my_query =client.query("SELECT snoring FROM my_snoring WHERE time > now() -12h") # not enough memory for a full night 
print(my_query)
# Out:
# ResultSet({'('my_snoring', None)': [{'time': '2022-01-11T20:30:16.545278Z', 'snoring': 0.06364712864160538}, {'time': '2022-01-11T20:30:17.089403Z', 'snoring': 0.06481613218784332}, {'time': '2022-01-11T20:30:17.632948Z', 'snoring': 0.06085388362407684}, {'time': '2022-01-11T20:30:18.174472Z', 'snoring': 0.07503601908683777}, {'time': '2022-01-11T20:30:18.718526Z', 'snoring': 0.09147290885448456}, {'time': '2022-01-11T20:30:19.263252Z', 'snoring': 0.08799783140420914}, {'time': '2022-01-11T20:30:19.807354Z', 'snoring': 0.1255640834569931}, {'time': '2022-01-11T20:30:20.351558Z', 'snoring': 0.07267340272665024}, {'time': '2022-01-11T20:30:20.894120Z', 'snoring': 0.07314488291740417}, {'time': '2022-01-11T20:30:21.437782Z', 'snoring': 0.07205292582511902}, {'time': '2022-01-11T20:30:21.982186Z', 'snoring': 0.07616283744573593}, {'time': '2022-01-11T20:30:22.525461Z', 'snoring': 0.10176752507686615}, {'time': '2022-01-11T20:30:23.070807Z', 'snoring': 0.06448861211538315}, {'time': '2022-01-11T20:30:23.612106Z', 'snoring': 0.06687817722558975}, {'time': '2022-01-11T20:30:24.152457Z', 'snoring': 0.075749970972538}, {'time': '2022-01-11T20:30:24.695668Z', 'snoring': 0.0973748192191124}, {'time': '2022-01-11T20:30:25.234141Z', 'snoring': 0.08309659361839294}, {'time': '2022-01-11T20:30:25.756149Z', 'snoring': 0.1605300009250641}, {'time': '2022-01-11T20:30:26.281846Z', 'snoring': 0.23091737926006317}, {'time': '2022-01-11T20:30:26.822832Z', 'snoring': 0.08141739666461945}, {'time': '2022-01-11T20:30:27.362762Z', 'snoring': 0.07988027483224869}, {'time': '2022-01-11T20:30:27.909179Z', 'snoring': 0.07447075843811035}, {'time': '2022-01-11T20:30:28.455646Z', 'snoring': 0.06352140009403229}, {'time': '2022-01-11T20:30:29.001968Z', 'snoring': 0.061624184250831604}, {'time': '2022-01-11T20:30:29.546762Z', 'snoring': 0.06218932569026947}, {'time': '2022-01-11T20:30:30.088140Z', 'snoring': 0.0638827383518219}, {'time': '2022-01-11T20:30:30.635765Z', 'snoring': 0.0682244673371315}, {'time': '2022-01-11T20:30:31.175573Z', 'snoring': 0.06350404769182205}, {'time': '2022-01-11T20:30:31.718642Z', 'snoring': 0.058652594685554504}, {'time': '2022-01-11T20:30:32.262653Z', 'snoring': 0.07236102968454361}, {'time': '2022-01-11T20:30:32.802517Z', 'snoring': 0.06629759818315506}, {'time': '2022-01-11T20:30:33.347896Z', 'snoring': 0.07786954939365387}, {'time': '2022-01-11T20:30:33.891594Z', 'snoring': 0.084531269967556}, {'time': '2022-01-11T20:30:34.438292Z', 'snoring': 0.07352259010076523}, {'time': '2022-01-11T20:30:34.982997Z', 'snoring': 0.11067352443933487}, {'time': '2022-01-11T20:30:35.521658Z', 'snoring': 0.10658439993858337}, {'time': '2022-01-11T20:30:36.046658Z', 'snoring': 0.11899887025356293}, {'time': '2022-01-11T20:30:36.592748Z', 'snoring': 0.172316312789917}, {'time': '2022-01-11T20:30:37.137449Z', 'snoring': 0.11806131899356842}, {'time': '2022-01-11T20:30:37.680678Z', 'snoring': 0.07405010610818863}, {'time': '2022-01-11T20:30:38.217461Z', 'snoring': 0.07592785358428955}, {'time': '2022-01-11T20:30:38.762727Z', 'snoring': 0.09846340119838715}, {'time': '2022-01-11T20:30:39.307786Z', 'snoring': 0.06647591292858124}, {'time': '2022-01-11T20:30:39.850326Z', 'snoring': 0.06132712960243225}, {'time': '2022-01-11T20:30:40.390012Z', 'snoring': 0.06544168293476105}, {'time': '2022-01-11T20:30:40.929562Z', 'snoring': 0.06727542728185654}, {'time': '2022-01-11T20:30:41.475593Z', 'snoring': 0.0633000060915947}, {'time': '2022-01-11T20:30:42.018916Z', 'snoring': 0.07546503096818924}, {'time': '2022-01-11T20:30:42.564188Z', 'snoring': 0.08893892168998718}, {'time': '2022-01-11T20:30:43.107709Z', 'snoring': 0.10525482892990112}, {'time': '2022-01-11T20:30:43.649232Z', 'snoring': 0.05839550867676735}, {'time': '2022-01-11T20:30:44.188641Z', 'snoring': 0.27687332034111023}, {'time': '2022-01-11T20:30:44.731091Z', 'snoring': 0.12845291197299957}, {'time': '2022-01-11T20:30:45.266645Z', 'snoring': 0.12297319620847702}, {'time': '2022-01-11T20:30:45.78 ...

# %%
my_query =client.query("SELECT snoring FROM my_snoring WHERE time > now() -12h") # not enough memory for a full night 
print(my_query)

# %%
type(my_query)
# Out:
# influxdb.resultset.ResultSet

# %% [markdown]
# ## 1.5 Retention policies

# %%
#create a retention policty
client.create_retention_policy('my_retention_policy', '4w', replication=1,  database='SNORING', default=False)

# %%
#get a list of retention policies
client.get_list_retention_policies(database='SNORING')
# Out:
# [{'name': 'autogen',
#   'duration': '0s',
#   'shardGroupDuration': '168h0m0s',
#   'replicaN': 1,
#   'default': True},
#  {'name': 'my_retention_policy',
#   'duration': '672h0m0s',
#   'shardGroupDuration': '24h0m0s',
#   'replicaN': 1,
#   'default': False}]

# %%
# drop retention policy
client.drop_retention_policy('my_retention_policy', database='SNORING')

# %%
#Check by getting the list again
client.get_list_retention_policies(database='SNORING')
# Out:
# [{'name': 'autogen',
#   'duration': '0s',
#   'shardGroupDuration': '168h0m0s',
#   'replicaN': 1,
#   'default': True},
#  {'name': 'my_retention_policy',
#   'duration': '672h0m0s',
#   'shardGroupDuration': '24h0m0s',
#   'replicaN': 1,
#   'default': False}]

# %% [markdown]
# ## 2. Some basic scripts with DataFrameClient.
# https://influxdb-python.readthedocs.io/en/latest/api-documentation.html#dataframeclient

# %%
import notebooks_config
red_rpi_ip =notebooks_config.red_rpi_ip
print(red_rpi_ip)
# Out:
# 192.168.178.50

# %%
# instantiate a client and assign the RPI and database to it
import pandas as pd
from influxdb import DataFrameClient
mydf_client = DataFrameClient(host= red_rpi_ip, port=8086, database='SNORING')# this is my raspberry ip on a local network
pang = mydf_client.ping()
print(pang)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000016CAF49CE80>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='192.168.178.50', port=8086): Max retries exceeded with url: /ping (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016CAF49CE80>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_60280/4135445465.py in <module>
#       3 from influxdb import DataFrameClient
#       4 mydf_client = DataFrameClient(host= red_rpi_ip, port=8086, database='SNORING')# this is my raspberry ip on a local network
# ----> 5 pang = mydf_client.ping()
#       6 print(pang)
#
# ~\anaconda3\lib\site-packages\influxdb\client.py in ping(self)
#     613         :returns: The version of the InfluxDB the client is connected to
#     614         """
# --> 615         response = self.request(
#     616             url="ping",
#     617             method='GET',
#
# ~\anaconda3\lib\site-packages\influxdb\client.py in request(self, url, method, params, data, stream, expected_response_code, headers)
#     330             try:
#     331                 auth = (self._username, self._password)
# --> 332                 response = self._session.request(
#     333                     method=method,
#     334                     url=url,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     517                 raise SSLError(e, request=request)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#     521         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='192.168.178.50', port=8086): Max retries exceeded with url: /ping (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016CAF49CE80>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
my_df = mydf_client.query('SELECT * FROM my_snoring WHERE time > now() -36h')
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                         sheets   silence   snoring  \
#              2022-01-10 20:35:08.377425+00:00  1.651487e-03  0.934139  0.064199
#              2022-01-10 20:35:08.926313+00:00  1.482377e-03  0.936084  0.062425
#              2022-01-10 20:35:09.481355+00:00  1.522833e-03  0.932783  0.065684
#              2022-01-10 20:35:10.005872+00:00  1.588519e-03  0.935053  0.063349
#              2022-01-10 20:35:10.549029+00:00  1.626174e-03  0.933614  0.064749
#              ...                                        ...       ...       ...
#              2022-01-12 01:00:25.762287+00:00  2.746958e-08  0.074458  0.925533
#              2022-01-12 01:00:26.294059+00:00  6.762272e-06  0.844603  0.155386
#              2022-01-12 01:00:26.844680+00:00  1.053335e-07  0.126094  0.873903
#              2022-01-12 01:00:27.393015+00:00  9.624481e-08  0.126924  0.873065
#              2022-01-12 01:00:27.938871+00:00  2.884231e-05  0.924508  0.075460
#
#                                                softtalking
#              2022-01-10 20:35:08.377425+00:00     0.000011
#              2022-01-10 20:35:08.926313+00:00     0.000009
#              2022-01-10 20:35:09.481355+00:00     0.000010
#              2022-01-10 20:35:10.005872+00:00     0.000010
#              2022-01-10 20:35:10.549029+00:00     0.000011
#              ...                                       ...
#              2022-01-12 01:00:25.762287+00:00     0.000008
#              2022-01-12 01:00:26.294059+00:00     0.000004
#              2022-01-12 01:00:26.844680+00:00     0.000003
#              2022-01-12 01:00:27.393015+00:00     0.000011
#              2022-01-12 01:00:27.938871+00:00     0.000003
#
#              [102473 rows x 4 columns]})

# %%
my_df2 = mydf_client.query("SELECT * FROM my_snoring WHERE time >= '2021-12-23 22:58:38' AND time <='2021-12-24 07:42:38'")
my_df2
# Out:
# {}

# %%
my_df['my_snoring']
# Out:
#                                         sheets   silence   snoring  \
# 2022-01-10 20:35:08.377425+00:00  1.651487e-03  0.934139  0.064199
# 2022-01-10 20:35:08.926313+00:00  1.482377e-03  0.936084  0.062425
# 2022-01-10 20:35:09.481355+00:00  1.522833e-03  0.932783  0.065684
# 2022-01-10 20:35:10.005872+00:00  1.588519e-03  0.935053  0.063349
# 2022-01-10 20:35:10.549029+00:00  1.626174e-03  0.933614  0.064749
# ...                                        ...       ...       ...
# 2022-01-12 01:00:25.762287+00:00  2.746958e-08  0.074458  0.925533
# 2022-01-12 01:00:26.294059+00:00  6.762272e-06  0.844603  0.155386
# 2022-01-12 01:00:26.844680+00:00  1.053335e-07  0.126094  0.873903
# 2022-01-12 01:00:27.393015+00:00  9.624481e-08  0.126924  0.873065
# 2022-01-12 01:00:27.938871+00:00  2.884231e-05  0.924508  0.075460
#
#                                   softtalking
# 2022-01-10 20:35:08.377425+00:00     0.000011
# 2022-01-10 20:35:08.926313+00:00     0.000009
# 2022-01-10 20:35:09.481355+00:00     0.000010
# 2022-01-10 20:35:10.005872+00:00     0.000010
# 2022-01-10 20:35:10.549029+00:00     0.000011
# ...                                       ...
# 2022-01-12 01:00:25.762287+00:00     0.000008
# 2022-01-12 01:00:26.294059+00:00     0.000004
# 2022-01-12 01:00:26.844680+00:00     0.000003
# 2022-01-12 01:00:27.393015+00:00     0.000011
# 2022-01-12 01:00:27.938871+00:00     0.000003
#
# [102473 rows x 4 columns]

# %%
snoring_df = my_df['my_snoring']
snoring_df
# Out:
#                                         sheets   silence   snoring  \
# 2022-01-10 20:35:08.377425+00:00  1.651487e-03  0.934139  0.064199
# 2022-01-10 20:35:08.926313+00:00  1.482377e-03  0.936084  0.062425
# 2022-01-10 20:35:09.481355+00:00  1.522833e-03  0.932783  0.065684
# 2022-01-10 20:35:10.005872+00:00  1.588519e-03  0.935053  0.063349
# 2022-01-10 20:35:10.549029+00:00  1.626174e-03  0.933614  0.064749
# ...                                        ...       ...       ...
# 2022-01-12 01:00:25.762287+00:00  2.746958e-08  0.074458  0.925533
# 2022-01-12 01:00:26.294059+00:00  6.762272e-06  0.844603  0.155386
# 2022-01-12 01:00:26.844680+00:00  1.053335e-07  0.126094  0.873903
# 2022-01-12 01:00:27.393015+00:00  9.624481e-08  0.126924  0.873065
# 2022-01-12 01:00:27.938871+00:00  2.884231e-05  0.924508  0.075460
#
#                                   softtalking
# 2022-01-10 20:35:08.377425+00:00     0.000011
# 2022-01-10 20:35:08.926313+00:00     0.000009
# 2022-01-10 20:35:09.481355+00:00     0.000010
# 2022-01-10 20:35:10.005872+00:00     0.000010
# 2022-01-10 20:35:10.549029+00:00     0.000011
# ...                                       ...
# 2022-01-12 01:00:25.762287+00:00     0.000008
# 2022-01-12 01:00:26.294059+00:00     0.000004
# 2022-01-12 01:00:26.844680+00:00     0.000003
# 2022-01-12 01:00:27.393015+00:00     0.000011
# 2022-01-12 01:00:27.938871+00:00     0.000003
#
# [102473 rows x 4 columns]

# %%
snoring_df.describe()
# Out:
#              sheets       silence       snoring   softtalking
# count  8.502700e+04  8.502700e+04  85027.000000  8.502700e+04
# mean   1.944689e-03  8.800199e-01      0.118016  1.920559e-05
# std    4.878714e-03  1.657497e-01      0.165570  1.295645e-04
# min    3.613211e-23  4.187816e-07      0.025557  1.872570e-10
# 25%    1.207991e-03  9.285924e-01      0.064717  8.333343e-06
# 50%    1.813529e-03  9.321837e-01      0.065950  1.185190e-05
# 75%    1.948026e-03  9.335327e-01      0.070025  1.274839e-05
# max    3.389907e-01  9.666468e-01      1.000000  1.228169e-02

# %% [markdown]
# ### 2.1 Create a query string and call the database

# %%
base_string = "SELECT * FROM my_snoring WHERE time >="
middle_string = " AND time <="
base_string+middle_string
# Out:
# 'SELECT * FROM my_snoring WHERE time >= AND time <='

# %%
start_time = "'2021-12-11 23:02:31'" #does not work with time zone! Make sure you'll use '' for the time zone
end_time = "'2021-12-12 09:00:31'"

# %%
query_string = base_string + start_time + middle_string + end_time
query_string
# Out:
# "SELECT * FROM my_snoring WHERE time >='2021-12-11 23:02:31' AND time <='2021-12-12 09:00:31'"

# %%
my_df = mydf_client.query(query_string)
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                     sheets   silence   snoring  softtalking
#              2021-12-11 23:02:31.386149+00:00  0.001840  0.932856  0.065292     0.000012
#              2021-12-11 23:02:31.929059+00:00  0.001868  0.933797  0.064324     0.000012
#              2021-12-11 23:02:32.467791+00:00  0.001810  0.933317  0.064862     0.000011
#              2021-12-11 23:02:33.014969+00:00  0.001759  0.933197  0.065032     0.000011
#              2021-12-11 23:02:33.559208+00:00  0.001639  0.932970  0.065380     0.000011
#              ...                                    ...       ...       ...          ...
#              2021-12-12 09:00:28.677956+00:00  0.000047  0.325029  0.674875     0.000049
#              2021-12-12 09:00:29.227086+00:00  0.001690  0.928522  0.069777     0.000011
#              2021-12-12 09:00:29.777596+00:00  0.001856  0.931699  0.066433     0.000012
#              2021-12-12 09:00:30.325116+00:00  0.001994  0.932072  0.065921     0.000013
#              2021-12-12 09:00:30.874813+00:00  0.001959  0.932623  0.065405     0.000012
#
#              [66154 rows x 4 columns]})

# %%
my_df = mydf_client.query("SELECT * FROM my_snoring WHERE time >='2021-12-11 23:02:31' AND time <= '2021-12-12 09:00:31'")
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                     sheets   silence   snoring  softtalking
#              2021-12-11 23:02:31.386149+00:00  0.001840  0.932856  0.065292     0.000012
#              2021-12-11 23:02:31.929059+00:00  0.001868  0.933797  0.064324     0.000012
#              2021-12-11 23:02:32.467791+00:00  0.001810  0.933317  0.064862     0.000011
#              2021-12-11 23:02:33.014969+00:00  0.001759  0.933197  0.065032     0.000011
#              2021-12-11 23:02:33.559208+00:00  0.001639  0.932970  0.065380     0.000011
#              ...                                    ...       ...       ...          ...
#              2021-12-12 09:00:28.677956+00:00  0.000047  0.325029  0.674875     0.000049
#              2021-12-12 09:00:29.227086+00:00  0.001690  0.928522  0.069777     0.000011
#              2021-12-12 09:00:29.777596+00:00  0.001856  0.931699  0.066433     0.000012
#              2021-12-12 09:00:30.325116+00:00  0.001994  0.932072  0.065921     0.000013
#              2021-12-12 09:00:30.874813+00:00  0.001959  0.932623  0.065405     0.000012
#
#              [66154 rows x 4 columns]})
