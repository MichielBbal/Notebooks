# %% [markdown]
# ## Python worlds forest map
#
# source: https://towardsdatascience.com/creating-beautiful-forest-maps-with-python-59a60fba3e27
#
# ### Contents
# 0. Get the raw data and install the packages
# 1. Make the map

# %% [markdown]
# ## 0. Install packages and get the raw data
#
# It's best to create a new environment especially for rasterio. Do so with Ananconda and conda install
# Next install the packages

# %%
#!pip install matplotlib
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.5-cp39-cp39-macosx_10_15_x86_64.whl (31.4 MB)
#      |████████████████████████████████| 31.4 MB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: attrs in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (21.4.0)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (61.2.0)
# Requirement already satisfied: click-plugins in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click>=4.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: numpy>=1.18 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (1.21.5)
# Requirement already satisfied: certifi in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from rasterio) (2021.10.8)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from snuggs>=1.4.1->rasterio) (3.0.4)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.5 snuggs-1.4.7

# %%
#check all installs
import rasterio
import matplotlib.pyplot as plt
print('done')
# Out:
# done

# %%
pwd
# Out:
# '/Users/michielbontenbal/Documents/GitHub/Notebooks'

# %%
# !mkdir trees

# %%
cd trees
# Out:
# C:\Users\31653\Documents\GitHub\Notebooks\trees

# %%
#DO USE!
# !git clone https://github.com/globalmaps/gm_ve_v1
# Out:
# Cloning into 'gm_ve_v1'...

# %%
pwd
# Out:
# '/Users/michielbontenbal/Documents/GitHub/Notebooks'

# %%
cd trees/gm_ve_v1
# Out:
# [Errno 2] No such file or directory: 'trees/gm_ve_v1'
# /Users/michielbontenbal/Documents/GitHub/Notebooks

# %%
#extract a zipfile
import zipfile
with zipfile.ZipFile('gm_ve_v1.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2818-58FB
#
#  Directory of C:\Users\31653\Documents\GitHub\Notebooks\trees\gm_ve_v1
#
# 06/03/2022  10:50    <DIR>          .
# 06/03/2022  10:30    <DIR>          ..
# 06/03/2022  10:50        91.258.317 gm_ve_v1.tif
# 06/03/2022  10:30        80.454.632 gm_ve_v1.zip
# 06/03/2022  10:30               691 README.md
#                3 File(s)    171.713.640 bytes
#                2 Dir(s)  217.192.316.928 bytes free

# %% [markdown]
# ## 1. Make the map

# %%
import rasterio
import numpy as np
from rasterio.crs import CRS

forests_file = rasterio.open('gm_ve_v1.tif')
forests = forests_file.read()

print(np.amin(forests))
print(np.amax(forests))
print(len(np.unique(forests)))
# Out:
# 0
# 254
# 102

# %%
type(forests)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

ax = plt.axes()
fig.set_size_inches(18, 9)

imgs = plt.imshow(forests[0],
                  cmap='Greens',
                  interpolation='nearest')

ax.axis('off')
plt.show()

# %%
#adjust the colors, make the sea white
from matplotlib.colors import ListedColormap
from matplotlib import cm

forests[0][forests[0] == 254] = 0.0

ourcmap = cm.get_cmap('Greens', 101)
newcolors = ourcmap(np.linspace(0, 1, 101))
background_colour = np.array([0.9882352941176471, 0.9647058823529412, 0.9607843137254902, 1.0])
newcolors[:1, :] = background_colour
newcmp_forests = ListedColormap(newcolors)

# %%
#plot again with some improvements
import matplotlib.pyplot as plt

fig = plt.figure(facecolor='#FCF6F5FF')
ax = plt.axes()
fig.set_size_inches(18, 9)
ax.patch.set_facecolor('#FCF6F5FF')

imgs = plt.imshow(forests[0],
                  cmap=newcmp_forests,
                  interpolation='nearest')

ax.set_xlim(2000, 43500)
ax.set_ylim(19500, 800)
ax.axis('off')
plt.show()

# %%
# !pip install rioxarray
# Out:
# Collecting rioxarray
#   Downloading rioxarray-0.10.2.tar.gz (47 kB)
#      -------------------------------------- 47.8/47.8 KB 482.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyproj>=2.2
#   Downloading pyproj-3.3.0-cp38-cp38-win_amd64.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 8.8 MB/s eta 0:00:00
# Collecting xarray>=0.17
#   Downloading xarray-2022.3.0-py3-none-any.whl (870 kB)
#      ------------------------------------- 870.9/870.9 KB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rioxarray) (21.3)
# Requirement already satisfied: rasterio>=1.1.1 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rioxarray) (1.2.10)
# Requirement already satisfied: certifi in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from pyproj>=2.2->rioxarray) (2021.10.8)
# Requirement already satisfied: affine in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (2.3.0)
# Requirement already satisfied: attrs in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (21.4.0)
# Requirement already satisfied: click>=4.0 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (0.7.2)
# Requirement already satisfied: numpy in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (1.22.3)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from rasterio>=1.1.1->rioxarray) (60.9.3)
# Collecting pandas>=1.1
#   Downloading pandas-1.4.1-cp38-cp38-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from packaging->rioxarray) (3.0.7)
# Requirement already satisfied: colorama in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from click>=4.0->rasterio>=1.1.1->rioxarray) (0.4.4)
# Collecting pytz>=2020.1
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from pandas>=1.1->xarray>=0.17->rioxarray) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\31653\anaconda3\envs\rasterio\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->xarray>=0.17->rioxarray) (1.16.0)
# Building wheels for collected packages: rioxarray
#   Building wheel for rioxarray (pyproject.toml): started
#   Building wheel for rioxarray (pyproject.toml): finished with status 'done'
#   Created wheel for rioxarray: filename=rioxarray-0.10.2-py3-none-any.whl size=55519 sha256=66ea6a301f02217d73526523e5a35f4589d37d36b13e09aff4875aa723e335e5
#   Stored in directory: c:\users\31653\appdata\local\pip\cache\wheels\33\d0\5e\8bd5964aa9f262a5e744f6e203259dde2c16d8e9f1ff4a1c7f
# Successfully built rioxarray
# Installing collected packages: pytz, pyproj, pandas, xarray, rioxarray
# Successfully installed pandas-1.4.1 pyproj-3.3.0 pytz-2021.3 rioxarray-0.10.2 xarray-2022.3.0

# %%
import rioxarray as rxr #extends xarray with the rio accessor and allows rasters from tiff and geotiff files to be clipped, merged and reprojected
from rasterio.crs import CRS

forests_file = rxr.open_rasterio('gm_ve_v1.tif', masked=True).squeeze()
crs_rob = CRS.from_string('+proj=robin')
forests = forests_file.rio.reproject(crs_rob)
forests = forests.to_numpy()

# %%
forests[forests > 100] = 0.0

fig = plt.figure(facecolor='#FCF6F5FF')

ax = plt.axes()
fig.set_size_inches(18, 9)
ax.patch.set_facecolor('#FCF6F5FF')

imgs = plt.imshow(forests,
                  cmap=newcmp_forests,
                  interpolation='nearest')
ax.axis('off')
ax.set_xlim(2000, 43500)
ax.set_ylim(19500, 800)
# Out:
# (19500.0, 800.0)
