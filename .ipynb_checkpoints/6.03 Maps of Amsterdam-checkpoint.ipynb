# %% [markdown]
# # Maps of Amsterdam
#
# OSMnx is a very nice interpretation of OpenStreetMaps but scripts might be very time consuming.
#
# ## Contents
# 0. Install with Conda
# 1. My first ox map

# %% [markdown]
# ## 0. Install Conda environment

# %% [markdown]
# Please visit https://osmnx.readthedocs.io/en/stable/ how to install the packages with Conda
#
# This will create a new conda environment named 'ox' that you'll need to use.
# Close the notebook, open the environment in Anaconda navigator and reopen Jupyter.

# %% [markdown]
# ## 1. My first ox map

# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Beemster, Netherlands'))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.plot_graph(ox.graph_from_place('Amsterdam, Netherlands'))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)
