# %% [markdown]
# https://towardsdatascience.com/create-simple-optical-character-recognition-ocr-with-python-6d90adb82bb8
# https://github.com/UB-Mannheim/tesseract/wiki

# %%
#install the pytesseract module
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\31653\anaconda3\envs\opencv\lib\site-packages (0.3.6)
# Requirement already satisfied: Pillow in c:\users\31653\anaconda3\envs\opencv\lib\site-packages (from pytesseract) (8.0.1)

# %%
#Import the modules
from PIL import Image
import numpy as np
import pytesseract

# %%
#define the path to tesseract:
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
#The default language is English. With this command you can change the language:
print(pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra'))

# %%
filename = 'image_01.png'
img1 = np.array(Image.open(filename))
text = pytesseract.image_to_string(img1)

# %%
print(text)
# Out:
# Tesseract sample

# %% [markdown]
# ## Toegepast op de Sententie van Claes

# %%
from IPython.display import Image
Image(filename= 'Sententie p2.JPG')

# %%
filename = 'Sententie p2.jpg'
img1 = np.array(Image.open(filename))
sententie = pytesseract.image_to_string(img1)

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
print(pytesseract.image_to_string(Image.open('Sententie p2.jpg'), lang='frk'))
# Out:
#
#
# 129. Shagber Datter vooaghenomen wasDeregiermgtz
# "M
# alhierte Kandexeverander en/3eggenbehp CHs Fa
# hetopn, Äbampenvee zzt 'hetzdo wel beiteecken ende
# uetzulekenm 1zoude te weghe ghebzacht..werden
# Foch5auväſte aber ERNEEEEED EREN
# Sheſch19den/ zondevdathp2emgheundd: de
# 309de werden armhemgh, EIGE endg
# varhpghehanglen'ſſchere derhne hp den:vamnE
# 4. Zent de ded wmp icemetkonienbe/teltz
# heeft? watvandezakewasgf
#
# ofde nar ert kä Erlen wern
# vate wude M eden vboznoeEs
#
# Caus 3 warmen twoogthad:
# AI aub 1208
#
# gangen aerbyDamdt Coozn-wiader gheweſen (Ses
# Siles SHARE, verandermahoimndert 4 nbndeoch
# zeggh enden voomoemdenCEeEnmnnderdat de zake
# UDP 06 Romana gh 08 gan me tons
# Ge Eningen g - 'Dattermqeh norden: ig
# I" ü as/

# %%
print(sententie)
# Out:
#
#
# fn. Swagher wooneno
# 8 ghedaen / Datter vooaghenomen wasderegrerin,
# albier te Randeseveranoet' en seggenbeb ors yanks
# dag hp, dAchpmecnde dat eo soo wel belterckenenve
# unsesebloraseabhetponets Wweghe ghebacht: werden
# Datyrcuuntte gheen-2dloedt-ftogtinghe: bart Door oun
# shelshinden/ i pind eratloraen oy paler pear
# joude werden
#
# Saudia chen emacs at ceri eap ao
# pe orabutaannscemeamae
# ofde chaineren teiiatiehonahpencyeubal thee ee
#
# parnaphs shy postmaretinans ie
#
#  Go28 Fanks.telchen repley dass dp geantwongehadz
# be orreabee
#
# ta a cudieetachabdubehensaber none
# panei jaexbp Davide frat se gyrmelen Ses
#
# wba ent erchel hennilie eubeopemaghe is yebactt
# naNcnde Re voorseNde becnnBermughsindert Geringhes
# ener \@oor br 3ake
#
# staat mt Deozoemtpen: mainder gas
#
# une? | celeeecremniteceusrsoktmanaiearnins
# wc allinen wel mecubs: /. endewattermery garden mote
# tne ai was/
