# %% [markdown]
# ## 4.04 InfluxDB
#
# #### Links
# - Readthedocs : https://influxdb-python.readthedocs.io/en/latest/api-documentation.html
# - Pypi:https://pypi.org/project/influxdb/
# - GitHub: https://github.com/influxdata/influxdb-python
#
# This Notebook is for InfluxDB 1.8.
# November 2021.

# %% [markdown]
# ## Contents
# 0. Install packages
# 1. Some basic scripts with InfluxDBClient
# 2. Some basic scripts with DataframeClient

# %% [markdown]
# ## 0. Install packages

# %%
# %pip install influxdb
# Out:
# Collecting influxdb
#   Downloading influxdb-5.3.1-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: python-dateutil>=2.6.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2.8.1)
# Requirement already satisfied: msgpack in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (1.0.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (1.15.0)
# Requirement already satisfied: requests>=2.17.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2.25.1)
# Requirement already satisfied: pytz in c:\users\31653\anaconda3\lib\site-packages (from influxdb) (2020.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.17.0->influxdb) (1.26.4)
# Installing collected packages: influxdb
# Successfully installed influxdb-5.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install influxdb-client
# Out:
# Collecting influxdb-client
#   Downloading influxdb_client-1.23.0-py3-none-any.whl (522 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (1.26.7)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: pytz>=2019.1 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2021.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (58.2.0)
# Requirement already satisfied: six>=1.10 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (1.16.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\31653\anaconda3\lib\site-packages (from influxdb-client) (2021.10.8)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.23.0 rx-3.2.0

# %% [markdown]
# ## 1. Some basic scripts with InfluxDBclient

# %%
import notebooks_config
red_rpi_ip =notebooks_config.red_rpi_ip
print(red_rpi_ip)
# Out:
# 192.168.178.50

# %%
#check connection with the Influxdb on the raspberry
from influxdb import InfluxDBClient
client = InfluxDBClient(host= red_rpi_ip, port=8086) # rry ip on a local network
pong = client.ping()
print(pong)
# Out:
# 1.8.10

# %% [markdown]
# ### 1.1 Getting, creating and deleting users

# %%
# get a list of users
from influxdb import InfluxDBClient
client = InfluxDBClient(host='192.168.178.50', port=8086)
users = client.get_list_users()
print(users)
# Out:
# []

# %%
# create a new user called Henk
client.create_user('Henk', 'henkspw', admin=False)
users = client.get_list_users()
print(users)
# Out:
# [{'user': 'Henk', 'admin': False}]

# %%
# drop Henk again
client.drop_user('Henk')
users = client.get_list_users()
print(users)
# Out:
# []

# %% [markdown]
# ### 1.2 Getting, creating and deleting databases

# %%
#also working
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING2'}, {'name': 'SNORING'}, {'name': 'TEST'}, {'name': 'TEST2'}]

# %%
#create a new database and check it 
client.create_database('example2')
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING2'}, {'name': 'SNORING'}, {'name': 'example'}, {'name': 'example2'}]

# %%
# delete a database and check it
client.drop_database('example2')
dbs = client.get_list_database()
print(dbs)
# Out:
# [{'name': '_internal'}, {'name': 'SNORING2'}, {'name': 'SNORING'}]

# %%
# switch to database
client.switch_database('SNORING')

# %% [markdown]
# ### 1.3 Get measurements and series

# %%
#when switched to a database you can get a list of measurements
msmts = client.get_list_measurements()
print(msmts)
# Out:
# [{'name': 'my_snoring'}]

# %%
series = client.get_list_series(database=None, measurement=None, tags=None)
series
# Out:
# ['my_snoring']

# %% [markdown]
# ### 1.4 Queries

# %%
my_query =client.query("SELECT snoring FROM my_snoring WHERE time > now() -24h") # not enough memory for a full night 
print(my_query)
# Out:
# ResultSet({'('my_snoring', None)': [{'time': '2021-12-12T08:02:06.018665Z', 'snoring': 0.06400009989738464}, {'time': '2021-12-12T08:02:06.569293Z', 'snoring': 0.06371307373046875}, {'time': '2021-12-12T08:02:07.114503Z', 'snoring': 0.06634443998336792}, {'time': '2021-12-12T08:02:07.661626Z', 'snoring': 0.06654532998800278}, {'time': '2021-12-12T08:02:08.208551Z', 'snoring': 0.06525807082653046}, {'time': '2021-12-12T08:02:08.759073Z', 'snoring': 0.06613625586032867}, {'time': '2021-12-12T08:02:09.305266Z', 'snoring': 0.06626633554697037}, {'time': '2021-12-12T08:02:09.857131Z', 'snoring': 0.06559804826974869}, {'time': '2021-12-12T08:02:10.414048Z', 'snoring': 0.0658656507730484}, {'time': '2021-12-12T08:02:10.964050Z', 'snoring': 0.0666724294424057}, {'time': '2021-12-12T08:02:11.513498Z', 'snoring': 0.06575428694486618}, {'time': '2021-12-12T08:02:12.060482Z', 'snoring': 0.06551174074411392}, {'time': '2021-12-12T08:02:12.605443Z', 'snoring': 0.0656290352344513}, {'time': '2021-12-12T08:02:13.155884Z', 'snoring': 0.06645146757364273}, {'time': '2021-12-12T08:02:13.701567Z', 'snoring': 0.06632832437753677}, {'time': '2021-12-12T08:02:14.229192Z', 'snoring': 0.0653199851512909}, {'time': '2021-12-12T08:02:14.763390Z', 'snoring': 0.06555476039648056}, {'time': '2021-12-12T08:02:15.306870Z', 'snoring': 0.06503093242645264}, {'time': '2021-12-12T08:02:15.847409Z', 'snoring': 0.06578703969717026}, {'time': '2021-12-12T08:02:16.384928Z', 'snoring': 0.06626201421022415}, {'time': '2021-12-12T08:02:16.928975Z', 'snoring': 0.06611961126327515}, {'time': '2021-12-12T08:02:17.469639Z', 'snoring': 0.06529232859611511}, {'time': '2021-12-12T08:02:18.006999Z', 'snoring': 0.06620627641677856}, {'time': '2021-12-12T08:02:18.549001Z', 'snoring': 0.06525343656539917}, {'time': '2021-12-12T08:02:19.089151Z', 'snoring': 0.06636376678943634}, {'time': '2021-12-12T08:02:19.630072Z', 'snoring': 0.06636825948953629}, {'time': '2021-12-12T08:02:20.171017Z', 'snoring': 0.06561403721570969}, {'time': '2021-12-12T08:02:20.712279Z', 'snoring': 0.06562107801437378}, {'time': '2021-12-12T08:02:21.254411Z', 'snoring': 0.06603042036294937}, {'time': '2021-12-12T08:02:21.794873Z', 'snoring': 0.0663219690322876}, {'time': '2021-12-12T08:02:22.331950Z', 'snoring': 0.06646015495061874}, {'time': '2021-12-12T08:02:22.873715Z', 'snoring': 0.06403370946645737}, {'time': '2021-12-12T08:02:23.415520Z', 'snoring': 0.06477858871221542}, {'time': '2021-12-12T08:02:23.948495Z', 'snoring': 0.06347738206386566}, {'time': '2021-12-12T08:02:24.472730Z', 'snoring': 0.06730391085147858}, {'time': '2021-12-12T08:02:25.015168Z', 'snoring': 0.06526622176170349}, {'time': '2021-12-12T08:02:25.550126Z', 'snoring': 0.06612804532051086}, {'time': '2021-12-12T08:02:26.092224Z', 'snoring': 0.06547611951828003}, {'time': '2021-12-12T08:02:26.632407Z', 'snoring': 0.06614255160093307}, {'time': '2021-12-12T08:02:27.177826Z', 'snoring': 0.06593087315559387}, {'time': '2021-12-12T08:02:27.719483Z', 'snoring': 0.06613592803478241}, {'time': '2021-12-12T08:02:28.261884Z', 'snoring': 0.06608404219150543}, {'time': '2021-12-12T08:02:28.800027Z', 'snoring': 0.06646668910980225}, {'time': '2021-12-12T08:02:29.321631Z', 'snoring': 0.06560293585062027}, {'time': '2021-12-12T08:02:29.846008Z', 'snoring': 0.06466525048017502}, {'time': '2021-12-12T08:02:30.388512Z', 'snoring': 0.06462162733078003}, {'time': '2021-12-12T08:02:30.934968Z', 'snoring': 0.06551475077867508}, {'time': '2021-12-12T08:02:31.480181Z', 'snoring': 0.06575217843055725}, {'time': '2021-12-12T08:02:32.019006Z', 'snoring': 0.064488485455513}, {'time': '2021-12-12T08:02:32.559940Z', 'snoring': 0.06548291444778442}, {'time': '2021-12-12T08:02:33.106934Z', 'snoring': 0.06336644291877747}, {'time': '2021-12-12T08:02:33.646038Z', 'snoring': 0.06464771181344986}, {'time': '2021-12-12T08:02:34.166425Z', 'snoring': 0.06264236569404602}, {'time': '2021-12-12T08:02:34.690573Z', 'snoring': 0.062407296150922775}, {'time': '2021-12-12T08:02:3 ...

# %%
type(my_query)
# Out:
# influxdb.resultset.ResultSet

# %% [markdown]
# ## 1.5 Retention policies

# %%
#create a retention policty
client.create_retention_policy('my_retention_policy', '4w', replication=1,  database='SNORING', default=False)

# %%
#get a list of retention policies
client.get_list_retention_policies(database='SNORING')
# Out:
# [{'name': 'autogen',
#   'duration': '0s',
#   'shardGroupDuration': '168h0m0s',
#   'replicaN': 1,
#   'default': True},
#  {'name': 'my_retention_policy',
#   'duration': '672h0m0s',
#   'shardGroupDuration': '24h0m0s',
#   'replicaN': 1,
#   'default': False}]

# %%
# drop retention policy
client.drop_retention_policy('my_retention_policy', database='SNORING')

# %%
#Check by getting the list again
client.get_list_retention_policies(database='SNORING')
# Out:
# [{'name': 'autogen',
#   'duration': '0s',
#   'shardGroupDuration': '168h0m0s',
#   'replicaN': 1,
#   'default': True}]

# %% [markdown]
# ## 2. Some basic scripts with DataFrameClient.
# https://influxdb-python.readthedocs.io/en/latest/api-documentation.html#dataframeclient

# %%
import notebooks_config
red_rpi_ip =notebooks_config.red_rpi_ip
print(red_rpi_ip)
# Out:
# 192.168.178.50

# %%
# instantiate a client and assign the RPI and database to it
import pandas as pd
from influxdb import DataFrameClient
mydf_client = DataFrameClient(host= red_rpi_ip, port=8086, database='SNORING')# this is my raspberry ip on a local network
pang = mydf_client.ping()
print(pang)
# Out:
# 1.8.10

# %%
my_df = mydf_client.query('SELECT * FROM my_snoring WHERE time > now() -36h')
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                         sheets   silence   snoring  \
#              2021-12-11 21:48:35.131469+00:00  9.515630e-11  0.120238  0.879759
#              2021-12-11 21:48:35.676604+00:00  6.111926e-09  0.518310  0.481681
#              2021-12-11 21:48:36.227088+00:00  6.492470e-07  0.523055  0.476935
#              2021-12-11 21:48:36.783244+00:00  2.262778e-05  0.785224  0.214749
#              2021-12-11 21:48:37.331709+00:00  7.292821e-05  0.865907  0.134018
#              ...                                        ...       ...       ...
#              2021-12-12 09:30:13.279410+00:00  1.940937e-03  0.931897  0.066150
#              2021-12-12 09:30:13.818906+00:00  1.883686e-03  0.933720  0.064384
#              2021-12-12 09:30:14.342584+00:00  1.818181e-03  0.932599  0.065570
#              2021-12-12 09:30:14.885844+00:00  1.767137e-03  0.933930  0.064292
#              2021-12-12 09:30:15.430490+00:00  1.820051e-03  0.932493  0.065675
#
#                                                softtalking
#              2021-12-11 21:48:35.131469+00:00     0.000003
#              2021-12-11 21:48:35.676604+00:00     0.000009
#              2021-12-11 21:48:36.227088+00:00     0.000009
#              2021-12-11 21:48:36.783244+00:00     0.000004
#              2021-12-11 21:48:37.331709+00:00     0.000002
#              ...                                       ...
#              2021-12-12 09:30:13.279410+00:00     0.000013
#              2021-12-12 09:30:13.818906+00:00     0.000012
#              2021-12-12 09:30:14.342584+00:00     0.000012
#              2021-12-12 09:30:14.885844+00:00     0.000011
#              2021-12-12 09:30:15.430490+00:00     0.000012
#
#              [77606 rows x 4 columns]})

# %%
snoring_df = my_df['my_snoring']
snoring_df
# Out:
#                                     sheets   silence   snoring  softtalking
# 2021-12-11 20:41:21.340676+00:00  0.000138  0.766212  0.233639     0.000011
# 2021-12-11 20:41:21.898765+00:00  0.000714  0.933641  0.065642     0.000003
# 2021-12-11 20:41:22.447193+00:00  0.000577  0.935076  0.064343     0.000003
# 2021-12-11 20:41:22.999820+00:00  0.000657  0.937097  0.062242     0.000003
# 2021-12-11 20:41:23.547119+00:00  0.000357  0.902826  0.096814     0.000003
# ...                                    ...       ...       ...          ...
# 2021-12-12 09:30:13.279410+00:00  0.001941  0.931897  0.066150     0.000013
# 2021-12-12 09:30:13.818906+00:00  0.001884  0.933720  0.064384     0.000012
# 2021-12-12 09:30:14.342584+00:00  0.001818  0.932599  0.065570     0.000012
# 2021-12-12 09:30:14.885844+00:00  0.001767  0.933930  0.064292     0.000011
# 2021-12-12 09:30:15.430490+00:00  0.001820  0.932493  0.065675     0.000012
#
# [85027 rows x 4 columns]

# %%
snoring_df.describe()
# Out:
#              sheets       silence       snoring   softtalking
# count  8.502700e+04  8.502700e+04  85027.000000  8.502700e+04
# mean   1.944689e-03  8.800199e-01      0.118016  1.920559e-05
# std    4.878714e-03  1.657497e-01      0.165570  1.295645e-04
# min    3.613211e-23  4.187816e-07      0.025557  1.872570e-10
# 25%    1.207991e-03  9.285924e-01      0.064717  8.333343e-06
# 50%    1.813529e-03  9.321837e-01      0.065950  1.185190e-05
# 75%    1.948026e-03  9.335327e-01      0.070025  1.274839e-05
# max    3.389907e-01  9.666468e-01      1.000000  1.228169e-02

# %% [markdown]
# ### 2.1 Create a query string and call the database

# %%
base_string = "SELECT * FROM my_snoring WHERE time >="
middle_string = " AND time <="
base_string+middle_string
# Out:
# 'SELECT * FROM my_snoring WHERE time >= AND time <='

# %%
start_time = "'2021-12-11 23:02:31'" #does not work with time zone! Make sure you'll use '' for the time zone
end_time = "'2021-12-12 09:00:31'"

# %%
query_string = base_string + start_time + middle_string + end_time
query_string
# Out:
# "SELECT * FROM my_snoring WHERE time >='2021-12-11 23:02:31' AND time <='2021-12-12 09:00:31'"

# %%
my_df = mydf_client.query(query_string)
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                     sheets   silence   snoring  softtalking
#              2021-12-11 23:02:31.386149+00:00  0.001840  0.932856  0.065292     0.000012
#              2021-12-11 23:02:31.929059+00:00  0.001868  0.933797  0.064324     0.000012
#              2021-12-11 23:02:32.467791+00:00  0.001810  0.933317  0.064862     0.000011
#              2021-12-11 23:02:33.014969+00:00  0.001759  0.933197  0.065032     0.000011
#              2021-12-11 23:02:33.559208+00:00  0.001639  0.932970  0.065380     0.000011
#              ...                                    ...       ...       ...          ...
#              2021-12-12 09:00:28.677956+00:00  0.000047  0.325029  0.674875     0.000049
#              2021-12-12 09:00:29.227086+00:00  0.001690  0.928522  0.069777     0.000011
#              2021-12-12 09:00:29.777596+00:00  0.001856  0.931699  0.066433     0.000012
#              2021-12-12 09:00:30.325116+00:00  0.001994  0.932072  0.065921     0.000013
#              2021-12-12 09:00:30.874813+00:00  0.001959  0.932623  0.065405     0.000012
#
#              [66154 rows x 4 columns]})

# %%
my_df = mydf_client.query("SELECT * FROM my_snoring WHERE time >='2021-12-11 23:02:31' AND time <= '2021-12-12 09:00:31'")
my_df
# Out:
# defaultdict(list,
#             {'my_snoring':                                     sheets   silence   snoring  softtalking
#              2021-12-11 23:02:31.386149+00:00  0.001840  0.932856  0.065292     0.000012
#              2021-12-11 23:02:31.929059+00:00  0.001868  0.933797  0.064324     0.000012
#              2021-12-11 23:02:32.467791+00:00  0.001810  0.933317  0.064862     0.000011
#              2021-12-11 23:02:33.014969+00:00  0.001759  0.933197  0.065032     0.000011
#              2021-12-11 23:02:33.559208+00:00  0.001639  0.932970  0.065380     0.000011
#              ...                                    ...       ...       ...          ...
#              2021-12-12 09:00:28.677956+00:00  0.000047  0.325029  0.674875     0.000049
#              2021-12-12 09:00:29.227086+00:00  0.001690  0.928522  0.069777     0.000011
#              2021-12-12 09:00:29.777596+00:00  0.001856  0.931699  0.066433     0.000012
#              2021-12-12 09:00:30.325116+00:00  0.001994  0.932072  0.065921     0.000013
#              2021-12-12 09:00:30.874813+00:00  0.001959  0.932623  0.065405     0.000012
#
#              [66154 rows x 4 columns]})
