# %% [markdown]
# # 4.11 Analyse van webservices met Zeep
#
# ### Documentation
# https://docs.python-zeep.org/en/master/index.html <br>
# https://github.com/mvantellingen/python-zeep
#
# ### Inhoud
#
# 1. Shareworx wsdl
# 2. Tobias wsdl
# 3. Woningnet wsdl
# 4. Corporatieportaal wsdl

# %% [markdown]
# ## 0. Install packages

# %%
#!pip install zeep==4.0.0

# %% [markdown]
# ## 1. TobiasAX wsdl

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks'

# %%
cd de_alliantie
# Out:
# C:\Users\31653\Documents\GitHub\Notebooks\de_alliantie

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie'

# %%
import glob
my_wsdls = glob.glob('*.wsdl')
my_wsdls
# Out:
# []

# %%
#Getting the methods of the webservice
#source: https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
import operator
from zeep import Client

TobiasAX_methods_list = []
wsdl = 'C:\\Users\\31653\\Desktop\\DeAlliantie\\TobiasAX.wsdl'
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            #print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
for i in range (len(TobiasAX_methods_list)):
    print(TobiasAX_methods_list[i])
# Out:
# service : ServiceCustomerPortalAX
# 574
# AddServiceRequestComment
# ApprovePurchWorkflow
# ArchiveDocument
# ChangePassword
# ChangePasswordByTemporaryPassword
# CheckEworxDMS
# CheckExistingPersons
# CreateActivityByEntity
# CreateAsbestosProject
# CreateAsbestosSource
# CreateAsbestosTask
# CreateCaseContactMomentLine
# CreateCoRegistrant
# CreateCoRegistrantIncome
# CreateContactMoment
# CreateContactMomentLine
# CreateContractRentcomponent
# CreateCorrespondence
# CreateDocuRefByEntityName
# CreateDocumentFile
# CreateDossier
# CreateDossierLine
# CreateEquipTransactionByEstateId
# CreateInspection
# CreateLocationPreference
# CreateMandate
# CreateNotes
# CreateObjectGroupOption
# CreateParticipation
# CreatePaymentScheme
# CreatePaymentSchemeSax
# CreatePerson
# CreatePersonAddress
# CreatePersonBankAccount
# CreatePersonCommunication
# CreatePersonFutureAddressTimeline
# CreatePersonIncome
# CreateResidenceAdaptation
# CreateSeekerRegistration
# ...

# %%
method_list= []
for operation in operations:
    #print(" method :", operation.name)
    method_list.append(operation.name)
    #TobiasAX_methods_list.append(operation.name)
    #print("  input :", operation.input.signature())
    #print(" output :", operation.output.signature())
print(method_list)
# Out:
# ['AddServiceRequestComment', 'ApprovePurchWorkflow', 'ArchiveDocument', 'ChangePassword', 'ChangePasswordByTemporaryPassword', 'CheckEworxDMS', 'CheckExistingPersons', 'CreateActivityByEntity', 'CreateAsbestosProject', 'CreateAsbestosSource', 'CreateAsbestosTask', 'CreateCaseContactMomentLine', 'CreateCoRegistrant', 'CreateCoRegistrantIncome', 'CreateContactMoment', 'CreateContactMomentLine', 'CreateContractRentcomponent', 'CreateCorrespondence', 'CreateDocuRefByEntityName', 'CreateDocumentFile', 'CreateDossier', 'CreateDossierLine', 'CreateEquipTransactionByEstateId', 'CreateInspection', 'CreateLocationPreference', 'CreateMandate', 'CreateNotes', 'CreateObjectGroupOption', 'CreateParticipation', 'CreatePaymentScheme', 'CreatePaymentSchemeSax', 'CreatePerson', 'CreatePersonAddress', 'CreatePersonBankAccount', 'CreatePersonCommunication', 'CreatePersonFutureAddressTimeline', 'CreatePersonIncome', 'CreateResidenceAdaptation', 'CreateSeekerRegistration', 'CreateSeekerRegistrationRequire
# ...

# %%
client.namespaces
# Out:
# {'xsd': 'http://www.w3.org/2001/XMLSchema',
#  'ns0': 'http://www.SG.nl/services/20121122/CustomerPortalAX',
#  'ns1': 'http://schemas.microsoft.com/2003/10/Serialization/',
#  'ns2': 'http://schemas.datacontract.org/2004/07/SG.Models.Rentals',
#  'ns3': 'http://schemas.datacontract.org/2004/07/SG.Models.RealEstate',
#  'ns4': 'http://schemas.datacontract.org/2004/07/SG.Models.Vendors',
#  'ns5': 'http://schemas.datacontract.org/2004/07/SG.Models.Global',
#  'ns6': 'http://schemas.microsoft.com/Message',
#  'ns7': 'http://schemas.datacontract.org/2004/07/SG.Models.Asbestos',
#  'ns8': 'http://schemas.datacontract.org/2004/07/SG.Models.Livability',
#  'ns9': 'http://schemas.datacontract.org/2004/07/SG.Models.Contracts',
#  'ns10': 'http://schemas.datacontract.org/2004/07/SG.Models.Maintenance',
#  'ns11': 'http://schemas.datacontract.org/2004/07/SG.Models.Customers',
#  'ns12': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.CRM',
# ...

# %%
client.wsdl.messages
# Out:
# {'{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_CreateResidenceAdaptation_InputMessage': <AbstractMessage(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_CreateResidenceAdaptation_InputMessage')>,
#  '{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_CreateResidenceAdaptation_OutputMessage': <AbstractMessage(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_CreateResidenceAdaptation_OutputMessage')>,
#  '{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_GetEquipmentItems_InputMessage': <AbstractMessage(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX_GetEquipmentItems_InputMessage')>,
# ...

# %%
print(dir(client.wsdl.messages))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
print(dir(client.namespaces.items))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']

# %%
print(dir(client.type_factory))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__func__', '__ge__', '__get__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
service.resolve
# Out:
# <bound method Service.resolve of <Service(name='ServiceCustomerPortalAX', ports=OrderedDict([('soap', <Port(name='soap', binding=<Soap12Binding(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}soap', port_type=<PortType(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX')>)>, {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/'})>), ('basicHttpBinding', <Port(name='basicHttpBinding', binding=<Soap11Binding(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}basicHttpBinding', port_type=<PortType(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX')>)>, {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/basic'})>)]))>>

# %%
port.binding_options
# Out:
# {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/basic'}

# %%
dir(operation)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'abstract',
#  'binding',
#  'create',
#  'faults',
#  'input',
#  'name',
#  'nsmap',
#  'output',
#  'parse',
#  'process_reply',
#  'resolve',
#  'soapaction',
#  'style']

# %%
#source: https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
#client= Client('url_to_wsdl')
for service in client.wsdl.services.values():
    for port in service.ports.values():
        operations = sorted(
        port.binding._operations.values(),
        key=operator.attrgetter('name'))

        for operation in operations:
            try:
                #print(operation.name)
                node = client.create_message(client.service, operation.name)
                print(node)
            except:
                pass
# Out:
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767f0c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fd40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757ce00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757ce00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cfc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fd40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644840>
# ...

# %%
client.wsdl.types.deserialize
# Out:
# <bound method Schema.deserialize of <Schema(location='C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\TobiasAX.wsdl', tns='http://www.SG.nl/services/20121122/CustomerPortalAX')>>

# %% [markdown]
# ## 3.  Woningnet wsdl

# %%
# !python -mzeep "C:\Users\31653\Desktop\DeAlliantie\ax-woningnet.wsdl"
# Out:
# Prefixes:
#      xsd: http://www.w3.org/2001/XMLSchema
#      ns0: http://www.daan.com/ax/woningnet/
#
# Global elements:
#      ns0:Completed(Publication: {Id: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string}, Participation: {PropertySeekerId: xsd:string, PropertySeekerExternal: xsd:string, AcceptationDate: xsd:string, ContractSigningDateTime: xsd:string, PreliminaryContractDate: xsd:string, PreliminaryContractToDate: xsd:string, PreliminaryRentFromDate: xsd:string})
#      ns0:CompletedResult(Processed: xsd:string, Report: xsd:string)
# ...

# %%
from zeep import Client, Settings

settings = Settings(strict=False, xml_huge_tree=True)
client = Client('C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl', settings=settings)
print(settings)
# Out:
# _local(strict=False, raw_response=False, force_https=True, extra_http_headers=None, xml_huge_tree=True, forbid_dtd=False, forbid_entities=True, forbid_external=True, xsd_ignore_sequence_order=False, _tls=<_thread._local object at 0x00000281ADB29CC0>)

# %%
with client.settings(raw_response=True):
    response = client.service.leegmelden
print(response)

# %%
from zeep import Client

#client = Client('http://my-enterprise-endpoint.com')
factory = client.type_factory('ns0')
print(factory)
print('---------------------------')
print(dir(factory._ns))
# Out:
# ...
# ---------------------------
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(client.service.kandidaatOphalen)
print(dir(client.service.kandidaatOphalen))
# Out:
# ...
# ['__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_merge_soap_headers', '_op_name', '_proxy']

# %%
for service in client.service:
    print(service)
# Out:
# ('leegmelden', <zeep.proxy.OperationProxy object at 0x00000281ADB58250>)
# ('kandidaatOphalen', <zeep.proxy.OperationProxy object at 0x00000281ADB58160>)
# ('objectAfmelden', <zeep.proxy.OperationProxy object at 0x00000281ADB580D0>)

# %%
print(dir(client.service))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__self_class__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__thisclass__', 'kandidaatOphalen', 'leegmelden', 'objectAfmelden']

# %%
# best script
import operator
from zeep import Client

woningnet_methods_list = []
wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl"
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))
        method_list = []
        SOAP_list =[]
        for operation in operations:
            print(" method :", operation.name)
            woningnet_methods_list.append(operation.name)
            print("  input :", operation.input.signature())
            SOAP_list.append(operation.input.signature())#[operation.name]
            method_list.append(operation.name)
            print(" output :", operation.output.signature())
print(len(woningnet_methods_list))
print('-----------------------')
#print(woningnet_methods_list)
print(SOAP_list)
print(method_list)
#print(dir(operation))
# Out:
# service : ax-woningnet
#  method : kandidaatOphalen
#   input : Publication: {Id: xsd:string, Number: xsd:string, Sequence: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string, Corporatienummer: xsd:string, Vestigingsnummer: xsd:string}
# ...

# %%
SOAP_list[0]
# Out:
# 'Publication: {Id: xsd:string, Number: xsd:string, Sequence: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string, Corporatienummer: xsd:string, Vestigingsnummer: xsd:string}'

# %%
SOAP_list[1]
# Out:
# 'Publication: {Id: xsd:string, Number: xsd:string, Sequence: xsd:string, RealEstateObjectId: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string, DistrictId: xsd:string, District: xsd:string, NeighborhoodId: xsd:string, Neighborhood: xsd:string, RegistrationTypeId: xsd:string, RegistrationType: xsd:string, HousingId: xsd:string, Housing: xsd:string, PlotTypeId: xsd:string, PlotType: xsd:string, NetRent: xsd:string, EligibleRent: xsd:string, GrossRent: xsd:string, DateEmpty: xsd:string, DateAvailable: xsd:string, Start: xsd:string, End: xsd:string, FloorNo: xsd:string, BuiltYear: xsd:string, SellingPrice: xsd:string, PractitionerId: xsd:string, Practitioner: xsd:string, PublicationText: xsd:string, ObjectGroupId: xsd:string, ObjectGroup: xsd:string, SortField1Id: xsd:string, SortField1: xsd:string, SortField2Id: xsd:string, SortField2: xsd:string, SortField3Id: xsd:string, So
# ...

# %%
string =SOAP_list[2]
my_list =string.split("},", )
print(my_list[1])
print(len(my_list))
# Out:
#  Participation: {PropertySeekerId: xsd:string, PropertySeekerExternal: xsd:string, AcceptationDate: xsd:string, ContractSigningDateTime: xsd:string, PreliminaryContractDate: xsd:string, PreliminaryContractToDate: xsd:string, PreliminaryRentFromDate: xsd:string}
# 2

# %%
# to do remove whitespaces and :
for i in range(len(SOAP_list)):
    string =SOAP_list[i]
    my_list =string.split("},", )
    #print(my_list[i])
    #print(len(my_list))
    method_dict[i]={}
    for j in range (len(my_list)):
        string = my_list[j]
        l = string.split("{", )
        object_ = l[0]
        object_ = object_.strip() 
        object_ = object_.replace(":", "")
        attributes =l[1]
        #print(attributes)
        att_l = attributes.split(",")
        #print(att_l)
        attributes = []
        for k in range(len(att_l)):
            string = att_l[k]
            string = string.split(":", )
            att = string[0]
            att =att.strip()
            attributes.append(att)
            #print(string)
        print(object_, attributes)
        print('---------------------------------')
        method_dict[object_] = attributes
# Out:
# Publication ['Id', 'Number', 'Sequence', 'AddressStreet', 'AddressHouseNumber', 'AddressHouseNumberAddition', 'AddressZipcode', 'AddressCity', 'Corporatienummer', 'Vestigingsnummer']
# ---------------------------------
# Publication ['Id', 'Number', 'Sequence', 'RealEstateObjectId', 'AddressStreet', 'AddressHouseNumber', 'AddressHouseNumberAddition', 'AddressZipcode', 'AddressCity', 'DistrictId', 'District', 'NeighborhoodId', 'Neighborhood', 'RegistrationTypeId', 'RegistrationType', 'HousingId', 'Housing', 'PlotTypeId', 'PlotType', 'NetRent', 'EligibleRent', 'GrossRent', 'DateEmpty', 'DateAvailable', 'Start', 'End', 'FloorNo', 'BuiltYear', 'SellingPrice', 'PractitionerId', 'Practitioner', 'PublicationText', 'ObjectGroupId', 'ObjectGroup', 'SortField1Id', 'SortField1', 'SortField2Id', 'SortField2', 'SortField3Id', 'SortField3', 'DestinationId', 'Destination', 'Corporatienummer', 'Vestigingsnummer']
# ---------------------------------
# Components ['Component']
# ...

# %%
method_dict
# Out:
# {'Publication': ['Id',
#   'AddressStreet',
#   'AddressHouseNumber',
#   'AddressHouseNumberAddition',
#   'AddressZipcode',
#   'AddressCity'],
#  'Participation': ['PropertySeekerId',
#   'PropertySeekerExternal',
#   'AcceptationDate',
#   'ContractSigningDateTime',
#   'PreliminaryContractDate',
#   'PreliminaryContractToDate',
#   'PreliminaryRentFromDate'],
#  0: {},
#  1: {},
#  'Components': ['Component'],
#  'ContractForms': ['ContractForm'],
#  'Attributes': ['Attribute'],
#  'Criterion': ['Criteria'],
#  'Rules': ['Rule'],
#  'Pictures': ['Picture'],
#  2: {}}

# %%
# TO DO IMPROVE SCRIPT FOR NESTED XMLS
string = xmls_list[1]
l = string.split("{", )
object_ = l[0]
attributes =l[1]
#print(attributes)
att_l = attributes.split(",")
#print(att_l)
attributes = []
for i in range(len(att_l)):
    string = att_l[i]
    string = string.split(":", )
    att = string[0]
    attributes.append(att)
    #print(string)
print(object_, attributes)
# Out:
# Publication:  ['Id', ' Number', ' Sequence', ' RealEstateObjectId', ' AddressStreet', ' AddressHouseNumber', ' AddressHouseNumberAddition', ' AddressZipcode', ' AddressCity', ' DistrictId', ' District', ' NeighborhoodId', ' Neighborhood', ' RegistrationTypeId', ' RegistrationType', ' HousingId', ' Housing', ' PlotTypeId', ' PlotType', ' NetRent', ' EligibleRent', ' GrossRent', ' DateEmpty', ' DateAvailable', ' Start', ' End', ' FloorNo', ' BuiltYear', ' SellingPrice', ' PractitionerId', ' Practitioner', ' PublicationText', ' ObjectGroupId', ' ObjectGroup', ' SortField1Id', ' SortField1', ' SortField2Id', ' SortField2', ' SortField3Id', ' SortField3', ' DestinationId', ' Destination', ' Corporatienummer', ' Vestigingsnummer', ' Components']

# %%
xmls_list[2]
# Out:
# 'Publication: {Id: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string}, Participation: {PropertySeekerId: xsd:string, PropertySeekerExternal: xsd:string, AcceptationDate: xsd:string, ContractSigningDateTime: xsd:string, PreliminaryContractDate: xsd:string, PreliminaryContractToDate: xsd:string, PreliminaryRentFromDate: xsd:string}'

# %%
# All attributes except publication and participation
string = xmls_list[2]
l = string.split("{", )
object_ = l[0]
attributes =l[1:]
#print(attributes)
attributes_l = []
for i in range (len(attributes)):
    att_l = attributes[i].split(",")
    #print(att_l)
    for j in range(len(att_l)):
        string = att_l[j]
        string = string.split(":", )
        att = string[0]
        attributes_l.append(att)
        #print(string)
print(attributes_l)
# Out:
# ['Id', ' AddressStreet', ' AddressHouseNumber', ' AddressHouseNumberAddition', ' AddressZipcode', ' AddressCity', ' Participation', 'PropertySeekerId', ' PropertySeekerExternal', ' AcceptationDate', ' ContractSigningDateTime', ' PreliminaryContractDate', ' PreliminaryContractToDate', ' PreliminaryRentFromDate']

# %%
attributes
# Out:
# ['Id: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string}, Participation: ',
#  'PropertySeekerId: xsd:string, PropertySeekerExternal: xsd:string, AcceptationDate: xsd:string, ContractSigningDateTime: xsd:string, PreliminaryContractDate: xsd:string, PreliminaryContractToDate: xsd:string, PreliminaryRentFromDate: xsd:string}']

# %%
print(type(l))
print(len(l))
print(l)
# Out:
# <class 'list'>
# 3
# ['Publication: ', 'Id: xsd:string, AddressStreet: xsd:string, AddressHouseNumber: xsd:string, AddressHouseNumberAddition: xsd:string, AddressZipcode: xsd:string, AddressCity: xsd:string}, Participation: ', 'PropertySeekerId: xsd:string, PropertySeekerExternal: xsd:string, AcceptationDate: xsd:string, ContractSigningDateTime: xsd:string, PreliminaryContractDate: xsd:string, PreliminaryContractToDate: xsd:string, PreliminaryRentFromDate: xsd:string}']

# %% [markdown]
# ### Client

# %%
print(dir(client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_default_port_name', '_default_service', '_default_service_name', '_default_soapheaders', '_default_transport', '_get_port', '_get_service', 'bind', 'create_message', 'create_service', 'get_element', 'get_type', 'namespaces', 'plugins', 'service', 'set_default_soapheaders', 'set_ns_prefix', 'settings', 'transport', 'type_factory', 'wsdl', 'wsse']

# %%
print(dir(client.settings))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
print(dir(client.transport))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_load_remote_data', 'cache', 'get', 'load', 'load_timeout', 'logger', 'operation_timeout', 'post', 'post_xml', 'session', 'settings']

# %%
transport = client.transport
print(transport)
print(type(transport))
# Out:
# ...
# <class 'zeep.transports.Transport'>

# %%
wsdl = client.wsdl
print(wsdl)
# Out:
# <WSDL(location='C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl')>

# %% [markdown]
# ### Namespaces

# %%
print(dir(client.namespaces))
client.namespaces
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# {'xsd': 'http://www.w3.org/2001/XMLSchema',
#  'ns0': 'http://www.daan.com/ax/woningnet/'}

# %%
print(dir(client.namespaces.values))
for keys, values in client.namespaces.items():
    print(keys, values)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# xsd http://www.w3.org/2001/XMLSchema
# ns0 http://www.daan.com/ax/woningnet/

# %% [markdown]
# ### Wsdl

# %%
print(dir(client.wsdl))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_definition', '_definitions', '_get_xml_document', 'bindings', 'dump', 'load', 'location', 'messages', 'port_types', 'services', 'settings', 'transport', 'types']

# %%
print(dir(client.namespaces.values))
values = client.namespaces.values
print(values)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# <built-in method values of dict object at 0x000001969AC837C0>

# %%
print(dir(client.namespaces.items))
items = client.namespaces.items
print(items)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# <built-in method items of dict object at 0x00000281AFEF9680>

# %% [markdown]
# ### Ports

# %%
print(dir(client.service.ports))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\zeep\proxy.py in __getitem__(self, key)
#      96         try:
# ---> 97             return self._operations[key]
#      98         except KeyError:
#
# KeyError: 'ports'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36776/3898432099.py in <module>
# ----> 1 print(dir(client.service.ports))
#
# ~\anaconda3\lib\site-packages\zeep\proxy.py in __getattr__(self, key)
#      86
#      87         """
# ---> 88         return self[key]
#      89
#      90     def __getitem__(self, key):
#
# ~\anaconda3\lib\site-packages\zeep\proxy.py in __getitem__(self, key)
#      97             return self._operations[key]
#      98         except KeyError:
# ...

# %%
binding = port.binding
print(binding)
# Out:
# Soap11Binding: {http://www.daan.com/ax/woningnet/}ax-woningnetSOAP

# %%
name = port.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36776/2445304261.py in <module>
# ----> 1 name = port.name
#
# NameError: name 'port' is not defined

# %% [markdown]
# ### Services

# %%
print(dir(client.wsdl.services))
print(dir(client.wsdl.services.values))
services = client.wsdl.services
print(services)
print(type(services))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'move_to_end', 'pop', 'popitem', 'setdefault', 'update', 'values']
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# ...

# %%
print(services.items())
print('------------------------')
print(services.keys())
print('------------------------')
print(services.values())
print(type(services.values()))
# Out:
# odict_items([('ax-woningnet', <Service(name='ax-woningnet', ports=OrderedDict([('ax-woningnetSOAP', <Port(name='ax-woningnetSOAP', binding=<Soap11Binding(name='{http://www.daan.com/ax/woningnet/}ax-woningnetSOAP', port_type=<PortType(name='{http://www.daan.com/ax/woningnet/}ax-woningnet')>)>, {'address': 'http://localhost:9080/ax/woningnet'})>)]))>)])
# ------------------------
# odict_keys(['ax-woningnet'])
# ------------------------
# odict_values([<Service(name='ax-woningnet', ports=OrderedDict([('ax-woningnetSOAP', <Port(name='ax-woningnetSOAP', binding=<Soap11Binding(name='{http://www.daan.com/ax/woningnet/}ax-woningnetSOAP', port_type=<PortType(name='{http://www.daan.com/ax/woningnet/}ax-woningnet')>)>, {'address': 'http://localhost:9080/ax/woningnet'})>)]))>])
# <class 'odict_values'>

# %%
# Out:
# odict_keys(['ax-woningnet'])

# %%
print(dir(client.wsdl.services.values))
services_values =client.wsdl.services.values
print(services_values)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# <built-in method values of collections.OrderedDict object at 0x000001969ACA9DC0>

# %%
print(type(client.wsdl.services))
#for service in client.wsdl.services():
#   print(service)
# Out:
# <class 'collections.OrderedDict'>

# %%
print(type(client.wsdl.services.values))
for service in client.wsdl.services.values():
    print("service :", service.name)
    print('ports :' , service.ports)
# Out:
# <class 'builtin_function_or_method'>
# service : ax-woningnet
# ports : OrderedDict([('ax-woningnetSOAP', <Port(name='ax-woningnetSOAP', binding=<Soap11Binding(name='{http://www.daan.com/ax/woningnet/}ax-woningnetSOAP', port_type=<PortType(name='{http://www.daan.com/ax/woningnet/}ax-woningnet')>)>, {'address': 'http://localhost:9080/ax/woningnet'})>)])

# %% [markdown]
# ### Types

# %%
print(dir(client.wsdl.types))
types = client.wsdl.types
print(types)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_create_prefix_map', '_create_qname', '_get_instance', '_get_schema_documents', '_load_default_documents', '_prefix_map_auto', '_prefix_map_custom', '_transport', 'add_document_by_url', 'add_documents', 'create_new_document', 'deserialize', 'documents', 'elements', 'get_attribute', 'get_attribute_group', 'get_element', 'get_group', 'get_ns_prefix', 'get_shorthand_for_ns', 'get_type', 'is_empty', 'merge', 'namespaces', 'prefix_map', 'root_document', 'set_ns_prefix', 'settings', 'types']
# <Schema(location='C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl', tns='http://www.daan.com/ax/woningnet/')>

# %%
elements = client.wsdl.types.elements
print(elements)
# Out:
# <generator object Schema.elements at 0x000001969B3D66D0>

# %%
print(dir(client.wsdl.types))
types=client.wsdl.types
print(types)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_create_prefix_map', '_create_qname', '_get_instance', '_get_schema_documents', '_load_default_documents', '_prefix_map_auto', '_prefix_map_custom', '_transport', 'add_document_by_url', 'add_documents', 'create_new_document', 'deserialize', 'documents', 'elements', 'get_attribute', 'get_attribute_group', 'get_element', 'get_group', 'get_ns_prefix', 'get_shorthand_for_ns', 'get_type', 'is_empty', 'merge', 'namespaces', 'prefix_map', 'root_document', 'set_ns_prefix', 'settings', 'types']
# <Schema(location='C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl', tns='http://www.daan.com/ax/woningnet/')>

# %%
print(dir(client.wsdl.types._get_schema_documents))
schema_docs = client.wsdl.types._get_schema_documents
schema_docs
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__func__', '__ge__', '__get__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# <bound method Schema._get_schema_documents of <Schema(location='C:\\Users\\31653\\Desktop\\DeAlliantie\\ax-woningnet.wsdl', tns='http://www.daan.com/ax/woningnet/')>>

# %% [markdown]
# ### Messages

# %%
print(dir(client.wsdl.messages))
messages = client.wsdl.messages
print(type(messages))
messages
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# <class 'dict'>
# {'{http://www.daan.com/ax/woningnet/}LeegmeldenRequest': <AbstractMessage(name='{http://www.daan.com/ax/woningnet/}LeegmeldenRequest')>,
#  '{http://www.daan.com/ax/woningnet/}LeegmeldenResponse': <AbstractMessage(name='{http://www.daan.com/ax/woningnet/}LeegmeldenResponse')>,
#  '{http://www.daan.com/ax/woningnet/}KandidaatOphalenRequest': <AbstractMessage(name='{http://www.daan.com/ax/woningnet/}KandidaatOphalenRequest')>,
# ...

# %%
#my script to create a list of all messages
messages = client.wsdl.messages
help_list = list(messages)
messages_list=[]
for i in range (len(help_list)):
    string = help_list[i]
    l = string.split("}", )
    message =l[1]
    messages_list.append(message)
    print(message)
print(messages_list)
# Out:
# LeegmeldenRequest
# LeegmeldenResponse
# KandidaatOphalenRequest
# KandidaatOphalenResponse
# ObjectAfmeldenRequest
# ObjectAfmeldenResponse
# ['LeegmeldenRequest', 'LeegmeldenResponse', 'KandidaatOphalenRequest', 'KandidaatOphalenResponse', 'ObjectAfmeldenRequest', 'ObjectAfmeldenResponse']

# %%
for message in messages:
    print(message)
# Out:
# {http://www.daan.com/ax/woningnet/}LeegmeldenRequest
# {http://www.daan.com/ax/woningnet/}LeegmeldenResponse
# {http://www.daan.com/ax/woningnet/}KandidaatOphalenRequest
# {http://www.daan.com/ax/woningnet/}KandidaatOphalenResponse
# {http://www.daan.com/ax/woningnet/}ObjectAfmeldenRequest
# {http://www.daan.com/ax/woningnet/}ObjectAfmeldenResponse

# %%
print(dir(client.wsdl.messages.items))
items = client.wsdl.messages.items
print(items)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__text_signature__']
# <built-in method items of dict object at 0x00000281ADB31580>

# %%
from zeep import Client
from pprint import pprint

wsdl = 'C:\\Users\\31653\\Desktop\\DeAlliantie\\TobiasAX.wsdl'
client = Client(wsdl)


def parseElements(elements):
    all_elements = {}
    for name, element in elements:
        all_elements[name] = {}
        all_elements[name]['optional'] = element.is_optional
        if hasattr(element.type, 'elements'):
            all_elements[name]['type'] = parseElements(
                element.type.elements)
        else:
            all_elements[name]['type'] = str(element.type)

    return all_elements

interface = {}
for service in client.wsdl.services.values():
    interface[service.name] = {}
    for port in service.ports.values():
        interface[service.name][port.name] = {}
        operations = {}
        for operation in port.binding._operations.values():
            print(operation.name)
            operations[operation.name] = {}
            operations[operation.name]['input'] = {}
            elements = operation.input.body.type.elements
            #operations[operation.name]['input'] = parseElements(elements)
            #interface[service.name][port.name]['operations'] = operations
# Out:
# CreateResidenceAdaptation
# GetEquipmentItems
# GetResindenceAdaptationsByContract
# CreateSeekerRegistrationUrgency
# GetSeekerRegistrationUrgencies
# UpdateSeekerRegistrationUrgency
# DeleteSeekerRegistrationUrgency
# GetInvoiceReasonCodes
# GetVendInvoices
# CreateNotes
# RoutingInvoiceAction
# GetVendInvoiceNotes
# GetVendInvoiceSpecLedgers
# GetVendInvoiceSpecExpenses
# GetVendInvoiceSpecPurchaseOrders
# RoutingInvoiceToEmpl
# GetDocuRefsVendInvoice
# GetDocuUrlVendInvoiceExternalDMS
# GetPurchOrderForApproval
# GetPurchLines
# GetPurchWorkflowInfo
# ApprovePurchWorkflow
# ReturnPurchWorkflow
# ResubmitPurchWorkflow
# DelegatePurchWorkflow
# GetDocumentFileFromEworxDMS
# CheckEworxDMS
# CreateAsbestosProject
# UpdateAsbestosProject
# CreateAsbestosTask
# UpdateAsbestosTask
# CreateAsbestosSource
# UpdateAsbestosSource
# GetSocialComplaint
# GetSocialComplaintRelationsByPerson
# GetSocialComplaintByResponsiblePerson
# GetSocialComplaintByPerson
# ...

# %%
type(operation)
# Out:
# zeep.wsdl.bindings.soap.SoapOperation
