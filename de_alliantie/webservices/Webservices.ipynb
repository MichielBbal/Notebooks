# %% [markdown]
# # 4.11 Zeep is a Python SOAP client
#
# ### Documentation
# https://docs.python-zeep.org/en/master/index.html
# https://github.com/mvantellingen/python-zeep
#
# ### Content
# - 0. Install packages
# - 1. Dummy example
# - 2. Calculator example
# - 3. Echte voorbeelden de Alliantie

# %% [markdown]
# ## 0. Install packages

# %%
# !pip install zeep==4.0.0
# Out:
# Requirement already satisfied: zeep==4.0.0 in c:\users\31653\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (0.9.1)
# Requirement already satisfied: defusedxml>=0.4.1 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (0.7.1)
# Requirement already satisfied: requests>=2.7.0 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (2.26.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (4.6.3)
# Requirement already satisfied: appdirs>=1.4.0 in c:\users\31653\appdata\roaming\python\python38\site-packages (from zeep==4.0.0) (1.4.4)
# Requirement already satisfied: attrs>=17.2.0 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (21.2.0)
# Requirement already satisfied: pytz in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (2021.3)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (0.6.1)
# Requirement already satisfied: requests-file>=1.5.1 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (1.5.1)
# Requirement already satisfied: cached-property>=1.3.0 in c:\users\31653\anaconda3\lib\site-packages (from zeep==4.0.0) (1.5.2)
# Requirement already satisfied: six in c:\users\31653\anaconda3\lib\site-packages (from isodate>=0.5.4->zeep==4.0.0) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.7.0->zeep==4.0.0) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.7.0->zeep==4.0.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.7.0->zeep==4.0.0) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\31653\anaconda3\lib\site-packages (from requests>=2.7.0->zeep==4.0.0) (1.26.7)

# %% [markdown]
# ## 1. Dummies

# %%
# source: https://python.plainenglish.io/work-with-wsdl-files-using-python-and-zeep-2948e9918c29
from zeep import Client

wsdl = 'http://www.soapclient.com/xml/soapresponder.wsdl'
client = Client(wsdl=wsdl)
my_result = client.service.Method1('Zeep', 'is cool')
print(my_result)
# Out:
# Your input parameters are Zeep and is cool

# %%
# uncomment if you want to see it in action
#!python -mzeep http://www.soapclient.com/xml/soapresponder.wsdl

# %%
from zeep import Client
wsdl = "https://wsvc.cdiscount.com/MarketplaceAPIService.svc?wsdl"
client = Client(wsdl)
print(client)
# Out:
# <zeep.client.Client object at 0x0000020988F9D400>

# %%
#dir(client)

# %%
dir(client.service)
# Out:
# ['CloseDiscussionList',
#  'CreateExternalOrder',
#  'CreateRefundVoucher',
#  'CreateRefundVoucherAfterShipment',
#  'GenerateDiscussionMailGuid',
#  'GetAllAllowedCategoryTree',
#  'GetAllModelList',
#  'GetAllowedCategoryTree',
#  'GetBrandList',
#  'GetCompetingOfferChanges',
#  'GetCompetingOffers',
#  'GetDiscussionList',
#  'GetDiscussionMailList',
#  'GetExternalOrderStatus',
#  'GetFulfilmentActivationReportList',
#  'GetFulfilmentDeliveryDocument',
#  'GetFulfilmentOrderListToSupply',
#  'GetFulfilmentSupplyOrder',
#  'GetFulfilmentSupplyOrderReportList',
#  'GetGlobalConfiguration',
#  'GetModelList',
#  'GetOfferList',
#  'GetOfferListPaginated',
#  'GetOfferPackageSubmissionResult',
#  'GetOfferQuestionList',
#  'GetOrderClaimList',
#  'GetOrderList',
#  'GetOrderQuestionList',
#  'GetParcelShopList',
#  'GetProductList',
#  'GetProductListByIdentifier',
#  'GetProductPackageProductMatchingFileData',
#  'GetProductPackageSubmissionResult',
#  'GetProductStockList',
#  'GetRelaysFileSubmissionResult',
#  'GetSellerDeals',
#  'GetSellerIndicators',
#  'GetSellerInformation',
#  'GetServiceOrderList',
#  'ManageParcel',
#  'SubmitFulfilmentActivation',
#  'SubmitFulfilmentOnDemandSupplyOrder',
#  'SubmitFulfilmentSupplyOrder',
#  'SubmitOfferPackage',
#  'SubmitOfferStateAction',
#  'SubmitProductPackage',
#  'SubmitRelaysFile',
#  'ValidateOrderList',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__self_class__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__thisclass__']

# %%
# Not working
# source: https://docs.python-zeep.org/en/master/client.html#creating-the-raw-xml-documents
from zeep import Client

client = Client('https://wsvc.cdiscount.com/MarketplaceAPIService.svc?wsdl')
node = client.create_message(client.service, 'GetModelList')

# %%
print(node)
type(node)
# Out:
# <Element {http://schemas.xmlsoap.org/soap/envelope/}Envelope at 0x20988d6d2c0>
# lxml.etree._Element

# %%
node.xpath
# Out:
# <bound method _Element.xpath of <Element {http://schemas.xmlsoap.org/soap/envelope/}Envelope at 0x20988d6d2c0>>

# %%
print(dir(node))
# Out:
# ['__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '_init', 'addnext', 'addprevious', 'append', 'attrib', 'base', 'clear', 'cssselect', 'extend', 'find', 'findall', 'findtext', 'get', 'getchildren', 'getiterator', 'getnext', 'getparent', 'getprevious', 'getroottree', 'index', 'insert', 'items', 'iter', 'iterancestors', 'iterchildren', 'iterdescendants', 'iterfind', 'itersiblings', 'itertext', 'keys', 'makeelement', 'nsmap', 'prefix', 'remove', 'replace', 'set', 'sourceline', 'tag', 'tail', 'text', 'values', 'xpath']

# %%
node.keys
# Out:
# <bound method _Element.keys of <Element {http://schemas.xmlsoap.org/soap/envelope/}Envelope at 0x20988d6d2c0>>

# %% [markdown]
# ## 2. Calculator example:
#
# http://www.dneonline.com/calculator.asmx

# %%
from zeep import Client

client =Client(wsdl='http://www.dneonline.com/calculator.asmx?wsdl')
print(client.service.Add(12,13))
# Out:
# 25

# %%
#!python -mzeep http://www.dneonline.com/calculator.asmx?wsdl

# %%
from zeep import Client, Settings

settings = Settings(strict=False, xml_huge_tree=True)
client = Client('http://www.dneonline.com/calculator.asmx?wsdl', settings=settings)
client

# %%
#https://docs.python-zeep.org/en/master/settings.html#settings
with client.settings(raw_response=True):
    response = client.service.Add(12,14)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><AddResponse xmlns="http://tempuri.org/"><AddResult>26</AddResult></AddResponse></soap:Body></soap:Envelope>'

# %%
my_response = response.content
my_response
# Out:
# b'<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><AddResponse xmlns="http://tempuri.org/"><AddResult>26</AddResult></AddResponse></soap:Body></soap:Envelope>'

# %%
response.links
# Out:
# {}

# %%
#https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
import operator
from zeep import Client

wsdl = 'http://www.soapclient.com/xml/soapresponder.wsdl'
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            print(" method :", operation.name)
            print("  input :", operation.input.signature())
            print(" output :", operation.output.signature())
# Out:
# service : SoapResponder
#  method : Method1
#   input : bstrParam1: xsd:string, bstrParam2: xsd:string
#  output : bstrReturn: xsd:string

# %%
#dir(service)

# %%
operation.input.body.type.elements[1]
# Out:
# ('bstrParam2',
#  <Element(name='bstrParam2', type=<zeep.xsd.types.builtins.String object at 0x000002098669D2E0>)>)

# %%
#dir(operation.input.body.parse_xmlelements)

# %%
operation.name
# Out:
# 'Method1'

# %% [markdown]
# ## TO DO

# %%
#https://www.geeksforgeeks.org/making-soap-api-calls-using-python/

# %% [markdown]
# ## 3. Echte voorbeelden (deAlliantie)
#
# - 3.1 Shareworx wsdl
# - 3.2 Tobias wsdl
# - 3.3 Woningnet wsdl
# - 3.4 Corporatieportaal wsdl

# %% [markdown]
# ### 3.1 Shareworx wsdl

# %%
# !python -mzeep "C:\Users\31653\Desktop\DeAlliantie\Shareworx.v1.11.wsdl"
# Out:
# Prefixes:
#      xsd: http://www.w3.org/2001/XMLSchema
#      ns0: http://SquareDMS.com/ShareWorXWebService/v1.0
#      ns1: http://schemas.microsoft.com/2003/10/Serialization/
#      ns2: http://SquareDMS.com/ShareWorXWebService/v1.1
#      ns3: http://SquareDMS.com/ShareWorXWebService/v1.2
#      ns4: http://SquareDMS.com/ShareWorXWebService/v1.3
#      ns5: http://SquareDMS.com/ShareWorXWebService/v1.4
#      ns6: http://SquareDMS.com/ShareWorXWebService/v1.5
#      ns7: http://SquareDMS.com/ShareWorXWebService/v1.6
#      ns8: http://schemas.microsoft.com/2003/10/Serialization/Arrays
#      ns9: http://SquareDMS.com/ShareWorXWebService/v1.7
#      ns10: http://SquareDMS.com/ShareWorXWebService/v1.8
#      ns11: http://SquareDMS.com/ShareWorXWebService/v1.9
#      ns12: http://ShareWorX.nl/ShareWorXWebService/v1.10
#      ns13: http://schemas.microsoft.com/Message
#
# Global elements:
#      ns12:Extension(xsd:string)
#      ns12:FileName(xsd:string)
#      ns12:GetFileVersionRequest(context: ns0:CallContext, recno: xsd:int)
#      ns12:GetFileVersionResponse(FileContents: ns13:StreamBody)
#      ns0:Address(ns0:Address)
#      ns0:ArrayOfCase(ns0:ArrayOfCase)
#      ns0:ArrayOfCodeTableEntry(ns0:ArrayOfCodeTableEntry)
#      ns0:ArrayOfConnectTo(ns0:ArrayOfConnectTo)
#      ns0:ArrayOfConnectToContact(ns0:ArrayOfConnectToContact)
#      ns0:ArrayOfConnectToFile(ns0:ArrayOfConnectToFile)
#      ns0:ArrayOfConnectableContact(ns0:ArrayOfConnectableContact)
#      ns0:ArrayOfConnectableDossier(ns0:ArrayOfConnectableDossier)
#      ns0:ArrayOfConnectableEstate(ns0:ArrayOfConnectableEstate)
#      ns0:ArrayOfConnectableProject(ns0:ArrayOfConnectableProject)
#      ns0:ArrayOfContact(ns0:ArrayOfContact)
#      ns0:ArrayOfContactRole(ns0:ArrayOfContactRole)
#      ns0:ArrayOfDocument(ns0:ArrayOfDocument)
#      ns0:ArrayOfDocumentDirection(ns0:ArrayOfDocumentDirection)
#      ns0:ArrayOfDossierCategory(ns0:ArrayOfDossierCategory)
#      ns0:ArrayOfHasAccessEntityType(ns0:ArrayOfHasAccessEntityType)
#      ns0:ArrayOfResponsiblePerson(ns0:ArrayOfResponsiblePerson)
#      ns0:ArrayOfRole(ns0:ArrayOfRole)
#      ns0:CallContext(ns0:CallContext)
#      ns0:Case(ns0:Case)
#      ns0:CaseBase(ns0:CaseBase)
#      ns0:CaseRefDocument(ns0:CaseRefDocument)
#      ns0:CodeTableEntry(ns0:CodeTableEntry)
#      ns0:Company(ns0:Company)
#      ns0:ConnectTo(ns0:ConnectTo)
#      ns0:ConnectToContact(ns0:ConnectToContact)
#      ns0:ConnectToFile(ns0:ConnectToFile)
#      ns0:ConnectableContact(ns0:ConnectableContact)
#      ns0:ConnectableDossier(ns0:ConnectableDossier)
#      ns0:ConnectableEstate(ns0:ConnectableEstate)
#      ns0:ConnectableProject(ns0:ConnectableProject)
#      ns0:Contact(ns0:Contact)
#      ns0:ContactBase(ns0:ContactBase)
#      ns0:ContactPerson(ns0:ContactPerson)
#      ns0:ContactRole(ns0:ContactRole)
#      ns0:CreateCompany(context: ns0:CallContext, company: ns0:Company, contacts: ns0:ArrayOfConnectTo)
#      ns0:CreateCompanyResponse(CreateCompanyResult: xsd:int)
#      ns0:CreateContactPerson(context: ns0:CallContext, contactPerson: ns0:ContactPerson, contacts: ns0:ArrayOfConnectTo)
#      ns0:CreateContactPersonResponse(CreateContactPersonResult: xsd:int)
#      ns0:CreateGeneralCase(context: ns0:CallContext, generalCase: ns0:GeneralCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns0:CreateGeneralCaseDocument(context: ns0:CallContext, generalCaseDocument: ns0:GeneralCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns0:CreateGeneralCaseDocumentResponse(CreateGeneralCaseDocumentResult: xsd:int)
#      ns0:CreateGeneralCaseResponse(CreateGeneralCaseResult: xsd:int)
#      ns0:CreatePrivatePerson(context: ns0:CallContext, privatePerson: ns0:PrivatePerson, contacts: ns0:ArrayOfConnectTo)
#      ns0:CreatePrivatePersonResponse(CreatePrivatePersonResult: xsd:int)
#      ns0:CreateTenantDossier(context: ns0:CallContext, tenantDossier: ns0:TenantDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns0:CreateTenantDossierDocument(context: ns0:CallContext, tenantDossierDocument: ns0:TenantDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns0:CreateTenantDossierDocumentResponse(CreateTenantDossierDocumentResult: xsd:int)
#      ns0:CreateTenantDossierResponse(CreateTenantDossierResult: xsd:int)
#      ns0:Document(ns0:Document)
#      ns0:DocumentBase(ns0:DocumentBase)
#      ns0:DocumentDirection(ns0:DocumentDirection)
#      ns0:Dossier(ns0:Dossier)
#      ns0:DossierCategory(ns0:DossierCategory)
#      ns0:EmployeeCase(ns0:EmployeeCase)
#      ns0:EmployeeDossier(ns0:EmployeeDossier)
#      ns0:EntityType(ns0:EntityType)
#      ns0:Extension(xsd:string)
#      ns0:FieldUsage(ns0:FieldUsage)
#      ns0:FileName(xsd:string)
#      ns0:FileUploadParameters(ns0:FileUploadParameters)
#      ns0:Fillable(ns0:Fillable)
#      ns0:GeneralCase(ns0:GeneralCase)
#      ns0:GeneralCaseDocument(ns0:GeneralCaseDocument)
#      ns0:GetAccessCodes(context: ns0:CallContext, forEntityType: ns0:EntityType, forEntitySubType: xsd:int)
#      ns0:GetAccessCodesResponse(GetAccessCodesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetAccessGroups(context: ns0:CallContext, forEntityType: ns0:EntityType, forEntitySubType: xsd:int, pageOf500: xsd:int)
#      ns0:GetAccessGroupsResponse(GetAccessGroupsResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetArchiveCodes(context: ns0:CallContext, pageOf500: xsd:int)
#      ns0:GetArchiveCodesResponse(GetArchiveCodesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetAvailableProcessTemplates(context: ns0:CallContext, forEntityType: ns0:EntityType, forEntitySubType: xsd:int, pageOf500: xsd:int)
#      ns0:GetAvailableProcessTemplatesResponse(GetAvailableProcessTemplatesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetCaseStatusses(context: ns0:CallContext, forCaseType: xsd:int)
#      ns0:GetCaseStatussesResponse(GetCaseStatussesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetCaseTypes(context: ns0:CallContext)
#      ns0:GetCaseTypesResponse(GetCaseTypesResult: ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka)
#      ns0:GetCompanies(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetCompaniesResponse(GetCompaniesResult: ns0:ResultTableOfContactJ_SwLf7Ka)
#      ns0:GetConnectableContacts(context: ns0:CallContext, likeSearchName: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, toConnectToEntity: ns0:EntityType, forContactRole: xsd:int, pageOf500: xsd:int)
#      ns0:GetConnectableContactsResponse(GetConnectableContactsResult: ns0:ResultTableOfConnectableContactJ_SwLf7Ka)
#      ns0:GetConnectableDossiers(context: ns0:CallContext, ofDossierCategory: xsd:int, syncedEntityPrefix: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetConnectableDossiersResponse(GetConnectableDossiersResult: ns0:ResultTableOfConnectableDossierJ_SwLf7Ka)
#      ns0:GetConnectableEstates(context: ns0:CallContext, likeSearchName: xsd:string, ofEstateCategory: xsd:int, syncedEntityPrefix: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetConnectableEstatesResponse(GetConnectableEstatesResult: ns0:ResultTableOfConnectableEstateJ_SwLf7Ka)
#      ns0:GetConnectableProjects(context: ns0:CallContext, ourProjectNumber: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetConnectableProjectsResponse(GetConnectableProjectsResult: ns0:ResultTableOfConnectableProjectJ_SwLf7Ka)
#      ns0:GetContactCaseRoles(context: ns0:CallContext, internalRole: xsd:boolean, forCaseType: xsd:int)
#      ns0:GetContactCaseRolesResponse(GetContactCaseRolesResult: ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns0:GetContactContactRoles(context: ns0:CallContext, internalRole: xsd:boolean, forContactType: xsd:int)
#      ns0:GetContactContactRolesResponse(GetContactContactRolesResult: ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns0:GetContactDocumentRoles(context: ns0:CallContext, forDocumentProfile: xsd:int)
#      ns0:GetContactDocumentRolesResponse(GetContactDocumentRolesResult: ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns0:GetContactGenders(context: ns0:CallContext)
#      ns0:GetContactGendersResponse(GetContactGendersResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetContactPersons(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetContactPersonsResponse(GetContactPersonsResult: ns0:ResultTableOfContactJ_SwLf7Ka)
#      ns0:GetContactTypes(context: ns0:CallContext)
#      ns0:GetContactTypesResponse(GetContactTypesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetContactsToConnectToContact(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, forContactContactRole: xsd:int, pageOf500: xsd:int)
#      ns0:GetContactsToConnectToContactResponse(GetContactsToConnectToContactResult: ns0:ResultTableOfContactJ_SwLf7Ka)
#      ns0:GetCountries(context: ns0:CallContext, ISO31661Alpha3Code: xsd:string)
#      ns0:GetCountriesResponse(GetCountriesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetDocumentDirections(context: ns0:CallContext, forDocumentProfile: xsd:int)
#      ns0:GetDocumentDirectionsResponse(GetDocumentDirectionsResult: ns0:ResultTableOfDocumentDirectionJ_SwLf7Ka)
#      ns0:GetDocumentProfiles(context: ns0:CallContext)
#      ns0:GetDocumentProfilesResponse(GetDocumentProfilesResult: ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka)
#      ns0:GetDocumentStatusses(context: ns0:CallContext, forDocumentProfile: xsd:int)
#      ns0:GetDocumentStatussesResponse(GetDocumentStatussesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetDocumentTypes(context: ns0:CallContext)
#      ns0:GetDocumentTypesResponse(GetDocumentTypesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetDossierCategories(context: ns0:CallContext)
#      ns0:GetDossierCategoriesResponse(GetDossierCategoriesResult: ns0:ResultTableOfDossierCategoryJ_SwLf7Ka)
#      ns0:GetEstateCaseRoles(context: ns0:CallContext)
#      ns0:GetEstateCaseRolesResponse(GetEstateCaseRolesResult: ns0:ResultTableOfRoleJ_SwLf7Ka)
#      ns0:GetEstateCategories(context: ns0:CallContext)
#      ns0:GetEstateCategoriesResponse(GetEstateCategoriesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetEstateDocumentRoles(context: ns0:CallContext)
#      ns0:GetEstateDocumentRolesResponse(GetEstateDocumentRolesResult: ns0:ResultTableOfRoleJ_SwLf7Ka)
#      ns0:GetFileRelationTypes(context: ns0:CallContext)
#      ns0:GetFileRelationTypesResponse(GetFileRelationTypesResult: ns0:ResultTableOfRoleJ_SwLf7Ka)
#      ns0:GetFileVersionRequest(context: ns0:CallContext, recno: xsd:int)
#      ns0:GetFileVersionResponse(FileContents: ns13:StreamBody)
#      ns0:GetGeneralCaseDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns0:GetGeneralCaseDocumentsResponse(GetGeneralCaseDocumentsResult: ns0:ResultTableOfDocumentJ_SwLf7Ka)
#      ns0:GetGeneralCases(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns0:GetGeneralCasesResponse(GetGeneralCasesResult: ns0:ResultTableOfCaseJ_SwLf7Ka)
#      ns0:GetPrivatePersons(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns0:GetPrivatePersonsResponse(GetPrivatePersonsResult: ns0:ResultTableOfContactJ_SwLf7Ka)
#      ns0:GetResponsibleOrgUnits(context: ns0:CallContext)
#      ns0:GetResponsibleOrgUnitsResponse(GetResponsibleOrgUnitsResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetResponsiblePersons(context: ns0:CallContext, forOrgUnit: xsd:int)
#      ns0:GetResponsiblePersonsResponse(GetResponsiblePersonsResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka)
#      ns0:GetResponsibleUnitsAndPersons(context: ns0:CallContext, pageOf500: xsd:int)
#      ns0:GetResponsibleUnitsAndPersonsResponse(GetResponsibleUnitsAndPersonsResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka)
#      ns0:GetSyncedEntityPrefixes(context: ns0:CallContext)
#      ns0:GetSyncedEntityPrefixesResponse(GetSyncedEntityPrefixesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:GetTenantDossierDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, tenantNumber: xsd:string, pageOf500: xsd:int)
#      ns0:GetTenantDossierDocumentsResponse(GetTenantDossierDocumentsResult: ns0:ResultTableOfDocumentJ_SwLf7Ka)
#      ns0:GetTenantDossiers(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, tenantNumber: xsd:string, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns0:GetTenantDossiersResponse(GetTenantDossiersResult: ns0:ResultTableOfCaseJ_SwLf7Ka)
#      ns0:HasAccessEntityType(ns0:HasAccessEntityType)
#      ns0:InvalidOperationFault(ns0:InvalidOperationFault)
#      ns0:InvalidParameterFault(ns0:InvalidParameterFault)
#      ns0:InvoiceCase(ns0:InvoiceCase)
#      ns0:LogonFault(ns0:LogonFault)
#      ns0:Person(ns0:Person)
#      ns0:PrivatePerson(ns0:PrivatePerson)
#      ns0:PublicCallObject(ns0:PublicCallObject)
#      ns0:ResponsiblePerson(ns0:ResponsiblePerson)
#      ns0:ResultTableOfArchiveCodeyYn4mPMI(ns0:ResultTableOfArchiveCodeyYn4mPMI)
#      ns0:ResultTableOfCaseJ_SwLf7Ka(ns0:ResultTableOfCaseJ_SwLf7Ka)
#      ns0:ResultTableOfCasehQEV8L7t(ns0:ResultTableOfCasehQEV8L7t)
#      ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka(ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns0:ResultTableOfConnectableContactJ_SwLf7Ka(ns0:ResultTableOfConnectableContactJ_SwLf7Ka)
#      ns0:ResultTableOfConnectableDossierJ_SwLf7Ka(ns0:ResultTableOfConnectableDossierJ_SwLf7Ka)
#      ns0:ResultTableOfConnectableEstateJ_SwLf7Ka(ns0:ResultTableOfConnectableEstateJ_SwLf7Ka)
#      ns0:ResultTableOfConnectableProjectJ_SwLf7Ka(ns0:ResultTableOfConnectableProjectJ_SwLf7Ka)
#      ns0:ResultTableOfContact2kaByk1qn(ns0:ResultTableOfContact2kaByk1qn)
#      ns0:ResultTableOfContactExhQEV8L7t(ns0:ResultTableOfContactExhQEV8L7t)
#      ns0:ResultTableOfContactJ_SwLf7Ka(ns0:ResultTableOfContactJ_SwLf7Ka)
#      ns0:ResultTableOfContactRoleJ_SwLf7Ka(ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns0:ResultTableOfDocument2NoNafOTX(ns0:ResultTableOfDocument2NoNafOTX)
#      ns0:ResultTableOfDocumentDirectionExadiuXtug(ns0:ResultTableOfDocumentDirectionExadiuXtug)
#      ns0:ResultTableOfDocumentDirectionJ_SwLf7Ka(ns0:ResultTableOfDocumentDirectionJ_SwLf7Ka)
#      ns0:ResultTableOfDocumentJ_SwLf7Ka(ns0:ResultTableOfDocumentJ_SwLf7Ka)
#      ns0:ResultTableOfDocumentProfileNoNafOTX(ns0:ResultTableOfDocumentProfileNoNafOTX)
#      ns0:ResultTableOfDocumentadiuXtug(ns0:ResultTableOfDocumentadiuXtug)
#      ns0:ResultTableOfDocumenthQEV8L7t(ns0:ResultTableOfDocumenthQEV8L7t)
#      ns0:ResultTableOfDossierCategoryJ_SwLf7Ka(ns0:ResultTableOfDossierCategoryJ_SwLf7Ka)
#      ns0:ResultTableOfEstatehQEV8L7t(ns0:ResultTableOfEstatehQEV8L7t)
#      ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka(ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka)
#      ns0:ResultTableOfProjecthQEV8L7t(ns0:ResultTableOfProjecthQEV8L7t)
#      ns0:ResultTableOfRecordTypeyYn4mPMI(ns0:ResultTableOfRecordTypeyYn4mPMI)
#      ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka(ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka)
#      ns0:ResultTableOfRoleJ_SwLf7Ka(ns0:ResultTableOfRoleJ_SwLf7Ka)
#      ns0:ResultTableOfSignOffCodeadiuXtug(ns0:ResultTableOfSignOffCodeadiuXtug)
#      ns0:ResultTableOfSpecialFilteradiuXtug(ns0:ResultTableOfSpecialFilteradiuXtug)
#      ns0:Role(ns0:Role)
#      ns0:TenantDossier(ns0:TenantDossier)
#      ns0:TenantDossierDocument(ns0:TenantDossierDocument)
#      ns0:UnexpectedFault(ns0:UnexpectedFault)
#      ns0:UpdateCompany(context: ns0:CallContext, recno: xsd:int, company: ns0:Company)
#      ns0:UpdateCompanyResponse(UpdateCompanyResult: xsd:boolean)
#      ns0:UpdateContactPerson(context: ns0:CallContext, recno: xsd:int, contactPerson: ns0:ContactPerson)
#      ns0:UpdateContactPersonResponse(UpdateContactPersonResult: xsd:boolean)
#      ns0:UpdateGeneralCase(context: ns0:CallContext, recno: xsd:int, generalCase: ns0:GeneralCase)
#      ns0:UpdateGeneralCaseDocument(context: ns0:CallContext, recno: xsd:int, generalCaseDocumment: ns0:GeneralCaseDocument)
#      ns0:UpdateGeneralCaseDocumentResponse(UpdateGeneralCaseDocumentResult: xsd:boolean)
#      ns0:UpdateGeneralCaseResponse(UpdateGeneralCaseResult: xsd:boolean)
#      ns0:UpdatePrivatePerson(context: ns0:CallContext, recno: xsd:int, privatePerson: ns0:PrivatePerson)
#      ns0:UpdatePrivatePersonResponse(UpdatePrivatePersonResult: xsd:boolean)
#      ns0:UpdateTenantDossier(context: ns0:CallContext, recno: xsd:int, tenantDossier: ns0:TenantDossier)
#      ns0:UpdateTenantDossierDocument(context: ns0:CallContext, recno: xsd:int, tenantDossierDocument: ns0:TenantDossierDocument)
#      ns0:UpdateTenantDossierDocumentResponse(UpdateTenantDossierDocumentResult: xsd:boolean)
#      ns0:UpdateTenantDossierResponse(UpdateTenantDossierResult: xsd:boolean)
#      ns2:GetGeneralCaseDocumentsEx(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns2:GetGeneralCaseDocumentsExResponse(GetGeneralCaseDocumentsExResult: ns0:ResultTableOfDocumentJ_SwLf7Ka)
#      ns2:GetTenantDossierDocumentsEx(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, tenantNumber: xsd:string, pageOf500: xsd:int)
#      ns2:GetTenantDossierDocumentsExResponse(GetTenantDossierDocumentsExResult: ns0:ResultTableOfDocumentJ_SwLf7Ka)
#      ns3:ArrayOfCase(ns3:ArrayOfCase)
#      ns3:ArrayOfContactEx(ns3:ArrayOfContactEx)
#      ns3:ArrayOfDocument(ns3:ArrayOfDocument)
#      ns3:ArrayOfEstate(ns3:ArrayOfEstate)
#      ns3:ArrayOfProject(ns3:ArrayOfProject)
#      ns3:Case(ns3:Case)
#      ns3:CompanyEx(ns3:CompanyEx)
#      ns3:Complex(ns3:Complex)
#      ns3:ContactEx(ns3:ContactEx)
#      ns3:CreateCompanyEx(context: ns0:CallContext, companyEx: ns3:CompanyEx, contacts: ns0:ArrayOfConnectTo)
#      ns3:CreateCompanyExResponse(CreateCompanyExResult: xsd:int)
#      ns3:CreateComplex(context: ns0:CallContext, complex: ns3:Complex, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact)
#      ns3:CreateComplexResponse(CreateComplexResult: xsd:int)
#      ns3:CreateEmployeeCase(context: ns0:CallContext, employeeCase: ns0:EmployeeCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateEmployeeCaseDocument(context: ns0:CallContext, employeeCaseDocument: ns3:EmployeeCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns3:CreateEmployeeCaseDocumentResponse(CreateEmployeeCaseDocumentResult: xsd:int)
#      ns3:CreateEmployeeCaseResponse(CreateEmployeeCaseResult: xsd:int)
#      ns3:CreateEmployeeDossier(context: ns0:CallContext, employeeDossier: ns0:EmployeeDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateEmployeeDossierDocument(context: ns0:CallContext, employeeDossierDocument: ns3:EmployeeDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns3:CreateEmployeeDossierDocumentResponse(CreateEmployeeDossierDocumentResult: xsd:int)
#      ns3:CreateEmployeeDossierResponse(CreateEmployeeDossierResult: xsd:int)
#      ns3:CreateEstateDossier(context: ns0:CallContext, estateDossier: ns3:EstateDossier, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateEstateDossierDocument(context: ns0:CallContext, estateDossierDocument: ns3:EstateDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns3:CreateEstateDossierDocumentResponse(CreateEstateDossierDocumentResult: xsd:int)
#      ns3:CreateEstateDossierResponse(CreateEstateDossierResult: xsd:int)
#      ns3:CreateInvoiceCase(context: ns0:CallContext, invoiceCase: ns0:InvoiceCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateInvoiceCaseDocument(context: ns0:CallContext, invoiceCaseDocument: ns3:InvoiceCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns3:CreateInvoiceCaseDocumentResponse(CreateInvoiceCaseDocumentResult: xsd:int)
#      ns3:CreateInvoiceCaseResponse(CreateInvoiceCaseResult: xsd:int)
#      ns3:CreateMainProject(context: ns0:CallContext, mainProject: ns3:MainProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateMainProjectResponse(CreateMainProjectResult: xsd:int)
#      ns3:CreateProjectDossier(context: ns0:CallContext, projectDossier: ns3:ProjectDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateProjectDossierDocument(context: ns0:CallContext, projectDossierDocument: ns3:ProjectDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns3:CreateProjectDossierDocumentResponse(CreateProjectDossierDocumentResult: xsd:int)
#      ns3:CreateProjectDossierResponse(CreateProjectDossierResult: xsd:int)
#      ns3:CreateRentableUnit(context: ns0:CallContext, rentableUnit: ns3:RentableUnit, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact)
#      ns3:CreateRentableUnitResponse(CreateRentableUnitResult: xsd:int)
#      ns3:CreateSubProject(context: ns0:CallContext, subProject: ns3:SubProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns3:CreateSubProjectResponse(CreateSubProjectResult: xsd:int)
#      ns3:Document(ns3:Document)
#      ns3:EmployeeCaseDocument(ns3:EmployeeCaseDocument)
#      ns3:EmployeeDossierDocument(ns3:EmployeeDossierDocument)
#      ns3:Estate(ns3:Estate)
#      ns3:EstateBase(ns3:EstateBase)
#      ns3:EstateDossier(ns3:EstateDossier)
#      ns3:EstateDossierDocument(ns3:EstateDossierDocument)
#      ns3:GetCompaniesEx(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, pageOf500: xsd:int)
#      ns3:GetCompaniesExResponse(GetCompaniesExResult: ns3:ResultTableOfContactEx)
#      ns3:GetComplexes(context: ns0:CallContext, recno: xsd:int, estateNumber: xsd:string, likeSearchName: xsd:string, externalKey: xsd:string, zipCode: xsd:string, status: xsd:int, contact: ns0:ConnectToContact, parentRecno: xsd:int, parentEstateNumber: xsd:string, likeParentSearchName: xsd:string, parentSyncedEntityPrefix: xsd:string, parentExternalKey: xsd:string, parentEstateCategory: xsd:int, pageOf500: xsd:int)
#      ns3:GetComplexesResponse(GetComplexesResult: ns3:ResultTableOfEstate)
#      ns3:GetContactEstateRoles(context: ns0:CallContext, internalRole: xsd:boolean)
#      ns3:GetContactEstateRolesResponse(GetContactEstateRolesResult: ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns3:GetContactProjectRoles(context: ns0:CallContext, internalRole: xsd:boolean)
#      ns3:GetContactProjectRolesResponse(GetContactProjectRolesResult: ns0:ResultTableOfContactRoleJ_SwLf7Ka)
#      ns3:GetEmployeeCaseDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, project: xsd:int, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEmployeeCaseDocumentsResponse(GetEmployeeCaseDocumentsResult: ns3:ResultTableOfDocument)
#      ns3:GetEmployeeCases(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, project: xsd:int, contact: ns0:ConnectToContact, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEmployeeCasesResponse(GetEmployeeCasesResult: ns3:ResultTableOfCase)
#      ns3:GetEmployeeDossierDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, project: xsd:int, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEmployeeDossierDocumentsResponse(GetEmployeeDossierDocumentsResult: ns3:ResultTableOfDocument)
#      ns3:GetEmployeeDossiers(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, contact: ns0:ConnectToContact, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEmployeeDossiersResponse(GetEmployeeDossiersResult: ns3:ResultTableOfCase)
#      ns3:GetEstateDossierDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseSyncedEntityPrefix: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEstateDossierDocumentsResponse(GetEstateDossierDocumentsResult: ns3:ResultTableOfDocument)
#      ns3:GetEstateDossiers(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetEstateDossiersResponse(GetEstateDossiersResult: ns3:ResultTableOfCase)
#      ns3:GetEstateProjectRoles(context: ns0:CallContext)
#      ns3:GetEstateProjectRolesResponse(GetEstateProjectRolesResult: ns0:ResultTableOfRoleJ_SwLf7Ka)
#      ns3:GetEstateStatusses(context: ns0:CallContext, forEstateType: xsd:int)
#      ns3:GetEstateStatussesResponse(GetEstateStatussesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns3:GetEstateTypes(context: ns0:CallContext)
#      ns3:GetEstateTypesResponse(GetEstateTypesResult: ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka)
#      ns3:GetGeneralCasesEx(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, project: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetGeneralCasesExResponse(GetGeneralCasesExResult: ns3:ResultTableOfCase)
#      ns3:GetInvoiceCaseDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, project: xsd:int, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetInvoiceCaseDocumentsResponse(GetInvoiceCaseDocumentsResult: ns3:ResultTableOfDocument)
#      ns3:GetInvoiceCases(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, project: xsd:int, searchInvoiceNumber: xsd:string, externalInvoiceNumber: xsd:string, contact: ns0:ConnectToContact, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetInvoiceCasesResponse(GetInvoiceCasesResult: ns3:ResultTableOfCase)
#      ns3:GetMainProjects(context: ns0:CallContext, recno: xsd:int, externalKey: xsd:string, ourProjectNumber: xsd:string, generatedProjectName: xsd:string, likeProjectName: xsd:string, isClosed: xsd:boolean, estate: ns0:ConnectTo, pageOf500: xsd:int)
#      ns3:GetMainProjectsResponse(GetMainProjectsResult: ns3:ResultTableOfProject)
#      ns3:GetProjectDossierDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, project: xsd:int, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetProjectDossierDocumentsResponse(GetProjectDossierDocumentsResult: ns3:ResultTableOfDocument)
#      ns3:GetProjectDossiers(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, project: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetProjectDossiersResponse(GetProjectDossiersResult: ns3:ResultTableOfCase)
#      ns3:GetProjectStatusses(context: ns0:CallContext, forProjectType: xsd:int)
#      ns3:GetProjectStatussesResponse(GetProjectStatussesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns3:GetProjectTypes(context: ns0:CallContext)
#      ns3:GetProjectTypesResponse(GetProjectTypesResult: ns0:ResultTableOfHasAccessEntityTypeJ_SwLf7Ka)
#      ns3:GetRentableUnits(context: ns0:CallContext, recno: xsd:int, estateNumber: xsd:string, likeSearchName: xsd:string, externalKey: xsd:string, zipCode: xsd:string, status: xsd:int, contact: ns0:ConnectToContact, parentRecno: xsd:int, parentEstateNumber: xsd:string, likeParentSearchName: xsd:string, parentSyncedEntityPrefix: xsd:string, parentExternalKey: xsd:string, parentEstateCategory: xsd:int, pageOf500: xsd:int)
#      ns3:GetRentableUnitsResponse(GetRentableUnitsResult: ns3:ResultTableOfEstate)
#      ns3:GetResponsibleOrgUnitsEx(context: ns0:CallContext, forLogonName: xsd:string)
#      ns3:GetResponsibleOrgUnitsExResponse(GetResponsibleOrgUnitsExResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns3:GetSubProjects(context: ns0:CallContext, recno: xsd:int, externalKey: xsd:string, ourProjectNumber: xsd:string, generatedProjectName: xsd:string, likeProjectName: xsd:string, isClosed: xsd:boolean, estate: ns0:ConnectTo, parentRecno: xsd:int, parentExternalKey: xsd:string, parentIsSubProject: xsd:boolean, ourParentProjectNumber: xsd:string, generatedParentProjectName: xsd:string, likeParentProjectName: xsd:string, parentIsClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetSubProjectsResponse(GetSubProjectsResult: ns3:ResultTableOfProject)
#      ns3:GetTenantDossiersEx(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, rentAgreementNumber: xsd:string, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, pageOf500: xsd:int)
#      ns3:GetTenantDossiersExResponse(GetTenantDossiersExResult: ns3:ResultTableOfCase)
#      ns3:InvoiceCaseDocument(ns3:InvoiceCaseDocument)
#      ns3:MainProject(ns3:MainProject)
#      ns3:NewFileVersion(context: ns0:CallContext, activeFileVersion: xsd:int, uploadData: ns0:FileUploadParameters)
#      ns3:NewFileVersionResponse(NewFileVersionResult: xsd:int)
#      ns3:Project(ns3:Project)
#      ns3:ProjectBase(ns3:ProjectBase)
#      ns3:ProjectDossier(ns3:ProjectDossier)
#      ns3:ProjectDossierDocument(ns3:ProjectDossierDocument)
#      ns3:RentableUnit(ns3:RentableUnit)
#      ns3:ResultTableOfCase(ns3:ResultTableOfCase)
#      ns3:ResultTableOfContactEx(ns3:ResultTableOfContactEx)
#      ns3:ResultTableOfDocument(ns3:ResultTableOfDocument)
#      ns3:ResultTableOfEstate(ns3:ResultTableOfEstate)
#      ns3:ResultTableOfProject(ns3:ResultTableOfProject)
#      ns3:SubProject(ns3:SubProject)
#      ns3:UpdateCompanyEx(context: ns0:CallContext, recno: xsd:int, companyEx: ns3:CompanyEx)
#      ns3:UpdateCompanyExResponse(UpdateCompanyExResult: xsd:boolean)
#      ns3:UpdateComplex(context: ns0:CallContext, recno: xsd:int, complex: ns3:Complex)
#      ns3:UpdateComplexResponse(UpdateComplexResult: xsd:boolean)
#      ns3:UpdateEmployeeCase(context: ns0:CallContext, recno: xsd:int, employeeCase: ns0:EmployeeCase)
#      ns3:UpdateEmployeeCaseDocument(context: ns0:CallContext, recno: xsd:int, employeeCaseDocument: ns3:EmployeeCaseDocument)
#      ns3:UpdateEmployeeCaseDocumentResponse(UpdateEmployeeCaseDocumentResult: xsd:boolean)
#      ns3:UpdateEmployeeCaseResponse(UpdateEmployeeCaseResult: xsd:boolean)
#      ns3:UpdateEmployeeDossier(context: ns0:CallContext, recno: xsd:int, employeeDossier: ns0:EmployeeDossier)
#      ns3:UpdateEmployeeDossierDocument(context: ns0:CallContext, recno: xsd:int, employeeDossierDocument: ns3:EmployeeDossierDocument)
#      ns3:UpdateEmployeeDossierDocumentResponse(UpdateEmployeeDossierDocumentResult: xsd:boolean)
#      ns3:UpdateEmployeeDossierResponse(UpdateEmployeeDossierResult: xsd:boolean)
#      ns3:UpdateEstateDossier(context: ns0:CallContext, recno: xsd:int, estateDossier: ns3:EstateDossier)
#      ns3:UpdateEstateDossierDocument(context: ns0:CallContext, recno: xsd:int, estateDossierDocument: ns3:EstateDossierDocument)
#      ns3:UpdateEstateDossierDocumentResponse(UpdateEstateDossierDocumentResult: xsd:boolean)
#      ns3:UpdateEstateDossierResponse(UpdateEstateDossierResult: xsd:boolean)
#      ns3:UpdateInvoiceCase(context: ns0:CallContext, recno: xsd:int, invoiceCase: ns0:InvoiceCase)
#      ns3:UpdateInvoiceCaseDocument(context: ns0:CallContext, recno: xsd:int, invoiceCaseDocument: ns3:InvoiceCaseDocument)
#      ns3:UpdateInvoiceCaseDocumentResponse(UpdateInvoiceCaseDocumentResult: xsd:boolean)
#      ns3:UpdateInvoiceCaseResponse(UpdateInvoiceCaseResult: xsd:boolean)
#      ns3:UpdateMainProject(context: ns0:CallContext, recno: xsd:int, mainProject: ns3:MainProject)
#      ns3:UpdateMainProjectResponse(UpdateMainProjectResult: xsd:boolean)
#      ns3:UpdateProjectDossier(context: ns0:CallContext, recno: xsd:int, projectDossier: ns3:ProjectDossier)
#      ns3:UpdateProjectDossierDocument(context: ns0:CallContext, recno: xsd:int, projectDossierDocument: ns3:ProjectDossierDocument)
#      ns3:UpdateProjectDossierDocumentResponse(UpdateProjectDossierDocumentResult: xsd:boolean)
#      ns3:UpdateProjectDossierResponse(UpdateProjectDossierResult: xsd:boolean)
#      ns3:UpdateRentableUnit(context: ns0:CallContext, recno: xsd:int, rentableUnit: ns3:RentableUnit)
#      ns3:UpdateRentableUnitResponse(UpdateRentableUnitResult: xsd:boolean)
#      ns3:UpdateSubProject(context: ns0:CallContext, recno: xsd:int, subProject: ns3:SubProject)
#      ns3:UpdateSubProjectResponse(UpdateSubProjectResult: xsd:boolean)
#      ns4:GetAnyCases(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, project: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns4:GetAnyCasesResponse(GetAnyCasesResult: ns3:ResultTableOfCase)
#      ns4:GetAnyContacts(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns4:GetAnyContactsResponse(GetAnyContactsResult: ns3:ResultTableOfContactEx)
#      ns4:GetAnyDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, project: xsd:int, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseSyncedEntityPrefix: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns4:GetAnyDocumentsResponse(GetAnyDocumentsResult: ns3:ResultTableOfDocument)
#      ns4:GetAnyEstates(context: ns0:CallContext, recno: xsd:int, estateNumber: xsd:string, likeSearchName: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, zipCode: xsd:string, status: xsd:int, contact: ns0:ConnectToContact, parentRecno: xsd:int, parentEstateNumber: xsd:string, likeParentSearchName: xsd:string, parentSyncedEntityPrefix: xsd:string, parentExternalKey: xsd:string, parentEstateCategory: xsd:int, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns4:GetAnyEstatesResponse(GetAnyEstatesResult: ns3:ResultTableOfEstate)
#      ns4:GetAnyProjects(context: ns0:CallContext, recno: xsd:int, syncedEntityPrefix: xsd:string, externalKey: xsd:string, ourProjectNumber: xsd:string, generatedProjectName: xsd:string, likeProjectName: xsd:string, isClosed: xsd:boolean, estate: ns0:ConnectTo, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns4:GetAnyProjectsResponse(GetAnyProjectsResult: ns3:ResultTableOfProject)
#      ns4:GetWebserviceVersion()
#      ns4:GetWebserviceVersionDL()
#      ns4:GetWebserviceVersionDLResponse(GetWebserviceVersionDLResult: xsd:string)
#      ns4:GetWebserviceVersionResponse(GetWebserviceVersionResult: xsd:string)
#      ns5:ArrayOfContact2(ns5:ArrayOfContact2)
#      ns5:Company2(ns5:Company2)
#      ns5:Contact2(ns5:Contact2)
#      ns5:ContactPerson2(ns5:ContactPerson2)
#      ns5:CreateCompany2(context: ns0:CallContext, company2: ns5:Company2, contacts: ns0:ArrayOfConnectTo)
#      ns5:CreateCompany2Response(CreateCompany2Result: xsd:int)
#      ns5:CreateContactPerson2(context: ns0:CallContext, contactPerson2: ns5:ContactPerson2, contacts: ns0:ArrayOfConnectTo)
#      ns5:CreateContactPerson2Response(CreateContactPerson2Result: xsd:int)
#      ns5:CreatePrivatePerson2(context: ns0:CallContext, privatePerson2: ns5:PrivatePerson2, contacts: ns0:ArrayOfConnectTo)
#      ns5:CreatePrivatePerson2Response(CreatePrivatePerson2Result: xsd:int)
#      ns5:GetAnyContacts2(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, syncedEntityPrefix: xsd:string, externalKey: xsd:string, isInternal: xsd:boolean, eMail: xsd:string, personNumber: xsd:string, contact: ns0:ConnectTo, forContactContactRole: xsd:int, alwaysIncludeDetails: xsd:boolean, pageOf500: xsd:int)
#      ns5:GetAnyContacts2Response(GetAnyContacts2Result: ns5:ResultTableOfContact2)
#      ns5:GetCompanies2(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, isInternal: xsd:boolean, eMail: xsd:string, personNumber: xsd:string, contact: ns0:ConnectTo, creditorNumber: xsd:string, parentCompany: xsd:int, organisationNumber: xsd:string, pageOf500: xsd:int)
#      ns5:GetCompanies2Response(GetCompanies2Result: ns5:ResultTableOfContact2)
#      ns5:GetContactPersons2(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, isInternal: xsd:boolean, eMail: xsd:string, personNumber: xsd:string, contact: ns0:ConnectTo, employer: xsd:int, pageOf500: xsd:int)
#      ns5:GetContactPersons2Response(GetContactPersons2Result: ns5:ResultTableOfContact2)
#      ns5:GetPrivatePersons2(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, externalKey: xsd:string, isInternal: xsd:boolean, eMail: xsd:string, personNumber: xsd:string, contact: ns0:ConnectTo, personalIdentityNumber: xsd:string, pageOf500: xsd:int)
#      ns5:GetPrivatePersons2Response(GetPrivatePersons2Result: ns5:ResultTableOfContact2)
#      ns5:PrivatePerson2(ns5:PrivatePerson2)
#      ns5:ResultTableOfContact2(ns5:ResultTableOfContact2)
#      ns5:UpdateExCompany2(context: ns0:CallContext, recno: xsd:int, company2: ns5:Company2, contacts: ns0:ArrayOfConnectTo)
#      ns5:UpdateExCompany2Response(UpdateExCompany2Result: xsd:boolean)
#      ns5:UpdateExComplex(context: ns0:CallContext, recno: xsd:int, complex: ns3:Complex, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact)
#      ns5:UpdateExComplexResponse(UpdateExComplexResult: xsd:boolean)
#      ns5:UpdateExContactPerson2(context: ns0:CallContext, recno: xsd:int, contactPerson2: ns5:ContactPerson2, contacts: ns0:ArrayOfConnectTo)
#      ns5:UpdateExContactPerson2Response(UpdateExContactPerson2Result: xsd:boolean)
#      ns5:UpdateExEmployeeCase(context: ns0:CallContext, recno: xsd:int, employeeCase: ns0:EmployeeCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEmployeeCaseDocument(context: ns0:CallContext, recno: xsd:int, employeeCaseDocument: ns3:EmployeeCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEmployeeCaseDocumentResponse(UpdateExEmployeeCaseDocumentResult: xsd:boolean)
#      ns5:UpdateExEmployeeCaseResponse(UpdateExEmployeeCaseResult: xsd:boolean)
#      ns5:UpdateExEmployeeDossier(context: ns0:CallContext, recno: xsd:int, employeeDossier: ns0:EmployeeDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEmployeeDossierDocument(context: ns0:CallContext, recno: xsd:int, employeeDossierDocument: ns3:EmployeeDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEmployeeDossierDocumentResponse(UpdateExEmployeeDossierDocumentResult: xsd:boolean)
#      ns5:UpdateExEmployeeDossierResponse(UpdateExEmployeeDossierResult: xsd:boolean)
#      ns5:UpdateExEstateDossier(context: ns0:CallContext, recno: xsd:int, estateDossier: ns3:EstateDossier, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEstateDossierDocument(context: ns0:CallContext, recno: xsd:int, estateDossierDocument: ns3:EstateDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExEstateDossierDocumentResponse(UpdateExEstateDossierDocumentResult: xsd:boolean)
#      ns5:UpdateExEstateDossierResponse(UpdateExEstateDossierResult: xsd:boolean)
#      ns5:UpdateExGeneralCase(context: ns0:CallContext, recno: xsd:int, generalCase: ns0:GeneralCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExGeneralCaseDocument(context: ns0:CallContext, recno: xsd:int, generalCaseDocumment: ns0:GeneralCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExGeneralCaseDocumentResponse(UpdateExGeneralCaseDocumentResult: xsd:boolean)
#      ns5:UpdateExGeneralCaseResponse(UpdateExGeneralCaseResult: xsd:boolean)
#      ns5:UpdateExInvoiceCase(context: ns0:CallContext, recno: xsd:int, invoiceCase: ns0:InvoiceCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExInvoiceCaseDocument(context: ns0:CallContext, recno: xsd:int, invoiceCaseDocument: ns3:InvoiceCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExInvoiceCaseDocumentResponse(UpdateExInvoiceCaseDocumentResult: xsd:boolean)
#      ns5:UpdateExInvoiceCaseResponse(UpdateExInvoiceCaseResult: xsd:boolean)
#      ns5:UpdateExMainProject(context: ns0:CallContext, recno: xsd:int, mainProject: ns3:MainProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExMainProjectResponse(UpdateExMainProjectResult: xsd:boolean)
#      ns5:UpdateExPrivatePerson2(context: ns0:CallContext, recno: xsd:int, privatePerson2: ns5:PrivatePerson2, contacts: ns0:ArrayOfConnectTo)
#      ns5:UpdateExPrivatePerson2Response(UpdateExPrivatePerson2Result: xsd:boolean)
#      ns5:UpdateExProjectDossier(context: ns0:CallContext, recno: xsd:int, projectDossier: ns3:ProjectDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExProjectDossierDocument(context: ns0:CallContext, recno: xsd:int, projectDossierDocument: ns3:ProjectDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExProjectDossierDocumentResponse(UpdateExProjectDossierDocumentResult: xsd:boolean)
#      ns5:UpdateExProjectDossierResponse(UpdateExProjectDossierResult: xsd:boolean)
#      ns5:UpdateExRentableUnit(context: ns0:CallContext, recno: xsd:int, rentableUnit: ns3:RentableUnit, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact)
#      ns5:UpdateExRentableUnitResponse(UpdateExRentableUnitResult: xsd:boolean)
#      ns5:UpdateExSubProject(context: ns0:CallContext, recno: xsd:int, subProject: ns3:SubProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExSubProjectResponse(UpdateExSubProjectResult: xsd:boolean)
#      ns5:UpdateExTenantDossier(context: ns0:CallContext, recno: xsd:int, tenantDossier: ns0:TenantDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExTenantDossierDocument(context: ns0:CallContext, recno: xsd:int, tenantDossierDocument: ns0:TenantDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo)
#      ns5:UpdateExTenantDossierDocumentResponse(UpdateExTenantDossierDocumentResult: xsd:boolean)
#      ns5:UpdateExTenantDossierResponse(UpdateExTenantDossierResult: xsd:boolean)
#      ns6:GetResponsibleUnitsAndPersonsEx(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, logonName: xsd:string, orgUnitRecno: xsd:int, likeOrgUnitSearchName: xsd:string, onlyDefaultOrgUnit: xsd:boolean, pageOf500: xsd:int)
#      ns6:GetResponsibleUnitsAndPersonsExResponse(GetResponsibleUnitsAndPersonsExResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka)
#      ns7:AddFile(context: ns0:CallContext, docRecno: xsd:int, uploadData: ns0:FileUploadParameters, fileRelationType: xsd:int)
#      ns7:AddFileResponse(AddFileResult: xsd:int)
#      ns7:ArrayOfDocument(ns7:ArrayOfDocument)
#      ns7:ArrayOfDocumentDirectionEx(ns7:ArrayOfDocumentDirectionEx)
#      ns7:ArrayOfSignOffCode(ns7:ArrayOfSignOffCode)
#      ns7:ArrayOfSpecialFilter(ns7:ArrayOfSpecialFilter)
#      ns7:CreateGeneralDocument(context: ns0:CallContext, generalDocument: ns7:GeneralDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo, uploadData: ns0:FileUploadParameters)
#      ns7:CreateGeneralDocumentResponse(CreateGeneralDocumentResult: xsd:int)
#      ns7:Document(ns7:Document)
#      ns7:DocumentDirectionEx(ns7:DocumentDirectionEx)
#      ns7:GeneralDocument(ns7:GeneralDocument)
#      ns7:GetAccessCodesEx(context: ns0:CallContext, recno: xsd:int, forEntityType: ns0:EntityType, forEntitySubType: xsd:int, includeInactive: xsd:boolean)
#      ns7:GetAccessCodesExResponse(GetAccessCodesExResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
#      ns7:GetAccessGroupsEx(context: ns0:CallContext, recno: xsd:int, forEntityType: ns0:EntityType, forEntitySubType: xsd:int, includeInactive: xsd:boolean, pageOf500: xsd:int)
#      ns7:GetAccessGroupsExResponse(GetAccessGroupsExResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka)
# ...
#             GetResponsibleOrgUnits(context: ns0:CallContext) -> GetResponsibleOrgUnitsResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka
#             GetResponsibleOrgUnitsEx(context: ns0:CallContext, forLogonName: xsd:string) -> GetResponsibleOrgUnitsExResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka
#             GetResponsibleOrgUnitsEx2(context: ns0:CallContext, recno: xsd:int, includeInactive: xsd:boolean) -> GetResponsibleOrgUnitsEx2Result: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka
#             GetResponsiblePersons(context: ns0:CallContext, forOrgUnit: xsd:int) -> GetResponsiblePersonsResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka
#             GetResponsibleUnitsAndPersons(context: ns0:CallContext, pageOf500: xsd:int) -> GetResponsibleUnitsAndPersonsResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka
#             GetResponsibleUnitsAndPersonsEx(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, logonName: xsd:string, orgUnitRecno: xsd:int, likeOrgUnitSearchName: xsd:string, onlyDefaultOrgUnit: xsd:boolean, pageOf500: xsd:int) -> GetResponsibleUnitsAndPersonsExResult: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka
#             GetResponsibleUnitsAndPersonsEx2(context: ns0:CallContext, recno: xsd:int, likeSearchName: xsd:string, logonName: xsd:string, orgUnitRecno: xsd:int, likeOrgUnitSearchName: xsd:string, onlyDefaultOrgUnit: xsd:boolean, includeInactive: xsd:boolean, pageOf500: xsd:int) -> GetResponsibleUnitsAndPersonsEx2Result: ns0:ResultTableOfResponsiblePersonJ_SwLf7Ka
#             GetSignOffCodes(context: ns0:CallContext, recno: xsd:int, code: xsd:string, isRepliedCode: xsd:boolean, includeInactive: xsd:boolean) -> GetSignOffCodesResult: ns0:ResultTableOfSignOffCodeadiuXtug
#             GetSpecialFilters(context: ns0:CallContext) -> GetSpecialFiltersResult: ns0:ResultTableOfSpecialFilteradiuXtug
#             GetSubProjects(context: ns0:CallContext, recno: xsd:int, externalKey: xsd:string, ourProjectNumber: xsd:string, generatedProjectName: xsd:string, likeProjectName: xsd:string, isClosed: xsd:boolean, estate: ns0:ConnectTo, parentRecno: xsd:int, parentExternalKey: xsd:string, parentIsSubProject: xsd:boolean, ourParentProjectNumber: xsd:string, generatedParentProjectName: xsd:string, likeParentProjectName: xsd:string, parentIsClosed: xsd:boolean, pageOf500: xsd:int) -> GetSubProjectsResult: ns3:ResultTableOfProject
#             GetSyncedEntityPrefixes(context: ns0:CallContext) -> GetSyncedEntityPrefixesResult: ns0:ResultTableOfCodeTableEntryJ_SwLf7Ka
#             GetTenantDossierDocuments(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, tenantNumber: xsd:string, pageOf500: xsd:int) -> GetTenantDossierDocumentsResult: ns0:ResultTableOfDocumentJ_SwLf7Ka
#             GetTenantDossierDocumentsEx(context: ns0:CallContext, recno: xsd:int, likeTitle: xsd:string, externalKey: xsd:string, documentType: xsd:int, accessCode: xsd:int, archiveCode: xsd:int, contact: ns0:ConnectToContact, caseRecno: xsd:int, caseLikeTitle: xsd:string, caseExternalKey: xsd:string, caseIsClosed: xsd:boolean, tenantNumber: xsd:string, pageOf500: xsd:int) -> GetTenantDossierDocumentsExResult: ns0:ResultTableOfDocumentJ_SwLf7Ka
#             GetTenantDossiers(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, tenantNumber: xsd:string, isClosed: xsd:boolean, pageOf500: xsd:int) -> GetTenantDossiersResult: ns0:ResultTableOfCaseJ_SwLf7Ka
#             GetTenantDossiersEx(context: ns0:CallContext, recno: xsd:int, name: xsd:string, likeTitle: xsd:string, externalKey: xsd:string, rentAgreementNumber: xsd:string, contact: ns0:ConnectToContact, estate: ns0:ConnectTo, isClosed: xsd:boolean, pageOf500: xsd:int) -> GetTenantDossiersExResult: ns3:ResultTableOfCase
#             GetWebserviceVersion() -> GetWebserviceVersionResult: xsd:string
#             NewFileVersion(context: ns0:CallContext, activeFileVersion: xsd:int, uploadData: ns0:FileUploadParameters) -> NewFileVersionResult: xsd:int
#             PurgeCache(context: ns0:CallContext)
#             SignOffDocument(context: ns0:CallContext, document: xsd:int, userOrgUnit: xsd:int, signOffCode: xsd:int, note: xsd:string) ->
#             UpdateCompany(context: ns0:CallContext, recno: xsd:int, company: ns0:Company) -> UpdateCompanyResult: xsd:boolean
#             UpdateCompanyEx(context: ns0:CallContext, recno: xsd:int, companyEx: ns3:CompanyEx) -> UpdateCompanyExResult: xsd:boolean
#             UpdateComplex(context: ns0:CallContext, recno: xsd:int, complex: ns3:Complex) -> UpdateComplexResult: xsd:boolean
#             UpdateContactPerson(context: ns0:CallContext, recno: xsd:int, contactPerson: ns0:ContactPerson) -> UpdateContactPersonResult: xsd:boolean
#             UpdateEmployeeCase(context: ns0:CallContext, recno: xsd:int, employeeCase: ns0:EmployeeCase) -> UpdateEmployeeCaseResult: xsd:boolean
#             UpdateEmployeeCaseDocument(context: ns0:CallContext, recno: xsd:int, employeeCaseDocument: ns3:EmployeeCaseDocument) -> UpdateEmployeeCaseDocumentResult: xsd:boolean
#             UpdateEmployeeDossier(context: ns0:CallContext, recno: xsd:int, employeeDossier: ns0:EmployeeDossier) -> UpdateEmployeeDossierResult: xsd:boolean
#             UpdateEmployeeDossierDocument(context: ns0:CallContext, recno: xsd:int, employeeDossierDocument: ns3:EmployeeDossierDocument) -> UpdateEmployeeDossierDocumentResult: xsd:boolean
#             UpdateEstateDossier(context: ns0:CallContext, recno: xsd:int, estateDossier: ns3:EstateDossier) -> UpdateEstateDossierResult: xsd:boolean
#             UpdateEstateDossierDocument(context: ns0:CallContext, recno: xsd:int, estateDossierDocument: ns3:EstateDossierDocument) -> UpdateEstateDossierDocumentResult: xsd:boolean
#             UpdateExCompany2(context: ns0:CallContext, recno: xsd:int, company2: ns5:Company2, contacts: ns0:ArrayOfConnectTo) -> UpdateExCompany2Result: xsd:boolean
#             UpdateExComplex(context: ns0:CallContext, recno: xsd:int, complex: ns3:Complex, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact) -> UpdateExComplexResult: xsd:boolean
#             UpdateExContactPerson2(context: ns0:CallContext, recno: xsd:int, contactPerson2: ns5:ContactPerson2, contacts: ns0:ArrayOfConnectTo) -> UpdateExContactPerson2Result: xsd:boolean
#             UpdateExEmployeeCase(context: ns0:CallContext, recno: xsd:int, employeeCase: ns0:EmployeeCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeCaseResult: xsd:boolean
#             UpdateExEmployeeCaseDocument(context: ns0:CallContext, recno: xsd:int, employeeCaseDocument: ns3:EmployeeCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeCaseDocumentResult: xsd:boolean
#             UpdateExEmployeeCaseDocument2(context: ns0:CallContext, recno: xsd:int, employeeCaseDocument2: ns9:EmployeeCaseDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeCaseDocument2Result: xsd:boolean
#             UpdateExEmployeeDossier(context: ns0:CallContext, recno: xsd:int, employeeDossier: ns0:EmployeeDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeDossierResult: xsd:boolean
#             UpdateExEmployeeDossierDocument(context: ns0:CallContext, recno: xsd:int, employeeDossierDocument: ns3:EmployeeDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeDossierDocumentResult: xsd:boolean
#             UpdateExEmployeeDossierDocument2(context: ns0:CallContext, recno: xsd:int, employeeDossierDocument2: ns9:EmployeeDossierDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEmployeeDossierDocument2Result: xsd:boolean
#             UpdateExEstateDossier(context: ns0:CallContext, recno: xsd:int, estateDossier: ns3:EstateDossier, estates: ns0:ArrayOfConnectTo) -> UpdateExEstateDossierResult: xsd:boolean
#             UpdateExEstateDossierDocument(context: ns0:CallContext, recno: xsd:int, estateDossierDocument: ns3:EstateDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEstateDossierDocumentResult: xsd:boolean
#             UpdateExEstateDossierDocument2(context: ns0:CallContext, recno: xsd:int, estateDossierDocument2: ns9:EstateDossierDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExEstateDossierDocument2Result: xsd:boolean
#             UpdateExGeneralCase(context: ns0:CallContext, recno: xsd:int, generalCase: ns0:GeneralCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExGeneralCaseResult: xsd:boolean
#             UpdateExGeneralCaseDocument(context: ns0:CallContext, recno: xsd:int, generalCaseDocumment: ns0:GeneralCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExGeneralCaseDocumentResult: xsd:boolean
#             UpdateExGeneralCaseDocument2(context: ns0:CallContext, recno: xsd:int, generalCaseDocument2: ns9:GeneralCaseDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExGeneralCaseDocument2Result: xsd:boolean
#             UpdateExGeneralDocument(context: ns0:CallContext, recno: xsd:int, generalDocumment: ns7:GeneralDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExGeneralDocumentResult: xsd:boolean
#             UpdateExGeneralDocument2(context: ns0:CallContext, recno: xsd:int, generalDocument2: ns9:GeneralDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExGeneralDocument2Result: xsd:boolean
#             UpdateExInvoiceCase(context: ns0:CallContext, recno: xsd:int, invoiceCase: ns0:InvoiceCase, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExInvoiceCaseResult: xsd:boolean
#             UpdateExInvoiceCaseDocument(context: ns0:CallContext, recno: xsd:int, invoiceCaseDocument: ns3:InvoiceCaseDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExInvoiceCaseDocumentResult: xsd:boolean
#             UpdateExInvoiceCaseDocument2(context: ns0:CallContext, recno: xsd:int, invoiceCaseDocument2: ns9:InvoiceCaseDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExInvoiceCaseDocument2Result: xsd:boolean
#             UpdateExMainProject(context: ns0:CallContext, recno: xsd:int, mainProject: ns3:MainProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExMainProjectResult: xsd:boolean
#             UpdateExPrivatePerson2(context: ns0:CallContext, recno: xsd:int, privatePerson2: ns5:PrivatePerson2, contacts: ns0:ArrayOfConnectTo) -> UpdateExPrivatePerson2Result: xsd:boolean
#             UpdateExProjectDossier(context: ns0:CallContext, recno: xsd:int, projectDossier: ns3:ProjectDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExProjectDossierResult: xsd:boolean
#             UpdateExProjectDossierDocument(context: ns0:CallContext, recno: xsd:int, projectDossierDocument: ns3:ProjectDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExProjectDossierDocumentResult: xsd:boolean
#             UpdateExProjectDossierDocument2(context: ns0:CallContext, recno: xsd:int, projectDossierDocument2: ns9:ProjectDossierDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExProjectDossierDocument2Result: xsd:boolean
#             UpdateExRentableUnit(context: ns0:CallContext, recno: xsd:int, rentableUnit: ns3:RentableUnit, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact) -> UpdateExRentableUnitResult: xsd:boolean
#             UpdateExSubProject(context: ns0:CallContext, recno: xsd:int, subProject: ns3:SubProject, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExSubProjectResult: xsd:boolean
#             UpdateExTenantDossier(context: ns0:CallContext, recno: xsd:int, tenantDossier: ns0:TenantDossier, externalContacts: ns0:ArrayOfConnectToContact, internalContacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExTenantDossierResult: xsd:boolean
#             UpdateExTenantDossierDocument(context: ns0:CallContext, recno: xsd:int, tenantDossierDocument: ns0:TenantDossierDocument, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExTenantDossierDocumentResult: xsd:boolean
#             UpdateExTenantDossierDocument2(context: ns0:CallContext, recno: xsd:int, tenantDossierDocument2: ns9:TenantDossierDocument2, contacts: ns0:ArrayOfConnectToContact, estates: ns0:ArrayOfConnectTo) -> UpdateExTenantDossierDocument2Result: xsd:boolean
#             UpdateGeneralCase(context: ns0:CallContext, recno: xsd:int, generalCase: ns0:GeneralCase) -> UpdateGeneralCaseResult: xsd:boolean
#             UpdateGeneralCaseDocument(context: ns0:CallContext, recno: xsd:int, generalCaseDocumment: ns0:GeneralCaseDocument) -> UpdateGeneralCaseDocumentResult: xsd:boolean
#             UpdateInvoiceCase(context: ns0:CallContext, recno: xsd:int, invoiceCase: ns0:InvoiceCase) -> UpdateInvoiceCaseResult: xsd:boolean
#             UpdateInvoiceCaseDocument(context: ns0:CallContext, recno: xsd:int, invoiceCaseDocument: ns3:InvoiceCaseDocument) -> UpdateInvoiceCaseDocumentResult: xsd:boolean
#             UpdateMainProject(context: ns0:CallContext, recno: xsd:int, mainProject: ns3:MainProject) -> UpdateMainProjectResult: xsd:boolean
#             UpdatePrivatePerson(context: ns0:CallContext, recno: xsd:int, privatePerson: ns0:PrivatePerson) -> UpdatePrivatePersonResult: xsd:boolean
#             UpdateProjectDossier(context: ns0:CallContext, recno: xsd:int, projectDossier: ns3:ProjectDossier) -> UpdateProjectDossierResult: xsd:boolean
#             UpdateProjectDossierDocument(context: ns0:CallContext, recno: xsd:int, projectDossierDocument: ns3:ProjectDossierDocument) -> UpdateProjectDossierDocumentResult: xsd:boolean
#             UpdateRentableUnit(context: ns0:CallContext, recno: xsd:int, rentableUnit: ns3:RentableUnit) -> UpdateRentableUnitResult: xsd:boolean
#             UpdateSubProject(context: ns0:CallContext, recno: xsd:int, subProject: ns3:SubProject) -> UpdateSubProjectResult: xsd:boolean
#             UpdateTenantDossier(context: ns0:CallContext, recno: xsd:int, tenantDossier: ns0:TenantDossier) -> UpdateTenantDossierResult: xsd:boolean
#             UpdateTenantDossierDocument(context: ns0:CallContext, recno: xsd:int, tenantDossierDocument: ns0:TenantDossierDocument) -> UpdateTenantDossierDocumentResult: xsd:boolean
#
#      Port: BasicHttpBinding_IDownload (Soap11Binding: {http://ShareWorX.nl/ShareWorXWebService/v1.10}BasicHttpBinding_IDownload)
#          Operations:
#             GetFileVersion(context: ns0:CallContext, recno: xsd:int) -> header: {Extension: xsd:string, FileName: xsd:string}, body: {FileContents: ns13:StreamBody}
#             GetWebserviceVersionDL() -> GetWebserviceVersionDLResult: xsd:string

# %%
#Getting the methods of the webservice
#source: https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
import operator
from zeep import Client

TobiasAX_methods_list = []
wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\Shareworx.v1.11.wsdl"
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            #print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
print(TobiasAX_methods_list)
# Out:
# service : Service
# 208
# ['AddFile', 'CreateCompany', 'CreateCompany2', 'CreateCompanyEx', 'CreateComplex', 'CreateContactPerson', 'CreateContactPerson2', 'CreateEmployeeCase', 'CreateEmployeeCaseDocument', 'CreateEmployeeCaseDocument2', 'CreateEmployeeDossier', 'CreateEmployeeDossierDocument', 'CreateEmployeeDossierDocument2', 'CreateEstateDossier', 'CreateEstateDossierDocument', 'CreateEstateDossierDocument2', 'CreateGeneralCase', 'CreateGeneralCaseDocument', 'CreateGeneralCaseDocument2', 'CreateGeneralDocument', 'CreateGeneralDocument2', 'CreateInvoiceCase', 'CreateInvoiceCaseDocument', 'CreateInvoiceCaseDocument2', 'CreateMainProject', 'CreatePrivatePerson', 'CreatePrivatePerson2', 'CreateProjectDossier', 'CreateProjectDossierDocument', 'CreateProjectDossierDocument2', 'CreateRentableUnit', 'CreateSubProject', 'CreateTenantDossier', 'CreateTenantDossierDocument', 'CreateTenantDossierDocument2', 'DropFolderGateway', 'DropFolderGatewayAlt', 'GetAccessCodes', 'GetAccessCodesEx', 'GetAccessGroups', 'GetAccessGroupsEx', 'GetAnyCases', 'GetAnyCasesEx', 'GetAnyContacts', 'GetAnyContacts2', 'GetAnyContacts2Ex', 'GetAnyDocuments', 'GetAnyDocuments2', 'GetAnyDocumentsEx', 'GetAnyEstates', 'GetAnyProjects', 'GetArchiveCodes', 'GetArchiveCodesEx', 'GetArchiveCodesEx2', 'GetArchiveCodesEx3', 'GetAvailableProcessTemplates', 'GetCaseStatusses', 'GetCaseStatussesEx', 'GetCaseTypes', 'GetCaseTypesEx', 'GetCompanies', 'GetCompanies2', 'GetCompaniesEx', 'GetComplexes', 'GetConnectableContacts', 'GetConnectableDossiers', 'GetConnectableEstates', 'GetConnectableProjects', 'GetContactCaseRoles', 'GetContactCaseRolesEx', 'GetContactContactRoles', 'GetContactContactRolesEx', 'GetContactDocumentRoles', 'GetContactDocumentRolesEx', 'GetContactEstateRoles', 'GetContactEstateRolesEx', 'GetContactGenders', 'GetContactPersons', 'GetContactPersons2', 'GetContactProjectRoles', 'GetContactProjectRolesEx', 'GetContactTypes', 'GetContactsToConnectToContact', 'GetCountries', 'GetDocumentDirections', 'GetDocumentDirectionsEx', 'GetDocumentProfiles', 'GetDocumentProfilesEx', 'GetDocumentProfilesEx2', 'GetDocumentStatusses', 'GetDocumentStatussesEx', 'GetDocumentTypes', 'GetDocumentTypesEx', 'GetDossierCategories', 'GetDossierCategoriesEx', 'GetEmployeeCaseDocuments', 'GetEmployeeCases', 'GetEmployeeDossierDocuments', 'GetEmployeeDossiers', 'GetEstateCaseRoles', 'GetEstateCaseRolesEx', 'GetEstateCategories', 'GetEstateCategoriesEx', 'GetEstateDocumentRoles', 'GetEstateDocumentRolesEx', 'GetEstateDossierDocuments', 'GetEstateDossiers', 'GetEstateProjectRoles', 'GetEstateProjectRolesEx', 'GetEstateStatusses', 'GetEstateStatussesEx', 'GetEstateTypes', 'GetEstateTypesEx', 'GetFileRelationTypes', 'GetFileRelationTypesEx', 'GetFileVersionBuffered', 'GetGeneralCaseDocuments', 'GetGeneralCaseDocumentsEx', 'GetGeneralCases', 'GetGeneralCasesEx', 'GetInvoiceCaseDocuments', 'GetInvoiceCases', 'GetMainProjects', 'GetPrivatePersons', 'GetPrivatePersons2', 'GetProgressTemplates', 'GetProjectDossierDocuments', 'GetProjectDossiers', 'GetProjectStatusses', 'GetProjectStatussesEx', 'GetProjectTypes', 'GetProjectTypesEx', 'GetRecordTypes', 'GetRecordTypesEx', 'GetRentableUnits', 'GetResponsibleOrgUnits', 'GetResponsibleOrgUnitsEx', 'GetResponsibleOrgUnitsEx2', 'GetResponsiblePersons', 'GetResponsibleUnitsAndPersons', 'GetResponsibleUnitsAndPersonsEx', 'GetResponsibleUnitsAndPersonsEx2', 'GetSignOffCodes', 'GetSpecialFilters', 'GetSubProjects', 'GetSyncedEntityPrefixes', 'GetTenantDossierDocuments', 'GetTenantDossierDocumentsEx', 'GetTenantDossiers', 'GetTenantDossiersEx', 'GetWebserviceVersion', 'NewFileVersion', 'PurgeCache', 'SignOffDocument', 'UpdateCompany', 'UpdateCompanyEx', 'UpdateComplex', 'UpdateContactPerson', 'UpdateEmployeeCase', 'UpdateEmployeeCaseDocument', 'UpdateEmployeeDossier', 'UpdateEmployeeDossierDocument', 'UpdateEstateDossier', 'UpdateEstateDossierDocument', 'UpdateExCompany2', 'UpdateExComplex', 'UpdateExContactPerson2', 'UpdateExEmployeeCase', 'UpdateExEmployeeCaseDocument', 'Upd ...

# %% [markdown]
# ### 3.2 Getting the methods of the TobiasAX wsdl

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks'

# %%
cd de_alliantie
# Out:
# C:\Users\31653\Documents\GitHub\Notebooks\de_alliantie

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie'

# %%
import glob
my_wsdls = glob.glob('*.wsdl')
my_wsdls
# Out:
# ['TobiasAX.wsdl']

# %%
#Getting the methods of the webservice
#source: https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
import operator
from zeep import Client

TobiasAX_methods_list = []
wsdl = 'TobiasAX.wsdl'
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            #print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
print(TobiasAX_methods_list)
# Out:
# service : ServiceCustomerPortalAX
# 574
# ['AddServiceRequestComment', 'ApprovePurchWorkflow', 'ArchiveDocument', 'ChangePassword', 'ChangePasswordByTemporaryPassword', 'CheckEworxDMS', 'CheckExistingPersons', 'CreateActivityByEntity', 'CreateAsbestosProject', 'CreateAsbestosSource', 'CreateAsbestosTask', 'CreateCaseContactMomentLine', 'CreateCoRegistrant', 'CreateCoRegistrantIncome', 'CreateContactMoment', 'CreateContactMomentLine', 'CreateContractRentcomponent', 'CreateCorrespondence', 'CreateDocuRefByEntityName', 'CreateDocumentFile', 'CreateDossier', 'CreateDossierLine', 'CreateEquipTransactionByEstateId', 'CreateInspection', 'CreateLocationPreference', 'CreateMandate', 'CreateNotes', 'CreateObjectGroupOption', 'CreateParticipation', 'CreatePaymentScheme', 'CreatePaymentSchemeSax', 'CreatePerson', 'CreatePersonAddress', 'CreatePersonBankAccount', 'CreatePersonCommunication', 'CreatePersonFutureAddressTimeline', 'CreatePersonIncome', 'CreateResidenceAdaptation', 'CreateSeekerRegistration', 'CreateSeekerRegistrationRequirement', 'CreateSeekerRegistrationUrgency', 'CreateServiceRequest', 'CreateServiceSubscription', 'CreateServiceTask', 'CreateSocialComplaint', 'CreateSocialComplaintAction', 'CreateSocialComplaintLogbookEntry', 'CreateUser', 'DPGetActualRentDeposit', 'DPGetContractBalace', 'DPGetExpectedRentDeposit', 'DPGetPerson', 'DPGetRentComponents', 'DPSeekerLogin', 'DPSeekerOptIn', 'DPSeekerRegistration', 'DPSeekerUnregistration', 'DPSetBankAccountDetails', 'DPSetPersonAddress', 'DPSetPersonEmail', 'DPSetPersonPhonenumber', 'DPSyncFeedback', 'DPseekerSubscription', 'DelegatePurchWorkflow', 'DeleteAddress', 'DeleteAddressTimeline', 'DeleteCoRegistrant', 'DeleteCommunication', 'DeleteDocuRef', 'DeleteDossier', 'DeleteDossierLine', 'DeleteHourLines', 'DeleteIncome', 'DeleteLocationPreference', 'DeleteObjectGroupOption', 'DeleteParticipation', 'DeleteSeekerRegistrationRequirement', 'DeleteSeekerRegistrationUrgency', 'DeleteServiceSubscription', 'EndActivity', 'GetAOSName', 'GetAXUserByDomainUser', 'GetActiveContractsByPerson', 'GetActiveDMSList', 'GetActivePublications', 'GetActivitiesByEntity', 'GetActivitiesByResponsibleEmployee', 'GetActivitiesByResponsibleEmployees', 'GetAddressByZipcodeAndHouseNumber', 'GetAllCustomerMandates', 'GetAllCustomerTransactions', 'GetAllPublications', 'GetAttributes', 'GetCoRegistrants', 'GetCollectionInvoiceFirstRent', 'GetContactMoment', 'GetContactMomentsByPerson', 'GetContract', 'GetContractBalance', 'GetContractBalanceHistory', 'GetContractHistoricPrices', 'GetContractPayerById', 'GetContractPayers', 'GetContractPayersByContractDate', 'GetContractPrices', 'GetContractPricesByReferenceDay', 'GetContractPricesFuture', 'GetContractRelations', 'GetContractRentSpecification', 'GetContractsByAddress', 'GetContractsByPersonAndDateRange', 'GetCustDebtSettlementByFileNumber', 'GetCustDebtSettlementsBySearch', 'GetCustomer', 'GetCustomerBalance', 'GetCustomerBalanceHistory', 'GetCustomerBalanceSax', 'GetCustomerCollectionLetters', 'GetCustomerInvoiceMethods', 'GetCustomerPaymentMethods', 'GetCustomerPaymentModes', 'GetCustomerPaymentTerms', 'GetCustomerTransactionSettlements', 'GetDPQueue', 'GetDebtSettlementTransactions', 'GetDebtSettlements', 'GetDecisionTreeByType', 'GetDecisionTreeObject', 'GetDecisionTreePrevious', 'GetDocuRefsByEntityName', 'GetDocuRefsVendInvoice', 'GetDocuUrlVendInvoiceExternalDMS', 'GetDocumentFile', 'GetDocumentFileFromEworxDMS', 'GetDossier', 'GetDossierLines', 'GetDossiers', 'GetEmailByUsername', 'GetEmployee', 'GetEmployees', 'GetEnumItems', 'GetEquipTransactionByEstateId', 'GetEquipmentItems', 'GetExistingPersons', 'GetFileByGuid', 'GetInspectionAppointments', 'GetInspectionPlanProposals', 'GetInspectionsByContract', 'GetInspectionsByDateAndInspector', 'GetInspectors', 'GetInventoryItemGroups', 'GetInventoryItems', 'GetInvoiceReasonCodes', 'GetListItems', 'GetLocationPreferenceOptions', 'GetLocationPreferenceSettings', 'GetLocationPreferences', 'GetMailToPayRequest', 'GetMandateById', 'GetMandateByReference ...

# %%
for operation in operations:
    #print(" method :", operation.name)
    #TobiasAX_methods_list.append(operation.name)
    #print("  input :", operation.input.signature())
    #print(" output :", operation.output.signature())
# Out:
#  output :
#  output : ApprovePurchWorkflowResult: ns4:Purch
#  output :
#  output :
#  output :
#  output : CheckEworxDMSResult: xsd:boolean
#  output : CheckExistingPersonsResult: xsd:int
#  output : CreateActivityByEntityResult: ns5:Activity
#  output : CreateAsbestosProjectResult: xsd:string
#  output : CreateAsbestosSourceResult: xsd:string
#  output : CreateAsbestosTaskResult: xsd:string
#  output : CreateCaseContactMomentLineResult: ns12:Case
#  output : CreateCoRegistrantResult: ns2:CoRegistrant
#  output : CreateCoRegistrantIncomeResult: ns5:Income
#  output : CreateContactMomentResult: ns5:ContactMoment
#  output : CreateContactMomentLineResult: ns5:ContactMomentLine
#  output : CreateContractRentcomponentResult: ns9:Contract
#  output : CreateCorrespondenceResult: ns5:ArrayOfCorrespondenceResult
#  output : CreateDocuRefByEntityNameResult: ns5:DocumentReference
#  output : CreateDocumentFileResult: xsd:string
#  output : CreateDossierResult: ns5:Dossier
#  output : CreateDossierLineResult: ns5:DossierLine
#  output : CreateEquipTransactionByEstateIdResult: xsd:boolean
#  output : CreateInspectionResult: ns18:Inspection
#  output : CreateLocationPreferenceResult: ns2:LocationPreference
#  output : CreateMandateResult: ns11:CustomerDirectDebitMandate
#  output : CreateNotesResult: ns4:VendInvoiceNotes
#  output : CreateObjectGroupOptionResult: ns2:ObjectGroupOption
#  output : CreateParticipationResult: ns2:Participation
#  output :
#  output :
#  output : CreatePersonResult: ns5:Person
#  output : CreatePersonAddressResult: ns5:Address
#  output : CreatePersonBankAccountResult: ns5:BankAccount
#  output : CreatePersonCommunicationResult: ns5:Communication
#  output : CreatePersonFutureAddressTimelineResult: ns5:AddressTimeline
#  output : CreatePersonIncomeResult: ns5:Income
#  output : CreateResidenceAdaptationResult: ns2:ResidenceAdaptation
#  output : CreateSeekerRegistrationResult: ns2:SeekerRegistration
#  output : CreateSeekerRegistrationRequirementResult: ns2:SeekerRegistrationRequirement
#  output : CreateSeekerRegistrationUrgencyResult: ns2:SeekerRegistrationUrgency
#  output : CreateServiceRequestResult: ns10:ServiceRequest
#  output : CreateServiceSubscriptionResult: ns2:ServiceSubscription
#  output : CreateServiceTaskResult: ns10:ServiceTask
#  output : CreateSocialComplaintResult: ns8:SocialComplaint
#  output : CreateSocialComplaintActionResult: ns8:SocialComplaintAction
#  output : CreateSocialComplaintLogbookEntryResult: ns8:SocialComplaintLogbook
#  output : CreateUserResult: ns5:User
#  output : DPGetActualRentDepositResult: xsd:string
#  output : DPGetContractBalaceResult: xsd:string
#  output : DPGetExpectedRentDepositResult: xsd:string
#  output : DPGetPersonResult: xsd:string
#  output : DPGetRentComponentsResult: xsd:string
#  output : DPSeekerLoginResult: xsd:string
#  output : DPSeekerOptInResult: xsd:string
#  output : DPSeekerRegistrationResult: xsd:string
#  output : DPSeekerUnregistrationResult: xsd:string
#  output : DPSetBankAccountDetailsResult: xsd:string
#  output : DPSetPersonAddressResult: xsd:string
#  output : DPSetPersonEmailResult: xsd:string
#  output : DPSetPersonPhonenumberResult: xsd:string
#  output : DPSyncFeedbackResult: xsd:string
#  output : DPseekerSubscriptionResult: xsd:string
#  output : DelegatePurchWorkflowResult: ns4:Purch
#  output :
#  output :
#  output :
#  output :
#  output :
#  output :
#  output :
#  output : DeleteHourLinesResult: ns10:ArrayOfServiceTaskHourLine_ResultObject
#  output :
#  output :
#  output :
#  output :
#  output :
#  output :
#  output :
#  output :
#  output : GetAOSNameResult: xsd:string
#  output : GetAXUserByDomainUserResult: ns5:AXUser
#  output : GetActiveContractsByPersonResult: ns9:ArrayOfContract
#  output : GetActiveDMSListResult: ns16:ArrayOfDMS
#  output : GetActivePublicationsResult: ns2:ArrayOfPublication
#  output : GetActivitiesByEntityResult: ns5:ArrayOfActivity
#  output : GetActivitiesByResponsibleEmployeeResult: ns5:ArrayOfActivity
#  output : GetActivitiesByResponsibleEmployeesResult: ns5:ArrayOfActivity
#  output : GetAddressByZipcodeAndHouseNumberResult: ns5:Address
#  output : GetAllCustomerMandatesResult: ns11:ArrayOfCustomerDirectDebitMandate
#  output : GetAllCustomerTransactionsResult: ns9:ArrayOfCustomerTransaction
#  output : GetAllPublicationsResult: ns2:ArrayOfPublication
#  output : GetAttributesResult: ns5:ArrayOfAttribute
#  output : GetCoRegistrantsResult: ns2:ArrayOfCoRegistrant
#  output : GetCollectionInvoiceFirstRentResult: ns11:CollectionInvoice
#  output : GetContactMomentResult: ns5:ContactMoment
#  output : GetContactMomentsByPersonResult: ns5:ArrayOfContactMoment
#  output : GetContractResult: ns9:Contract
#  output : GetContractBalanceResult: ns9:ArrayOfCustomerBalanceSax
#  output : GetContractBalanceHistoryResult: ns9:ArrayOfCustomerBalanceSax
#  output : GetContractHistoricPricesResult: ns9:ArrayOfContractPrice
#  output : GetContractPayerByIdResult: ns9:ContractPayer
#  output : GetContractPayersResult: ns9:ArrayOfContractPayer
#  output : GetContractPayersByContractDateResult: ns9:ArrayOfContractPayer
#  output : GetContractPricesResult: ns9:ArrayOfContractPrice
#  output : GetContractPricesByReferenceDayResult: ns9:ArrayOfContractPrice
#  output : GetContractPricesFutureResult: ns9:ArrayOfContractPrice
#  output : GetContractRelationsResult: ns9:ArrayOfContractRelation
#  output : GetContractRentSpecificationResult: ns5:ArrayOfCorrespondenceResult
#  output : GetContractsByAddressResult: ns9:ArrayOfContract
#  output : GetContractsByPersonAndDateRangeResult: ns9:ArrayOfContract
#  output : GetCustDebtSettlementByFileNumberResult: ns9:CustDebtSettlement
#  output : GetCustDebtSettlementsBySearchResult: ns9:ArrayOfCustDebtSettlement
#  output : GetCustomerResult: ns9:Customer
#  output : GetCustomerBalanceResult: ns11:ArrayOfCustomerBalance
#  output : GetCustomerBalanceHistoryResult: ns9:ArrayOfCustomerBalanceSax
#  output : GetCustomerBalanceSaxResult: ns9:ArrayOfCustomerBalanceSax
#  output : GetCustomerCollectionLettersResult: ns11:ArrayOfCustomerCollectionLetter
#  output : GetCustomerInvoiceMethodsResult: ns11:ArrayOfInvoiceMethod
#  output : GetCustomerPaymentMethodsResult: ns11:ArrayOfCustomerPaymentMethod
#  output : GetCustomerPaymentModesResult: ns11:ArrayOfCustomerPaymentMode
#  output : GetCustomerPaymentTermsResult: ns11:ArrayOfPaymentTerm
#  output : GetCustomerTransactionSettlementsResult: ns11:ArrayOfCustSettlement
#  output : GetDPQueueResult: ns5:DPQueueResultObject
#  output : GetDebtSettlementTransactionsResult: ns11:ArrayOfDebtSettlementTransaction
#  output : GetDebtSettlementsResult: ns9:ArrayOfCustDebtSettlement
#  output : GetDecisionTreeByTypeResult: ns21:DecisionTree
#  output : GetDecisionTreeObjectResult: ns21:DecisionTree
#  output : GetDecisionTreePreviousResult: ns21:DecisionTree
#  output : GetDocuRefsByEntityNameResult: ns5:ArrayOfDocumentReference
#  output : GetDocuRefsVendInvoiceResult: ns5:ArrayOfDocumentReference
#  output : GetDocuUrlVendInvoiceExternalDMSResult: xsd:string
#  output : GetDocumentFileResult: ns6:StreamBody
#  output : GetDocumentFileFromEworxDMSResult: ns6:StreamBody
#  output : GetDossierResult: ns5:Dossier
#  output : GetDossierLinesResult: ns5:ArrayOfDossierLine
#  output : GetDossiersResult: ns5:ArrayOfDossier
#  output : GetEmailByUsernameResult: xsd:string
#  output : GetEmployeeResult: ns5:Employee
#  output : GetEmployeesResult: ns5:ArrayOfEmployee
#  output : GetEnumItemsResult: ns5:ArrayOfEnumItem
#  output : GetEquipTransactionByEstateIdResult: ns3:ArrayOfEquipmentTransaction
#  output : GetEquipmentItemsResult: ns3:ArrayOfEquipment
#  output : GetExistingPersonsResult: ns5:ArrayOfPerson
#  output : GetFileByGuidResult: ns6:StreamBody
#  output : GetInspectionAppointmentsResult: ns18:ArrayOfInspectionAppointment
#  output : GetInspectionPlanProposalsResult: ns14:ArrayOfPlanProposal
#  output : GetInspectionsByContractResult: ns18:ArrayOfInspection
#  output : GetInspectionsByDateAndInspectorResult: ns18:ArrayOfInspection
#  output : GetInspectorsResult: ns18:ArrayOfInspector
#  output : GetInventoryItemGroupsResult: ns13:ArrayOfInventoryItemGroup
#  output : GetInventoryItemsResult: ns13:ArrayOfInventoryItem
#  output : GetInvoiceReasonCodesResult: ns4:ArrayOfInvoiceReasonCode
#  output : GetListItemsResult: ns5:ArrayOfListItem
#  output : GetLocationPreferenceOptionsResult: ns2:ArrayOfLocationPreferenceOption
#  output : GetLocationPreferenceSettingsResult: ns2:ArrayOfLocationPreferenceSettings
#  output : GetLocationPreferencesResult: ns2:ArrayOfLocationPreference
#  output : GetMailToPayRequestResult: ns20:ArrayOfMailToPayRequestEntity
#  output : GetMandateByIdResult: ns11:CustomerDirectDebitMandate
#  output : GetMandateByReferenceResult: ns11:CustomerDirectDebitMandate
#  output : GetMappedEntitiesResult: ns17:ArrayOfstring
#  output : GetObjectGroupResult: ns2:ObjectGroup
#  output : GetObjectGroupsResult: ns2:ArrayOfObjectGroup
#  output : GetOpenCustomerTransactionsResult: ns9:ArrayOfCustomerTransaction
#  output : GetParticipationsResult: ns2:ArrayOfParticipation
#  output : GetPayerPaymentDetailsResult: ns11:ArrayOfCustomerPaymentDetail
#  output : GetPaymentSchemeLatestResult: ns9:PaymentScheme
#  output : GetPaymentSchemesByRangeResult: ns9:ArrayOfPaymentScheme
#  output : GetPaymentSchemesByStatusResult: ns9:ArrayOfPaymentScheme
#  output : GetPersonResult: ns5:Person
#  output : GetPersonBankAccountByIBANResult: ns5:BankAccount
#  output : GetPersonBankAccountByIdResult: ns5:BankAccount
#  output : GetPersonByLoginResult: ns5:Person
#  output : GetPersonFutureAddressTimelinesResult: ns5:ArrayOfAddressTimeline
#  output : GetPersonsResult: ns5:ArrayOfPerson
#  output : GetPlanProposalsResult: ns14:ArrayOfPlanProposal
#  output : GetPropertyScoringResult: ns3:PropertyScoring
#  output : GetPropertySearchResult: ns3:ArrayOfPropertySearchResult
#  output : GetPropertySeekerByPersonIdResult: ns2:PropertySeeker
#  output : GetPropertyValuationsResult: ns3:ArrayOfPropertyValuation
#  output : GetPublicationResult: ns2:Publication
#  output : GetPublicationsResult: ns2:ArrayOfPublication
#  output : GetPurchLinesResult: ns4:ArrayOfPurchLine
#  output : GetPurchOrderForApprovalResult: ns4:ArrayOfPurch
#  output : GetPurchWorkflowInfoResult: ns4:ArrayOfWorkflowInfo
#  output : GetRealEstateContactPersonsResult: ns5:ArrayOfContactPerson
#  output : GetRealEstateEquipmentResult: ns3:ArrayOfEquipment
#  output : GetRealEstateObjectResult: ns9:RealEstateObject
#  output : GetRealEstateObjectPhotosResult: ns5:ArrayOfDocumentReference
#  output : GetRealEstateObjectPricesResult: ns9:ArrayOfRealEstateObjectPrice
#  output : GetRealEstateObjectPricesFutureResult: ns9:ArrayOfRealEstateObjectPrice
#  output : GetRealEstateObjectRelationsResult: ns3:ArrayOfRealEstateObjectRelation
#  output : GetRelatedServiceObjectsResult: ns10:ArrayOfServiceObject
#  output : GetRentalServicesResult: ns2:ArrayOfService
#  output : GetResindenceAdaptationsByContractResult: ns2:ArrayOfResidenceAdaptation
#  output : GetSeekerRegistrationResult: ns2:SeekerRegistration
#  output : GetSeekerRegistrationRequirementsResult: ns2:ArrayOfSeekerRegistrationRequirement
#  output : GetSeekerRegistrationUrgenciesResult: ns2:ArrayOfSeekerRegistrationUrgency
#  output : GetSeekerRegistrationsResult: ns2:ArrayOfSeekerRegistration
#  output : GetServerNameResult: xsd:string
#  output : GetServiceObjectByRoutingResult: ns10:ServiceObject
#  output : GetServiceObjectsByAddressResult: ns10:ArrayOfServiceObject
#  output : GetServiceObjectsByContractIdResult: ns10:ArrayOfServiceObject
#  output : GetServiceObjectsByRentalObjectIdResult: ns10:ArrayOfServiceObject
#  output : GetServiceRequestResult: ns10:ServiceRequest
#  output : GetServiceRequestsByServiceObjectIdResult: ns10:ArrayOfServiceRequest
#  output : GetServiceTaskResult: ns10:ServiceTask
#  output : GetServiceTasksByServiceObjectActionCodeResult: ns10:ArrayOfServiceTask
#  output : GetServiceTasksByServiceObjectIdResult: ns10:ArrayOfServiceTask
#  output : GetSocialComplaintResult: ns8:SocialComplaint
#  output : GetSocialComplaintByPersonResult: ns8:ArrayOfSocialComplaintRelation
#  output : GetSocialComplaintByResponsiblePersonResult: ns8:ArrayOfSocialComplaint
#  output : GetSocialComplaintRelationsByPersonResult: ns8:ArrayOfSocialComplaintRelation
#  output : GetStandardWorkResult: ns10:StandardWork
#  output : GetStatusLogResult: ns10:ArrayOfStatusLog
#  output : GetSupervisorProjectResult: ns15:ArrayOfSVProject
#  output : GetSystemInformationResult: ns5:SystemInformation
#  output : GetTemporaryPasswordResult: xsd:string
#  output : GetUserByEmailResult: ns5:User
#  output : GetUserByPersonIdResult: ns5:User
#  output : GetUsernameByEmailResult: xsd:string
#  output : GetVendInvoiceNotesResult: ns4:ArrayOfVendInvoiceNotes
#  output : GetVendInvoiceSpecExpensesResult: ns4:ArrayOfVendSpecExpenses
#  output : GetVendInvoiceSpecLedgersResult: ns4:ArrayOfVendSpecLedger
#  output : GetVendInvoiceSpecPurchaseOrdersResult: ns4:ArrayOfVendSpecPurch
#  output : GetVendInvoicesResult: ns4:ArrayOfVendInvoice
#  output : GetVendorResult: ns5:Vendor
#  output : GetVersionResult: xsd:string
#  output : GetWrkCtrPlanProposalsResult: ns14:ArrayOfPlanProposal
#  output :
#  output : PostPurchLinesByServiceCallResult: ns10:ArrayOfServiceTask_ResultObject
#  output : ProcessDecisionTreeResult: ns21:DecisionTree
#  output : RegisterActivityHourLinesResult: ns10:ArrayOfServiceHourTransaction_ResultObject
#  output : RescheduleServiceTaskResult: xsd:boolean
#  output : ResubmitPurchWorkflowResult: ns4:Purch
#  output : ReturnPurchWorkflowResult: ns4:Purch
#  output : RoutingInvoiceActionResult: ns4:VendInvoice
#  output : RoutingInvoiceToEmplResult: ns4:VendInvoice
#  output : ServiceTaskCancelResult: xsd:boolean
#  output : ServiceTaskRegisterHoursResult: xsd:boolean
#  output : ServiceTaskRegisterIndirectHoursResult: xsd:boolean
#  output : ServiceTaskRegisterItemsResult: xsd:boolean
#  output : ServiceTaskReportBackResult: xsd:boolean
#  output : ServiceTaskScheduledResult: xsd:boolean
#  output : ServiceTaskStartTaskResult: xsd:boolean
#  output : ServiceTaskUnscheduledResult: xsd:boolean
#  output :
#  output :
#  output : SetContractStatusToActiveResult: ns9:Contract
#  output : SetContractStatusToCessationResult: ns9:Contract
#  output :
#  output :
#  output :
#  output : SignDirectDebitMandateResult: ns11:CustomerDirectDebitMandate
#  output : UpdateAddressResult: ns5:Address
#  output :
#  output :
#  output :
#  output : UpdateAttributeResult: ns5:Attribute
#  output : UpdateCoRegistrantResult: ns2:CoRegistrant
#  output : UpdateCommunicationResult: ns5:Communication
#  output : UpdateContactMomentResult: ns5:ContactMoment
#  output : UpdateContractPayerResult: ns9:ContractPayer
#  output :
#  output : UpdateDocuRefResult: ns5:DocumentReference
#  output : UpdateDossierResult: ns5:Dossier
#  output : UpdateDossierLineResult: ns5:DossierLine
#  output : UpdateIncomeResult: ns5:Income
#  output : UpdateInspectionResult: ns18:Inspection
#  output : UpdateLocationPreferenceResult: ns2:LocationPreference
#  output :
#  output : UpdateParticipationResult: ns2:Participation
#  output : UpdatePayerPaymentDetailsResult: ns9:ContractPayer
#  output :
#  output : UpdatePersonResult: ns5:Person
#  output : UpdatePersonBankAccountResult: ns5:BankAccount
#  output : UpdatePropertySeekerResult: ns2:PropertySeeker
#  output : UpdateSVProjectResult: ns15:SVProjectUpdate
#  output : UpdateSVTermResult: ns15:SVTermUpdate
#  output : UpdateSeekerRegistrationResult: ns2:SeekerRegistration
#  output : UpdateSeekerRegistrationRequirementResult: ns2:SeekerRegistrationRequirement
#  output : UpdateSeekerRegistrationUrgencyResult: ns2:SeekerRegistrationUrgency
#  output : UpdateServiceSubscriptionResult: ns2:ServiceSubscription
#  output : UpdateUserResult: ns5:User
#  output : ValidateCredentialsResult: ns5:ValidationResult
#  output : serviceTaskRegisterHourLinesResult: ns10:ArrayOfServiceHourTransaction_ResultObject
#  output : serviceTaskRegisterItemLinesResult: ns13:ArrayOfInventoryItemTransaction_ResultObject

# %%
client.namespaces
# Out:
# {'xsd': 'http://www.w3.org/2001/XMLSchema',
#  'ns0': 'http://www.SG.nl/services/20121122/CustomerPortalAX',
#  'ns1': 'http://schemas.microsoft.com/2003/10/Serialization/',
#  'ns2': 'http://schemas.datacontract.org/2004/07/SG.Models.Rentals',
#  'ns3': 'http://schemas.datacontract.org/2004/07/SG.Models.RealEstate',
#  'ns4': 'http://schemas.datacontract.org/2004/07/SG.Models.Vendors',
#  'ns5': 'http://schemas.datacontract.org/2004/07/SG.Models.Global',
#  'ns6': 'http://schemas.microsoft.com/Message',
#  'ns7': 'http://schemas.datacontract.org/2004/07/SG.Models.Asbestos',
#  'ns8': 'http://schemas.datacontract.org/2004/07/SG.Models.Livability',
#  'ns9': 'http://schemas.datacontract.org/2004/07/SG.Models.Contracts',
#  'ns10': 'http://schemas.datacontract.org/2004/07/SG.Models.Maintenance',
#  'ns11': 'http://schemas.datacontract.org/2004/07/SG.Models.Customers',
#  'ns12': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.CRM',
#  'ns13': 'http://schemas.datacontract.org/2004/07/SG.Models.Inventory',
#  'ns14': 'http://schemas.datacontract.org/2004/07/SG.Models.Maintenance.ExternalPlanboard',
#  'ns15': 'http://schemas.datacontract.org/2004/07/SG.Models.Projects',
#  'ns16': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.DMS',
#  'ns17': 'http://schemas.microsoft.com/2003/10/Serialization/Arrays',
#  'ns18': 'http://schemas.datacontract.org/2004/07/SG.Models.Inspections',
#  'ns19': 'http://schemas.datacontract.org/2004/07/SG.Models.MailToPay',
#  'ns20': 'http://schemas.datacontract.org/2004/07/SG.Models.MailTopay',
#  'ns21': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.DecisionTree'}

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_default_port_name',
#  '_default_service',
#  '_default_service_name',
#  '_default_soapheaders',
#  '_default_transport',
#  '_get_port',
#  '_get_service',
#  'bind',
#  'create_message',
#  'create_service',
#  'get_element',
#  'get_type',
#  'namespaces',
#  'plugins',
#  'service',
#  'set_default_soapheaders',
#  'set_ns_prefix',
#  'settings',
#  'transport',
#  'type_factory',
#  'wsdl',
#  'wsse']

# %%
dir(client.type_factory)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
service.resolve
# Out:
# <bound method Service.resolve of <Service(name='ServiceCustomerPortalAX', ports=OrderedDict([('soap', <Port(name='soap', binding=<Soap12Binding(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}soap', port_type=<PortType(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX')>)>, {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/'})>), ('basicHttpBinding', <Port(name='basicHttpBinding', binding=<Soap11Binding(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}basicHttpBinding', port_type=<PortType(name='{http://www.SG.nl/services/20121122/CustomerPortalAX}IServiceCustomerPortalAX')>)>, {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/basic'})>)]))>>

# %%
port.binding_options
# Out:
# {'address': 'http://serviceax-ontwikkel.de-alliantie.nl/basic'}

# %%
dir(operation)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'abstract',
#  'binding',
#  'create',
#  'faults',
#  'input',
#  'name',
#  'nsmap',
#  'output',
#  'parse',
#  'process_reply',
#  'resolve',
#  'soapaction',
#  'style']

# %%
#source: https://stackoverflow.com/questions/44885439/parse-wsdl-with-zeep
#client= Client('url_to_wsdl')
for service in client.wsdl.services.values():
    for port in service.ports.values():
        operations = sorted(
        port.binding._operations.values(),
        key=operator.attrgetter('name'))

        for operation in operations:
            try:
                #print(operation.name)
                node = client.create_message(client.service, operation.name)
                print(node)
            except:
                pass
# Out:
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767f0c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fd40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757ce00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757ce00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cfc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098757cf80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fd40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f4ac0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876b0540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987668a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098766a880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876ac180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876ace80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987644480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646ac0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987542700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6ec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654300>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876549c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876544c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767eb80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ef00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767eb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f4500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767eb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fe80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fe80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f0c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876548c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876548c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f380>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f380>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f4500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767eb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e680>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e200>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e680>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ed00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876c96c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874e43c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f05c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874c9040>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f05c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654ac0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767c800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767c800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875a0f00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876817c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681cc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681cc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876540c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876901c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876901c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876904c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876904c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690240>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690240>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a53c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690900>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690900>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690240>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f05c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876901c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876901c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876908c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876818c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876818c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681cc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681900>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874e43c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874c3540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987507bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b6d80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f4500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987460dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b6d80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f4500>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876544c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa3c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fe80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fe80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fc80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876770c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769f780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ef00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e200>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ec80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ef00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098769fb00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646ac0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ef00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874e43c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767ef00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876c96c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767e280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987646a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876544c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876b0ec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876b0ec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987507bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876b0ec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767c700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b4bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876b0ec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681980>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876819c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876817c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876812c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681900>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681480>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a50c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681600>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20986796800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa5c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767f4c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20986796800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aacc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a53c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aaa80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a53c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20986796800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876a5080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876901c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690b40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690dc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690f40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690400>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876908c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690080>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690d40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681100>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681ac0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987690840>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677240>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677240>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677340>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677740>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677440>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876778c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987677d80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20986796800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987537940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767f4c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987537940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6f80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767fec0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987542700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987542700>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aab00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209875f6180>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aab00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b6d80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b4bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aab00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b4bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aab00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874b6d80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa3c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987670280>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874c3540>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876707c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876aa3c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767c800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654880>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209874e43c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x2098767c800>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876c92c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987668940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654640>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654c00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654bc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654a40>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987668940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681cc0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681a80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987654580>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681780>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x209876817c0>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681e00>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681c80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681940>
# <Element {http://www.w3.org/2003/05/soap-envelope}Envelope at 0x20987681b80>

# %%
client.namespaces
# Out:
# {'xsd': 'http://www.w3.org/2001/XMLSchema',
#  'ns0': 'http://www.SG.nl/services/20121122/CustomerPortalAX',
#  'ns1': 'http://schemas.microsoft.com/2003/10/Serialization/',
#  'ns2': 'http://schemas.datacontract.org/2004/07/SG.Models.Rentals',
#  'ns3': 'http://schemas.datacontract.org/2004/07/SG.Models.RealEstate',
#  'ns4': 'http://schemas.datacontract.org/2004/07/SG.Models.Vendors',
#  'ns5': 'http://schemas.datacontract.org/2004/07/SG.Models.Global',
#  'ns6': 'http://schemas.microsoft.com/Message',
#  'ns7': 'http://schemas.datacontract.org/2004/07/SG.Models.Asbestos',
#  'ns8': 'http://schemas.datacontract.org/2004/07/SG.Models.Livability',
#  'ns9': 'http://schemas.datacontract.org/2004/07/SG.Models.Contracts',
#  'ns10': 'http://schemas.datacontract.org/2004/07/SG.Models.Maintenance',
#  'ns11': 'http://schemas.datacontract.org/2004/07/SG.Models.Customers',
#  'ns12': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.CRM',
#  'ns13': 'http://schemas.datacontract.org/2004/07/SG.Models.Inventory',
#  'ns14': 'http://schemas.datacontract.org/2004/07/SG.Models.Maintenance.ExternalPlanboard',
#  'ns15': 'http://schemas.datacontract.org/2004/07/SG.Models.Projects',
#  'ns16': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.DMS',
#  'ns17': 'http://schemas.microsoft.com/2003/10/Serialization/Arrays',
#  'ns18': 'http://schemas.datacontract.org/2004/07/SG.Models.Inspections',
#  'ns19': 'http://schemas.datacontract.org/2004/07/SG.Models.MailToPay',
#  'ns20': 'http://schemas.datacontract.org/2004/07/SG.Models.MailTopay',
#  'ns21': 'http://schemas.datacontract.org/2004/07/SG.Models.Global.DecisionTree'}

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_default_port_name',
#  '_default_service',
#  '_default_service_name',
#  '_default_soapheaders',
#  '_default_transport',
#  '_get_port',
#  '_get_service',
#  'bind',
#  'create_message',
#  'create_service',
#  'get_element',
#  'get_type',
#  'namespaces',
#  'plugins',
#  'service',
#  'set_default_soapheaders',
#  'set_ns_prefix',
#  'settings',
#  'transport',
#  'type_factory',
#  'wsdl',
#  'wsse']

# %%
dir(client.wsdl.types)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_create_prefix_map',
#  '_create_qname',
#  '_get_instance',
#  '_get_schema_documents',
#  '_load_default_documents',
#  '_prefix_map_auto',
#  '_prefix_map_custom',
#  '_transport',
#  'add_document_by_url',
#  'add_documents',
#  'create_new_document',
#  'deserialize',
#  'documents',
#  'elements',
#  'get_attribute',
#  'get_attribute_group',
#  'get_element',
#  'get_group',
#  'get_ns_prefix',
#  'get_shorthand_for_ns',
#  'get_type',
#  'is_empty',
#  'merge',
#  'namespaces',
#  'prefix_map',
#  'root_document',
#  'set_ns_prefix',
#  'settings',
#  'types']

# %%
client.wsdl.types.deserialize
# Out:
# <bound method Schema.deserialize of <Schema(location='C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\TobiasAX.wsdl', tns='http://www.SG.nl/services/20121122/CustomerPortalAX')>>

# %% [markdown]
# ### 3.3 Woningnet wsdl (ax-woninnet.wsdl)

# %%
# !python -mzeep "C:\Users\31653\Desktop\DeAlliantie\wsdl\ObjectISService_ep_1.wsdl"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\31653\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\31653\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\__main__.py", line 92, in <module>
#     main(args)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\__main__.py", line 81, in main
#     client = Client(args.wsdl_file, transport=transport, settings=settings)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\client.py", line 73, in __init__
#     self.wsdl = Document(wsdl, self.transport, settings=self.settings)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py", line 92, in __init__
#     self.load(location)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py", line 97, in load
#     root_definitions = Definition(self, document, self.location)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py", line 193, in __init__
#     self._load(doc)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py", line 198, in _load
#     self.parse_types(doc)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py", line 330, in parse_types
#     self.types.add_documents(schema_nodes, self.location)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\schema.py", line 111, in add_documents
#     document = self.create_new_document(node, location)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\schema.py", line 195, in create_new_document
#     schema.load(self, node)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\schema.py", line 421, in load
#     visitor.visit_schema(node)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\visitor.py", line 165, in visit_schema
#     self.process(child, parent=node)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\visitor.py", line 93, in process
#     result = visit_func(self, node, parent)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\visitor.py", line 238, in visit_import
#     schema_node = self._retrieve_data(location, base_url=self.document._location)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\xsd\visitor.py", line 1198, in _retrieve_data
#     return load_external(
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\loader.py", line 79, in load_external
#     content = transport.load(url)
#   File "C:\Users\31653\anaconda3\lib\site-packages\zeep\transports.py", line 129, in load
#     with open(os.path.expanduser(url), "rb") as fh:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\ObjectISService_ep.xsd'

# %%
import operator
from zeep import Client

TobiasAX_methods_list = []
wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\ax-woningnet.wsdl"
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            #print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
print(TobiasAX_methods_list)
# Out:
# service : ax-woningnet
# 3
# ['kandidaatOphalen', 'leegmelden', 'objectAfmelden']

# %%
# Three others
import operator
from zeep import Client

TobiasAX_methods_list = []
#wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\AanbiedingISService_ep_1.wsdl"
wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\ObjectISService_ep_1.wsdl"
#wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\PublicatieISService_ep_1.wsdl"

client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            #print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
print(TobiasAX_methods_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13904/1527668951.py in <module>
#       8 #wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\PublicatieISService_ep_1.wsdl"
#       9
# ---> 10 client = Client(wsdl=wsdl)
#      11 for service in client.wsdl.services.values():
#      12     print("service :", service.name)
#
# ~\anaconda3\lib\site-packages\zeep\client.py in __init__(self, wsdl, wsse, transport, service_name, port_name, plugins, settings)
#      71             transport if transport is not None else self._default_transport()
#      72         )
# ---> 73         self.wsdl = Document(wsdl, self.transport, settings=self.settings)
#      74         self.wsse = wsse
#      75         self.plugins = plugins if plugins is not None else []
#
# ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py in __init__(self, location, transport, base, settings)
#      90             settings=self.settings,
#      91         )
# ---> 92         self.load(location)
#      93
#      94     def load(self, location):
#
# ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py in load(self, location)
#      95         document = self._get_xml_document(location)
#      96
# ---> 97         root_definitions = Definition(self, document, self.location)
#      98         root_definitions.resolve_imports()
#      99
#
# ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py in __init__(self, wsdl, doc, location)
#     191         self.wsdl._add_definition(self)
#     192         self.nsmap = doc.nsmap
# --> 193         self._load(doc)
#     194
#     195     def _load(self, doc):
#
# ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py in _load(self, doc)
#     196         self.parse_imports(doc)
#     197
# --> 198         self.parse_types(doc)
#     199         self.messages = self.parse_messages(doc)
#     200         self.port_types = self.parse_ports(doc)
#
# ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py in parse_types(self, doc)
#     328         # Find xsd:schema elements (wsdl:types/xsd:schema)
#     329         schema_nodes = findall_multiple_ns(doc, "wsdl:types/xsd:schema", namespace_sets)
# --> 330         self.types.add_documents(schema_nodes, self.location)
#     331
#     332     def parse_messages(self, doc: etree._Element):
#
# ~\anaconda3\lib\site-packages\zeep\xsd\schema.py in add_documents(self, schema_nodes, location)
#     109         resolve_queue = []
#     110         for node in schema_nodes:
# --> 111             document = self.create_new_document(node, location)
#     112             resolve_queue.append(document)
#     113
#
# ~\anaconda3\lib\site-packages\zeep\xsd\schema.py in create_new_document(self, node, url, base_url, target_namespace)
#     193         schema = SchemaDocument(namespace, url, base_url)
#     194         self.documents.add(schema)
# --> 195         schema.load(self, node)
#     196         return schema
#     197
#
# ~\anaconda3\lib\site-packages\zeep\xsd\schema.py in load(self, schema, node)
#     419         #     self.xml_schema = etree.XMLSchema(node)
#     420         visitor = SchemaVisitor(schema, self)
# --> 421         visitor.visit_schema(node)
#     422
#     423     def resolve(self):
#
# ~\anaconda3\lib\site-packages\zeep\xsd\visitor.py in visit_schema(self, node)
#     163
#     164         for child in node:
# --> 165             self.process(child, parent=node)
#     166
#     167     def visit_import(self, node, parent):
#
# ~\anaconda3\lib\site-packages\zeep\xsd\visitor.py in process(self, node, parent)
#      91         if not visit_func:
#      92             raise ValueError("No visitor defined for %r" % node.tag)
# ---> 93         result = visit_func(self, node, parent)
#      94         return result
#      95
#
# ~\anaconda3\lib\site-packages\zeep\xsd\visitor.py in visit_import(self, node, parent)
#     236
#     237         # Load the XML
# --> 238         schema_node = self._retrieve_data(location, base_url=self.document._location)
#     239
#     240         # Check if the xsd:import namespace matches the targetNamespace. If
#
# ~\anaconda3\lib\site-packages\zeep\xsd\visitor.py in _retrieve_data(self, url, base_url)
#    1196
#    1197     def _retrieve_data(self, url: typing.IO, base_url=None):
# -> 1198         return load_external(
#    1199             url, self.schema._transport, base_url, settings=self.schema.settings
#    1200         )
#
# ~\anaconda3\lib\site-packages\zeep\loader.py in load_external(url, transport, base_url, settings)
#      77         if base_url:
#      78             url = absolute_location(url, base_url)
# ---> 79         content = transport.load(url)
#      80     return parse_xml(content, transport, base_url, settings=settings)
#      81
#
# ~\anaconda3\lib\site-packages\zeep\transports.py in load(self, url)
#     127             return content
#     128         else:
# --> 129             with open(os.path.expanduser(url), "rb") as fh:
#     130                 return fh.read()
#     131
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\31653\\Desktop\\DeAlliantie\\wsdl\\ObjectISService_ep.xsd'

# %% [markdown]
# ### 3.4 Corporatieportaal wsdl

# %%
# !python -mzeep "C:\Users\31653\Desktop\DeAlliantie\Corporatieportaal.wsdl"
# Out:
# Prefixes:
#      xsd: http://www.w3.org/2001/XMLSchema
#      ns0: http://tempuri.org/
#      ns1: http://schemas.microsoft.com/2003/10/Serialization/
#      ns2: http://schemas.microsoft.com/Message
#      ns3: http://schemas.datacontract.org/2004/07/OntObjServ
#
# Global elements:
#      ns3:CPReturnObject(ns3:CPReturnObject)
#      ns3:KeuringsError(ns3:KeuringsError)
#      ns1:QName(xsd:QName)
#      ns1:anyType(None)
#      ns1:anyURI(xsd:anyURI)
#      ns1:base64Binary(xsd:base64Binary)
#      ns1:boolean(xsd:boolean)
#      ns1:byte(xsd:byte)
#      ns1:char(ns1:char)
#      ns1:dateTime(xsd:dateTime)
#      ns1:decimal(xsd:decimal)
#      ns1:double(xsd:double)
#      ns1:duration(ns1:duration)
#      ns1:float(xsd:float)
#      ns1:guid(ns1:guid)
#      ns1:int(xsd:int)
#      ns1:long(xsd:long)
#      ns1:short(xsd:short)
#      ns1:string(xsd:string)
#      ns1:unsignedByte(xsd:unsignedByte)
#      ns1:unsignedInt(xsd:unsignedInt)
#      ns1:unsignedLong(xsd:unsignedLong)
#      ns1:unsignedShort(xsd:unsignedShort)
#      ns0:AddBuurt(xel: {_value_1: ANY})
#      ns0:AddBuurtResponse(AddBuurtResult: ns3:CPReturnObject)
#      ns0:AddComplex(xel: {_value_1: ANY})
#      ns0:AddComplexResponse(AddComplexResult: ns3:CPReturnObject)
#      ns0:AddDossier(xel: {_value_1: ANY})
#      ns0:AddDossierResponse(AddDossierResult: ns3:CPReturnObject)
#      ns0:AddKeuringsdatum(klantnummer: xsd:string, dossierid: xsd:int, keuringsdatum: xsd:dateTime)
#      ns0:AddKeuringsdatumResponse(AddKeuringsdatumResult: ns3:KeuringsError)
#      ns0:AddObject(xel: {_value_1: ANY})
#      ns0:AddObjectResponse(AddObjectResult: ns3:CPReturnObject)
#      ns0:AddPlandatumKeuringsopdracht(klantnummer: xsd:string, dossierid: xsd:int, plandatum: xsd:dateTime)
#      ns0:AddPlandatumKeuringsopdrachtResponse(AddPlandatumKeuringsopdrachtResult: ns3:KeuringsError)
#      ns0:AddWijk(xel: {_value_1: ANY})
#      ns0:AddWijkResponse(AddWijkResult: ns3:CPReturnObject)
#      ns0:GetBuurten(regioID: xsd:int)
#      ns0:GetBuurtenResponse(GetBuurtenResult: xsd:string)
#      ns0:GetComplexen()
#      ns0:GetComplexenResponse(GetComplexenResult: xsd:string)
#      ns0:GetCorporatieNaam()
#      ns0:GetCorporatieNaamResponse(GetCorporatieNaamResult: xsd:string)
#      ns0:GetFile(filename: xsd:string)
#      ns0:GetFileMtom(filename: xsd:string)
#      ns0:GetFileMtomResponse(GetFileMtomResult: ns2:StreamBody)
#      ns0:GetFileResponse(GetFileResult: ns2:StreamBody)
#      ns0:GetKeuringsOpdrachten()
#      ns0:GetKeuringsOpdrachtenResponse(GetKeuringsOpdrachtenResult: xsd:string)
#      ns0:GetObject(perceelNummer: xsd:string)
#      ns0:GetObjectResponse(GetObjectResult: {_value_1: ANY})
#      ns0:GetObjectTypen()
#      ns0:GetObjectTypenResponse(GetObjectTypenResult: xsd:string)
#      ns0:GetObjecten()
#      ns0:GetObjectenResponse(GetObjectenResult: {_value_1: ANY})
#      ns0:GetRegios()
#      ns0:GetRegiosResponse(GetRegiosResult: xsd:string)
#      ns0:GetWijken(regioID: xsd:int)
#      ns0:GetWijkenResponse(GetWijkenResult: xsd:string)
#      ns0:KeuringsRapport(documentinhoud: ns2:StreamBody)
#      ns0:OntSluitenObjectenVbi(inclusiefPub: xsd:boolean, inclusiefHuur: xsd:boolean)
#      ns0:OntSluitenObjectenVbiResponse(OntSluitenObjectenVbiResult: {_value_1: ANY})
#      ns0:OntsluitObjecten()
#      ns0:OntsluitObjectenInclHuur(inclusiefHuur: xsd:boolean)
#      ns0:OntsluitObjectenInclHuurResponse(OntsluitObjectenInclHuurResult: {_value_1: ANY})
#      ns0:OntsluitObjectenResponse(OntsluitObjectenResult: {_value_1: ANY})
#      ns0:UpdateObject(xel: {_value_1: ANY})
#      ns0:UpdateObjectResponse(UpdateObjectResult: ns3:CPReturnObject)
#      ns0:Welkom(msg: xsd:string)
#      ns0:WelkomResponse(WelkomResult: xsd:string)
#      ns0:documentType(xsd:int)
#      ns0:documentnaam(xsd:string)
#      ns0:dossierId(xsd:int)
#
#
# Global types:
#      xsd:anyType
#      ns3:CPReturnObject(fout: xsd:string, objectID: xsd:int)
#      ns3:KeuringsError
#      ns1:char
#      ns1:duration
#      ns1:guid
#      ns2:StreamBody
#      xsd:ENTITIES
#      xsd:ENTITY
#      xsd:ID
#      xsd:IDREF
#      xsd:IDREFS
#      xsd:NCName
#      xsd:NMTOKEN
#      xsd:NMTOKENS
#      xsd:NOTATION
#      xsd:Name
#      xsd:QName
#      xsd:anySimpleType
#      xsd:anyURI
#      xsd:base64Binary
#      xsd:boolean
#      xsd:byte
#      xsd:date
#      xsd:dateTime
#      xsd:decimal
#      xsd:double
#      xsd:duration
#      xsd:float
#      xsd:gDay
#      xsd:gMonth
#      xsd:gMonthDay
#      xsd:gYear
#      xsd:gYearMonth
#      xsd:hexBinary
#      xsd:int
#      xsd:integer
#      xsd:language
#      xsd:long
#      xsd:negativeInteger
#      xsd:nonNegativeInteger
#      xsd:nonPositiveInteger
#      xsd:normalizedString
#      xsd:positiveInteger
#      xsd:short
#      xsd:string
#      xsd:time
#      xsd:token
#      xsd:unsignedByte
#      xsd:unsignedInt
#      xsd:unsignedLong
#      xsd:unsignedShort
#
# Bindings:
#      Soap11Binding: {http://tempuri.org/}BasicHttpBinding_IOntsluitenObjService
#      Soap11Binding: {http://tempuri.org/}BasicHttpBinding_IOntsluitenObjServiceFile
#
# Service: OntsluitenObjService
#      Port: BasicHttpBinding_IOntsluitenObjService (Soap11Binding: {http://tempuri.org/}BasicHttpBinding_IOntsluitenObjService)
#          Operations:
#             AddBuurt(xel: {_value_1: ANY}) -> AddBuurtResult: ns3:CPReturnObject
#             AddComplex(xel: {_value_1: ANY}) -> AddComplexResult: ns3:CPReturnObject
#             AddDossier(xel: {_value_1: ANY}) -> AddDossierResult: ns3:CPReturnObject
#             AddKeuringsRapport(documentinhoud: ns2:StreamBody, _soapheaders={documentType: xsd:int, documentnaam: xsd:string, dossierId: xsd:int}) -> None
#             AddKeuringsdatum(klantnummer: xsd:string, dossierid: xsd:int, keuringsdatum: xsd:dateTime) -> AddKeuringsdatumResult: ns3:KeuringsError
#             AddObject(xel: {_value_1: ANY}) -> AddObjectResult: ns3:CPReturnObject
#             AddPlandatumKeuringsopdracht(klantnummer: xsd:string, dossierid: xsd:int, plandatum: xsd:dateTime) -> AddPlandatumKeuringsopdrachtResult: ns3:KeuringsError
#             AddWijk(xel: {_value_1: ANY}) -> AddWijkResult: ns3:CPReturnObject
#             GetBuurten(regioID: xsd:int) -> GetBuurtenResult: xsd:string
#             GetComplexen() -> GetComplexenResult: xsd:string
#             GetCorporatieNaam() -> GetCorporatieNaamResult: xsd:string
#             GetFile(filename: xsd:string) -> GetFileResult: ns2:StreamBody
#             GetKeuringsOpdrachten() -> GetKeuringsOpdrachtenResult: xsd:string
#             GetObject(perceelNummer: xsd:string) -> GetObjectResult: {_value_1: ANY}
#             GetObjectTypen() -> GetObjectTypenResult: xsd:string
#             GetObjecten() -> GetObjectenResult: {_value_1: ANY}
#             GetRegios() -> GetRegiosResult: xsd:string
#             GetWijken(regioID: xsd:int) -> GetWijkenResult: xsd:string
#             OntSluitenObjectenVbi(inclusiefPub: xsd:boolean, inclusiefHuur: xsd:boolean) -> OntSluitenObjectenVbiResult: {_value_1: ANY}
#             OntsluitObjecten() -> OntsluitObjectenResult: {_value_1: ANY}
#             OntsluitObjectenInclHuur(inclusiefHuur: xsd:boolean) -> OntsluitObjectenInclHuurResult: {_value_1: ANY}
#             UpdateObject(xel: {_value_1: ANY}) -> UpdateObjectResult: ns3:CPReturnObject
#             Welkom(msg: xsd:string) -> WelkomResult: xsd:string
#
#      Port: BasicHttpBinding_IOntsluitenObjServiceFile (Soap11Binding: {http://tempuri.org/}BasicHttpBinding_IOntsluitenObjServiceFile)
#          Operations:
#             GetFileMtom(filename: xsd:string) -> GetFileMtomResult: ns2:StreamBody

# %%
import operator
from zeep import Client

TobiasAX_methods_list = []
wsdl = "C:\\Users\\31653\\Desktop\\DeAlliantie\\Corporatieportaal.wsdl"
client = Client(wsdl=wsdl)
for service in client.wsdl.services.values():
    print("service :", service.name)
    for port in service.ports.values():
        operations = sorted(
            port.binding._operations.values(),
            key=operator.attrgetter('name'))

        for operation in operations:
            #print(" method :", operation.name)
            TobiasAX_methods_list.append(operation.name)
            print("  input :", operation.input.signature())
            #print(" output :", operation.output.signature())
print(len(TobiasAX_methods_list))
print(TobiasAX_methods_list)
# Out:
# service : OntsluitenObjService
#   input : xel: {_value_1: ANY}
#   input : xel: {_value_1: ANY}
#   input : xel: {_value_1: ANY}
#   input : documentinhoud: ns2:StreamBody, _soapheaders={documentType: xsd:int, documentnaam: xsd:string, dossierId: xsd:int}
#   input : klantnummer: xsd:string, dossierid: xsd:int, keuringsdatum: xsd:dateTime
#   input : xel: {_value_1: ANY}
#   input : klantnummer: xsd:string, dossierid: xsd:int, plandatum: xsd:dateTime
#   input : xel: {_value_1: ANY}
#   input : regioID: xsd:int
#   input :
#   input :
#   input : filename: xsd:string
#   input :
#   input : perceelNummer: xsd:string
#   input :
#   input :
#   input :
#   input : regioID: xsd:int
#   input : inclusiefPub: xsd:boolean, inclusiefHuur: xsd:boolean
#   input :
#   input : inclusiefHuur: xsd:boolean
#   input : xel: {_value_1: ANY}
#   input : msg: xsd:string
#   input : filename: xsd:string
# 24
# ['AddBuurt', 'AddComplex', 'AddDossier', 'AddKeuringsRapport', 'AddKeuringsdatum', 'AddObject', 'AddPlandatumKeuringsopdracht', 'AddWijk', 'GetBuurten', 'GetComplexen', 'GetCorporatieNaam', 'GetFile', 'GetKeuringsOpdrachten', 'GetObject', 'GetObjectTypen', 'GetObjecten', 'GetRegios', 'GetWijken', 'OntSluitenObjectenVbi', 'OntsluitObjecten', 'OntsluitObjectenInclHuur', 'UpdateObject', 'Welkom', 'GetFileMtom']

# %%
for i in range (len(TobiasAX_methods_list)):
    print(TobiasAX_methods_list[i])
# Out:
# AddBuurt
# AddComplex
# AddDossier
# AddKeuringsRapport
# AddKeuringsdatum
# AddObject
# AddPlandatumKeuringsopdracht
# AddWijk
# GetBuurten
# GetComplexen
# GetCorporatieNaam
# GetFile
# GetKeuringsOpdrachten
# GetObject
# GetObjectTypen
# GetObjecten
# GetRegios
# GetWijken
# OntSluitenObjectenVbi
# OntsluitObjecten
# OntsluitObjectenInclHuur
# UpdateObject
# Welkom
# GetFileMtom
