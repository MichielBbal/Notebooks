# %% [markdown]
# # Reverse Engineering the onderhoudsverzoeken API

# %% [markdown]
# ## To do:
# [] plantuml png handmatig => automatisch <br>
#
# ## Contents:
# 1. Basic info of the API and inspection
# 2. Getting the paths and endpoints
# 3. Getting the objects with attributes
# 4. Writing it to json, plantuml and .csv

# %% [markdown]
# ## 1. Basic info of the API and inspection

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie'

# %%
import glob
my_jsons=glob.glob('*.json')
my_yamls = glob.glob('*.yaml')
my_jsons, my_yamls
# Out:
# (['planningsverzoeken-api.json',
#   'planningsverzoeken-api_data.json',
#   'Saxton API_data.json',
#   'saxton.json'],
#  ['saxton.yaml'])

# %%
#loading the API into active dictionary
import json

with open('C:\\Users\\31653\\Desktop\\DeAlliantie\\onderhoudsverzoeken-api.json') as f:
    spec = json.load(f)

# %%
list(spec)
# Out:
# ['swagger',
#  'info',
#  'host',
#  'tags',
#  'schemes',
#  'paths',
#  'definitions',
#  'security',
#  'securityDefinitions',
#  'basePath']

# %%
spec['schemes']
# Out:
# ['https']

# %%
API_version =spec['info']['version']
API_version = "v"+API_version[:5]
OAS_version =spec['swagger']
API_name = spec['info']['title']
print('OAS:'+OAS_version, API_name, API_version)
# Out:
# OAS:2.0 onderhoudsverzoeken-api v1.7.7

# %% [markdown]
# ## 2. Getting the paths and endpoints

# %%
paths =list(spec['paths'])
print(len(paths))
paths
# Out:
# 2
# ['/v1/onderhoud/onderhoudsverzoeken',
#  '/v1/onderhoud/onderhoudsverzoeken/{identificatie}']

# %%
endpoints_dict = {}
for i in range (len(paths)):
    endpoints_dict[paths[i]]=list(spec['paths'][paths[i]])
endpoints_dict
# Out:
# {'/v1/onderhoud/onderhoudsverzoeken': ['get', 'post'],
#  '/v1/onderhoud/onderhoudsverzoeken/{identificatie}': ['get']}

# %% [markdown]
# ## 3. Getting the objects

# %%
#inspection of the objects
spec['definitions']
# Out:
# {'OnderhoudsverzoekResponse': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'omschrijving': {'type': 'string'},
#    'status': {'type': 'string'},
#    'onderhoudSoort': {'type': 'string'},
#    'melddatum': {'type': 'string', 'format': 'date-time'},
#    'extraElementen': {'$ref': '#/definitions/ExtraElementenOnderhoudsverzoekResponse'},
#    'alternatiefContactgegeven': {'type': 'string'},
#    'onderhoudsorders': {'type': 'array',
#     'items': {'$ref': '#/definitions/OnderhoudsorderResponse'}},
#    'melder': {'$ref': '#/definitions/NatuurlijkPersoon'},
#    'onderhoudstaken': {'type': 'array',
#     'items': {'$ref': '#/definitions/OnderhoudstaakResponse'}}}},
#  'Eenheid': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'gebouw': {'$ref': '#/definitions/Gebouw'},
#    'extraElementen': {'$ref': '#/definitions/ExtraElementenEenheid'}}},
#  'Pand': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'}}},
#  'ExtraElementenEenheid': {'type': 'object',
#   'properties': {'gebouw': {'$ref': '#/definitions/Gebouw'},
#    'pand': {'$ref': '#/definitions/Pand'},
#    'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'},
#    'contractvalidfromdatum': {'type': 'string', 'format': 'date-time'}}},
#  'OmschrijvingDetails': {'type': 'object',
#   'properties': {'adres': {'type': 'string'},
#    'telefoonnummer': {'type': 'string'},
#    'betreftVve': {'type': 'string'},
#    'betreftSa': {'type': 'string'},
#    'opmerking': {'type': 'string'},
#    'gebruiker': {'type': 'string'},
#    'locatie': {'type': 'string'},
#    'locatieOnderdeel': {'type': 'string'},
#    'probleem': {'type': 'string'},
#    'probleemDetails': {'type': 'string'},
#    'onderwerp': {'type': 'string'},
#    'gegevenAntwoorden': {'type': 'array',
#     'items': {'$ref': '#/definitions/GegevenAntwoorden'}}}},
#  'GegevenAntwoorden': {'type': 'object',
#   'properties': {'vraag': {'type': 'string'}, 'antwoord': {'type': 'string'}}},
#  'ExtraElementenOnderhoudstaakResponse': {'type': 'object',
#   'properties': {'actieCode': {'type': 'string'},
#    'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'},
#    'omschrijvingDetails': {'$ref': '#/definitions/OmschrijvingDetails'}}},
#  'Gebouw': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'pand': {'$ref': '#/definitions/Pand'}}},
#  'OnderhoudsorderResponse': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'omschrijving': {'type': 'string'},
#    'onderhoudSoort': {'type': 'string'},
#    'begindatum': {'type': 'string', 'format': 'date-time'},
#    'einddatum': {'type': 'string', 'format': 'date-time'},
#    'technischGereeddatum': {'type': 'string', 'format': 'date-time'},
#    'financieelGereeddatum': {'type': 'string', 'format': 'date-time'},
#    'status': {'type': 'string'},
#    'uitersteGereeddatum': {'type': 'string', 'format': 'date-time'},
#    'opdrachtdatum': {'type': 'string', 'format': 'date-time'},
#    'uitvoerendeSoort': {'type': 'string'},
#    'onderhoudstaken': {'type': 'array',
#     'items': {'$ref': '#/definitions/OnderhoudstaakResponse'}},
#    'afspraken': {'type': 'array', 'items': {'$ref': '#/definitions/Afspraak'}},
#    'uitvoerende': {'$ref': '#/definitions/Rechtspersoon'}}},
#  'NatuurlijkPersoon': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'}}},
#  'Punt': {'type': 'object',
#   'properties': {'soort': {'type': 'string'},
#    'lengtegraad': {'type': 'number'},
#    'breedtegraad': {'type': 'number'}}},
#  'FinancieelBedrijf': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'}}},
#  'Rechtspersoon': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'soort': {'type': 'string'},
#    'naam': {'type': 'string'}}},
#  'OnderhoudstaakResponse': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'omschrijving': {'type': 'string'},
#    'status': {'type': 'string'},
#    'detailStatus': {'type': 'string'},
#    'extraElementen': {'$ref': '#/definitions/ExtraElementenOnderhoudstaakResponse'},
#    'specialisme': {'type': 'string'},
#    'afspraken': {'type': 'array', 'items': {'$ref': '#/definitions/Afspraak'}},
#    'uitvoerende': {'$ref': '#/definitions/Rechtspersoon'},
#    'onderhoudsverzoek': {'$ref': '#/definitions/OnderhoudsverzoekKerngevens'}}},
#  'OnderhoudsverzoekKerngevens': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'}}},
#  'Gemeente': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'naam': {'type': 'string'}}},
#  'Contactgegeven': {'type': 'object',
#   'properties': {'soort': {'type': 'string'},
#    'detailSoort': {'type': 'string'},
#    'waarde': {'type': 'string'},
#    'voorkeur': {'type': 'string'},
#    'landnummer': {'type': 'string'},
#    'netnummer': {'type': 'string'},
#    'abonneenummer': {'type': 'string'},
#    'extensie': {'type': 'string'},
#    'dagdelen': {'type': 'array', 'items': {'type': 'string'}}}},
#  'ExtraElementenOnderhoudsverzoekResponse': {'type': 'object',
#   'properties': {'onderwerp': {'type': 'string'},
#    'eenheid': {'$ref': '#/definitions/Eenheid'},
#    'omschrijvingDetails': {'$ref': '#/definitions/OmschrijvingDetails'},
#    'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'}}},
#  'Wijk': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'naam': {'type': 'string'}}},
#  'Buurt': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'naam': {'type': 'string'}}},
#  'Woonplaats': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'naam': {'type': 'string'}}},
#  'Adres': {'type': 'object',
#   'properties': {'identificatie': {'type': 'string'},
#    'straatnaam': {'type': 'string'},
#    'huisnummer': {'type': 'string'},
#    'huisletter': {'type': 'string'},
#    'huisnummertoevoeging': {'type': 'string'},
#    'postcode': {'type': 'string'},
#    'woonplaats': {'$ref': '#/definitions/Woonplaats'},
#    'buurt': {'$ref': '#/definitions/Buurt'},
#    'wijk': {'$ref': '#/definitions/Wijk'},
#    'gemeente': {'$ref': '#/definitions/Gemeente'},
#    'geometrie': {'$ref': '#/definitions/Punt'}}},
#  'Afspraak': {'type': 'object',
#   'properties': {'onderwerp': {'type': 'string'},
#    'begindatum': {'type': 'string', 'format': 'date-time'},
#    'einddatum': {'type': 'string', 'format': 'date-time'},
#    'bloktijdBegin': {'type': 'string', 'format': 'date-time'},
#    'bloktijdEind': {'type': 'string', 'format': 'date-time'},
#    'locatie': {'$ref': '#/definitions/Adres'},
#    'medewerker': {'$ref': '#/definitions/NatuurlijkPersoon'},
#    'contactgegeven': {'$ref': '#/definitions/Contactgegeven'}}},
#  'ErrorResponse': {'type': 'object',
#   'properties': {'timestamp': {'type': 'integer', 'format': 'int64'},
#    'status': {'type': 'integer', 'format': 'int32'},
#    'error': {'type': 'string'},
#    'message': {'type': 'string'}}},
#  'OnderhoudsorderRequest': {'type': 'object',
#   'properties': {'extraElementen': {'$ref': '#/definitions/OnderhoudsorderRequestExtraElementen'}}},
#  'OnderhoudsverzoekRequest': {'type': 'object',
#   'properties': {'omschrijving': {'type': 'string'},
#    'status': {'type': 'string'},
#    'onderhoudSoort': {'type': 'string'},
#    'melddatum': {'type': 'string', 'format': 'date-time'},
#    'extraElementen': {'$ref': '#/definitions/ExtraElementenOnderhoudsverzoekRequest'},
#    'alternatiefContactgegeven': {'type': 'string'},
#    'onderhoudsorders': {'type': 'array',
#     'items': {'$ref': '#/definitions/OnderhoudsorderRequest'}},
#    'melder': {'$ref': '#/definitions/NatuurlijkPersoon'}}},
#  'OnderhoudstaakRequest': {'type': 'object',
#   'properties': {'omschrijving': {'type': 'string'},
#    'extraElementen': {'$ref': '#/definitions/OnderhoudstaakRequestExtraElementen'}}},
#  'OnderhoudsorderRequestExtraElementen': {'type': 'object',
#   'properties': {'onderhoudsverzoekId': {'type': 'string'},
#    'onderhoudstaak': {'$ref': '#/definitions/OnderhoudstaakRequest'},
#    'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'}}},
#  'ExtraElementenOnderhoudsverzoekRequest': {'type': 'object',
#   'properties': {'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'},
#    'onderwerp': {'type': 'string'},
#    'gebouw': {'$ref': '#/definitions/Gebouw'},
#    'pand': {'$ref': '#/definitions/Pand'}}},
#  'OnderhoudstaakRequestExtraElementen': {'type': 'object',
#   'properties': {'actiecode': {'type': 'string'},
#    'afspraak': {'$ref': '#/definitions/Afspraak'},
#    'bedrijf': {'$ref': '#/definitions/FinancieelBedrijf'}}}}

# %%
objects = list(spec['definitions'])
print(len(objects))
objects
# Out:
# 30
# ['OnderhoudsverzoekResponse',
#  'Eenheid',
#  'Pand',
#  'ExtraElementenEenheid',
#  'OmschrijvingDetails',
#  'GegevenAntwoorden',
#  'ExtraElementenOnderhoudstaakResponse',
#  'Gebouw',
#  'OnderhoudsorderResponse',
#  'NatuurlijkPersoon',
#  'Punt',
#  'FinancieelBedrijf',
#  'Rechtspersoon',
#  'OnderhoudstaakResponse',
#  'OnderhoudsverzoekKerngevens',
#  'Gemeente',
#  'Contactgegeven',
#  'ExtraElementenOnderhoudsverzoekResponse',
#  'Wijk',
#  'Buurt',
#  'Woonplaats',
#  'Adres',
#  'Afspraak',
#  'ErrorResponse',
#  'OnderhoudsorderRequest',
#  'OnderhoudsverzoekRequest',
#  'OnderhoudstaakRequest',
#  'OnderhoudsorderRequestExtraElementen',
#  'ExtraElementenOnderhoudsverzoekRequest',
#  'OnderhoudstaakRequestExtraElementen']

# %%
#inspection of an object
spec['definitions']['Eenheid']
# Out:
# {'type': 'object',
#  'properties': {'identificatie': {'type': 'string'},
#   'gebouw': {'$ref': '#/definitions/Gebouw'},
#   'extraElementen': {'$ref': '#/definitions/ExtraElementenEenheid'}}}

# %%
#creating a dictionary with objects and their properties
object_dict ={}
objects = list(spec['definitions'])
for i in range (len(objects)):
    try:
        object_dict[objects[i]]=list(spec['definitions'][objects[i]]['properties'])#['properties']
    except:
        pass
object_dict
# Out:
# {'OnderhoudsverzoekResponse': ['identificatie',
#   'omschrijving',
#   'status',
#   'onderhoudSoort',
#   'melddatum',
#   'extraElementen',
#   'alternatiefContactgegeven',
#   'onderhoudsorders',
#   'melder',
#   'onderhoudstaken'],
#  'Eenheid': ['identificatie', 'gebouw', 'extraElementen'],
#  'Pand': ['identificatie'],
#  'ExtraElementenEenheid': ['gebouw',
#   'pand',
#   'bedrijf',
#   'contractvalidfromdatum'],
#  'OmschrijvingDetails': ['adres',
#   'telefoonnummer',
#   'betreftVve',
#   'betreftSa',
#   'opmerking',
#   'gebruiker',
#   'locatie',
#   'locatieOnderdeel',
#   'probleem',
#   'probleemDetails',
#   'onderwerp',
#   'gegevenAntwoorden'],
#  'GegevenAntwoorden': ['vraag', 'antwoord'],
#  'ExtraElementenOnderhoudstaakResponse': ['actieCode',
#   'bedrijf',
#   'omschrijvingDetails'],
#  'Gebouw': ['identificatie', 'pand'],
#  'OnderhoudsorderResponse': ['identificatie',
#   'omschrijving',
#   'onderhoudSoort',
#   'begindatum',
#   'einddatum',
#   'technischGereeddatum',
#   'financieelGereeddatum',
#   'status',
#   'uitersteGereeddatum',
#   'opdrachtdatum',
#   'uitvoerendeSoort',
#   'onderhoudstaken',
#   'afspraken',
#   'uitvoerende'],
#  'NatuurlijkPersoon': ['identificatie'],
#  'Punt': ['soort', 'lengtegraad', 'breedtegraad'],
#  'FinancieelBedrijf': ['identificatie'],
#  'Rechtspersoon': ['identificatie', 'soort', 'naam'],
#  'OnderhoudstaakResponse': ['identificatie',
#   'omschrijving',
#   'status',
#   'detailStatus',
#   'extraElementen',
#   'specialisme',
#   'afspraken',
#   'uitvoerende',
#   'onderhoudsverzoek'],
#  'OnderhoudsverzoekKerngevens': ['identificatie'],
#  'Gemeente': ['identificatie', 'naam'],
#  'Contactgegeven': ['soort',
#   'detailSoort',
#   'waarde',
#   'voorkeur',
#   'landnummer',
#   'netnummer',
#   'abonneenummer',
#   'extensie',
#   'dagdelen'],
#  'ExtraElementenOnderhoudsverzoekResponse': ['onderwerp',
#   'eenheid',
#   'omschrijvingDetails',
#   'bedrijf'],
#  'Wijk': ['identificatie', 'naam'],
#  'Buurt': ['identificatie', 'naam'],
#  'Woonplaats': ['identificatie', 'naam'],
#  'Adres': ['identificatie',
#   'straatnaam',
#   'huisnummer',
#   'huisletter',
#   'huisnummertoevoeging',
#   'postcode',
#   'woonplaats',
#   'buurt',
#   'wijk',
#   'gemeente',
#   'geometrie'],
#  'Afspraak': ['onderwerp',
#   'begindatum',
#   'einddatum',
#   'bloktijdBegin',
#   'bloktijdEind',
#   'locatie',
#   'medewerker',
#   'contactgegeven'],
#  'ErrorResponse': ['timestamp', 'status', 'error', 'message'],
#  'OnderhoudsorderRequest': ['extraElementen'],
#  'OnderhoudsverzoekRequest': ['omschrijving',
#   'status',
#   'onderhoudSoort',
#   'melddatum',
#   'extraElementen',
#   'alternatiefContactgegeven',
#   'onderhoudsorders',
#   'melder'],
#  'OnderhoudstaakRequest': ['omschrijving', 'extraElementen'],
#  'OnderhoudsorderRequestExtraElementen': ['onderhoudsverzoekId',
#   'onderhoudstaak',
#   'bedrijf'],
#  'ExtraElementenOnderhoudsverzoekRequest': ['bedrijf',
#   'onderwerp',
#   'gebouw',
#   'pand'],
#  'OnderhoudstaakRequestExtraElementen': ['actiecode', 'afspraak', 'bedrijf']}

# %%
#converting the python dict to a JSON 
import json 
      
# Serializing json  
json_object = json.dumps(object_dict, indent = 4) 
print(json_object)
# Out:
# {
#     "OnderhoudsverzoekResponse": [
#         "identificatie",
#         "omschrijving",
#         "status",
#         "onderhoudSoort",
#         "melddatum",
#         "extraElementen",
#         "alternatiefContactgegeven",
#         "onderhoudsorders",
#         "melder",
#         "onderhoudstaken"
#     ],
#     "Eenheid": [
#         "identificatie",
#         "gebouw",
#         "extraElementen"
#     ],
#     "Pand": [
#         "identificatie"
#     ],
#     "ExtraElementenEenheid": [
#         "gebouw",
#         "pand",
#         "bedrijf",
#         "contractvalidfromdatum"
#     ],
#     "OmschrijvingDetails": [
#         "adres",
#         "telefoonnummer",
#         "betreftVve",
#         "betreftSa",
#         "opmerking",
#         "gebruiker",
#         "locatie",
#         "locatieOnderdeel",
#         "probleem",
#         "probleemDetails",
#         "onderwerp",
#         "gegevenAntwoorden"
#     ],
#     "GegevenAntwoorden": [
#         "vraag",
#         "antwoord"
#     ],
#     "ExtraElementenOnderhoudstaakResponse": [
#         "actieCode",
#         "bedrijf",
#         "omschrijvingDetails"
#     ],
#     "Gebouw": [
#         "identificatie",
#         "pand"
#     ],
#     "OnderhoudsorderResponse": [
#         "identificatie",
#         "omschrijving",
#         "onderhoudSoort",
#         "begindatum",
#         "einddatum",
#         "technischGereeddatum",
#         "financieelGereeddatum",
#         "status",
#         "uitersteGereeddatum",
#         "opdrachtdatum",
#         "uitvoerendeSoort",
#         "onderhoudstaken",
#         "afspraken",
#         "uitvoerende"
#     ],
#     "NatuurlijkPersoon": [
#         "identificatie"
#     ],
#     "Punt": [
#         "soort",
#         "lengtegraad",
#         "breedtegraad"
#     ],
#     "FinancieelBedrijf": [
#         "identificatie"
#     ],
#     "Rechtspersoon": [
#         "identificatie",
#         "soort",
#         "naam"
#     ],
#     "OnderhoudstaakResponse": [
#         "identificatie",
#         "omschrijving",
#         "status",
#         "detailStatus",
#         "extraElementen",
#         "specialisme",
#         "afspraken",
#         "uitvoerende",
#         "onderhoudsverzoek"
#     ],
#     "OnderhoudsverzoekKerngevens": [
#         "identificatie"
#     ],
#     "Gemeente": [
#         "identificatie",
#         "naam"
#     ],
#     "Contactgegeven": [
#         "soort",
#         "detailSoort",
#         "waarde",
#         "voorkeur",
#         "landnummer",
#         "netnummer",
#         "abonneenummer",
#         "extensie",
#         "dagdelen"
#     ],
#     "ExtraElementenOnderhoudsverzoekResponse": [
#         "onderwerp",
#         "eenheid",
#         "omschrijvingDetails",
#         "bedrijf"
#     ],
#     "Wijk": [
#         "identificatie",
#         "naam"
#     ],
#     "Buurt": [
#         "identificatie",
#         "naam"
#     ],
#     "Woonplaats": [
#         "identificatie",
#         "naam"
#     ],
#     "Adres": [
#         "identificatie",
#         "straatnaam",
#         "huisnummer",
#         "huisletter",
#         "huisnummertoevoeging",
#         "postcode",
#         "woonplaats",
#         "buurt",
#         "wijk",
#         "gemeente",
#         "geometrie"
#     ],
#     "Afspraak": [
#         "onderwerp",
#         "begindatum",
#         "einddatum",
#         "bloktijdBegin",
#         "bloktijdEind",
#         "locatie",
#         "medewerker",
#         "contactgegeven"
#     ],
#     "ErrorResponse": [
#         "timestamp",
#         "status",
#         "error",
#         "message"
#     ],
#     "OnderhoudsorderRequest": [
#         "extraElementen"
#     ],
#     "OnderhoudsverzoekRequest": [
#         "omschrijving",
#         "status",
#         "onderhoudSoort",
#         "melddatum",
#         "extraElementen",
#         "alternatiefContactgegeven",
#         "onderhoudsorders",
#         "melder"
#     ],
#     "OnderhoudstaakRequest": [
#         "omschrijving",
#         "extraElementen"
#     ],
#     "OnderhoudsorderRequestExtraElementen": [
#         "onderhoudsverzoekId",
#         "onderhoudstaak",
#         "bedrijf"
#     ],
#     "ExtraElementenOnderhoudsverzoekRequest": [
#         "bedrijf",
#         "onderwerp",
#         "gebouw",
#         "pand"
#     ],
#     "OnderhoudstaakRequestExtraElementen": [
#         "actiecode",
#         "afspraak",
#         "bedrijf"
#     ]
# }

# %% [markdown]
# ## 4. Writing it to a .json, plantuml and .csv file

# %%
#writing it to a json
import json
with open(API_name+'_data.json', 'w', encoding='utf-8') as f:
    json.dump(json_object, f, ensure_ascii=False, indent=4)

# %%
import glob
my_jsons = glob.glob('*.json')
my_jsons
# Out:
# ['onderhoudsverzoeken-api_data.json',
#  'planningsverzoeken-api.json',
#  'planningsverzoeken-api_data.json',
#  'Saxton API_data.json',
#  'saxton.json']

# %%
textfile = open(API_name+"_API_plantuml.txt", "w")
textfile.write('@startuml\n')
for key, value in object_dict.items():
    textfile.write('class '+str(key) +'{\n')
    for i in range (len(value)):
        textfile.write(value[i] + "\n")
    textfile.write('}\n')
#textfile.write('}\n')
textfile.write('@enduml')
textfile.close()

# %%
import glob
my_txts = glob.glob('*.txt')
my_txts
# Out:
# ['onderhoudsverzoeken-api_API_plantuml.txt',
#  'plantuml_planningsverzoeken-api_data.txt',
#  'plantuml_planningsverzoeken.txt',
#  'plantuml_Saxton API_data.txt',
#  'plantuml_Saxton_API_data.txt',
#  'Saxton_API_datamodel_A.txt',
#  'Saxton_API_datamodel_C.txt',
#  'Saxton_API_datamodel_D-G.txt',
#  'Saxton_API_datamodel_H-M.txt',
#  'Saxton_API_datamodel_N-Z.txt']

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie'

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\onderhoudsverzoeken-api_API_plantuml.txt

# %%
#convert the txt file to an .png image using plantuml
# !python -m plantuml onderhoudsverzoeken-api_API_plantuml.txt
# Out:
# [{'filename': 'onderhoudsverzoeken-api_API_plantuml.txt', 'gen_success': True}]

# %%
#show the generated png
from IPython import display
display.Image(filename="onderhoudsverzoeken-api_API_plantuml.png", width=1200, height=500)

# %% [markdown]
# ## Write it to a .csv file
#
#  a .csv file with a ; seperator between key and values

# %%
with open(API_name+"_data.csv", mode="w") as pv:
    for key, value in object_dict.items():
        pv.write(str(key)+";")
        for i in range (len(value)-1):
            pv.write(value[i]+",")#write values + a comma  
        pv.write(value[-1]+"\n") #write last value (and no comma)

# %%
import glob
my_csvs=glob.glob('*.csv')
my_csvs
# Out:
# ['onderhoudsverzoeken-api_data.csv',
#  'planningsverzoeken-api_data.csv',
#  'Saxton API_API_objecten.csv',
#  'Saxton API_data.csv']

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\VERA\\planningsverzoeken-api_data.csv
