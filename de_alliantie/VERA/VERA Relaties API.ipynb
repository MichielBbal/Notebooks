# %% [markdown]
# # Reverse engineering de VERA Relaties API
#
# ### Korte beschrijving werkwijze
# 1. VERA heeft in januari 2022 de nieuwe OpenAPI specificaties gepubliceerd. Per domein wordt één API gepubliceerd op GitHub. Deze OpenAPI3 specificatie zijn flinke bestanden, circa 8000 regels code. In totaal zijn er dus 10 API's.
# 2. In dit Notebook wordt de Vastgoed API ge-reverse-engineered zodat er inzicht komt in de dataobjecten in de VERA OpenAPI. Dit inzicht wordt verkregen door drie bestanden op te leveren:
# - een UML Class diagram gemaakt met PlantUML
# - een .csv bestand met de objecten en hun klassen
# - een json bestand.

# %% [markdown]
# ## 1. Basic info of the API and inspection

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA'

# %%
import glob
my_yamls=glob.glob('*.yaml')
my_yamls
# Out:
# ['Algemeen.yaml',
#  'Dossier.yaml',
#  'Financien.yaml',
#  'Kwaliteit.yaml',
#  'Onderhoud.yaml',
#  'Overeenkomsten.yaml',
#  'Projectontwikkeling.yaml',
#  'Relaties.yaml',
#  'Vastgoed.yaml',
#  'Woonruimteverdeling.yaml']

# %%
import yaml

# load the spec file and read the yaml to create a python dictionary 'spec'
with open('relaties.yaml') as f:
    spec = yaml.safe_load(f.read())

# %%
list(spec)
# Out:
# ['openapi', 'info', 'servers', 'tags', 'paths', 'security', 'components']

# %%
OAS_version =spec['openapi']
API_name = spec['info']['title']
API_version =spec['info']['version']
print(OAS_version, API_name, API_version)
# Out:
# 3.0.0 VERA-Relaties 4.0

# %% [markdown]
# ## 2. Getting the paths and endpoints

# %%
#getting the paths
paths = list(spec['paths'])
len(paths)
# Out:
# 35

# %%
#getting the paths and http verbs
endpoints_dict = {}
for i in range (len(paths)):
    endpoints_dict[paths[i]]=list(spec['paths'][paths[i]])
endpoints_dict
# Out:
# {'/ping': ['get'],
#  '/accounts': ['get', 'post', 'put', 'patch'],
#  '/accounts/{id}': ['get', 'put', 'patch'],
#  '/afspraken': ['get', 'post', 'put', 'patch'],
#  '/afspraken/{id}': ['get', 'put', 'patch'],
#  '/afspraak-opties': ['get', 'post', 'put', 'patch'],
#  '/afspraak-opties/{id}': ['get', 'put', 'patch'],
#  '/afspraakverzoeken': ['get', 'post', 'put', 'patch'],
#  '/afspraakverzoeken/{id}': ['get', 'put', 'patch'],
#  '/betaalgegevens': ['get', 'post', 'put', 'patch'],
#  '/betaalgegevens/{id}': ['get', 'put', 'patch'],
#  '/contactgegevens': ['get', 'post', 'put', 'patch'],
#  '/contactgegevens/{id}': ['get', 'put', 'patch'],
#  '/contactmomenten': ['get', 'post', 'put', 'patch'],
#  '/contactmomenten/{id}': ['get', 'put', 'patch'],
#  '/inkomens': ['get', 'post', 'put', 'patch'],
#  '/inkomens/{id}': ['get', 'put', 'patch'],
#  '/natuurlijk-personen': ['get', 'post', 'put', 'patch'],
#  '/natuurlijk-personen/{id}': ['get', 'put', 'patch'],
#  '/opleidingen': ['get', 'post', 'put', 'patch'],
#  '/opleidingen/{id}': ['get', 'put', 'patch'],
#  '/rechtspersonen': ['get', 'post', 'put', 'patch'],
#  '/rechtspersonen/{id}': ['get', 'put', 'patch'],
#  '/relaties': ['get', 'post', 'put', 'patch'],
#  '/relaties/{id}': ['get', 'put', 'patch'],
#  '/relatie-adressen': ['get', 'post', 'put', 'patch'],
#  '/relatie-adressen/{id}': ['get', 'put', 'patch'],
#  '/relatiegroepen': ['get', 'post', 'put', 'patch'],
#  '/relatiegroepen/{id}': ['get', 'put', 'patch'],
#  '/relatierollen': ['get', 'post', 'put', 'patch'],
#  '/relatierollen/{id}': ['get', 'put', 'patch'],
#  '/signaleringen': ['get', 'post', 'put', 'patch'],
#  '/signaleringen/{id}': ['get', 'put', 'patch'],
#  '/telefoonnummers': ['get', 'post', 'put', 'patch'],
#  '/telefoonnummers/{id}': ['get', 'put', 'patch']}

# %%
#value_list=[]
for key, value in endpoints_dict.items():
    #print(value)
    value_list = value
    for i in range (len(value_list)):
        print(value_list[i], key)
# Out:
# get /ping
# get /accounts
# post /accounts
# put /accounts
# patch /accounts
# get /accounts/{id}
# put /accounts/{id}
# patch /accounts/{id}
# get /afspraken
# post /afspraken
# put /afspraken
# patch /afspraken
# get /afspraken/{id}
# put /afspraken/{id}
# patch /afspraken/{id}
# get /afspraak-opties
# post /afspraak-opties
# put /afspraak-opties
# patch /afspraak-opties
# get /afspraak-opties/{id}
# put /afspraak-opties/{id}
# patch /afspraak-opties/{id}
# get /afspraakverzoeken
# post /afspraakverzoeken
# put /afspraakverzoeken
# patch /afspraakverzoeken
# get /afspraakverzoeken/{id}
# put /afspraakverzoeken/{id}
# patch /afspraakverzoeken/{id}
# get /betaalgegevens
# post /betaalgegevens
# put /betaalgegevens
# patch /betaalgegevens
# get /betaalgegevens/{id}
# put /betaalgegevens/{id}
# patch /betaalgegevens/{id}
# get /contactgegevens
# post /contactgegevens
# put /contactgegevens
# patch /contactgegevens
# get /contactgegevens/{id}
# put /contactgegevens/{id}
# patch /contactgegevens/{id}
# get /contactmomenten
# post /contactmomenten
# put /contactmomenten
# patch /contactmomenten
# get /contactmomenten/{id}
# put /contactmomenten/{id}
# patch /contactmomenten/{id}
# get /inkomens
# post /inkomens
# put /inkomens
# patch /inkomens
# get /inkomens/{id}
# put /inkomens/{id}
# patch /inkomens/{id}
# get /natuurlijk-personen
# post /natuurlijk-personen
# put /natuurlijk-personen
# patch /natuurlijk-personen
# get /natuurlijk-personen/{id}
# put /natuurlijk-personen/{id}
# patch /natuurlijk-personen/{id}
# get /opleidingen
# post /opleidingen
# put /opleidingen
# patch /opleidingen
# get /opleidingen/{id}
# put /opleidingen/{id}
# patch /opleidingen/{id}
# get /rechtspersonen
# post /rechtspersonen
# put /rechtspersonen
# patch /rechtspersonen
# get /rechtspersonen/{id}
# put /rechtspersonen/{id}
# patch /rechtspersonen/{id}
# get /relaties
# post /relaties
# put /relaties
# patch /relaties
# get /relaties/{id}
# put /relaties/{id}
# patch /relaties/{id}
# get /relatie-adressen
# post /relatie-adressen
# put /relatie-adressen
# patch /relatie-adressen
# get /relatie-adressen/{id}
# put /relatie-adressen/{id}
# patch /relatie-adressen/{id}
# get /relatiegroepen
# post /relatiegroepen
# put /relatiegroepen
# patch /relatiegroepen
# get /relatiegroepen/{id}
# put /relatiegroepen/{id}
# patch /relatiegroepen/{id}
# get /relatierollen
# post /relatierollen
# put /relatierollen
# patch /relatierollen
# get /relatierollen/{id}
# put /relatierollen/{id}
# patch /relatierollen/{id}
# get /signaleringen
# post /signaleringen
# put /signaleringen
# patch /signaleringen
# get /signaleringen/{id}
# put /signaleringen/{id}
# patch /signaleringen/{id}
# get /telefoonnummers
# post /telefoonnummers
# put /telefoonnummers
# patch /telefoonnummers
# get /telefoonnummers/{id}
# put /telefoonnummers/{id}
# patch /telefoonnummers/{id}

# %%
#printing the paths, verbs and descriptions 
paths = list(spec['paths'])
for i in range (len(paths)):
    verbs = list(spec['paths'][paths[i]])
    for j in range (len(verbs)):
        description_string = spec['paths'][paths[i]][verbs[j]]['description']
        description_string = description_string.strip('\n')
        print(paths[i], verbs[j], description_string)
# Out:
# /ping get Een ping wordt beantwoord met response code 200
# /accounts get Ophalen van Accounts
# /accounts post Voegt een nieuw(e) Account toe.
# /accounts put Vervangen van een Account op basis van overeenkomstige sleutelvelden.
# /accounts patch Wijzigen van afzonderlijke attributen van een Account. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /accounts/{id} get Retourneert een Account met de gegeven identifier
# /accounts/{id} put Vervangen van een Account
# /accounts/{id} patch Wijzigen van een Account
# /afspraken get Ophalen van Afspraken
# /afspraken post Voegt een nieuw(e) Afspraak toe.
# /afspraken put Vervangen van een Afspraak op basis van overeenkomstige sleutelvelden.
# /afspraken patch Wijzigen van afzonderlijke attributen van een Afspraak. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /afspraken/{id} get Retourneert een Afspraak met de gegeven identifier
# /afspraken/{id} put Vervangen van een Afspraak
# /afspraken/{id} patch Wijzigen van een Afspraak
# /afspraak-opties get Ophalen van AfspraakOpties
# /afspraak-opties post Voegt een nieuw(e) AfspraakOptie toe.
# /afspraak-opties put Vervangen van een AfspraakOptie op basis van overeenkomstige sleutelvelden.
# /afspraak-opties patch Wijzigen van afzonderlijke attributen van een AfspraakOptie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /afspraak-opties/{id} get Retourneert een AfspraakOptie met de gegeven identifier
# /afspraak-opties/{id} put Vervangen van een AfspraakOptie
# /afspraak-opties/{id} patch Wijzigen van een AfspraakOptie
# /afspraakverzoeken get Ophalen van Afspraakverzoeken
# /afspraakverzoeken post Voegt een nieuw(e) Afspraakverzoek toe.
# /afspraakverzoeken put Vervangen van een Afspraakverzoek op basis van overeenkomstige sleutelvelden.
# /afspraakverzoeken patch Wijzigen van afzonderlijke attributen van een Afspraakverzoek. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /afspraakverzoeken/{id} get Retourneert een Afspraakverzoek met de gegeven identifier
# /afspraakverzoeken/{id} put Vervangen van een Afspraakverzoek
# /afspraakverzoeken/{id} patch Wijzigen van een Afspraakverzoek
# /betaalgegevens get Ophalen van Betaalgegevens
# /betaalgegevens post Voegt een nieuw(e) Betaalgegeven toe.
# /betaalgegevens put Vervangen van een Betaalgegeven op basis van overeenkomstige sleutelvelden.
# /betaalgegevens patch Wijzigen van afzonderlijke attributen van een Betaalgegeven. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /betaalgegevens/{id} get Retourneert een Betaalgegeven met de gegeven identifier
# /betaalgegevens/{id} put Vervangen van een Betaalgegeven
# /betaalgegevens/{id} patch Wijzigen van een Betaalgegeven
# /contactgegevens get Ophalen van Contactgegevens
# /contactgegevens post Voegt een nieuw(e) Contactgegeven toe.
# /contactgegevens put Vervangen van een Contactgegeven op basis van overeenkomstige sleutelvelden.
# /contactgegevens patch Wijzigen van afzonderlijke attributen van een Contactgegeven. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /contactgegevens/{id} get Retourneert een Contactgegeven met de gegeven identifier
# /contactgegevens/{id} put Vervangen van een Contactgegeven
# /contactgegevens/{id} patch Wijzigen van een Contactgegeven
# /contactmomenten get Ophalen van Contactmomenten
# /contactmomenten post Voegt een nieuw(e) Contactmoment toe.
# /contactmomenten put Vervangen van een Contactmoment op basis van overeenkomstige sleutelvelden.
# /contactmomenten patch Wijzigen van afzonderlijke attributen van een Contactmoment. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /contactmomenten/{id} get Retourneert een Contactmoment met de gegeven identifier
# /contactmomenten/{id} put Vervangen van een Contactmoment
# /contactmomenten/{id} patch Wijzigen van een Contactmoment
# /inkomens get Ophalen van Inkomens
# /inkomens post Voegt een nieuw(e) Inkomen toe.
# /inkomens put Vervangen van een Inkomen op basis van overeenkomstige sleutelvelden.
# /inkomens patch Wijzigen van afzonderlijke attributen van een Inkomen. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /inkomens/{id} get Retourneert een Inkomen met de gegeven identifier
# /inkomens/{id} put Vervangen van een Inkomen
# /inkomens/{id} patch Wijzigen van een Inkomen
# /natuurlijk-personen get Ophalen van NatuurlijkPersonen
# /natuurlijk-personen post Voegt een nieuw(e) NatuurlijkPersoon toe.
# /natuurlijk-personen put Vervangen van een NatuurlijkPersoon op basis van overeenkomstige sleutelvelden.
# /natuurlijk-personen patch Wijzigen van afzonderlijke attributen van een NatuurlijkPersoon. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /natuurlijk-personen/{id} get Retourneert een NatuurlijkPersoon met de gegeven identifier
# /natuurlijk-personen/{id} put Vervangen van een NatuurlijkPersoon
# /natuurlijk-personen/{id} patch Wijzigen van een NatuurlijkPersoon
# /opleidingen get Ophalen van Opleidingen
# /opleidingen post Voegt een nieuw(e) Opleiding toe.
# /opleidingen put Vervangen van een Opleiding op basis van overeenkomstige sleutelvelden.
# /opleidingen patch Wijzigen van afzonderlijke attributen van een Opleiding. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /opleidingen/{id} get Retourneert een Opleiding met de gegeven identifier
# /opleidingen/{id} put Vervangen van een Opleiding
# /opleidingen/{id} patch Wijzigen van een Opleiding
# /rechtspersonen get Ophalen van Rechtspersonen
# /rechtspersonen post Voegt een nieuw(e) Rechtspersoon toe.
# /rechtspersonen put Vervangen van een Rechtspersoon op basis van overeenkomstige sleutelvelden.
# /rechtspersonen patch Wijzigen van afzonderlijke attributen van een Rechtspersoon. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /rechtspersonen/{id} get Retourneert een Rechtspersoon met de gegeven identifier
# /rechtspersonen/{id} put Vervangen van een Rechtspersoon
# /rechtspersonen/{id} patch Wijzigen van een Rechtspersoon
# /relaties get Ophalen van Relaties
# /relaties post Voegt een nieuw(e) Relatie toe.
# /relaties put Vervangen van een Relatie op basis van overeenkomstige sleutelvelden.
# /relaties patch Wijzigen van afzonderlijke attributen van een Relatie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /relaties/{id} get Retourneert een Relatie met de gegeven identifier
# /relaties/{id} put Vervangen van een Relatie
# /relaties/{id} patch Wijzigen van een Relatie
# /relatie-adressen get Ophalen van RelatieAdressen
# /relatie-adressen post Voegt een nieuw(e) RelatieAdres toe.
# /relatie-adressen put Vervangen van een RelatieAdres op basis van overeenkomstige sleutelvelden.
# /relatie-adressen patch Wijzigen van afzonderlijke attributen van een RelatieAdres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /relatie-adressen/{id} get Retourneert een RelatieAdres met de gegeven identifier
# /relatie-adressen/{id} put Vervangen van een RelatieAdres
# /relatie-adressen/{id} patch Wijzigen van een RelatieAdres
# /relatiegroepen get Ophalen van Relatiegroepen
# /relatiegroepen post Voegt een nieuw(e) Relatiegroep toe.
# /relatiegroepen put Vervangen van een Relatiegroep op basis van overeenkomstige sleutelvelden.
# /relatiegroepen patch Wijzigen van afzonderlijke attributen van een Relatiegroep. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /relatiegroepen/{id} get Retourneert een Relatiegroep met de gegeven identifier
# /relatiegroepen/{id} put Vervangen van een Relatiegroep
# /relatiegroepen/{id} patch Wijzigen van een Relatiegroep
# /relatierollen get Ophalen van Relatierollen
# /relatierollen post Voegt een nieuw(e) Relatierol toe.
# /relatierollen put Vervangen van een Relatierol op basis van overeenkomstige sleutelvelden.
# /relatierollen patch Wijzigen van afzonderlijke attributen van een Relatierol. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /relatierollen/{id} get Retourneert een Relatierol met de gegeven identifier
# /relatierollen/{id} put Vervangen van een Relatierol
# /relatierollen/{id} patch Wijzigen van een Relatierol
# /signaleringen get Ophalen van Signaleringen
# /signaleringen post Voegt een nieuw(e) Signalering toe.
# /signaleringen put Vervangen van een Signalering op basis van overeenkomstige sleutelvelden.
# /signaleringen patch Wijzigen van afzonderlijke attributen van een Signalering. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /signaleringen/{id} get Retourneert een Signalering met de gegeven identifier
# /signaleringen/{id} put Vervangen van een Signalering
# /signaleringen/{id} patch Wijzigen van een Signalering
# /telefoonnummers get Ophalen van Telefoonnummers
# /telefoonnummers post Voegt een nieuw(e) Telefoonnummer toe.
# /telefoonnummers put Vervangen van een Telefoonnummer op basis van overeenkomstige sleutelvelden.
# /telefoonnummers patch Wijzigen van afzonderlijke attributen van een Telefoonnummer. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /telefoonnummers/{id} get Retourneert een Telefoonnummer met de gegeven identifier
# /telefoonnummers/{id} put Vervangen van een Telefoonnummer
# /telefoonnummers/{id} patch Wijzigen van een Telefoonnummer

# %% [markdown]
# ## Getting the components

# %%
objects = list(spec['components']['schemas'])
print(len(objects))
objects.sort()
# Out:
# 38

# %%
# super lambda function to remove '-sleutels' from the list of objects
objects = [x for x in objects if "-sleutels" not in x ]
print(objects)
# Out:
# ['Account', 'Afspraak', 'AfspraakOptie', 'Afspraakverzoek', 'Betaalgegeven', 'Contactgegeven', 'Contactmoment', 'ExtraAttribuut', 'Foutbericht', 'Inkomen', 'NatuurlijkPersoon', 'Opleiding', 'Rechtspersoon', 'Referentiedata', 'Relatie', 'RelatieAdres', 'Relatiegroep', 'Relatierol', 'Signalering', 'Telefoonnummer']

# %%
spec['components']['schemas']
# Out:
# {'Account': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van de registratie.Bijv. Geregistreerd, Geactiveerd, Beëindigd etc.'},
#    'begindatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De begindatum van de registratie.'},
#    'einddatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De einddatum van de registratie.'},
#    'gebruikersnaam': {'type': 'string',
#     'format': 'any',
#     'description': 'De gebruikersnaam van de registratie.'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie behorend bij de registratie.'},
#    'wachtwoorddatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd waarop het wachtwoord het laatst is gewijzigd.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Referentiedata': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken) Bijvoorbeeld NL.'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De soort van het referentiedata item. Bijvoorbeeld nationaliteit.'},
#    'naam': {'type': 'string',
#     'format': 'any',
#     'description': 'De te tonen waarde van het referentiedata item. Bijvoorbeeld Nederlandse.'},
#    'omschrijving': {'type': 'string',
#     'format': 'any',
#     'description': 'De omschrijving van de referentiedata. Bijvoorbeeld De Nederlandse nationaliteit.'},
#    'parent': {'$ref': '#/components/schemas/Referentiedata-sleutels',
#     'description': 'De bovenliggende referentiedata in het geval er sprake is van een hierarchische relatie tussen referentiedata.'},
#    'begindatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De begindatum van het klasse item.'},
#    'einddatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De einddatum van het klasse item.'},
#    'sortering': {'type': 'string',
#     'format': 'any',
#     'description': 'De sorteervolgorde van de referentiedata anders dan alfabetisch.'}}},
#  'Referentiedata-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken) Bijvoorbeeld NL.'},
#    'naam': {'type': 'string',
#     'format': 'any',
#     'description': 'De te tonen waarde van het referentiedata item. Bijvoorbeeld Nederlandse.'}}},
#  'Relatie': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort relatie: NatuurlijkPersoon, Relatiegroep of Rechtspersoon.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van de relatie, bijv. In het geval van een VVE kan deze de status slapend of actief hebben.'},
#    'adressen': {'description': 'De adressen behorend bij de relatie.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/RelatieAdres'}},
#    'afspraken': {'description': 'De afspraken behorend bij de relatie.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Afspraak'}},
#    'betaalgegevens': {'description': 'De betaalgegevens behorend bij de relatie. Bijvoorbeeld het rekeningnummer.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Betaalgegeven'}},
#    'contactgegevens': {'description': 'De contactgegevens van de relatie.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Contactgegeven'}},
#    'contactmomenten': {'description': 'De contactmomenten behorend bij de relatie.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Contactmoment'}},
#    'groepen': {'description': 'De relatiegroepen waar de relatie toe behoort.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatiegroep'}},
#    'inspecties': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Inspectie in de vorm: vera/v4/inspecties/12345'},
#    'onderhoudsverzoeken': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Onderhoudsverzoek in de vorm: vera/v4/onderhoudsverzoeken/12345'},
#    'overeenkomsten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Overeenkomst in de vorm: vera/v4/overeenkomsten/12345'},
#    'rollen': {'description': 'De rollen behorend bij de relatie. Bijvoorbeeld: Prospect, bewoner.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatierol'}},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}},
#   'oneOf': [{'$ref': '#/components/schemas/NatuurlijkPersoon'},
#    {'$ref': '#/components/schemas/Rechtspersoon'},
#    {'$ref': '#/components/schemas/Relatiegroep'}]},
#  'RelatieAdres': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort adres van de relatie. Bijvoorbeeld: Woonadres, postadres, bezoekadres en factuuradres.'},
#    'begindatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De begindatum waarop de relatie bij het adres hoort.'},
#    'einddatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De einddatum waarop de relatie niet meer bij het adres hoort.'},
#    'adres': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Adres in de vorm: vera/v4/adressen/12345'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie behorend bij het adres.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'ExtraAttribuut': {'type': 'object',
#   'properties': {'naam': {'type': 'string',
#     'format': 'any',
#     'description': 'De naam van het niet bestaande attribuut. Bijv. Huurprognose.'},
#    'waarde': {'type': 'string',
#     'format': 'any',
#     'description': 'De waarde van het niet bestaande attribuut. Bijv. €850,-.'}}},
#  'Afspraak': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'onderwerp': {'type': 'string',
#     'format': 'any',
#     'description': 'Het onderwerp van de afspraak.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van de afspraak.'},
#    'begindatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd waarop de afspraak plaatsvindt. Als (nog) geen afspraak begindatum bekend is kan er wel een bloktijd zijn opgeven.'},
#    'einddatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd tot wanneer de afspraak naar verwachting loopt.'},
#    'bloktijdBegin': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd die het begin van een blok markeert waarbinnen de afspraak bij voorkeur start. Pas als de afspraak daadwerkelijk ingepland is, is er ook een afspraak begindatum bekend.'},
#    'bloktijdEind': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd die het eind van een blok markeert waarbinnen de afspraak bij voorkeur start.'},
#    'alternatiefContactgegeven': {'type': 'string',
#     'format': 'any',
#     'description': 'Tekstveld waarin contactgegevens van een alternatieve contactpersoon opgenomen kunnen worden. Voorbeeld is het verzoek van een huurder (student) waarbij hij aangeeft contact op te nemen met zijn ouders voor de afhandeling van het verzoek.'},
#    'contactgegeven': {'$ref': '#/components/schemas/Contactgegeven',
#     'description': 'Het contactgegeven van de relatie welke van toepassing is voor de afspraak.'},
#    'locatie': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Adres in de vorm: vera/v4/adressen/12345'},
#    'relaties': {'description': 'De relatie waarmee de afspraak is gemaakt. Bijv. de huurder, medewerker etc.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatie'}},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Contactgegeven': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort communicatie. Bijvoorbeeld: Telefoon, E-mail, .Social media etc.'},
#    'detailSoort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort detail communicatie. Bijvoorbeeld: Mobiel, privé, werk.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van het contactgegeven. Bijv. Aangemaakt, Gevalideerd, Ongeldig etc.'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie behorend bij het contactgegeven.'},
#    'relatierol': {'$ref': '#/components/schemas/Relatierol',
#     'description': 'De relatie rol van de relatie behorend bij het contactgegeven.'},
#    'vertrouwelijkheid': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De classificatie van het vertrouwelijkheidsniveau.'},
#    'voorkeur': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De manier waarop de relatie contact wil krijgen door dit contactgegeven. Bijvoorbeeld: 1e voorkeur, 2e voorkeur.'},
#    'waarde': {'type': 'string',
#     'format': 'any',
#     'description': 'De aard van het contactgegeven. Dit kan de waarde zijn van een telefoonnummer, emailadres, of twitteradres. Bijvoorbeeld: 020-1234563 '},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}},
#   'oneOf': [{'$ref': '#/components/schemas/Telefoonnummer'}]},
#  'Relatierol': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort rol van de relatie. Bijvoorbeeld Klant, Prospect, Leverancier, Medewerker, Team etc.'},
#    'naam': {'type': 'string',
#     'format': 'any',
#     'description': 'De naam van de relatie rol.'},
#    'omschrijving': {'type': 'string',
#     'format': 'any',
#     'description': 'De omschrijving van de relatie rol.'},
#    'begindatum': {'type': 'string',
#     'format': 'date',
#     'description': 'begindatum van de rol'},
#    'einddatum': {'type': 'string',
#     'format': 'date',
#     'description': 'einddatum van de rol'},
#    'contactgegevens': {'description': 'De contactgegevens van een relatie in een bepaalde rol.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Contactgegeven'}},
#    'contactmomenten': {'description': 'De contactmomenten die de relatie vanuit een rol heeft.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Contactmoment'}},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie waarvoor de rol van toepassing is.'},
#    'relatieAdressen': {'description': 'De adresssen van de relatie die voor de rol van toepassing zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/RelatieAdres'}},
#    'rolRelatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie die aangeeft waar de relatie en rol koppeling van toepassing is. Dit attribuut geeft aan dat de aangegeven relatie de rol binnen bijvoorbeeld een relatiegroep heeft. Het attribuut relatie is dan bijvoorbeeld een persoon uit een huishouden en de rolRelatie is dan bijvoorbeeld de relatiegroep die het huishouden voorstelt.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Contactmoment': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'omschrijving': {'type': 'string',
#     'format': 'any',
#     'description': 'De omschrijving van het contactmoment'},
#    'datum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd waarop contact is geweest.'},
#    'dossier': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Dossier in de vorm: vera/v4/dossiers/12345'},
#    'kanaal': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het kanaal via welke het contact heeft gelopen. Bijvoorbeeld: Telefoon, email, balie, internet.'},
#    'relaties': {'description': 'De relatie waarmee contact is geweest. Bijv. een huurder, medewerker etc.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatie'}},
#    'richting': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De communicatierichting behorend bij het contact. Bijvoorbeeld: Uitgaand of ingaand.'},
#    'zaak': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Zaak in de vorm: vera/v4/zaken/12345'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Betaalgegeven': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort betaalgegeven (bijvoorbeeld een bankrekening, paypal, creditcard, G-rekening etc.).'},
#    'begindatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De begindatum van het betaalgegeven.'},
#    'einddatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De einddatum van het betaalgegeven.'},
#    'bic': {'type': 'string',
#     'format': 'any',
#     'description': 'Bank Identifier Code. Hierdoor komen internationale betalingsoverdrachten bij de juiste bank terecht. De BIC wordt ook wel SWIFT-adres of SWIFT-code genoemd.'},
#    'iban': {'type': 'string',
#     'format': 'any',
#     'description': 'Het International Bank Account Number. Identificeert elke rekeninghouder, inclusief bank en vestigingsland.'},
#    'incassomachtigingen': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Incassomachtiging in de vorm: vera/v4/incassomachtigingen/12345'},
#    'incassowijze': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De standaard incassowijze voor het betaalgegeven.'},
#    'overeenkomst': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Overeenkomst in de vorm: vera/v4/overeenkomsten/12345'},
#    'primair': {'type': 'boolean',
#     'description': 'De aanduiding dat het betaalgegeven het primaire betaalgegeven betreft.'},
#    'rekeninghouder': {'type': 'string',
#     'format': 'any',
#     'description': 'De naam van de rekeninghouder.'},
#    'rekeningnummer': {'type': 'string',
#     'format': 'any',
#     'description': 'Het rekeningnummer.'},
#    'rekeningPlaats': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Woonplaats in de vorm: vera/v4/woonplaatsen/12345'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie behorend bij het betaalgegeven.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Relatiegroep': {'allOf': [{'$ref': '#/components/schemas/Relatie'},
#    {'type': 'object',
#     'properties': {'naam': {'type': 'string',
#       'format': 'any',
#       'description': 'De naam van de relatiegroep.'},
#      'relaties': {'description': '',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/Relatie'}},
#      'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#      'informatieobjecten': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}}]},
#  'AfspraakOptie': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'begindatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd waarop de afspraak plaatsvindt.'},
#    'einddatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd tot wanneer de afspraak loopt.'},
#    'bloktijdBegin': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd die het begin van een blok markeert waarbinnen de afspraak bij voorkeur start. Pas als de afspraak daadwerkelijk ingepland is, is er ook een afspraak begindatum bekend.'},
#    'bloktijdEind': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd die het eind van een blok markeert waarbinnen de afspraak bij voorkeur start.'},
#    'locatie': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Adres in de vorm: vera/v4/adressen/12345'},
#    'onderhoudsorder': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Onderhoudsorder in de vorm: vera/v4/onderhoudsorders/12345'},
#    'onderhoudstaak': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Onderhoudstaak in de vorm: vera/v4/onderhoudstaken/12345'},
#    'onderhoudsverzoek': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Onderhoudsverzoek in de vorm: vera/v4/onderhoudsverzoeken/12345'},
#    'planningscore': {'type': 'number', 'format': 'float'},
#    'relaties': {'description': 'De relaties waarvoor de afspraak optie van toepassing is.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatie'}},
#    'specialisme': {'$ref': '#/components/schemas/Referentiedata',
#     'description': ''},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Afspraakverzoek': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken).'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Soort van de afspraak: bijvoorbeeld voorinspectie.'},
#    'duur': {'type': 'string',
#     'format': 'duration',
#     'description': 'Duur van de afspraak.',
#     'pattern': '^(-?)P(?=\\d|T\\d)(?:(\\d+)Y)?(?:(\\d+)M)?(?:(\\d+)([DW]))?(?:T(?:(\\d+)H)?(?:(\\d+)M)?(?:(\\d+(?:\\.\\d+)?)S)?)?$'},
#    'termijn': {'type': 'string',
#     'format': 'duration',
#     'description': 'Termijn waarbinnende afspraak moet plaatsvinden.',
#     'pattern': '^(-?)P(?=\\d|T\\d)(?:(\\d+)Y)?(?:(\\d+)M)?(?:(\\d+)([DW]))?(?:T(?:(\\d+)H)?(?:(\\d+)M)?(?:(\\d+(?:\\.\\d+)?)S)?)?$'},
#    'adres': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Adres in de vorm: vera/v4/adressen/12345'},
#    'opties': {'description': 'De mogelijke momenten waarop de afspraak kan worden gemaakt.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/AfspraakOptie'}},
#    'relaties': {'description': 'De betrokken relaties voor de te maken afspraak. Bijv. de huurder, medewerker etc.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatie'}},
#    'volgorde': {'type': 'integer',
#     'format': 'int32',
#     'description': 'De volgorde waarin de specifieke afspraak dient te worden uitgevoerd ten opzichte van andere afspraakverzoeken.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Inkomen': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'controledatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De datum en tijd waarop de inkomensgegevens zijn gecontroleerd.'},
#    'bron': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De waarde die aangeeft op welke wijze het inkomen vergaard. Bijvoorbeeld: Uit Werk of uitkering.'},
#    'brutoJaarinkomen': {'type': 'number',
#     'format': 'float',
#     'description': "Het bruto jaarinkomen in euro's van de natuurlijk persoon."},
#    'brutoMaandinkomen': {'type': 'number',
#     'format': 'float',
#     'description': "Het bruto maandinkomen in euro's van de natuurlijk persoon."},
#    'inkomensverklaringsoort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort inkomensverklaring waaruit het inkomen is overgenomen. Bijv. Jaaropgave, Inkomensverklaring belastingdienst etc.'},
#    'nettoJaarinkomen': {'type': 'number',
#     'format': 'float',
#     'description': "Het netto jaarinkomen in euro's van de natuurlijk persoon."},
#    'nettoMaandinkomen': {'type': 'number',
#     'format': 'float',
#     'description': "Het netto maandinkomen in euro's van de natuurlijk persoon."},
#    'relaties': {'description': 'De relaties behorend bij het inkomen. Bijv. de woningzoekende, huurder, controleur etc.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatie'}},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'NatuurlijkPersoon': {'allOf': [{'$ref': '#/components/schemas/Relatie'},
#    {'type': 'object',
#     'properties': {'bsn': {'type': 'string',
#       'format': 'any',
#       'description': 'Het BSN (Burger Service Nummer) van de natuurlijk persoon.'},
#      'geboortedatum': {'type': 'string',
#       'format': 'date',
#       'description': 'De geboortedatum van de natuurlijk persoon.'},
#      'overlijdensdatum': {'type': 'string',
#       'format': 'date',
#       'description': 'De datum van overlijden van de natuurlijk persoon.'},
#      'aanbiedingen': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Aanbieding in de vorm: vera/v4/aanbiedingen/12345'},
#      'aanhef': {'type': 'string',
#       'format': 'any',
#       'description': 'De aanhef of aanspreking is een (meestal vriendelijke) introducerende zin van een brief of e-mail. Het gaat doorgaans om standaardformuleringen waarmee de schrijver zich tot de geadresseerde richt.'},
#      'achternaam': {'type': 'string',
#       'format': 'any',
#       'description': 'De achternaam van de natuurlijk persoon.'},
#      'burgerlijkeStaat': {'$ref': '#/components/schemas/Referentiedata',
#       'description': 'De burgerlijke staat van de natuurlijk persoon.'},
#      'geslacht': {'$ref': '#/components/schemas/Referentiedata',
#       'description': 'Het geslacht van de natuurlijk persoon.'},
#      'initialen': {'type': 'string',
#       'format': 'any',
#       'description': 'De initialen van de natuurlijk persoon.'},
#      'inkomens': {'description': 'De inkomens van de natuurlijk persoon.',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/Inkomen'}},
#      'nationaliteit': {'$ref': '#/components/schemas/Referentiedata',
#       'description': 'De nationaliteit van de natuurlijk persoon.'},
#      'opleiding': {'$ref': '#/components/schemas/Opleiding',
#       'description': 'Het opleidingsgegeven van de natuurlijk persoon.'},
#      'reacties': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Reactie in de vorm: vera/v4/reacties/12345'},
#      'regelingen': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Regeling in de vorm: vera/v4/regelingen/12345'},
#      'roepnaam': {'type': 'string',
#       'format': 'any',
#       'description': 'De roepnaam van de natuurlijk persoon.'},
#      'signaleringen': {'description': 'De signaleringen behorend bij de natuurlijk persoon.',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/Signalering'}},
#      'toewijzingen': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Toewijzing in de vorm: vera/v4/toewijzingen/12345'},
#      'tussenvoegsels': {'type': 'string',
#       'format': 'any',
#       'description': 'De tussenvoegsels behorende bij de naam.'},
#      'voorkeurstaal': {'$ref': '#/components/schemas/Referentiedata',
#       'description': 'De voorkeurstaal die de natuurlijk persoon voert.'},
#      'voorletters': {'type': 'string',
#       'format': 'any',
#       'description': 'Een voorletter is een afkorting van een voornaam, die in adressering veel wordt gebruikt. De voorletters geven in combinatie met de achternaam meestal een duidelijk onderscheid tussen leden van hetzelfde gezin of dezelfde familie. Indien iemand meerdere voornamen heeft dan worden de voorletters door een punt gescheiden.'},
#      'voornaam': {'type': 'string',
#       'format': 'any',
#       'description': 'De voornaam van de natuurlijk persoon.'},
#      'voorrangsregelingen': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Voorrangsregeling in de vorm: vera/v4/voorrangsregelingen/12345'},
#      'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#      'informatieobjecten': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}}]},
#  'Opleiding': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'studentnummer': {'type': 'string',
#     'format': 'any',
#     'description': 'Het studentnummer van de relatie'},
#    'begindatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De begindatum waarop de studie is begonnen.'},
#    'einddatum': {'type': 'string',
#     'format': 'date',
#     'description': 'De einddatum waarop de studie is beëindigd.'},
#    'instelling': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De opleidingsinstelling die aangeeft waar de relatie de studie volgt. We hanteren hiervoor de BRIN.'},
#    'niveau': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het hoogst genoten opleidingsniveau van de relatie. Bijvoorbeeld: HBO of Universitair.'},
#    'plaats': {'type': 'string',
#     'format': 'any',
#     'description': 'De plaats waar de relatie de studie volgt.'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie die de opleiding volgt.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Signalering': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort signaal. Bijvoorbeeld: Huurschuld, overlast of wietplantage.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van de signalering. Bijvoorbeeld: Actief, vervallen of passief.'},
#    'detailStatus': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De detailstatus van de signalering. Bijvoorbeeld: Ontruiming, vertrokken.'},
#    'begindatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De begindatum van de signalering.'},
#    'einddatum': {'type': 'string',
#     'format': 'date-time',
#     'description': 'De einddatum van de signalering.'},
#    'adres': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Adres in de vorm: vera/v4/adressen/12345'},
#    'relatie': {'$ref': '#/components/schemas/Relatie',
#     'description': 'De relatie behorend bij de signalering.'},
#    'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#    'informatieobjecten': {'type': 'string',
#     'format': 'uri',
#     'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}},
#  'Rechtspersoon': {'allOf': [{'$ref': '#/components/schemas/Relatie'},
#    {'type': 'object',
#     'properties': {'kvkNummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Het KVK nummer van de rechtspersoon.'},
#      'globaalLocatienummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Een wereldwijd nummer ter identificatie van een partij of locatie. Het dertiencijferige nummer (GLN) wordt uitgegeven door GS1.'},
#      'naam': {'type': 'string',
#       'format': 'any',
#       'description': 'De naam de rechtspersoon.'},
#      'btwNummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Het BTW nummer van de rechtspersoon.'},
#      'organisatievorm': {'$ref': '#/components/schemas/Referentiedata',
#       'description': 'De organisatievorm van de rechtspersoon. Bijvoorbeeld: BV, NV, stichting of vereniging. Ook wel rechtsvorm genoemd.'},
#      'relaties': {'description': 'De contactpersonen behorend bij de rechtspersoon.',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/Relatie'}},
#      'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#      'informatieobjecten': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}}]},
#  'Telefoonnummer': {'allOf': [{'$ref': '#/components/schemas/Contactgegeven'},
#    {'type': 'object',
#     'properties': {'abonneenummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Het abonneenummer van het telefoonnummer.'},
#      'dagdelen': {'description': 'De dagdelen waarop er gebruikt gemaakt kan worden van het telefoonnummer.',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/Referentiedata'}},
#      'extensie': {'type': 'string',
#       'format': 'any',
#       'description': 'De extensie van het telefoonnummer.'},
#      'landnummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Het landnummer van het telefoonnummer.'},
#      'netnummer': {'type': 'string',
#       'format': 'any',
#       'description': 'Het netnummer van het telefoonnummer.'},
#      'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#       'type': 'array',
#       'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#      'informatieobjecten': {'type': 'string',
#       'format': 'uri',
#       'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}}]},
#  'Account-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'Afspraak-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'AfspraakOptie-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'Afspraakverzoek-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken).'}}},
#  'Betaalgegeven-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'iban': {'type': 'string',
#     'format': 'any',
#     'description': 'Het International Bank Account Number. Identificeert elke rekeninghouder, inclusief bank en vestigingsland.'},
#    'rekeningnummer': {'type': 'string',
#     'format': 'any',
#     'description': 'Het rekeningnummer.'}}},
#  'Contactgegeven-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort communicatie. Bijvoorbeeld: Telefoon, E-mail, .Social media etc.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van het contactgegeven. Bijv. Aangemaakt, Gevalideerd, Ongeldig etc.'}}},
#  'Contactmoment-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'Inkomen-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'NatuurlijkPersoon-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort relatie: NatuurlijkPersoon, Relatiegroep of Rechtspersoon.'},
#    'rollen': {'description': 'De rollen behorend bij de relatie. Bijvoorbeeld: Prospect, bewoner.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatierol'}}}},
#  'Opleiding-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'studentnummer': {'type': 'string',
#     'format': 'any',
#     'description': 'Het studentnummer van de relatie'}}},
#  'Rechtspersoon-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort relatie: NatuurlijkPersoon, Relatiegroep of Rechtspersoon.'},
#    'rollen': {'description': 'De rollen behorend bij de relatie. Bijvoorbeeld: Prospect, bewoner.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatierol'}}}},
#  'Relatie-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort relatie: NatuurlijkPersoon, Relatiegroep of Rechtspersoon.'},
#    'rollen': {'description': 'De rollen behorend bij de relatie. Bijvoorbeeld: Prospect, bewoner.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatierol'}}}},
#  'RelatieAdres-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort adres van de relatie. Bijvoorbeeld: Woonadres, postadres, bezoekadres en factuuradres.'}}},
#  'Relatiegroep-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort relatie: NatuurlijkPersoon, Relatiegroep of Rechtspersoon.'},
#    'rollen': {'description': 'De rollen behorend bij de relatie. Bijvoorbeeld: Prospect, bewoner.',
#     'type': 'array',
#     'items': {'$ref': '#/components/schemas/Relatierol'}}}},
#  'Relatierol-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'Signalering-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'}}},
#  'Telefoonnummer-sleutels': {'type': 'object',
#   'properties': {'id': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het bronsysteem. Je verstuurt een entiteit altijd met het eigen id. Id kan leeg zijn.'},
#    'idExtern': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven in het doelsysteem. Deze idExtern wisselt om met id afhankelijk van de richting van de gegevensuitwisseling.'},
#    'idGegevensbeheerder': {'type': 'string',
#     'format': 'any',
#     'description': 'De primaire sleutel van het gegeven van de gegevensbeheerder. Bijv. de overheid of andere standaarden.'},
#    'code': {'type': 'string',
#     'format': 'any',
#     'description': 'De unieke code (Bijvoorbeeld om te tonen of te zoeken)'},
#    'soort': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'Het soort communicatie. Bijvoorbeeld: Telefoon, E-mail, .Social media etc.'},
#    'status': {'$ref': '#/components/schemas/Referentiedata',
#     'description': 'De status van het contactgegeven. Bijv. Aangemaakt, Gevalideerd, Ongeldig etc.'}}},
#  'Foutbericht': {'type': 'object',
#   'properties': {'code': {'type': 'string'},
#    'omschrijving': {'type': 'string'}}}}

# %%
my_list= []
my_dict = spec['components']['schemas']['Punt']['allOf'][0]
for key, value in my_dict.items():
    my_string = str(value)
my_string = my_string.replace('#/components/schemas/', 'allOf ')
my_list.append(my_string)
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_108576/1474302593.py in <module>
#       1 my_list= []
# ----> 2 my_dict = spec['components']['schemas']['Punt']['allOf'][0]
#       3 for key, value in my_dict.items():
#       4     my_string = str(value)
#       5 my_string = my_string.replace('#/components/schemas/', 'allOf ')
#
# KeyError: 'Punt'

# %%
my_str='#/components/schemas/Geometrie'
print(my_str)
# Out:
# #/components/schemas/Geometrie

# %%
my_string.replace('#/components/schemas/', 'allOf ')
# Out:
# 'allOf Geometrie'

# %%
spec['components']['schemas']['Punt']['allOf'][0]
# Out:
# {'$ref': '#/components/schemas/Geometrie'}

# %%
punt_list = spec['components']['schemas']['Punt']['allOf']
punt_list[1]
# Out:
# {'type': 'object',
#  'properties': {'breedtegraad': {'type': 'number',
#    'format': 'float',
#    'description': 'De breedtegraad.'},
#   'lengtegraad': {'type': 'number',
#    'format': 'float',
#    'description': 'De lengtegraad.'},
#   'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#    'type': 'array',
#    'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#   'informatieobjecten': {'type': 'string',
#    'format': 'uri',
#    'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}}

# %%
punt_list_dict = punt_list[1]
list(punt_list_dict['properties'])
# Out:
# ['breedtegraad', 'lengtegraad', 'extra-attributen', 'informatieobjecten']

# %%
spec['components']['schemas']['Punt']['allOf'][1]['properties']
# Out:
# {'breedtegraad': {'type': 'number',
#   'format': 'float',
#   'description': 'De breedtegraad.'},
#  'lengtegraad': {'type': 'number',
#   'format': 'float',
#   'description': 'De lengtegraad.'},
#  'extra-attributen': {'description': 'Mogelijkheid om het bericht uit te breiden met attributen die nog niet in het logisch datamodel beschikbaar zijn',
#   'type': 'array',
#   'items': {'$ref': '#/components/schemas/ExtraAttribuut'}},
#  'informatieobjecten': {'type': 'string',
#   'format': 'uri',
#   'description': 'Referentie naar Informatieobject in de vorm: vera/v4/informatieobjecten/12345'}}

# %%
#creating a dictionary with objects and their properties
object_dict ={}
#objects = list(spec['components']['schemas'])
for i in range (len(objects)):
    try:
        object_dict[objects[i]]=list(spec['components']['schemas'][objects[i]]['properties'])#['properties']
    except:
        my_list= []
        my_dict = spec['components']['schemas'][objects[i]]['allOf'][0]
        for key, value in my_dict.items():
            my_string = str(value)
        my_string = my_string.replace('#/components/schemas/', 'allOf: ')
        my_list.append(my_string)
        object_dict[objects[i]] = my_list+list(spec['components']['schemas'][objects[i]]['allOf'][1]['properties'])
object_dict
# Out:
# {'Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam',
#   'extra-attributen',
#   'informatieobjecten'],
#  'AdresseerbaarObjectBasisregistratie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'bagGebruikersOppervlakte',
#   'bagGebruiksdoelen',
#   'bagHoofdadres',
#   'bagIdentificatie',
#   'bagInOnderzoek',
#   'bagNevenadressen',
#   'bagOfficieel',
#   'bagOppervlakteVerblijfsobject',
#   'bagPandenBasisregistratie',
#   'bagStatus',
#   'geometrie',
#   'extra-attributen',
#   'informatieobjecten'],
#  'BagAdres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'bagNummeraanduidingIdentificatie',
#   'bagOpenbareRuimteIdentificatie',
#   'bagNummeraanduidingInOnderzoek',
#   'bagNummeraanduidingOfficieel',
#   'bagNummeraanduidingStatus',
#   'bagOpenbareRuimteInOnderzoek',
#   'bagOpenbareruimteOfficieel',
#   'bagOpenbareruimtestatus',
#   'extra-attributen',
#   'informatieobjecten'],
#  'BagPand': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'bagIdentificatie',
#   'bagStatus',
#   'bagInOnderzoek',
#   'bagOfficieel',
#   'bagBouwdatum',
#   'extra-attributen',
#   'informatieobjecten'],
#  'BagWoonplaats': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'bagIdentificatie',
#   'bagStatus',
#   'bagInOnderzoek',
#   'bagOfficieel',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Beleidswaarde': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'achterstalligOnderhoud',
#   'afkoopErfpacht',
#   'beheerAfslag',
#   'beheerskosten',
#   'beschikbaarheidAfslag',
#   'betaalbaarheidAfslag',
#   'eenheid',
#   'kwaliteitAfslag',
#   'marktwaarde',
#   'onderhoudskosten',
#   'streefhuur',
#   'waarde',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Bouwdeel': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'bouwdelen',
#   'bouwkundigeElementen',
#   'collectieveObjecten',
#   'eenheden',
#   'gebouw',
#   'pand',
#   'extra-attributen',
#   'informatieobjecten'],
#  'BouwkundigElement': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'bouwdeel',
#   'garanties',
#   'relaties',
#   'extra-attributen',
#   'informatieobjecten'],
#  'BuitenlandsAdres': ['allOf: Adres',
#   'adresregel1',
#   'adresregel2',
#   'land',
#   'postbusnummer',
#   'provincie',
#   'woonplaats',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Buurt': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'eenheden',
#   'gebouwen',
#   'geometrie',
#   'relaties',
#   'wijk',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Cluster': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'omschrijving',
#   'bovenliggendeCluster',
#   'begindatum',
#   'einddatum',
#   'collectieveObjecten',
#   'conditiemeting',
#   'eenheden',
#   'garanties',
#   'geometrie',
#   'relaties',
#   'extra-attributen',
#   'informatieobjecten'],
#  'CollectiefObject': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'adres',
#   'bouwdelen',
#   'clusters',
#   'eenheden',
#   'garanties',
#   'relaties',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Conditiemeting': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'conditiescore',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Eenheid': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'naam',
#   'omschrijving',
#   'bouwnummer',
#   'status',
#   'detailStatus',
#   'inExploitatiedatum',
#   'uitExploitatiedatum',
#   'beginBouwdatum',
#   'opleverdatum',
#   'aantalOnzelfstandigeEenheden',
#   'aanvullendeDoelgroep',
#   'adres',
#   'adresseerbaarObjectBasisregistratie',
#   'beleidswaarde',
#   'benodigdeAfspraakverzoeken',
#   'beoogdUitExploitatieDatum',
#   'bestemming',
#   'bouwdelen',
#   'bovenliggendeEenheid',
#   'brutohuur',
#   'buitenruimten',
#   'clusters',
#   'collectieveObjecten',
#   'doelgroep',
#   'energieprestatie',
#   'energievoorzieningen',
#   'etage',
#   'gebouw',
#   'gebruiksoppervlakte',
#   'inExploitatieReden',
#   'interieur',
#   'isolatie',
#   'juridischEigendomspercentage',
#   'kadastraalNummer',
#   'kamersAantal',
#   'klimaatbeheersing',
#   'kwaliteitsniveau',
#   'ligging',
#   'liggingTuin',
#   'maatschappelijkLabel',
#   'marktlabel',
#   'marktwaarde',
#   'monumenten',
#   'nevenadressen',
#   'onderhoudslabel',
#   'overeenkomsten',
#   'overigeVertrekkenTotaalOppervlakte',
#   'panden',
#   'prestatieafspraken',
#   'prijscomponenten',
#   'prijsconditie',
#   'publicatie',
#   'publicatieLabel',
#   'rekenhuur',
#   'relaties',
#   'renovatie',
#   'sanitair',
#   'situering',
#   'streefhuur',
#   'taxaties',
#   'toegankelijkheidslabel',
#   'totaalInhoud',
#   'totaleOppervlakte',
#   'uitExploitatieReden',
#   'verkoop',
#   'vertrekken',
#   'vertrekkenAantal',
#   'verwarmdeVertrekkenAantal',
#   'volgnummer',
#   'voorwaarden',
#   'vraagprijs',
#   'woningwaarderingResultaat',
#   'woonvertrekInhoud',
#   'woonvertrekkenTotaalOppervlakte',
#   'woonvorm',
#   'wozEenheden',
#   'zekerheidVerpandingen',
#   'zelfstandig',
#   'zorgfaciliteitOmschrijving',
#   'extra-attributen',
#   'informatieobjecten'],
#  'EenheidToestand': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'status',
#   'detailStatus',
#   'begindatum',
#   'einddatum',
#   'eenheid',
#   'extra-attributen',
#   'informatieobjecten'],
#  'EenheidVoorwaarden': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'maximumAantalPersonen',
#   'maximuminkomen',
#   'maximunleeftijd',
#   'minimumAantalPersonen',
#   'minimuminkomen',
#   'minimumleeftijd',
#   'selectiecriteria',
#   'voorrangscriteria',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Eenheidadres': ['allOf: Adres',
#   'bag',
#   'buurt',
#   'gemeente',
#   'geometrie',
#   'land',
#   'provincie',
#   'wijk',
#   'woonplaats',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Energieprestatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'eenheid',
#   'index',
#   'label',
#   'relatie',
#   'extra-attributen',
#   'informatieobjecten'],
#  'ExtraAttribuut': ['naam', 'waarde'],
#  'Foutbericht': ['code', 'omschrijving'],
#  'Garantie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'omschrijving',
#   'begindatum',
#   'einddatum',
#   'bouwdelen',
#   'bouwkundigeElementen',
#   'clusters',
#   'collectieveObjecten',
#   'eenheden',
#   'overeenkomst',
#   'relatie',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Gebouw': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'bouwdelen',
#   'buurt',
#   'corporatieBuurt',
#   'corporatieWijk',
#   'eenheden',
#   'panden',
#   'wijk',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Gemeente': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'geometrie',
#   'provincie',
#   'stadsdelen',
#   'woonplaatsen',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Geometrie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'omschrijving',
#   'extra-attributen',
#   'informatieobjecten'],
#  'KadasterPerceel': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Marktwaarde': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'beheersKosten',
#   'contractJaarhuur',
#   'disconteringsvoet',
#   'doorexploiterenDisconteringsvoet',
#   'eenheid',
#   'leegwaarde',
#   'marktJaarhuur',
#   'onderhoudsKosten',
#   'verhuurderheffing',
#   'verslagJaar',
#   'waarde',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Pand': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'status',
#   'adresseerbareObjectenBasisregistratie',
#   'bag',
#   'bouwdelen',
#   'eenheden',
#   'gebouw',
#   'geometrie',
#   'kavelOppervlakte',
#   'liftAanwezig',
#   'renovatie',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Postadres': ['allOf: Adres',
#   'antwoordnummer',
#   'postbusnummer',
#   'woonplaats',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Punt': ['allOf: Geometrie',
#   'breedtegraad',
#   'lengtegraad',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Referentiedata': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'omschrijving',
#   'parent',
#   'begindatum',
#   'einddatum',
#   'sortering'],
#  'Renovatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'omschrijving',
#   'datum',
#   'eenheden',
#   'panden',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Stadsdeel': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'gemeente',
#   'geometrie',
#   'wijken',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Taxatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'datum',
#   'eenheid',
#   'waarde',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Vertrek': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'eenheid',
#   'inhoud',
#   'oppervlakte',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Wijk': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'buurten',
#   'geometrie',
#   'relaties',
#   'stadsdeel',
#   'woonplaats',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Woningwaardering': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'aantal',
#   'criterium',
#   'eenheid',
#   'groep',
#   'punten',
#   'extra-attributen',
#   'informatieobjecten'],
#  'WoningwaarderingCriterium': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'criteriumGroep',
#   'meeteenheid',
#   'stelsel',
#   'extra-attributen',
#   'informatieobjecten'],
#  'WoningwaarderingCriteriumGroep': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'omschrijving',
#   'criteria',
#   'soort',
#   'stelsel',
#   'extra-attributen',
#   'informatieobjecten'],
#  'WoningwaarderingGroep': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'criteriumGroep',
#   'eenheid',
#   'punten',
#   'woningwaarderingen',
#   'extra-attributen',
#   'informatieobjecten'],
#  'WoningwaarderingResultaat': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'eenheid',
#   'groepen',
#   'maximaleHuur',
#   'punten',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Woonplaats': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam',
#   'bag',
#   'gemeente',
#   'geometrie',
#   'wijken',
#   'extra-attributen',
#   'informatieobjecten'],
#  'WozEenheid': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'eenheid',
#   'vastgesteldeWaarde',
#   'waardepeildatum',
#   'extra-attributen',
#   'informatieobjecten'],
#  'ZekerheidVerpanding': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'begindatum',
#   'einddatum',
#   'akteSoort',
#   'belastingdienstRegistratiedatum',
#   'eenheid',
#   'onderpandWSW',
#   'relaties',
#   'extra-attributen',
#   'informatieobjecten']}

# %% [markdown]
# ### Creating a plantuml file

# %%
textfile = open(API_name+"_API_plantuml.txt", "w")
textfile.write('@startuml\n')
for key, value in object_dict.items():
    textfile.write('class '+str(key) +'{\n')
    for i in range (len(value)):
        textfile.write(value[i] + "\n")
    textfile.write('}\n')
#textfile.write('}\n')
textfile.write('@enduml')
textfile.close()

# %%
import glob
my_txts = glob.glob('*.txt')
my_txts
# Out:
# ['VERA-Onderhoud_API_plantuml.txt', 'VERA-Vastgoed_API_plantuml.txt']

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA'

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA\VERA-Vastgoed_API_plantuml.txt

# %%
#convert the txt file to an .png image using plantuml
# !python -m plantuml VERA-Vastgoed_API_plantuml.txt
# Out:
# [{'filename': 'VERA-Vastgoed_API_plantuml.txt', 'gen_success': True}]

# %%
#show the generated png
from IPython import display
display.Image(filename="VERA-Vastgoed_API_plantuml.png", width=1000, height=800)

# %% [markdown]
# ### Saving as a .csv file

# %%
with open(API_name+"_API_objecten.csv", mode="w") as my_csv:
    for key, value in object_dict.items():
        my_csv.write(str(key)+";")
        for i in range (len(value)-1):
            my_csv.write(value[i]+",")#write values + a comma  
        my_csv.write(value[-1]+"\n") #write last value (and no comma)

# %%
import glob
my_csvs=glob.glob('*.csv')
my_csvs
# Out:
# ['VERA-Onderhoud_API_objecten.csv', 'VERA-Vastgoed_API_objecten.csv']

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA\\VERA-Vastgoed_API_objecten.csv

# %% [markdown]
# ### Saving as a .json file

# %%
#converting the python dict to a JSON 
import json 
      
# Serializing json  
json_object = json.dumps(object_dict, indent = 4) 
print(json_object)
# Out:
# {
#     "Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "AdresseerbaarObjectBasisregistratie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "bagGebruikersOppervlakte",
#         "bagGebruiksdoelen",
#         "bagHoofdadres",
#         "bagIdentificatie",
#         "bagInOnderzoek",
#         "bagNevenadressen",
#         "bagOfficieel",
#         "bagOppervlakteVerblijfsobject",
#         "bagPandenBasisregistratie",
#         "bagStatus",
#         "geometrie",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "BagAdres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "bagNummeraanduidingIdentificatie",
#         "bagOpenbareRuimteIdentificatie",
#         "bagNummeraanduidingInOnderzoek",
#         "bagNummeraanduidingOfficieel",
#         "bagNummeraanduidingStatus",
#         "bagOpenbareRuimteInOnderzoek",
#         "bagOpenbareruimteOfficieel",
#         "bagOpenbareruimtestatus",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "BagPand": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "bagIdentificatie",
#         "bagStatus",
#         "bagInOnderzoek",
#         "bagOfficieel",
#         "bagBouwdatum",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "BagWoonplaats": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "bagIdentificatie",
#         "bagStatus",
#         "bagInOnderzoek",
#         "bagOfficieel",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Beleidswaarde": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "achterstalligOnderhoud",
#         "afkoopErfpacht",
#         "beheerAfslag",
#         "beheerskosten",
#         "beschikbaarheidAfslag",
#         "betaalbaarheidAfslag",
#         "eenheid",
#         "kwaliteitAfslag",
#         "marktwaarde",
#         "onderhoudskosten",
#         "streefhuur",
#         "waarde",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Bouwdeel": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "bouwdelen",
#         "bouwkundigeElementen",
#         "collectieveObjecten",
#         "eenheden",
#         "gebouw",
#         "pand",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "BouwkundigElement": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "bouwdeel",
#         "garanties",
#         "relaties",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "BuitenlandsAdres": [
#         "allOf: Adres",
#         "adresregel1",
#         "adresregel2",
#         "land",
#         "postbusnummer",
#         "provincie",
#         "woonplaats",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Buurt": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "eenheden",
#         "gebouwen",
#         "geometrie",
#         "relaties",
#         "wijk",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Cluster": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "omschrijving",
#         "bovenliggendeCluster",
#         "begindatum",
#         "einddatum",
#         "collectieveObjecten",
#         "conditiemeting",
#         "eenheden",
#         "garanties",
#         "geometrie",
#         "relaties",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "CollectiefObject": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "adres",
#         "bouwdelen",
#         "clusters",
#         "eenheden",
#         "garanties",
#         "relaties",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Conditiemeting": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "conditiescore",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Eenheid": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "naam",
#         "omschrijving",
#         "bouwnummer",
#         "status",
#         "detailStatus",
#         "inExploitatiedatum",
#         "uitExploitatiedatum",
#         "beginBouwdatum",
#         "opleverdatum",
#         "aantalOnzelfstandigeEenheden",
#         "aanvullendeDoelgroep",
#         "adres",
#         "adresseerbaarObjectBasisregistratie",
#         "beleidswaarde",
#         "benodigdeAfspraakverzoeken",
#         "beoogdUitExploitatieDatum",
#         "bestemming",
#         "bouwdelen",
#         "bovenliggendeEenheid",
#         "brutohuur",
#         "buitenruimten",
#         "clusters",
#         "collectieveObjecten",
#         "doelgroep",
#         "energieprestatie",
#         "energievoorzieningen",
#         "etage",
#         "gebouw",
#         "gebruiksoppervlakte",
#         "inExploitatieReden",
#         "interieur",
#         "isolatie",
#         "juridischEigendomspercentage",
#         "kadastraalNummer",
#         "kamersAantal",
#         "klimaatbeheersing",
#         "kwaliteitsniveau",
#         "ligging",
#         "liggingTuin",
#         "maatschappelijkLabel",
#         "marktlabel",
#         "marktwaarde",
#         "monumenten",
#         "nevenadressen",
#         "onderhoudslabel",
#         "overeenkomsten",
#         "overigeVertrekkenTotaalOppervlakte",
#         "panden",
#         "prestatieafspraken",
#         "prijscomponenten",
#         "prijsconditie",
#         "publicatie",
#         "publicatieLabel",
#         "rekenhuur",
#         "relaties",
#         "renovatie",
#         "sanitair",
#         "situering",
#         "streefhuur",
#         "taxaties",
#         "toegankelijkheidslabel",
#         "totaalInhoud",
#         "totaleOppervlakte",
#         "uitExploitatieReden",
#         "verkoop",
#         "vertrekken",
#         "vertrekkenAantal",
#         "verwarmdeVertrekkenAantal",
#         "volgnummer",
#         "voorwaarden",
#         "vraagprijs",
#         "woningwaarderingResultaat",
#         "woonvertrekInhoud",
#         "woonvertrekkenTotaalOppervlakte",
#         "woonvorm",
#         "wozEenheden",
#         "zekerheidVerpandingen",
#         "zelfstandig",
#         "zorgfaciliteitOmschrijving",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "EenheidToestand": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "status",
#         "detailStatus",
#         "begindatum",
#         "einddatum",
#         "eenheid",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "EenheidVoorwaarden": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "maximumAantalPersonen",
#         "maximuminkomen",
#         "maximunleeftijd",
#         "minimumAantalPersonen",
#         "minimuminkomen",
#         "minimumleeftijd",
#         "selectiecriteria",
#         "voorrangscriteria",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Eenheidadres": [
#         "allOf: Adres",
#         "bag",
#         "buurt",
#         "gemeente",
#         "geometrie",
#         "land",
#         "provincie",
#         "wijk",
#         "woonplaats",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Energieprestatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "eenheid",
#         "index",
#         "label",
#         "relatie",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "ExtraAttribuut": [
#         "naam",
#         "waarde"
#     ],
#     "Foutbericht": [
#         "code",
#         "omschrijving"
#     ],
#     "Garantie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "omschrijving",
#         "begindatum",
#         "einddatum",
#         "bouwdelen",
#         "bouwkundigeElementen",
#         "clusters",
#         "collectieveObjecten",
#         "eenheden",
#         "overeenkomst",
#         "relatie",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Gebouw": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "bouwdelen",
#         "buurt",
#         "corporatieBuurt",
#         "corporatieWijk",
#         "eenheden",
#         "panden",
#         "wijk",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Gemeente": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "geometrie",
#         "provincie",
#         "stadsdelen",
#         "woonplaatsen",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Geometrie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "omschrijving",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "KadasterPerceel": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Marktwaarde": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "beheersKosten",
#         "contractJaarhuur",
#         "disconteringsvoet",
#         "doorexploiterenDisconteringsvoet",
#         "eenheid",
#         "leegwaarde",
#         "marktJaarhuur",
#         "onderhoudsKosten",
#         "verhuurderheffing",
#         "verslagJaar",
#         "waarde",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Pand": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "status",
#         "adresseerbareObjectenBasisregistratie",
#         "bag",
#         "bouwdelen",
#         "eenheden",
#         "gebouw",
#         "geometrie",
#         "kavelOppervlakte",
#         "liftAanwezig",
#         "renovatie",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Postadres": [
#         "allOf: Adres",
#         "antwoordnummer",
#         "postbusnummer",
#         "woonplaats",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Punt": [
#         "allOf: Geometrie",
#         "breedtegraad",
#         "lengtegraad",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Referentiedata": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "omschrijving",
#         "parent",
#         "begindatum",
#         "einddatum",
#         "sortering"
#     ],
#     "Renovatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "omschrijving",
#         "datum",
#         "eenheden",
#         "panden",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Stadsdeel": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "gemeente",
#         "geometrie",
#         "wijken",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Taxatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "datum",
#         "eenheid",
#         "waarde",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Vertrek": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "eenheid",
#         "inhoud",
#         "oppervlakte",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Wijk": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "buurten",
#         "geometrie",
#         "relaties",
#         "stadsdeel",
#         "woonplaats",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Woningwaardering": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "aantal",
#         "criterium",
#         "eenheid",
#         "groep",
#         "punten",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "WoningwaarderingCriterium": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "criteriumGroep",
#         "meeteenheid",
#         "stelsel",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "WoningwaarderingCriteriumGroep": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "omschrijving",
#         "criteria",
#         "soort",
#         "stelsel",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "WoningwaarderingGroep": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "criteriumGroep",
#         "eenheid",
#         "punten",
#         "woningwaarderingen",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "WoningwaarderingResultaat": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "eenheid",
#         "groepen",
#         "maximaleHuur",
#         "punten",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Woonplaats": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam",
#         "bag",
#         "gemeente",
#         "geometrie",
#         "wijken",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "WozEenheid": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "eenheid",
#         "vastgesteldeWaarde",
#         "waardepeildatum",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "ZekerheidVerpanding": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "begindatum",
#         "einddatum",
#         "akteSoort",
#         "belastingdienstRegistratiedatum",
#         "eenheid",
#         "onderpandWSW",
#         "relaties",
#         "extra-attributen",
#         "informatieobjecten"
#     ]
# }

# %%
#saving the json
import json
with open(API_name+ '_API_data.json', 'w', encoding='utf-8') as f:
    json.dump(json_object, f, ensure_ascii=False, indent=4)

# %%
#check saved file
import glob
my_jsons = glob.glob('*.json')
my_jsons
# Out:
# ['VERA-Onderhoud_API_objecten.json', 'VERA-Vastgoed_API_data.json']
