# %% [markdown]
# # Reverse engineering de VERA API's
#
#
# ### Korte beschrijving werkwijze
# 1. VERA heeft in januari 2022 de nieuwe OpenAPI specificaties gepubliceerd. Per domein wordt één API gepubliceerd op GitHub. Deze OpenAPI3 specificatie zijn flinke bestanden, circa 8000 regels code. In totaal zijn er dus 10 API's.
# 2. In dit Notebook wordt de Vastgoed API ge-reverse-engineered zodat er inzicht komt in de dataobjecten in de VERA OpenAPI. Dit inzicht wordt verkregen door drie bestanden op te leveren:
# - een UML Class diagram gemaakt met PlantUML
# - een .csv bestand met de objecten en hun klassen
# - een json bestand.

# %% [markdown]
# ## 1. Basic info of the API and inspection

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA'

# %%
cd VERA
# Out:
# C:\Users\31653\Documents\GitHub\Notebooks\de_alliantie\VERA

# %%
import glob
my_yamls=glob.glob('*.yaml')
my_yamls
# Out:
# ['Algemeen.yaml',
#  'Dossier.yaml',
#  'Financien.yaml',
#  'Kwaliteit.yaml',
#  'Onderhoud.yaml',
#  'Overeenkomsten.yaml',
#  'Projectontwikkeling.yaml',
#  'Relaties.yaml',
#  'Vastgoed.yaml',
#  'Woonruimteverdeling.yaml']

# %%
import yaml

# load the spec file and read the yaml to create a python dictionary 'spec'
with open('Vastgoed.yaml') as f:
    spec = yaml.safe_load(f.read())

# %%
list(spec)
# Out:
# ['openapi', 'info', 'servers', 'tags', 'paths', 'security', 'components']

# %%
OAS_version =spec['openapi']
API_name = spec['info']['title']
API_name = API_name.replace(" ", "_")
API_version =spec['info']['version']
print(OAS_version, API_name, API_version)
# Out:
# 3.0.0 VERA-Vastgoed 4.0

# %%
type(API_name)
# Out:
# str

# %%
spec['paths']
# Out:
# {'/ping': {'get': {'description': 'Een ping wordt beantwoord met response code 200\n',
#    'operationId': 'ping',
#    'responses': {'200': {'description': 'OK'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/adressen': {'get': {'tags': ['Adressen'],
#    'description': 'Ophalen van Adressen',
#    'operationId': 'listAdressen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/Adres'}}],
#    'responses': {'200': {'description': 'Adres response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/Adres'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['Adressen'],
#    'description': 'Voegt een nieuw(e) Adres toe.',
#    'operationId': 'createAdres',
#    'requestBody': {'description': 'Adres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#    'responses': {'200': {'description': 'Adres succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Adressen'],
#    'description': 'Vervangen van een Adres op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceAdres',
#    'requestBody': {'description': 'Entiteit Adres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#    'responses': {'200': {'description': 'Adres succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Adres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Adressen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een Adres. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateAdres',
#    'requestBody': {'description': 'Entiteit Adres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#    'responses': {'200': {'description': 'Adres succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Adres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/adressen/{id}': {'get': {'tags': ['Adressen'],
#    'description': 'Retourneert een Adres met de gegeven identifier',
#    'operationId': 'readAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Adres om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'Adres response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Adres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Adressen'],
#    'description': 'Vervangen van een Adres',
#    'operationId': 'replaceAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Adres om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit Adres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#    'responses': {'200': {'description': 'Adres succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Adres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Adressen'],
#    'description': 'Wijzigen van een Adres',
#    'operationId': 'updateAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Adres om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit Adres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Adres'}}}},
#    'responses': {'200': {'description': 'Adres succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Adres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/adresseerbare-objecten-basisregistratie': {'get': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Ophalen van AdresseerbareObjectenBasisregistratie',
#    'operationId': 'listAdresseerbareObjectenBasisregistratie',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}],
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Voegt een nieuw(e) AdresseerbaarObjectBasisregistratie toe.',
#    'operationId': 'createAdresseerbaarObjectBasisregistratie',
#    'requestBody': {'description': 'AdresseerbaarObjectBasisregistratie',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Vervangen van een AdresseerbaarObjectBasisregistratie op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceAdresseerbaarObjectBasisregistratie',
#    'requestBody': {'description': 'Entiteit AdresseerbaarObjectBasisregistratie',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nAdresseerbaarObjectBasisregistratie bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'AdresseerbaarObjectBasisregistratie met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Wijzigen van afzonderlijke attributen van een AdresseerbaarObjectBasisregistratie. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateAdresseerbaarObjectBasisregistratie',
#    'requestBody': {'description': 'Entiteit AdresseerbaarObjectBasisregistratie',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nAdresseerbaarObjectBasisregistratie bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'AdresseerbaarObjectBasisregistratie met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/adresseerbare-objecten-basisregistratie/{id}': {'get': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Retourneert een AdresseerbaarObjectBasisregistratie met de gegeven identifier',
#    'operationId': 'readAdresseerbaarObjectBasisregistratieById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van AdresseerbaarObjectBasisregistratie om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'AdresseerbaarObjectBasisregistratie met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Vervangen van een AdresseerbaarObjectBasisregistratie',
#    'operationId': 'replaceAdresseerbaarObjectBasisregistratieById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van AdresseerbaarObjectBasisregistratie om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit AdresseerbaarObjectBasisregistratie',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'AdresseerbaarObjectBasisregistratie met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['AdresseerbareObjectenBasisregistratie'],
#    'description': 'Wijzigen van een AdresseerbaarObjectBasisregistratie',
#    'operationId': 'updateAdresseerbaarObjectBasisregistratieById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van AdresseerbaarObjectBasisregistratie om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit AdresseerbaarObjectBasisregistratie',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/AdresseerbaarObjectBasisregistratie'}}}},
#    'responses': {'200': {'description': 'AdresseerbaarObjectBasisregistratie succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'AdresseerbaarObjectBasisregistratie met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-adressen': {'get': {'tags': ['BagAdressen'],
#    'description': 'Ophalen van BagAdressen',
#    'operationId': 'listBagAdressen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/BagAdres'}}],
#    'responses': {'200': {'description': 'BagAdres response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/BagAdres'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['BagAdressen'],
#    'description': 'Voegt een nieuw(e) BagAdres toe.',
#    'operationId': 'createBagAdres',
#    'requestBody': {'description': 'BagAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#    'responses': {'200': {'description': 'BagAdres succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagAdressen'],
#    'description': 'Vervangen van een BagAdres op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBagAdres',
#    'requestBody': {'description': 'Entiteit BagAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#    'responses': {'200': {'description': 'BagAdres succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBagAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagAdres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagAdressen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een BagAdres. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBagAdres',
#    'requestBody': {'description': 'Entiteit BagAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#    'responses': {'200': {'description': 'BagAdres succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBagAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagAdres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-adressen/{id}': {'get': {'tags': ['BagAdressen'],
#    'description': 'Retourneert een BagAdres met de gegeven identifier',
#    'operationId': 'readBagAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagAdres om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'BagAdres response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagAdres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagAdressen'],
#    'description': 'Vervangen van een BagAdres',
#    'operationId': 'replaceBagAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagAdres om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit BagAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#    'responses': {'200': {'description': 'BagAdres succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagAdres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagAdressen'],
#    'description': 'Wijzigen van een BagAdres',
#    'operationId': 'updateBagAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagAdres om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit BagAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagAdres'}}}},
#    'responses': {'200': {'description': 'BagAdres succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagAdres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-panden': {'get': {'tags': ['BagPanden'],
#    'description': 'Ophalen van BagPanden',
#    'operationId': 'listBagPanden',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/BagPand'}}],
#    'responses': {'200': {'description': 'BagPand response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/BagPand'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['BagPanden'],
#    'description': 'Voegt een nieuw(e) BagPand toe.',
#    'operationId': 'createBagPand',
#    'requestBody': {'description': 'BagPand',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#    'responses': {'200': {'description': 'BagPand succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagPanden'],
#    'description': 'Vervangen van een BagPand op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBagPand',
#    'requestBody': {'description': 'Entiteit BagPand',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#    'responses': {'200': {'description': 'BagPand succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBagPand bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagPand met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagPanden'],
#    'description': 'Wijzigen van afzonderlijke attributen van een BagPand. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBagPand',
#    'requestBody': {'description': 'Entiteit BagPand',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#    'responses': {'200': {'description': 'BagPand succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBagPand bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagPand met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-panden/{id}': {'get': {'tags': ['BagPanden'],
#    'description': 'Retourneert een BagPand met de gegeven identifier',
#    'operationId': 'readBagPandById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagPand om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'BagPand response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagPand met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagPanden'],
#    'description': 'Vervangen van een BagPand',
#    'operationId': 'replaceBagPandById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagPand om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit BagPand',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#    'responses': {'200': {'description': 'BagPand succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagPand met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagPanden'],
#    'description': 'Wijzigen van een BagPand',
#    'operationId': 'updateBagPandById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagPand om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit BagPand',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagPand'}}}},
#    'responses': {'200': {'description': 'BagPand succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagPand met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-woonplaatsen': {'get': {'tags': ['BagWoonplaatsen'],
#    'description': 'Ophalen van BagWoonplaatsen',
#    'operationId': 'listBagWoonplaatsen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}],
#    'responses': {'200': {'description': 'BagWoonplaats response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/BagWoonplaats'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['BagWoonplaatsen'],
#    'description': 'Voegt een nieuw(e) BagWoonplaats toe.',
#    'operationId': 'createBagWoonplaats',
#    'requestBody': {'description': 'BagWoonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#    'responses': {'200': {'description': 'BagWoonplaats succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagWoonplaatsen'],
#    'description': 'Vervangen van een BagWoonplaats op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBagWoonplaats',
#    'requestBody': {'description': 'Entiteit BagWoonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#    'responses': {'200': {'description': 'BagWoonplaats succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBagWoonplaats bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagWoonplaats met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagWoonplaatsen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een BagWoonplaats. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBagWoonplaats',
#    'requestBody': {'description': 'Entiteit BagWoonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#    'responses': {'200': {'description': 'BagWoonplaats succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBagWoonplaats bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagWoonplaats met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bag-woonplaatsen/{id}': {'get': {'tags': ['BagWoonplaatsen'],
#    'description': 'Retourneert een BagWoonplaats met de gegeven identifier',
#    'operationId': 'readBagWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagWoonplaats om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'BagWoonplaats response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagWoonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BagWoonplaatsen'],
#    'description': 'Vervangen van een BagWoonplaats',
#    'operationId': 'replaceBagWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagWoonplaats om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit BagWoonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#    'responses': {'200': {'description': 'BagWoonplaats succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagWoonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BagWoonplaatsen'],
#    'description': 'Wijzigen van een BagWoonplaats',
#    'operationId': 'updateBagWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BagWoonplaats om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit BagWoonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BagWoonplaats'}}}},
#    'responses': {'200': {'description': 'BagWoonplaats succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BagWoonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/beleidswaarden': {'get': {'tags': ['Beleidswaarden'],
#    'description': 'Ophalen van Beleidswaarden',
#    'operationId': 'listBeleidswaarden',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}],
#    'responses': {'200': {'description': 'Beleidswaarde response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/Beleidswaarde'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['Beleidswaarden'],
#    'description': 'Voegt een nieuw(e) Beleidswaarde toe.',
#    'operationId': 'createBeleidswaarde',
#    'requestBody': {'description': 'Beleidswaarde',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#    'responses': {'200': {'description': 'Beleidswaarde succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Beleidswaarden'],
#    'description': 'Vervangen van een Beleidswaarde op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBeleidswaarde',
#    'requestBody': {'description': 'Entiteit Beleidswaarde',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#    'responses': {'200': {'description': 'Beleidswaarde succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBeleidswaarde bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Beleidswaarde met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Beleidswaarden'],
#    'description': 'Wijzigen van afzonderlijke attributen van een Beleidswaarde. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBeleidswaarde',
#    'requestBody': {'description': 'Entiteit Beleidswaarde',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#    'responses': {'200': {'description': 'Beleidswaarde succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBeleidswaarde bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Beleidswaarde met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/beleidswaarden/{id}': {'get': {'tags': ['Beleidswaarden'],
#    'description': 'Retourneert een Beleidswaarde met de gegeven identifier',
#    'operationId': 'readBeleidswaardeById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Beleidswaarde om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'Beleidswaarde response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Beleidswaarde met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Beleidswaarden'],
#    'description': 'Vervangen van een Beleidswaarde',
#    'operationId': 'replaceBeleidswaardeById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Beleidswaarde om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit Beleidswaarde',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#    'responses': {'200': {'description': 'Beleidswaarde succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Beleidswaarde met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Beleidswaarden'],
#    'description': 'Wijzigen van een Beleidswaarde',
#    'operationId': 'updateBeleidswaardeById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Beleidswaarde om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit Beleidswaarde',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Beleidswaarde'}}}},
#    'responses': {'200': {'description': 'Beleidswaarde succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Beleidswaarde met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bouwdelen': {'get': {'tags': ['Bouwdelen'],
#    'description': 'Ophalen van Bouwdelen',
#    'operationId': 'listBouwdelen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/Bouwdeel'}}],
#    'responses': {'200': {'description': 'Bouwdeel response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/Bouwdeel'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['Bouwdelen'],
#    'description': 'Voegt een nieuw(e) Bouwdeel toe.',
#    'operationId': 'createBouwdeel',
#    'requestBody': {'description': 'Bouwdeel',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#    'responses': {'200': {'description': 'Bouwdeel succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Bouwdelen'],
#    'description': 'Vervangen van een Bouwdeel op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBouwdeel',
#    'requestBody': {'description': 'Entiteit Bouwdeel',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#    'responses': {'200': {'description': 'Bouwdeel succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBouwdeel bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Bouwdeel met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Bouwdelen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een Bouwdeel. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBouwdeel',
#    'requestBody': {'description': 'Entiteit Bouwdeel',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#    'responses': {'200': {'description': 'Bouwdeel succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBouwdeel bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Bouwdeel met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bouwdelen/{id}': {'get': {'tags': ['Bouwdelen'],
#    'description': 'Retourneert een Bouwdeel met de gegeven identifier',
#    'operationId': 'readBouwdeelById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Bouwdeel om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'Bouwdeel response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Bouwdeel met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Bouwdelen'],
#    'description': 'Vervangen van een Bouwdeel',
#    'operationId': 'replaceBouwdeelById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Bouwdeel om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit Bouwdeel',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#    'responses': {'200': {'description': 'Bouwdeel succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Bouwdeel met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Bouwdelen'],
#    'description': 'Wijzigen van een Bouwdeel',
#    'operationId': 'updateBouwdeelById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Bouwdeel om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit Bouwdeel',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Bouwdeel'}}}},
#    'responses': {'200': {'description': 'Bouwdeel succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Bouwdeel met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bouwkundig-elementen': {'get': {'tags': ['BouwkundigElementen'],
#    'description': 'Ophalen van BouwkundigElementen',
#    'operationId': 'listBouwkundigElementen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}],
#    'responses': {'200': {'description': 'BouwkundigElement response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/BouwkundigElement'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['BouwkundigElementen'],
#    'description': 'Voegt een nieuw(e) BouwkundigElement toe.',
#    'operationId': 'createBouwkundigElement',
#    'requestBody': {'description': 'BouwkundigElement',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#    'responses': {'200': {'description': 'BouwkundigElement succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BouwkundigElementen'],
#    'description': 'Vervangen van een BouwkundigElement op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBouwkundigElement',
#    'requestBody': {'description': 'Entiteit BouwkundigElement',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#    'responses': {'200': {'description': 'BouwkundigElement succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBouwkundigElement bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BouwkundigElement met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BouwkundigElementen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een BouwkundigElement. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBouwkundigElement',
#    'requestBody': {'description': 'Entiteit BouwkundigElement',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#    'responses': {'200': {'description': 'BouwkundigElement succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBouwkundigElement bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BouwkundigElement met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/bouwkundig-elementen/{id}': {'get': {'tags': ['BouwkundigElementen'],
#    'description': 'Retourneert een BouwkundigElement met de gegeven identifier',
#    'operationId': 'readBouwkundigElementById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BouwkundigElement om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'BouwkundigElement response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BouwkundigElement met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BouwkundigElementen'],
#    'description': 'Vervangen van een BouwkundigElement',
#    'operationId': 'replaceBouwkundigElementById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BouwkundigElement om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit BouwkundigElement',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#    'responses': {'200': {'description': 'BouwkundigElement succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BouwkundigElement met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BouwkundigElementen'],
#    'description': 'Wijzigen van een BouwkundigElement',
#    'operationId': 'updateBouwkundigElementById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BouwkundigElement om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit BouwkundigElement',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BouwkundigElement'}}}},
#    'responses': {'200': {'description': 'BouwkundigElement succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BouwkundigElement met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/buitenlands-adressen': {'get': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Ophalen van BuitenlandsAdressen',
#    'operationId': 'listBuitenlandsAdressen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/BuitenlandsAdres'}}],
#    'responses': {'200': {'description': 'BuitenlandsAdres response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/BuitenlandsAdres'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Voegt een nieuw(e) BuitenlandsAdres toe.',
#    'operationId': 'createBuitenlandsAdres',
#    'requestBody': {'description': 'BuitenlandsAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BuitenlandsAdres'}}}},
#    'responses': {'200': {'description': 'BuitenlandsAdres succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Vervangen van een BuitenlandsAdres op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceBuitenlandsAdres',
#    'requestBody': {'description': 'Entiteit BuitenlandsAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BuitenlandsAdres'}}}},
#    'responses': {'200': {'description': 'BuitenlandsAdres succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nBuitenlandsAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BuitenlandsAdres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een BuitenlandsAdres. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateBuitenlandsAdres',
#    'requestBody': {'description': 'Entiteit BuitenlandsAdres',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BuitenlandsAdres'}}}},
#    'responses': {'200': {'description': 'BuitenlandsAdres succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nBuitenlandsAdres bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BuitenlandsAdres met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/buitenlands-adressen/{id}': {'get': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Retourneert een BuitenlandsAdres met de gegeven identifier',
#    'operationId': 'readBuitenlandsAdresById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van BuitenlandsAdres om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'BuitenlandsAdres response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/BuitenlandsAdres'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'BuitenlandsAdres met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['BuitenlandsAdressen'],
#    'description': 'Vervangen van een BuitenlandsAdres',
# ...
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/Woonplaats'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['Woonplaatsen'],
#    'description': 'Voegt een nieuw(e) Woonplaats toe.',
#    'operationId': 'createWoonplaats',
#    'requestBody': {'description': 'Woonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#    'responses': {'200': {'description': 'Woonplaats succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Woonplaatsen'],
#    'description': 'Vervangen van een Woonplaats op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceWoonplaats',
#    'requestBody': {'description': 'Entiteit Woonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#    'responses': {'200': {'description': 'Woonplaats succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nWoonplaats bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Woonplaats met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Woonplaatsen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een Woonplaats. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateWoonplaats',
#    'requestBody': {'description': 'Entiteit Woonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#    'responses': {'200': {'description': 'Woonplaats succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nWoonplaats bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Woonplaats met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/woonplaatsen/{id}': {'get': {'tags': ['Woonplaatsen'],
#    'description': 'Retourneert een Woonplaats met de gegeven identifier',
#    'operationId': 'readWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Woonplaats om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'Woonplaats response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Woonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['Woonplaatsen'],
#    'description': 'Vervangen van een Woonplaats',
#    'operationId': 'replaceWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Woonplaats om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit Woonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#    'responses': {'200': {'description': 'Woonplaats succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Woonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['Woonplaatsen'],
#    'description': 'Wijzigen van een Woonplaats',
#    'operationId': 'updateWoonplaatsById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van Woonplaats om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit Woonplaats',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Woonplaats'}}}},
#    'responses': {'200': {'description': 'Woonplaats succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'Woonplaats met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/woz-eenheden': {'get': {'tags': ['WozEenheden'],
#    'description': 'Ophalen van WozEenheden',
#    'operationId': 'listWozEenheden',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/WozEenheid'}}],
#    'responses': {'200': {'description': 'WozEenheid response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/WozEenheid'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['WozEenheden'],
#    'description': 'Voegt een nieuw(e) WozEenheid toe.',
#    'operationId': 'createWozEenheid',
#    'requestBody': {'description': 'WozEenheid',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#    'responses': {'200': {'description': 'WozEenheid succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['WozEenheden'],
#    'description': 'Vervangen van een WozEenheid op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceWozEenheid',
#    'requestBody': {'description': 'Entiteit WozEenheid',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#    'responses': {'200': {'description': 'WozEenheid succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nWozEenheid bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'WozEenheid met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['WozEenheden'],
#    'description': 'Wijzigen van afzonderlijke attributen van een WozEenheid. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateWozEenheid',
#    'requestBody': {'description': 'Entiteit WozEenheid',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#    'responses': {'200': {'description': 'WozEenheid succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nWozEenheid bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'WozEenheid met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/woz-eenheden/{id}': {'get': {'tags': ['WozEenheden'],
#    'description': 'Retourneert een WozEenheid met de gegeven identifier',
#    'operationId': 'readWozEenheidById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van WozEenheid om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'WozEenheid response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'WozEenheid met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['WozEenheden'],
#    'description': 'Vervangen van een WozEenheid',
#    'operationId': 'replaceWozEenheidById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van WozEenheid om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit WozEenheid',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#    'responses': {'200': {'description': 'WozEenheid succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'WozEenheid met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['WozEenheden'],
#    'description': 'Wijzigen van een WozEenheid',
#    'operationId': 'updateWozEenheidById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van WozEenheid om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit WozEenheid',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/WozEenheid'}}}},
#    'responses': {'200': {'description': 'WozEenheid succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'WozEenheid met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/zekerheid-verpandingen': {'get': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Ophalen van ZekerheidVerpandingen',
#    'operationId': 'listZekerheidVerpandingen',
#    'parameters': [{'name': 'params',
#      'in': 'query',
#      'style': 'form',
#      'explode': True,
#      'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}],
#    'responses': {'200': {'description': 'ZekerheidVerpanding response',
#      'content': {'application/json': {'schema': {'type': 'array',
#         'items': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'post': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Voegt een nieuw(e) ZekerheidVerpanding toe.',
#    'operationId': 'createZekerheidVerpanding',
#    'requestBody': {'description': 'ZekerheidVerpanding',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#    'responses': {'200': {'description': 'ZekerheidVerpanding succesvol toegevoegd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Vervangen van een ZekerheidVerpanding op basis van overeenkomstige sleutelvelden.\n',
#    'operationId': 'replaceZekerheidVerpanding',
#    'requestBody': {'description': 'Entiteit ZekerheidVerpanding',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#    'responses': {'200': {'description': 'ZekerheidVerpanding succesvol vervangen'},
#     '400': {'description': 'Fout in request.\nZekerheidVerpanding bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'ZekerheidVerpanding met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Wijzigen van afzonderlijke attributen van een ZekerheidVerpanding. In de meegestuurde entiteit moeten\nsleutelvelden aanwezig zijn.\n',
#    'operationId': 'updateZekerheidVerpanding',
#    'requestBody': {'description': 'Entiteit ZekerheidVerpanding',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#    'responses': {'200': {'description': 'ZekerheidVerpanding succesvol gewijzigd'},
#     '400': {'description': 'Fout in request.\nZekerheidVerpanding bevat geen sleutelveld(en).\n'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'ZekerheidVerpanding met gegeven sleutelveld(en) niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}},
#  '/zekerheid-verpandingen/{id}': {'get': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Retourneert een ZekerheidVerpanding met de gegeven identifier',
#    'operationId': 'readZekerheidVerpandingById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van ZekerheidVerpanding om op te halen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'responses': {'200': {'description': 'ZekerheidVerpanding response',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'ZekerheidVerpanding met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'put': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Vervangen van een ZekerheidVerpanding',
#    'operationId': 'replaceZekerheidVerpandingById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van ZekerheidVerpanding om te vervangen',
#      'required': True,
#      'schema': {'type': 'string'}}],
#    'requestBody': {'description': 'Entiteit ZekerheidVerpanding',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#    'responses': {'200': {'description': 'ZekerheidVerpanding succesvol vervangen'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'ZekerheidVerpanding met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}},
#   'patch': {'tags': ['ZekerheidVerpandingen'],
#    'description': 'Wijzigen van een ZekerheidVerpanding',
#    'operationId': 'updateZekerheidVerpandingById',
#    'parameters': [{'name': 'id',
#      'in': 'path',
#      'description': 'Id van ZekerheidVerpanding om te wijzigen',
#      'required': True,
#      'schema': {'type': 'integer'}}],
#    'requestBody': {'description': 'Entiteit ZekerheidVerpanding',
#     'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ZekerheidVerpanding'}}}},
#    'responses': {'200': {'description': 'ZekerheidVerpanding succesvol gewijzigd'},
#     '401': {'$ref': '#/components/responses/NietGeautoriseerd'},
#     '404': {'description': 'ZekerheidVerpanding met id niet gevonden'},
#     'default': {'description': 'Onverwachte fout',
#      'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Foutbericht'}}}}}}}}

# %% [markdown]
# ## 2. Getting the paths and endpoints

# %%
#getting the paths
paths = list(spec['paths'])
len(paths)
paths
# Out:
# ['/ping',
#  '/adressen',
#  '/adressen/{id}',
#  '/adresseerbare-objecten-basisregistratie',
#  '/adresseerbare-objecten-basisregistratie/{id}',
#  '/bag-adressen',
#  '/bag-adressen/{id}',
#  '/bag-panden',
#  '/bag-panden/{id}',
#  '/bag-woonplaatsen',
#  '/bag-woonplaatsen/{id}',
#  '/beleidswaarden',
#  '/beleidswaarden/{id}',
#  '/bouwdelen',
#  '/bouwdelen/{id}',
#  '/bouwkundig-elementen',
#  '/bouwkundig-elementen/{id}',
#  '/buitenlands-adressen',
#  '/buitenlands-adressen/{id}',
#  '/buurten',
#  '/buurten/{id}',
#  '/clusters',
#  '/clusters/{id}',
#  '/collectief-objecten',
#  '/collectief-objecten/{id}',
#  '/conditiemetingen',
#  '/conditiemetingen/{id}',
#  '/eenheden',
#  '/eenheden/{id}',
#  '/eenheidadressen',
#  '/eenheidadressen/{id}',
#  '/eenheid-toestanden',
#  '/eenheid-toestanden/{id}',
#  '/eenheid-voorwaardes',
#  '/eenheid-voorwaardes/{id}',
#  '/energieprestaties',
#  '/energieprestaties/{id}',
#  '/garanties',
#  '/garanties/{id}',
#  '/gebouwen',
#  '/gebouwen/{id}',
#  '/gemeenten',
#  '/gemeenten/{id}',
#  '/geometrieen',
#  '/geometrieen/{id}',
#  '/kadaster-percelen',
#  '/kadaster-percelen/{id}',
#  '/marktwaarden',
#  '/marktwaarden/{id}',
#  '/panden',
#  '/panden/{id}',
#  '/postadressen',
#  '/postadressen/{id}',
#  '/punten',
#  '/punten/{id}',
#  '/renovaties',
#  '/renovaties/{id}',
#  '/stadsdelen',
#  '/stadsdelen/{id}',
#  '/taxaties',
#  '/taxaties/{id}',
#  '/vertrekken',
#  '/vertrekken/{id}',
#  '/wijken',
#  '/wijken/{id}',
#  '/woningwaarderingen',
#  '/woningwaarderingen/{id}',
#  '/woningwaardering-criteria',
#  '/woningwaardering-criteria/{id}',
#  '/woningwaardering-criterium-groepen',
#  '/woningwaardering-criterium-groepen/{id}',
#  '/woningwaardering-groepen',
#  '/woningwaardering-groepen/{id}',
#  '/woningwaardering-resultaten',
#  '/woningwaardering-resultaten/{id}',
#  '/woonplaatsen',
#  '/woonplaatsen/{id}',
#  '/woz-eenheden',
#  '/woz-eenheden/{id}',
#  '/zekerheid-verpandingen',
#  '/zekerheid-verpandingen/{id}']

# %%
#getting the paths and http verbs
endpoints_dict = {}
for i in range (len(paths)):
    endpoints_dict[paths[i]]=list(spec['paths'][paths[i]])
endpoints_dict
# Out:
# {'/ping': ['get'],
#  '/adressen': ['get', 'post', 'put', 'patch'],
#  '/adressen/{id}': ['get', 'put', 'patch'],
#  '/adresseerbare-objecten-basisregistratie': ['get', 'post', 'put', 'patch'],
#  '/adresseerbare-objecten-basisregistratie/{id}': ['get', 'put', 'patch'],
#  '/bag-adressen': ['get', 'post', 'put', 'patch'],
#  '/bag-adressen/{id}': ['get', 'put', 'patch'],
#  '/bag-panden': ['get', 'post', 'put', 'patch'],
#  '/bag-panden/{id}': ['get', 'put', 'patch'],
#  '/bag-woonplaatsen': ['get', 'post', 'put', 'patch'],
#  '/bag-woonplaatsen/{id}': ['get', 'put', 'patch'],
#  '/beleidswaarden': ['get', 'post', 'put', 'patch'],
#  '/beleidswaarden/{id}': ['get', 'put', 'patch'],
#  '/bouwdelen': ['get', 'post', 'put', 'patch'],
#  '/bouwdelen/{id}': ['get', 'put', 'patch'],
#  '/bouwkundig-elementen': ['get', 'post', 'put', 'patch'],
#  '/bouwkundig-elementen/{id}': ['get', 'put', 'patch'],
#  '/buitenlands-adressen': ['get', 'post', 'put', 'patch'],
#  '/buitenlands-adressen/{id}': ['get', 'put', 'patch'],
#  '/buurten': ['get', 'post', 'put', 'patch'],
#  '/buurten/{id}': ['get', 'put', 'patch'],
#  '/clusters': ['get', 'post', 'put', 'patch'],
#  '/clusters/{id}': ['get', 'put', 'patch'],
#  '/collectief-objecten': ['get', 'post', 'put', 'patch'],
#  '/collectief-objecten/{id}': ['get', 'put', 'patch'],
#  '/conditiemetingen': ['get', 'post', 'put', 'patch'],
#  '/conditiemetingen/{id}': ['get', 'put', 'patch'],
#  '/eenheden': ['get', 'post', 'put', 'patch'],
#  '/eenheden/{id}': ['get', 'put', 'patch'],
#  '/eenheidadressen': ['get', 'post', 'put', 'patch'],
#  '/eenheidadressen/{id}': ['get', 'put', 'patch'],
#  '/eenheid-toestanden': ['get', 'post', 'put', 'patch'],
#  '/eenheid-toestanden/{id}': ['get', 'put', 'patch'],
#  '/eenheid-voorwaardes': ['get', 'post', 'put', 'patch'],
#  '/eenheid-voorwaardes/{id}': ['get', 'put', 'patch'],
#  '/energieprestaties': ['get', 'post', 'put', 'patch'],
#  '/energieprestaties/{id}': ['get', 'put', 'patch'],
#  '/garanties': ['get', 'post', 'put', 'patch'],
#  '/garanties/{id}': ['get', 'put', 'patch'],
#  '/gebouwen': ['get', 'post', 'put', 'patch'],
#  '/gebouwen/{id}': ['get', 'put', 'patch'],
#  '/gemeenten': ['get', 'post', 'put', 'patch'],
#  '/gemeenten/{id}': ['get', 'put', 'patch'],
#  '/geometrieen': ['get', 'post', 'put', 'patch'],
#  '/geometrieen/{id}': ['get', 'put', 'patch'],
#  '/kadaster-percelen': ['get', 'post', 'put', 'patch'],
#  '/kadaster-percelen/{id}': ['get', 'put', 'patch'],
#  '/marktwaarden': ['get', 'post', 'put', 'patch'],
#  '/marktwaarden/{id}': ['get', 'put', 'patch'],
#  '/panden': ['get', 'post', 'put', 'patch'],
#  '/panden/{id}': ['get', 'put', 'patch'],
#  '/postadressen': ['get', 'post', 'put', 'patch'],
#  '/postadressen/{id}': ['get', 'put', 'patch'],
#  '/punten': ['get', 'post', 'put', 'patch'],
#  '/punten/{id}': ['get', 'put', 'patch'],
#  '/renovaties': ['get', 'post', 'put', 'patch'],
#  '/renovaties/{id}': ['get', 'put', 'patch'],
#  '/stadsdelen': ['get', 'post', 'put', 'patch'],
#  '/stadsdelen/{id}': ['get', 'put', 'patch'],
#  '/taxaties': ['get', 'post', 'put', 'patch'],
#  '/taxaties/{id}': ['get', 'put', 'patch'],
#  '/vertrekken': ['get', 'post', 'put', 'patch'],
#  '/vertrekken/{id}': ['get', 'put', 'patch'],
#  '/wijken': ['get', 'post', 'put', 'patch'],
#  '/wijken/{id}': ['get', 'put', 'patch'],
#  '/woningwaarderingen': ['get', 'post', 'put', 'patch'],
#  '/woningwaarderingen/{id}': ['get', 'put', 'patch'],
#  '/woningwaardering-criteria': ['get', 'post', 'put', 'patch'],
#  '/woningwaardering-criteria/{id}': ['get', 'put', 'patch'],
#  '/woningwaardering-criterium-groepen': ['get', 'post', 'put', 'patch'],
#  '/woningwaardering-criterium-groepen/{id}': ['get', 'put', 'patch'],
#  '/woningwaardering-groepen': ['get', 'post', 'put', 'patch'],
#  '/woningwaardering-groepen/{id}': ['get', 'put', 'patch'],
#  '/woningwaardering-resultaten': ['get', 'post', 'put', 'patch'],
#  '/woningwaardering-resultaten/{id}': ['get', 'put', 'patch'],
#  '/woonplaatsen': ['get', 'post', 'put', 'patch'],
#  '/woonplaatsen/{id}': ['get', 'put', 'patch'],
#  '/woz-eenheden': ['get', 'post', 'put', 'patch'],
#  '/woz-eenheden/{id}': ['get', 'put', 'patch'],
#  '/zekerheid-verpandingen': ['get', 'post', 'put', 'patch'],
#  '/zekerheid-verpandingen/{id}': ['get', 'put', 'patch']}

# %%
#value_list=[]
for key, value in endpoints_dict.items():
    #print(value)
    value_list = value
    for i in range (len(value_list)):
        print(value_list[i], key)
# Out:
# get /ping
# get /adressen
# post /adressen
# put /adressen
# patch /adressen
# get /adressen/{id}
# put /adressen/{id}
# patch /adressen/{id}
# get /adresseerbare-objecten-basisregistratie
# post /adresseerbare-objecten-basisregistratie
# put /adresseerbare-objecten-basisregistratie
# patch /adresseerbare-objecten-basisregistratie
# get /adresseerbare-objecten-basisregistratie/{id}
# put /adresseerbare-objecten-basisregistratie/{id}
# patch /adresseerbare-objecten-basisregistratie/{id}
# get /bag-adressen
# post /bag-adressen
# put /bag-adressen
# patch /bag-adressen
# get /bag-adressen/{id}
# put /bag-adressen/{id}
# patch /bag-adressen/{id}
# get /bag-panden
# post /bag-panden
# put /bag-panden
# patch /bag-panden
# get /bag-panden/{id}
# put /bag-panden/{id}
# patch /bag-panden/{id}
# get /bag-woonplaatsen
# post /bag-woonplaatsen
# put /bag-woonplaatsen
# patch /bag-woonplaatsen
# get /bag-woonplaatsen/{id}
# put /bag-woonplaatsen/{id}
# patch /bag-woonplaatsen/{id}
# get /beleidswaarden
# post /beleidswaarden
# put /beleidswaarden
# patch /beleidswaarden
# get /beleidswaarden/{id}
# put /beleidswaarden/{id}
# patch /beleidswaarden/{id}
# get /bouwdelen
# post /bouwdelen
# put /bouwdelen
# patch /bouwdelen
# get /bouwdelen/{id}
# put /bouwdelen/{id}
# patch /bouwdelen/{id}
# get /bouwkundig-elementen
# post /bouwkundig-elementen
# put /bouwkundig-elementen
# patch /bouwkundig-elementen
# get /bouwkundig-elementen/{id}
# put /bouwkundig-elementen/{id}
# patch /bouwkundig-elementen/{id}
# get /buitenlands-adressen
# post /buitenlands-adressen
# put /buitenlands-adressen
# patch /buitenlands-adressen
# get /buitenlands-adressen/{id}
# put /buitenlands-adressen/{id}
# patch /buitenlands-adressen/{id}
# get /buurten
# post /buurten
# put /buurten
# patch /buurten
# get /buurten/{id}
# put /buurten/{id}
# patch /buurten/{id}
# get /clusters
# post /clusters
# put /clusters
# patch /clusters
# get /clusters/{id}
# put /clusters/{id}
# patch /clusters/{id}
# get /collectief-objecten
# post /collectief-objecten
# put /collectief-objecten
# patch /collectief-objecten
# get /collectief-objecten/{id}
# put /collectief-objecten/{id}
# patch /collectief-objecten/{id}
# get /conditiemetingen
# post /conditiemetingen
# put /conditiemetingen
# patch /conditiemetingen
# get /conditiemetingen/{id}
# put /conditiemetingen/{id}
# patch /conditiemetingen/{id}
# get /eenheden
# post /eenheden
# put /eenheden
# patch /eenheden
# get /eenheden/{id}
# put /eenheden/{id}
# patch /eenheden/{id}
# get /eenheidadressen
# post /eenheidadressen
# put /eenheidadressen
# patch /eenheidadressen
# get /eenheidadressen/{id}
# put /eenheidadressen/{id}
# patch /eenheidadressen/{id}
# get /eenheid-toestanden
# post /eenheid-toestanden
# put /eenheid-toestanden
# patch /eenheid-toestanden
# get /eenheid-toestanden/{id}
# put /eenheid-toestanden/{id}
# patch /eenheid-toestanden/{id}
# get /eenheid-voorwaardes
# post /eenheid-voorwaardes
# put /eenheid-voorwaardes
# patch /eenheid-voorwaardes
# get /eenheid-voorwaardes/{id}
# put /eenheid-voorwaardes/{id}
# patch /eenheid-voorwaardes/{id}
# get /energieprestaties
# post /energieprestaties
# put /energieprestaties
# patch /energieprestaties
# get /energieprestaties/{id}
# put /energieprestaties/{id}
# patch /energieprestaties/{id}
# get /garanties
# post /garanties
# put /garanties
# patch /garanties
# get /garanties/{id}
# put /garanties/{id}
# patch /garanties/{id}
# get /gebouwen
# post /gebouwen
# put /gebouwen
# patch /gebouwen
# get /gebouwen/{id}
# put /gebouwen/{id}
# patch /gebouwen/{id}
# get /gemeenten
# post /gemeenten
# put /gemeenten
# patch /gemeenten
# get /gemeenten/{id}
# put /gemeenten/{id}
# patch /gemeenten/{id}
# get /geometrieen
# post /geometrieen
# put /geometrieen
# patch /geometrieen
# get /geometrieen/{id}
# put /geometrieen/{id}
# patch /geometrieen/{id}
# get /kadaster-percelen
# post /kadaster-percelen
# put /kadaster-percelen
# patch /kadaster-percelen
# get /kadaster-percelen/{id}
# put /kadaster-percelen/{id}
# patch /kadaster-percelen/{id}
# get /marktwaarden
# post /marktwaarden
# put /marktwaarden
# patch /marktwaarden
# get /marktwaarden/{id}
# put /marktwaarden/{id}
# patch /marktwaarden/{id}
# get /panden
# post /panden
# put /panden
# patch /panden
# get /panden/{id}
# put /panden/{id}
# patch /panden/{id}
# get /postadressen
# post /postadressen
# put /postadressen
# patch /postadressen
# get /postadressen/{id}
# put /postadressen/{id}
# patch /postadressen/{id}
# get /punten
# post /punten
# put /punten
# patch /punten
# get /punten/{id}
# put /punten/{id}
# patch /punten/{id}
# get /renovaties
# post /renovaties
# put /renovaties
# patch /renovaties
# get /renovaties/{id}
# put /renovaties/{id}
# patch /renovaties/{id}
# get /stadsdelen
# post /stadsdelen
# put /stadsdelen
# patch /stadsdelen
# get /stadsdelen/{id}
# put /stadsdelen/{id}
# patch /stadsdelen/{id}
# get /taxaties
# post /taxaties
# put /taxaties
# patch /taxaties
# get /taxaties/{id}
# put /taxaties/{id}
# patch /taxaties/{id}
# get /vertrekken
# post /vertrekken
# put /vertrekken
# patch /vertrekken
# get /vertrekken/{id}
# put /vertrekken/{id}
# patch /vertrekken/{id}
# get /wijken
# post /wijken
# put /wijken
# patch /wijken
# get /wijken/{id}
# put /wijken/{id}
# patch /wijken/{id}
# get /woningwaarderingen
# post /woningwaarderingen
# put /woningwaarderingen
# patch /woningwaarderingen
# get /woningwaarderingen/{id}
# put /woningwaarderingen/{id}
# patch /woningwaarderingen/{id}
# get /woningwaardering-criteria
# post /woningwaardering-criteria
# put /woningwaardering-criteria
# patch /woningwaardering-criteria
# get /woningwaardering-criteria/{id}
# put /woningwaardering-criteria/{id}
# patch /woningwaardering-criteria/{id}
# get /woningwaardering-criterium-groepen
# post /woningwaardering-criterium-groepen
# put /woningwaardering-criterium-groepen
# patch /woningwaardering-criterium-groepen
# get /woningwaardering-criterium-groepen/{id}
# put /woningwaardering-criterium-groepen/{id}
# patch /woningwaardering-criterium-groepen/{id}
# get /woningwaardering-groepen
# post /woningwaardering-groepen
# put /woningwaardering-groepen
# patch /woningwaardering-groepen
# get /woningwaardering-groepen/{id}
# put /woningwaardering-groepen/{id}
# patch /woningwaardering-groepen/{id}
# get /woningwaardering-resultaten
# post /woningwaardering-resultaten
# put /woningwaardering-resultaten
# patch /woningwaardering-resultaten
# get /woningwaardering-resultaten/{id}
# put /woningwaardering-resultaten/{id}
# patch /woningwaardering-resultaten/{id}
# get /woonplaatsen
# post /woonplaatsen
# put /woonplaatsen
# patch /woonplaatsen
# get /woonplaatsen/{id}
# put /woonplaatsen/{id}
# patch /woonplaatsen/{id}
# get /woz-eenheden
# post /woz-eenheden
# put /woz-eenheden
# patch /woz-eenheden
# get /woz-eenheden/{id}
# put /woz-eenheden/{id}
# patch /woz-eenheden/{id}
# get /zekerheid-verpandingen
# post /zekerheid-verpandingen
# put /zekerheid-verpandingen
# patch /zekerheid-verpandingen
# get /zekerheid-verpandingen/{id}
# put /zekerheid-verpandingen/{id}
# patch /zekerheid-verpandingen/{id}

# %%
list(spec['paths'])
# Out:
# ['/ping',
#  '/adressen',
#  '/adressen/{id}',
#  '/adresseerbare-objecten-basisregistratie',
#  '/adresseerbare-objecten-basisregistratie/{id}',
#  '/bag-adressen',
#  '/bag-adressen/{id}',
#  '/bag-panden',
#  '/bag-panden/{id}',
#  '/bag-woonplaatsen',
#  '/bag-woonplaatsen/{id}',
#  '/beleidswaarden',
#  '/beleidswaarden/{id}',
#  '/bouwdelen',
#  '/bouwdelen/{id}',
#  '/bouwkundig-elementen',
#  '/bouwkundig-elementen/{id}',
#  '/buitenlands-adressen',
#  '/buitenlands-adressen/{id}',
#  '/buurten',
#  '/buurten/{id}',
#  '/clusters',
#  '/clusters/{id}',
#  '/collectief-objecten',
#  '/collectief-objecten/{id}',
#  '/conditiemetingen',
#  '/conditiemetingen/{id}',
#  '/eenheden',
#  '/eenheden/{id}',
#  '/eenheidadressen',
#  '/eenheidadressen/{id}',
#  '/eenheid-toestanden',
#  '/eenheid-toestanden/{id}',
#  '/eenheid-voorwaardes',
#  '/eenheid-voorwaardes/{id}',
#  '/energieprestaties',
#  '/energieprestaties/{id}',
#  '/garanties',
#  '/garanties/{id}',
#  '/gebouwen',
#  '/gebouwen/{id}',
#  '/gemeenten',
#  '/gemeenten/{id}',
#  '/geometrieen',
#  '/geometrieen/{id}',
#  '/kadaster-percelen',
#  '/kadaster-percelen/{id}',
#  '/marktwaarden',
#  '/marktwaarden/{id}',
#  '/panden',
#  '/panden/{id}',
#  '/postadressen',
#  '/postadressen/{id}',
#  '/punten',
#  '/punten/{id}',
#  '/renovaties',
#  '/renovaties/{id}',
#  '/stadsdelen',
#  '/stadsdelen/{id}',
#  '/taxaties',
#  '/taxaties/{id}',
#  '/vertrekken',
#  '/vertrekken/{id}',
#  '/wijken',
#  '/wijken/{id}',
#  '/woningwaarderingen',
#  '/woningwaarderingen/{id}',
#  '/woningwaardering-criteria',
#  '/woningwaardering-criteria/{id}',
#  '/woningwaardering-criterium-groepen',
#  '/woningwaardering-criterium-groepen/{id}',
#  '/woningwaardering-groepen',
#  '/woningwaardering-groepen/{id}',
#  '/woningwaardering-resultaten',
#  '/woningwaardering-resultaten/{id}',
#  '/woonplaatsen',
#  '/woonplaatsen/{id}',
#  '/woz-eenheden',
#  '/woz-eenheden/{id}',
#  '/zekerheid-verpandingen',
#  '/zekerheid-verpandingen/{id}']

# %%
#spec['paths']['/ping']#['get']#['description']

# %%
#spec['paths']['/dossiers']['get']['description']

# %%
#printing the paths, verbs and descriptions 
paths = list(spec['paths'])
for i in range (len(paths)):
    verbs = list(spec['paths'][paths[i]])
    for j in range (len(verbs)):
        description_string = spec['paths'][paths[i]][verbs[j]]['description']
        description_string = description_string.strip('\n')
        print(paths[i], verbs[j], description_string)
# Out:
# /ping get Een ping wordt beantwoord met response code 200
# /adressen get Ophalen van Adressen
# /adressen post Voegt een nieuw(e) Adres toe.
# /adressen put Vervangen van een Adres op basis van overeenkomstige sleutelvelden.
# /adressen patch Wijzigen van afzonderlijke attributen van een Adres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /adressen/{id} get Retourneert een Adres met de gegeven identifier
# /adressen/{id} put Vervangen van een Adres
# /adressen/{id} patch Wijzigen van een Adres
# /adresseerbare-objecten-basisregistratie get Ophalen van AdresseerbareObjectenBasisregistratie
# /adresseerbare-objecten-basisregistratie post Voegt een nieuw(e) AdresseerbaarObjectBasisregistratie toe.
# /adresseerbare-objecten-basisregistratie put Vervangen van een AdresseerbaarObjectBasisregistratie op basis van overeenkomstige sleutelvelden.
# /adresseerbare-objecten-basisregistratie patch Wijzigen van afzonderlijke attributen van een AdresseerbaarObjectBasisregistratie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /adresseerbare-objecten-basisregistratie/{id} get Retourneert een AdresseerbaarObjectBasisregistratie met de gegeven identifier
# /adresseerbare-objecten-basisregistratie/{id} put Vervangen van een AdresseerbaarObjectBasisregistratie
# /adresseerbare-objecten-basisregistratie/{id} patch Wijzigen van een AdresseerbaarObjectBasisregistratie
# /bag-adressen get Ophalen van BagAdressen
# /bag-adressen post Voegt een nieuw(e) BagAdres toe.
# /bag-adressen put Vervangen van een BagAdres op basis van overeenkomstige sleutelvelden.
# /bag-adressen patch Wijzigen van afzonderlijke attributen van een BagAdres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /bag-adressen/{id} get Retourneert een BagAdres met de gegeven identifier
# /bag-adressen/{id} put Vervangen van een BagAdres
# /bag-adressen/{id} patch Wijzigen van een BagAdres
# /bag-panden get Ophalen van BagPanden
# /bag-panden post Voegt een nieuw(e) BagPand toe.
# /bag-panden put Vervangen van een BagPand op basis van overeenkomstige sleutelvelden.
# /bag-panden patch Wijzigen van afzonderlijke attributen van een BagPand. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /bag-panden/{id} get Retourneert een BagPand met de gegeven identifier
# /bag-panden/{id} put Vervangen van een BagPand
# /bag-panden/{id} patch Wijzigen van een BagPand
# /bag-woonplaatsen get Ophalen van BagWoonplaatsen
# /bag-woonplaatsen post Voegt een nieuw(e) BagWoonplaats toe.
# /bag-woonplaatsen put Vervangen van een BagWoonplaats op basis van overeenkomstige sleutelvelden.
# /bag-woonplaatsen patch Wijzigen van afzonderlijke attributen van een BagWoonplaats. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /bag-woonplaatsen/{id} get Retourneert een BagWoonplaats met de gegeven identifier
# /bag-woonplaatsen/{id} put Vervangen van een BagWoonplaats
# /bag-woonplaatsen/{id} patch Wijzigen van een BagWoonplaats
# /beleidswaarden get Ophalen van Beleidswaarden
# /beleidswaarden post Voegt een nieuw(e) Beleidswaarde toe.
# /beleidswaarden put Vervangen van een Beleidswaarde op basis van overeenkomstige sleutelvelden.
# /beleidswaarden patch Wijzigen van afzonderlijke attributen van een Beleidswaarde. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /beleidswaarden/{id} get Retourneert een Beleidswaarde met de gegeven identifier
# /beleidswaarden/{id} put Vervangen van een Beleidswaarde
# /beleidswaarden/{id} patch Wijzigen van een Beleidswaarde
# /bouwdelen get Ophalen van Bouwdelen
# /bouwdelen post Voegt een nieuw(e) Bouwdeel toe.
# /bouwdelen put Vervangen van een Bouwdeel op basis van overeenkomstige sleutelvelden.
# /bouwdelen patch Wijzigen van afzonderlijke attributen van een Bouwdeel. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /bouwdelen/{id} get Retourneert een Bouwdeel met de gegeven identifier
# /bouwdelen/{id} put Vervangen van een Bouwdeel
# /bouwdelen/{id} patch Wijzigen van een Bouwdeel
# /bouwkundig-elementen get Ophalen van BouwkundigElementen
# /bouwkundig-elementen post Voegt een nieuw(e) BouwkundigElement toe.
# /bouwkundig-elementen put Vervangen van een BouwkundigElement op basis van overeenkomstige sleutelvelden.
# /bouwkundig-elementen patch Wijzigen van afzonderlijke attributen van een BouwkundigElement. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /bouwkundig-elementen/{id} get Retourneert een BouwkundigElement met de gegeven identifier
# /bouwkundig-elementen/{id} put Vervangen van een BouwkundigElement
# /bouwkundig-elementen/{id} patch Wijzigen van een BouwkundigElement
# /buitenlands-adressen get Ophalen van BuitenlandsAdressen
# /buitenlands-adressen post Voegt een nieuw(e) BuitenlandsAdres toe.
# /buitenlands-adressen put Vervangen van een BuitenlandsAdres op basis van overeenkomstige sleutelvelden.
# /buitenlands-adressen patch Wijzigen van afzonderlijke attributen van een BuitenlandsAdres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /buitenlands-adressen/{id} get Retourneert een BuitenlandsAdres met de gegeven identifier
# /buitenlands-adressen/{id} put Vervangen van een BuitenlandsAdres
# /buitenlands-adressen/{id} patch Wijzigen van een BuitenlandsAdres
# /buurten get Ophalen van Buurten
# /buurten post Voegt een nieuw(e) Buurt toe.
# /buurten put Vervangen van een Buurt op basis van overeenkomstige sleutelvelden.
# /buurten patch Wijzigen van afzonderlijke attributen van een Buurt. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /buurten/{id} get Retourneert een Buurt met de gegeven identifier
# /buurten/{id} put Vervangen van een Buurt
# /buurten/{id} patch Wijzigen van een Buurt
# /clusters get Ophalen van Clusters
# /clusters post Voegt een nieuw(e) Cluster toe.
# /clusters put Vervangen van een Cluster op basis van overeenkomstige sleutelvelden.
# /clusters patch Wijzigen van afzonderlijke attributen van een Cluster. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /clusters/{id} get Retourneert een Cluster met de gegeven identifier
# /clusters/{id} put Vervangen van een Cluster
# /clusters/{id} patch Wijzigen van een Cluster
# /collectief-objecten get Ophalen van CollectiefObjecten
# /collectief-objecten post Voegt een nieuw(e) CollectiefObject toe.
# /collectief-objecten put Vervangen van een CollectiefObject op basis van overeenkomstige sleutelvelden.
# /collectief-objecten patch Wijzigen van afzonderlijke attributen van een CollectiefObject. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /collectief-objecten/{id} get Retourneert een CollectiefObject met de gegeven identifier
# /collectief-objecten/{id} put Vervangen van een CollectiefObject
# /collectief-objecten/{id} patch Wijzigen van een CollectiefObject
# /conditiemetingen get Ophalen van Conditiemetingen
# /conditiemetingen post Voegt een nieuw(e) Conditiemeting toe.
# /conditiemetingen put Vervangen van een Conditiemeting op basis van overeenkomstige sleutelvelden.
# /conditiemetingen patch Wijzigen van afzonderlijke attributen van een Conditiemeting. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /conditiemetingen/{id} get Retourneert een Conditiemeting met de gegeven identifier
# /conditiemetingen/{id} put Vervangen van een Conditiemeting
# /conditiemetingen/{id} patch Wijzigen van een Conditiemeting
# /eenheden get Ophalen van Eenheden
# /eenheden post Voegt een nieuw(e) Eenheid toe.
# /eenheden put Vervangen van een Eenheid op basis van overeenkomstige sleutelvelden.
# /eenheden patch Wijzigen van afzonderlijke attributen van een Eenheid. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /eenheden/{id} get Retourneert een Eenheid met de gegeven identifier
# /eenheden/{id} put Vervangen van een Eenheid
# /eenheden/{id} patch Wijzigen van een Eenheid
# /eenheidadressen get Ophalen van Eenheidadressen
# /eenheidadressen post Voegt een nieuw(e) Eenheidadres toe.
# /eenheidadressen put Vervangen van een Eenheidadres op basis van overeenkomstige sleutelvelden.
# /eenheidadressen patch Wijzigen van afzonderlijke attributen van een Eenheidadres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /eenheidadressen/{id} get Retourneert een Eenheidadres met de gegeven identifier
# /eenheidadressen/{id} put Vervangen van een Eenheidadres
# /eenheidadressen/{id} patch Wijzigen van een Eenheidadres
# /eenheid-toestanden get Ophalen van EenheidToestanden
# /eenheid-toestanden post Voegt een nieuw(e) EenheidToestand toe.
# /eenheid-toestanden put Vervangen van een EenheidToestand op basis van overeenkomstige sleutelvelden.
# /eenheid-toestanden patch Wijzigen van afzonderlijke attributen van een EenheidToestand. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /eenheid-toestanden/{id} get Retourneert een EenheidToestand met de gegeven identifier
# /eenheid-toestanden/{id} put Vervangen van een EenheidToestand
# /eenheid-toestanden/{id} patch Wijzigen van een EenheidToestand
# /eenheid-voorwaardes get Ophalen van EenheidVoorwaardes
# /eenheid-voorwaardes post Voegt een nieuw(e) EenheidVoorwaarden toe.
# /eenheid-voorwaardes put Vervangen van een EenheidVoorwaarden op basis van overeenkomstige sleutelvelden.
# /eenheid-voorwaardes patch Wijzigen van afzonderlijke attributen van een EenheidVoorwaarden. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /eenheid-voorwaardes/{id} get Retourneert een EenheidVoorwaarden met de gegeven identifier
# /eenheid-voorwaardes/{id} put Vervangen van een EenheidVoorwaarden
# /eenheid-voorwaardes/{id} patch Wijzigen van een EenheidVoorwaarden
# /energieprestaties get Ophalen van Energieprestaties
# /energieprestaties post Voegt een nieuw(e) Energieprestatie toe.
# /energieprestaties put Vervangen van een Energieprestatie op basis van overeenkomstige sleutelvelden.
# /energieprestaties patch Wijzigen van afzonderlijke attributen van een Energieprestatie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /energieprestaties/{id} get Retourneert een Energieprestatie met de gegeven identifier
# /energieprestaties/{id} put Vervangen van een Energieprestatie
# /energieprestaties/{id} patch Wijzigen van een Energieprestatie
# /garanties get Ophalen van Garanties
# /garanties post Voegt een nieuw(e) Garantie toe.
# /garanties put Vervangen van een Garantie op basis van overeenkomstige sleutelvelden.
# /garanties patch Wijzigen van afzonderlijke attributen van een Garantie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /garanties/{id} get Retourneert een Garantie met de gegeven identifier
# /garanties/{id} put Vervangen van een Garantie
# /garanties/{id} patch Wijzigen van een Garantie
# /gebouwen get Ophalen van Gebouwen
# /gebouwen post Voegt een nieuw(e) Gebouw toe.
# /gebouwen put Vervangen van een Gebouw op basis van overeenkomstige sleutelvelden.
# /gebouwen patch Wijzigen van afzonderlijke attributen van een Gebouw. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /gebouwen/{id} get Retourneert een Gebouw met de gegeven identifier
# /gebouwen/{id} put Vervangen van een Gebouw
# /gebouwen/{id} patch Wijzigen van een Gebouw
# /gemeenten get Ophalen van Gemeenten
# /gemeenten post Voegt een nieuw(e) Gemeente toe.
# /gemeenten put Vervangen van een Gemeente op basis van overeenkomstige sleutelvelden.
# /gemeenten patch Wijzigen van afzonderlijke attributen van een Gemeente. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /gemeenten/{id} get Retourneert een Gemeente met de gegeven identifier
# /gemeenten/{id} put Vervangen van een Gemeente
# /gemeenten/{id} patch Wijzigen van een Gemeente
# /geometrieen get Ophalen van Geometrieen
# /geometrieen post Voegt een nieuw(e) Geometrie toe.
# /geometrieen put Vervangen van een Geometrie op basis van overeenkomstige sleutelvelden.
# /geometrieen patch Wijzigen van afzonderlijke attributen van een Geometrie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /geometrieen/{id} get Retourneert een Geometrie met de gegeven identifier
# /geometrieen/{id} put Vervangen van een Geometrie
# /geometrieen/{id} patch Wijzigen van een Geometrie
# /kadaster-percelen get Ophalen van KadasterPercelen
# /kadaster-percelen post Voegt een nieuw(e) KadasterPerceel toe.
# /kadaster-percelen put Vervangen van een KadasterPerceel op basis van overeenkomstige sleutelvelden.
# /kadaster-percelen patch Wijzigen van afzonderlijke attributen van een KadasterPerceel. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /kadaster-percelen/{id} get Retourneert een KadasterPerceel met de gegeven identifier
# /kadaster-percelen/{id} put Vervangen van een KadasterPerceel
# /kadaster-percelen/{id} patch Wijzigen van een KadasterPerceel
# /marktwaarden get Ophalen van Marktwaarden
# /marktwaarden post Voegt een nieuw(e) Marktwaarde toe.
# /marktwaarden put Vervangen van een Marktwaarde op basis van overeenkomstige sleutelvelden.
# /marktwaarden patch Wijzigen van afzonderlijke attributen van een Marktwaarde. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /marktwaarden/{id} get Retourneert een Marktwaarde met de gegeven identifier
# /marktwaarden/{id} put Vervangen van een Marktwaarde
# /marktwaarden/{id} patch Wijzigen van een Marktwaarde
# /panden get Ophalen van Panden
# /panden post Voegt een nieuw(e) Pand toe.
# /panden put Vervangen van een Pand op basis van overeenkomstige sleutelvelden.
# /panden patch Wijzigen van afzonderlijke attributen van een Pand. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /panden/{id} get Retourneert een Pand met de gegeven identifier
# /panden/{id} put Vervangen van een Pand
# /panden/{id} patch Wijzigen van een Pand
# /postadressen get Ophalen van Postadressen
# /postadressen post Voegt een nieuw(e) Postadres toe.
# /postadressen put Vervangen van een Postadres op basis van overeenkomstige sleutelvelden.
# /postadressen patch Wijzigen van afzonderlijke attributen van een Postadres. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /postadressen/{id} get Retourneert een Postadres met de gegeven identifier
# /postadressen/{id} put Vervangen van een Postadres
# /postadressen/{id} patch Wijzigen van een Postadres
# /punten get Ophalen van Punten
# /punten post Voegt een nieuw(e) Punt toe.
# /punten put Vervangen van een Punt op basis van overeenkomstige sleutelvelden.
# /punten patch Wijzigen van afzonderlijke attributen van een Punt. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /punten/{id} get Retourneert een Punt met de gegeven identifier
# /punten/{id} put Vervangen van een Punt
# /punten/{id} patch Wijzigen van een Punt
# /renovaties get Ophalen van Renovaties
# /renovaties post Voegt een nieuw(e) Renovatie toe.
# /renovaties put Vervangen van een Renovatie op basis van overeenkomstige sleutelvelden.
# /renovaties patch Wijzigen van afzonderlijke attributen van een Renovatie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /renovaties/{id} get Retourneert een Renovatie met de gegeven identifier
# /renovaties/{id} put Vervangen van een Renovatie
# /renovaties/{id} patch Wijzigen van een Renovatie
# /stadsdelen get Ophalen van Stadsdelen
# /stadsdelen post Voegt een nieuw(e) Stadsdeel toe.
# /stadsdelen put Vervangen van een Stadsdeel op basis van overeenkomstige sleutelvelden.
# /stadsdelen patch Wijzigen van afzonderlijke attributen van een Stadsdeel. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /stadsdelen/{id} get Retourneert een Stadsdeel met de gegeven identifier
# /stadsdelen/{id} put Vervangen van een Stadsdeel
# /stadsdelen/{id} patch Wijzigen van een Stadsdeel
# /taxaties get Ophalen van Taxaties
# /taxaties post Voegt een nieuw(e) Taxatie toe.
# /taxaties put Vervangen van een Taxatie op basis van overeenkomstige sleutelvelden.
# /taxaties patch Wijzigen van afzonderlijke attributen van een Taxatie. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /taxaties/{id} get Retourneert een Taxatie met de gegeven identifier
# /taxaties/{id} put Vervangen van een Taxatie
# /taxaties/{id} patch Wijzigen van een Taxatie
# /vertrekken get Ophalen van Vertrekken
# /vertrekken post Voegt een nieuw(e) Vertrek toe.
# /vertrekken put Vervangen van een Vertrek op basis van overeenkomstige sleutelvelden.
# /vertrekken patch Wijzigen van afzonderlijke attributen van een Vertrek. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /vertrekken/{id} get Retourneert een Vertrek met de gegeven identifier
# /vertrekken/{id} put Vervangen van een Vertrek
# /vertrekken/{id} patch Wijzigen van een Vertrek
# /wijken get Ophalen van Wijken
# /wijken post Voegt een nieuw(e) Wijk toe.
# /wijken put Vervangen van een Wijk op basis van overeenkomstige sleutelvelden.
# /wijken patch Wijzigen van afzonderlijke attributen van een Wijk. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /wijken/{id} get Retourneert een Wijk met de gegeven identifier
# /wijken/{id} put Vervangen van een Wijk
# /wijken/{id} patch Wijzigen van een Wijk
# /woningwaarderingen get Ophalen van Woningwaarderingen
# /woningwaarderingen post Voegt een nieuw(e) Woningwaardering toe.
# /woningwaarderingen put Vervangen van een Woningwaardering op basis van overeenkomstige sleutelvelden.
# /woningwaarderingen patch Wijzigen van afzonderlijke attributen van een Woningwaardering. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woningwaarderingen/{id} get Retourneert een Woningwaardering met de gegeven identifier
# /woningwaarderingen/{id} put Vervangen van een Woningwaardering
# /woningwaarderingen/{id} patch Wijzigen van een Woningwaardering
# /woningwaardering-criteria get Ophalen van WoningwaarderingCriteria
# /woningwaardering-criteria post Voegt een nieuw(e) WoningwaarderingCriterium toe.
# /woningwaardering-criteria put Vervangen van een WoningwaarderingCriterium op basis van overeenkomstige sleutelvelden.
# /woningwaardering-criteria patch Wijzigen van afzonderlijke attributen van een WoningwaarderingCriterium. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woningwaardering-criteria/{id} get Retourneert een WoningwaarderingCriterium met de gegeven identifier
# /woningwaardering-criteria/{id} put Vervangen van een WoningwaarderingCriterium
# /woningwaardering-criteria/{id} patch Wijzigen van een WoningwaarderingCriterium
# /woningwaardering-criterium-groepen get Ophalen van WoningwaarderingCriteriumGroepen
# /woningwaardering-criterium-groepen post Voegt een nieuw(e) WoningwaarderingCriteriumGroep toe.
# /woningwaardering-criterium-groepen put Vervangen van een WoningwaarderingCriteriumGroep op basis van overeenkomstige sleutelvelden.
# /woningwaardering-criterium-groepen patch Wijzigen van afzonderlijke attributen van een WoningwaarderingCriteriumGroep. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woningwaardering-criterium-groepen/{id} get Retourneert een WoningwaarderingCriteriumGroep met de gegeven identifier
# /woningwaardering-criterium-groepen/{id} put Vervangen van een WoningwaarderingCriteriumGroep
# /woningwaardering-criterium-groepen/{id} patch Wijzigen van een WoningwaarderingCriteriumGroep
# /woningwaardering-groepen get Ophalen van WoningwaarderingGroepen
# /woningwaardering-groepen post Voegt een nieuw(e) WoningwaarderingGroep toe.
# /woningwaardering-groepen put Vervangen van een WoningwaarderingGroep op basis van overeenkomstige sleutelvelden.
# /woningwaardering-groepen patch Wijzigen van afzonderlijke attributen van een WoningwaarderingGroep. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woningwaardering-groepen/{id} get Retourneert een WoningwaarderingGroep met de gegeven identifier
# /woningwaardering-groepen/{id} put Vervangen van een WoningwaarderingGroep
# /woningwaardering-groepen/{id} patch Wijzigen van een WoningwaarderingGroep
# /woningwaardering-resultaten get Ophalen van WoningwaarderingResultaten
# /woningwaardering-resultaten post Voegt een nieuw(e) WoningwaarderingResultaat toe.
# /woningwaardering-resultaten put Vervangen van een WoningwaarderingResultaat op basis van overeenkomstige sleutelvelden.
# /woningwaardering-resultaten patch Wijzigen van afzonderlijke attributen van een WoningwaarderingResultaat. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woningwaardering-resultaten/{id} get Retourneert een WoningwaarderingResultaat met de gegeven identifier
# /woningwaardering-resultaten/{id} put Vervangen van een WoningwaarderingResultaat
# /woningwaardering-resultaten/{id} patch Wijzigen van een WoningwaarderingResultaat
# /woonplaatsen get Ophalen van Woonplaatsen
# /woonplaatsen post Voegt een nieuw(e) Woonplaats toe.
# /woonplaatsen put Vervangen van een Woonplaats op basis van overeenkomstige sleutelvelden.
# /woonplaatsen patch Wijzigen van afzonderlijke attributen van een Woonplaats. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woonplaatsen/{id} get Retourneert een Woonplaats met de gegeven identifier
# /woonplaatsen/{id} put Vervangen van een Woonplaats
# /woonplaatsen/{id} patch Wijzigen van een Woonplaats
# /woz-eenheden get Ophalen van WozEenheden
# /woz-eenheden post Voegt een nieuw(e) WozEenheid toe.
# /woz-eenheden put Vervangen van een WozEenheid op basis van overeenkomstige sleutelvelden.
# /woz-eenheden patch Wijzigen van afzonderlijke attributen van een WozEenheid. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /woz-eenheden/{id} get Retourneert een WozEenheid met de gegeven identifier
# /woz-eenheden/{id} put Vervangen van een WozEenheid
# /woz-eenheden/{id} patch Wijzigen van een WozEenheid
# /zekerheid-verpandingen get Ophalen van ZekerheidVerpandingen
# /zekerheid-verpandingen post Voegt een nieuw(e) ZekerheidVerpanding toe.
# /zekerheid-verpandingen put Vervangen van een ZekerheidVerpanding op basis van overeenkomstige sleutelvelden.
# /zekerheid-verpandingen patch Wijzigen van afzonderlijke attributen van een ZekerheidVerpanding. In de meegestuurde entiteit moeten
# sleutelvelden aanwezig zijn.
# /zekerheid-verpandingen/{id} get Retourneert een ZekerheidVerpanding met de gegeven identifier
# /zekerheid-verpandingen/{id} put Vervangen van een ZekerheidVerpanding
# /zekerheid-verpandingen/{id} patch Wijzigen van een ZekerheidVerpanding

# %%
from prettytable import PrettyTable
    
my_table = PrettyTable()

my_table.field_names = ["Path", "Verb", "Description"]
endpoints = list(spec['paths'])
for i in range (len(endpoints)):
    verbs = list(spec['paths'][endpoints[i]])
    for j in range (len(verbs)):
        description_string = spec['paths'][endpoints[i]][verbs[j]]['description']
        description_string = description_string.strip('\n')
        #print(verbs[j], endpoints[i], description_string)
        my_table.add_row([endpoints[i], verbs[j], description_string[:80]])
print(my_table)
# Out:
# +-------------------------------+-------+----------------------------------------------------------------------------------+
# |              Path             |  Verb |                                   Description                                    |
# +-------------------------------+-------+----------------------------------------------------------------------------------+
# |             /ping             |  get  |                 Een ping wordt beantwoord met response code 200                  |
# |           /eenheden           |  get  |                               Ophalen van Eenheden                               |
# |           /eenheden           |  post |                         Voegt een nieuw(e) Eenheid toe.                          |
# |           /eenheden           |  put  |      Vervangen van een Eenheid op basis van overeenkomstige sleutelvelden.       |
# |           /eenheden           | patch | Wijzigen van afzonderlijke attributen van een Eenheid. In de meegestuurde entite |
# |         /eenheden/{id}        |  get  |                Retourneert een Eenheid met de gegeven identifier                 |
# |         /eenheden/{id}        |  put  |                            Vervangen van een Eenheid                             |
# |         /eenheden/{id}        | patch |                             Wijzigen van een Eenheid                             |
# |        /gebeurtenissen        |  get  |                            Ophalen van Gebeurtenissen                            |
# |        /gebeurtenissen        |  post |                       Voegt een nieuw(e) Gebeurtenis toe.                        |
# |        /gebeurtenissen        |  put  |    Vervangen van een Gebeurtenis op basis van overeenkomstige sleutelvelden.     |
# |        /gebeurtenissen        | patch | Wijzigen van afzonderlijke attributen van een Gebeurtenis. In de meegestuurde en |
# |      /gebeurtenissen/{id}     |  get  |              Retourneert een Gebeurtenis met de gegeven identifier               |
# |      /gebeurtenissen/{id}     |  put  |                          Vervangen van een Gebeurtenis                           |
# |      /gebeurtenissen/{id}     | patch |                           Wijzigen van een Gebeurtenis                           |
# |          /kandidaten          |  get  |                              Ophalen van Kandidaten                              |
# |          /kandidaten          |  post |                        Voegt een nieuw(e) Kandidaat toe.                         |
# |          /kandidaten          |  put  |     Vervangen van een Kandidaat op basis van overeenkomstige sleutelvelden.      |
# |          /kandidaten          | patch | Wijzigen van afzonderlijke attributen van een Kandidaat. In de meegestuurde enti |
# |        /kandidaten/{id}       |  get  |               Retourneert een Kandidaat met de gegeven identifier                |
# |        /kandidaten/{id}       |  put  |                           Vervangen van een Kandidaat                            |
# |        /kandidaten/{id}       | patch |                            Wijzigen van een Kandidaat                            |
# |        /overeenkomsten        |  get  |                            Ophalen van Overeenkomsten                            |
# |        /overeenkomsten        |  post |                       Voegt een nieuw(e) Overeenkomst toe.                       |
# |        /overeenkomsten        |  put  |    Vervangen van een Overeenkomst op basis van overeenkomstige sleutelvelden.    |
# |        /overeenkomsten        | patch | Wijzigen van afzonderlijke attributen van een Overeenkomst. In de meegestuurde e |
# |      /overeenkomsten/{id}     |  get  |              Retourneert een Overeenkomst met de gegeven identifier              |
# |      /overeenkomsten/{id}     |  put  |                          Vervangen van een Overeenkomst                          |
# |      /overeenkomsten/{id}     | patch |                          Wijzigen van een Overeenkomst                           |
# |    /overeenkomstkoppelingen   |  get  |                       Ophalen van Overeenkomstkoppelingen                        |
# |    /overeenkomstkoppelingen   |  post |                  Voegt een nieuw(e) Overeenkomstkoppeling toe.                   |
# |    /overeenkomstkoppelingen   |  put  | Vervangen van een Overeenkomstkoppeling op basis van overeenkomstige sleutelveld |
# |    /overeenkomstkoppelingen   | patch | Wijzigen van afzonderlijke attributen van een Overeenkomstkoppeling. In de meege |
# | /overeenkomstkoppelingen/{id} |  get  |         Retourneert een Overeenkomstkoppeling met de gegeven identifier          |
# | /overeenkomstkoppelingen/{id} |  put  |                     Vervangen van een Overeenkomstkoppeling                      |
# | /overeenkomstkoppelingen/{id} | patch |                      Wijzigen van een Overeenkomstkoppeling                      |
# |          /publicaties         |  get  |                             Ophalen van Publicaties                              |
# |          /publicaties         |  post |                        Voegt een nieuw(e) Publicatie toe.                        |
# |          /publicaties         |  put  |     Vervangen van een Publicatie op basis van overeenkomstige sleutelvelden.     |
# |          /publicaties         | patch | Wijzigen van afzonderlijke attributen van een Publicatie. In de meegestuurde ent |
# |       /publicaties/{id}       |  get  |               Retourneert een Publicatie met de gegeven identifier               |
# |       /publicaties/{id}       |  put  |                           Vervangen van een Publicatie                           |
# |       /publicaties/{id}       | patch |                           Wijzigen van een Publicatie                            |
# |      /puntenberekeningen      |  get  |                          Ophalen van Puntenberekeningen                          |
# |      /puntenberekeningen      |  post |                     Voegt een nieuw(e) Puntenberekening toe.                     |
# |      /puntenberekeningen      |  put  |  Vervangen van een Puntenberekening op basis van overeenkomstige sleutelvelden.  |
# |      /puntenberekeningen      | patch | Wijzigen van afzonderlijke attributen van een Puntenberekening. In de meegestuur |
# |    /puntenberekeningen/{id}   |  get  |            Retourneert een Puntenberekening met de gegeven identifier            |
# |    /puntenberekeningen/{id}   |  put  |                        Vervangen van een Puntenberekening                        |
# |    /puntenberekeningen/{id}   | patch |                        Wijzigen van een Puntenberekening                         |
# |           /relaties           |  get  |                               Ophalen van Relaties                               |
# |           /relaties           |  post |                         Voegt een nieuw(e) Relatie toe.                          |
# |           /relaties           |  put  |      Vervangen van een Relatie op basis van overeenkomstige sleutelvelden.       |
# |           /relaties           | patch | Wijzigen van afzonderlijke attributen van een Relatie. In de meegestuurde entite |
# |         /relaties/{id}        |  get  |                Retourneert een Relatie met de gegeven identifier                 |
# |         /relaties/{id}        |  put  |                            Vervangen van een Relatie                             |
# |         /relaties/{id}        | patch |                             Wijzigen van een Relatie                             |
# |           /sancties           |  get  |                               Ophalen van Sancties                               |
# |           /sancties           |  post |                         Voegt een nieuw(e) Sanctie toe.                          |
# |           /sancties           |  put  |      Vervangen van een Sanctie op basis van overeenkomstige sleutelvelden.       |
# |           /sancties           | patch | Wijzigen van afzonderlijke attributen van een Sanctie. In de meegestuurde entite |
# |         /sancties/{id}        |  get  |                Retourneert een Sanctie met de gegeven identifier                 |
# |         /sancties/{id}        |  put  |                            Vervangen van een Sanctie                             |
# |         /sancties/{id}        | patch |                             Wijzigen van een Sanctie                             |
# |         /toewijzingen         |  get  |                             Ophalen van Toewijzingen                             |
# |         /toewijzingen         |  post |                        Voegt een nieuw(e) Toewijzing toe.                        |
# |         /toewijzingen         |  put  |     Vervangen van een Toewijzing op basis van overeenkomstige sleutelvelden.     |
# |         /toewijzingen         | patch | Wijzigen van afzonderlijke attributen van een Toewijzing. In de meegestuurde ent |
# |       /toewijzingen/{id}      |  get  |               Retourneert een Toewijzing met de gegeven identifier               |
# |       /toewijzingen/{id}      |  put  |                           Vervangen van een Toewijzing                           |
# |       /toewijzingen/{id}      | patch |                           Wijzigen van een Toewijzing                            |
# +-------------------------------+-------+----------------------------------------------------------------------------------+

# %% [markdown]
# ## 3. Getting the components

# %%
objects = list(spec['components']['schemas'])
print(len(objects))
objects.sort()
objects
# Out:
# 114
# ['Eenheden-Adres',
#  'Eenheden-BuitenlandsAdres',
#  'Eenheden-Buurt',
#  'Eenheden-Cluster',
#  'Eenheden-Contactgegeven',
#  'Eenheden-Eenheid',
#  'Eenheden-EenheidVoorwaarden',
#  'Eenheden-Eenheidadres',
#  'Eenheden-Energieprestatie',
#  'Eenheden-Gemeente',
#  'Eenheden-Geometrie',
#  'Eenheden-Pand',
#  'Eenheden-Postadres',
#  'Eenheden-Prijscomponent',
#  'Eenheden-Punt',
#  'Eenheden-Relatie',
#  'Eenheden-RelatieAdres',
#  'Eenheden-Relatierol',
#  'Eenheden-Renovatie',
#  'Eenheden-Telefoonnummer',
#  'Eenheden-Vertrek',
#  'Eenheden-Wijk',
#  'Eenheden-Woonplaats',
#  'Eenheid-sleutels',
#  'ExtraAttribuut',
#  'Foutbericht',
#  'Gebeurtenissen-Adres',
#  'Gebeurtenissen-Cluster',
#  'Gebeurtenissen-Eenheidadres',
#  'Gebeurtenissen-Gebeurtenis',
#  'Gebeurtenissen-Gemeente',
#  'Gebeurtenissen-Overeenkomst',
#  'Gebeurtenissen-Serviceovereenkomst',
#  'Informatieobject',
#  'Kandidaten-Contactgegeven',
#  'Kandidaten-Inkomen',
#  'Kandidaten-Kandidaat',
#  'Kandidaten-NatuurlijkPersoon',
#  'Kandidaten-Opleiding',
#  'Kandidaten-Relatie',
#  'Kandidaten-Relatiegroep',
#  'Kandidaten-Relatierol',
#  'Kandidaten-Signalering',
#  'Overeenkomsten-Overeenkomst',
#  'Overeenkomsten-Serviceovereenkomst',
#  'Overeenkomstkoppelingen-Adres',
#  'Overeenkomstkoppelingen-NatuurlijkPersoon',
#  'Overeenkomstkoppelingen-Overeenkomst',
#  'Overeenkomstkoppelingen-Overeenkomstkoppeling',
#  'Overeenkomstkoppelingen-Relatie',
#  'Overeenkomstkoppelingen-RelatieAdres',
#  'Overeenkomstkoppelingen-Relatierol',
#  'Overeenkomstkoppelingen-Serviceovereenkomst',
#  'Publicaties-Adres',
#  'Publicaties-Buurt',
#  'Publicaties-Cluster',
#  'Publicaties-Contactgegeven',
#  'Publicaties-Eenheid',
#  'Publicaties-EenheidVoorwaarden',
#  'Publicaties-Eenheidadres',
#  'Publicaties-Energieprestatie',
#  'Publicaties-Gemeente',
#  'Publicaties-Geometrie',
#  'Publicaties-HuidigeGebruiker',
#  'Publicaties-NatuurlijkPersoon',
#  'Publicaties-Pand',
#  'Publicaties-Prijscomponent',
#  'Publicaties-Publicatie',
#  'Publicaties-Punt',
#  'Publicaties-Relatie',
#  'Publicaties-Relatierol',
#  'Publicaties-Renovatie',
#  'Publicaties-Telefoonnummer',
#  'Publicaties-Vertrek',
#  'Publicaties-Wijk',
#  'Publicaties-Woonplaats',
#  'Puntenberekeningen-Adres',
#  'Puntenberekeningen-Overeenkomst',
#  'Puntenberekeningen-Puntenberekening',
#  'Puntenberekeningen-Puntenmutatie',
#  'Puntenberekeningen-Serviceovereenkomst',
#  'Referentiedata',
#  'Relatie-sleutels',
#  'Relaties-Account',
#  'Relaties-Adres',
#  'Relaties-BuitenlandsAdres',
#  'Relaties-Contactgegeven',
#  'Relaties-Eenheidadres',
#  'Relaties-Inkomen',
#  'Relaties-NatuurlijkPersoon',
#  'Relaties-Opleiding',
#  'Relaties-Postadres',
#  'Relaties-Rechtspersoon',
#  'Relaties-Relatie',
#  'Relaties-RelatieAdres',
#  'Relaties-Relatiegroep',
#  'Relaties-Relatierol',
#  'Relaties-Woonplaats',
#  'Sancties-Adres',
#  'Sancties-Gebeurtenis',
#  'Sancties-Overeenkomst',
#  'Sancties-Sanctie',
#  'Sancties-Serviceovereenkomst',
#  'Toewijzingen-Inkomen',
#  'Toewijzingen-Kandidaat',
#  'Toewijzingen-NatuurlijkPersoon',
#  'Toewijzingen-Opleiding',
#  'Toewijzingen-Overeenkomst',
#  'Toewijzingen-Relatie',
#  'Toewijzingen-Relatierol',
#  'Toewijzingen-Signalering',
#  'Toewijzingen-Toewijzing',
#  'Toewijzingen-Voorrangsregeling',
#  'Toewijzingen-VoorrangsregelingProfiel']

# %%
# lambda function to remove '-sleutels' from the list of objects
objects = [x for x in objects if "-sleutels" not in x ]
objects
# Out:
# ['Eenheden-Adres',
#  'Eenheden-BuitenlandsAdres',
#  'Eenheden-Buurt',
#  'Eenheden-Cluster',
#  'Eenheden-Contactgegeven',
#  'Eenheden-Eenheid',
#  'Eenheden-EenheidVoorwaarden',
#  'Eenheden-Eenheidadres',
#  'Eenheden-Energieprestatie',
#  'Eenheden-Gemeente',
#  'Eenheden-Geometrie',
#  'Eenheden-Pand',
#  'Eenheden-Postadres',
#  'Eenheden-Prijscomponent',
#  'Eenheden-Punt',
#  'Eenheden-Relatie',
#  'Eenheden-RelatieAdres',
#  'Eenheden-Relatierol',
#  'Eenheden-Renovatie',
#  'Eenheden-Telefoonnummer',
#  'Eenheden-Vertrek',
#  'Eenheden-Wijk',
#  'Eenheden-Woonplaats',
#  'ExtraAttribuut',
#  'Foutbericht',
#  'Gebeurtenissen-Adres',
#  'Gebeurtenissen-Cluster',
#  'Gebeurtenissen-Eenheidadres',
#  'Gebeurtenissen-Gebeurtenis',
#  'Gebeurtenissen-Gemeente',
#  'Gebeurtenissen-Overeenkomst',
#  'Gebeurtenissen-Serviceovereenkomst',
#  'Informatieobject',
#  'Kandidaten-Contactgegeven',
#  'Kandidaten-Inkomen',
#  'Kandidaten-Kandidaat',
#  'Kandidaten-NatuurlijkPersoon',
#  'Kandidaten-Opleiding',
#  'Kandidaten-Relatie',
#  'Kandidaten-Relatiegroep',
#  'Kandidaten-Relatierol',
#  'Kandidaten-Signalering',
#  'Overeenkomsten-Overeenkomst',
#  'Overeenkomsten-Serviceovereenkomst',
#  'Overeenkomstkoppelingen-Adres',
#  'Overeenkomstkoppelingen-NatuurlijkPersoon',
#  'Overeenkomstkoppelingen-Overeenkomst',
#  'Overeenkomstkoppelingen-Overeenkomstkoppeling',
#  'Overeenkomstkoppelingen-Relatie',
#  'Overeenkomstkoppelingen-RelatieAdres',
#  'Overeenkomstkoppelingen-Relatierol',
#  'Overeenkomstkoppelingen-Serviceovereenkomst',
#  'Publicaties-Adres',
#  'Publicaties-Buurt',
#  'Publicaties-Cluster',
#  'Publicaties-Contactgegeven',
#  'Publicaties-Eenheid',
#  'Publicaties-EenheidVoorwaarden',
#  'Publicaties-Eenheidadres',
#  'Publicaties-Energieprestatie',
#  'Publicaties-Gemeente',
#  'Publicaties-Geometrie',
#  'Publicaties-HuidigeGebruiker',
#  'Publicaties-NatuurlijkPersoon',
#  'Publicaties-Pand',
#  'Publicaties-Prijscomponent',
#  'Publicaties-Publicatie',
#  'Publicaties-Punt',
#  'Publicaties-Relatie',
#  'Publicaties-Relatierol',
#  'Publicaties-Renovatie',
#  'Publicaties-Telefoonnummer',
#  'Publicaties-Vertrek',
#  'Publicaties-Wijk',
#  'Publicaties-Woonplaats',
#  'Puntenberekeningen-Adres',
#  'Puntenberekeningen-Overeenkomst',
#  'Puntenberekeningen-Puntenberekening',
#  'Puntenberekeningen-Puntenmutatie',
#  'Puntenberekeningen-Serviceovereenkomst',
#  'Referentiedata',
#  'Relaties-Account',
#  'Relaties-Adres',
#  'Relaties-BuitenlandsAdres',
#  'Relaties-Contactgegeven',
#  'Relaties-Eenheidadres',
#  'Relaties-Inkomen',
#  'Relaties-NatuurlijkPersoon',
#  'Relaties-Opleiding',
#  'Relaties-Postadres',
#  'Relaties-Rechtspersoon',
#  'Relaties-Relatie',
#  'Relaties-RelatieAdres',
#  'Relaties-Relatiegroep',
#  'Relaties-Relatierol',
#  'Relaties-Woonplaats',
#  'Sancties-Adres',
#  'Sancties-Gebeurtenis',
#  'Sancties-Overeenkomst',
#  'Sancties-Sanctie',
#  'Sancties-Serviceovereenkomst',
#  'Toewijzingen-Inkomen',
#  'Toewijzingen-Kandidaat',
#  'Toewijzingen-NatuurlijkPersoon',
#  'Toewijzingen-Opleiding',
#  'Toewijzingen-Overeenkomst',
#  'Toewijzingen-Relatie',
#  'Toewijzingen-Relatierol',
#  'Toewijzingen-Signalering',
#  'Toewijzingen-Toewijzing',
#  'Toewijzingen-Voorrangsregeling',
#  'Toewijzingen-VoorrangsregelingProfiel']

# %%
#creating a dictionary with objects and their properties
object_dict ={}
#objects = list(spec['components']['schemas'])
for i in range (len(objects)):
    try:
        object_dict[objects[i]]=list(spec['components']['schemas'][objects[i]]['properties'])#['properties']
    except:
        my_list= []
        my_dict = spec['components']['schemas'][objects[i]]['allOf'][0]
        for key, value in my_dict.items():
            my_string = str(value)
        my_string = my_string.replace('#/components/schemas/', 'allOf: ')
        my_list.append(my_string)
        object_dict[objects[i]] = my_list+list(spec['components']['schemas'][objects[i]]['allOf'][1]['properties'])
object_dict
# Out:
# {'Eenheden-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam'],
#  'Eenheden-BuitenlandsAdres': ['allOf: Eenheden-Adres', 'land'],
#  'Eenheden-Buurt': ['code', 'naam'],
#  'Eenheden-Cluster': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Eenheden-Contactgegeven': ['soort',
#   'detailSoort',
#   'status',
#   'vertrouwelijkheid',
#   'voorkeur',
#   'waarde'],
#  'Eenheden-Eenheid': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'naam',
#   'omschrijving',
#   'kadastraalNummer',
#   'status',
#   'detailStatus',
#   'beginBouwdatum',
#   'opleverdatum',
#   'inExploitatiedatum',
#   'uitExploitatiedatum',
#   'aantalOnzelfstandigeEenheden',
#   'aanvullendeDoelgroep',
#   'adres',
#   'beoogdUitExploitatieDatum',
#   'bestemming',
#   'bouwnummer',
#   'brutohuur',
#   'buitenruimten',
#   'clusters',
#   'doelgroep',
#   'energieprestatie',
#   'energievoorzieningen',
#   'etage',
#   'inExploitatieReden',
#   'interieur',
#   'isolatie',
#   'kamersAantal',
#   'klimaatbeheersing',
#   'kwaliteitsniveau',
#   'ligging',
#   'liggingTuin',
#   'maatschappelijkLabel',
#   'monumenten',
#   'overigeVertrekkenTotaalOppervlakte',
#   'panden',
#   'prijscomponenten',
#   'prijsconditie',
#   'publicatieLabel',
#   'rekenhuur',
#   'relaties',
#   'renovatie',
#   'sanitair',
#   'situering',
#   'streefhuur',
#   'toegankelijkheidslabel',
#   'totaalInhoud',
#   'totaleOppervlakte',
#   'uitExploitatieReden',
#   'verkoop',
#   'vertrekken',
#   'vertrekkenAantal',
#   'verwarmdeVertrekkenAantal',
#   'voorwaarden',
#   'vraagprijs',
#   'woonvertrekInhoud',
#   'woonvertrekkenTotaalOppervlakte',
#   'woonvorm',
#   'zelfstandig',
#   'zorgfaciliteitOmschrijving',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Eenheden-EenheidVoorwaarden': ['maximumAantalPersonen',
#   'maximuminkomen',
#   'maximunleeftijd',
#   'minimumAantalPersonen',
#   'minimuminkomen',
#   'minimumleeftijd'],
#  'Eenheden-Eenheidadres': ['allOf: Eenheden-Adres',
#   'geometrie',
#   'land',
#   'woonplaats'],
#  'Eenheden-Energieprestatie': ['begindatum', 'einddatum', 'index', 'label'],
#  'Eenheden-Gemeente': ['code', 'naam'],
#  'Eenheden-Geometrie': ['soort'],
#  'Eenheden-Pand': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'kavelOppervlakte',
#   'liftAanwezig',
#   'renovatie'],
#  'Eenheden-Postadres': ['allOf: Eenheden-Adres',
#   'antwoordnummer',
#   'postbusnummer',
#   'woonplaats'],
#  'Eenheden-Prijscomponent': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'bedrag',
#   'btw'],
#  'Eenheden-Punt': ['allOf: Eenheden-Geometrie', 'lengtegraad', 'breedtegraad'],
#  'Eenheden-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adressen',
#   'contactgegevens',
#   'rollen'],
#  'Eenheden-RelatieAdres': ['soort', 'adres'],
#  'Eenheden-Relatierol': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Eenheden-Renovatie': ['omschrijving', 'datum'],
#  'Eenheden-Telefoonnummer': ['allOf: Eenheden-Contactgegeven',
#   'abonneenummer',
#   'dagdelen',
#   'extensie',
#   'landnummer',
#   'netnummer'],
#  'Eenheden-Vertrek': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'inhoud',
#   'oppervlakte'],
#  'Eenheden-Wijk': ['code', 'naam'],
#  'Eenheden-Woonplaats': ['code', 'naam'],
#  'ExtraAttribuut': ['naam', 'waarde'],
#  'Foutbericht': ['code', 'omschrijving'],
#  'Gebeurtenissen-Adres': ['huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode'],
#  'Gebeurtenissen-Cluster': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'naam'],
#  'Gebeurtenissen-Eenheidadres': ['allOf: Gebeurtenissen-Adres',
#   'gemeente',
#   'geometrie',
#   'land',
#   'woonplaats'],
#  'Gebeurtenissen-Gebeurtenis': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'datum',
#   'begindatum',
#   'einddatum',
#   'adres',
#   'cluster',
#   'contextId',
#   'inschrijving',
#   'vestiging',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Gebeurtenissen-Gemeente': ['code', 'naam'],
#  'Gebeurtenissen-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'detailSoort'],
#  'Gebeurtenissen-Serviceovereenkomst': ['allOf: Gebeurtenissen-Overeenkomst',
#   'samenwerkingsverband'],
#  'Informatieobject': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'onderwerp',
#   'subonderwerp',
#   'titel',
#   'beschrijving',
#   'bestand',
#   'bestandsgrootte',
#   'bestandslocatie',
#   'bestandsnaam',
#   'externePublicatie',
#   'externePublicatietekst',
#   'formaat',
#   'gebruiksrechten',
#   'taal',
#   'versie',
#   'vertrouwelijkheid'],
#  'Kandidaten-Contactgegeven': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'status',
#   'vertrouwelijkheid',
#   'voorkeur',
#   'waarde'],
#  'Kandidaten-Inkomen': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'nettoMaandinkomen',
#   'brutoMaandinkomen',
#   'bron',
#   'brutoJaarinkomen',
#   'controledatum',
#   'nettoJaarinkomen'],
#  'Kandidaten-Kandidaat': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'status',
#   'detailStatus',
#   'aantalKinderen',
#   'aantalVolwassenen',
#   'eenheid',
#   'positie',
#   'relatie',
#   'verzamelinkomen',
#   'verzamelinkomenEU',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Kandidaten-NatuurlijkPersoon': ['allOf: Kandidaten-Relatie',
#   'voornaam',
#   'achternaam',
#   'geboortedatum',
#   'geslacht',
#   'initialen',
#   'inkomens',
#   'opleiding',
#   'roepnaam',
#   'signaleringen',
#   'tussenvoegsels'],
#  'Kandidaten-Opleiding': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'instelling',
#   'niveau',
#   'plaats',
#   'studentnummer'],
#  'Kandidaten-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'contactgegevens',
#   'rollen'],
#  'Kandidaten-Relatiegroep': ['allOf: Kandidaten-Relatie', 'naam', 'relaties'],
#  'Kandidaten-Relatierol': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Kandidaten-Signalering': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'status',
#   'detailStatus',
#   'begindatum',
#   'einddatum'],
#  'Overeenkomsten-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'detailSoort',
#   'status',
#   'begindatum',
#   'einddatum',
#   'eindeDetailReden',
#   'eindeReden',
#   'relaties',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Overeenkomsten-Serviceovereenkomst': ['allOf: Overeenkomsten-Overeenkomst',
#   'samenwerkingsverband',
#   'aantalPersonenHuishouden'],
#  'Overeenkomstkoppelingen-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam'],
#  'Overeenkomstkoppelingen-NatuurlijkPersoon': ['allOf: Overeenkomstkoppelingen-Relatie',
#   'geboortedatum',
#   'voornaam',
#   'achternaam',
#   'initialen',
#   'roepnaam',
#   'tussenvoegsels',
#   'voorletters'],
#  'Overeenkomstkoppelingen-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'detailSoort',
#   'status',
#   'begindatum',
#   'einddatum',
#   'redenOpzegging',
#   'relaties'],
#  'Overeenkomstkoppelingen-Overeenkomstkoppeling': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'status',
#   'begindatum',
#   'einddatum',
#   'overeenkomsten',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Overeenkomstkoppelingen-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adressen',
#   'huishoudledenAantal',
#   'rollen'],
#  'Overeenkomstkoppelingen-RelatieAdres': ['soort', 'adres'],
#  'Overeenkomstkoppelingen-Relatierol': ['soort', 'naam'],
#  'Overeenkomstkoppelingen-Serviceovereenkomst': ['allOf: Overeenkomstkoppelingen-Overeenkomst',
#   'samenwerkingsverband',
#   'aantalPersonenHuishouden'],
#  'Publicaties-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'buurt',
#   'gemeente',
#   'geometrie',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam',
#   'wijk',
#   'woonplaats'],
#  'Publicaties-Buurt': ['code', 'naam'],
#  'Publicaties-Cluster': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Publicaties-Contactgegeven': ['soort',
#   'detailSoort',
#   'status',
#   'vertrouwelijkheid',
#   'voorkeur',
#   'waarde'],
#  'Publicaties-Eenheid': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'naam',
#   'omschrijving',
#   'kadastraalNummer',
#   'bouwnummer',
#   'status',
#   'detailStatus',
#   'beginBouwdatum',
#   'opleverdatum',
#   'aantalOnzelfstandigeEenheden',
#   'aanvullendeDoelgroep',
#   'adres',
#   'beoogdUitExploitatieDatum',
#   'beschermdStadsgezicht',
#   'bewoonbareVertrekkenTotaalInhoud',
#   'brutohuur',
#   'buitenruimten',
#   'clusters',
#   'doelgroep',
#   'energieprestatie',
#   'energievoorzieningen',
#   'etage',
#   'inExploitatiedatum',
#   'inExploitatieReden',
#   'interieur',
#   'isolatie',
#   'kamersAantal',
#   'klimaatbeheersing',
#   'kwaliteitsniveau',
#   'ligging',
#   'liggingTuin',
#   'maatschappelijkLabel',
#   'monumenten',
#   'overigeVertrekkenTotaalOppervlakte',
#   'panden',
#   'prijscomponenten',
#   'prijsconditie',
#   'publicatieLabel',
#   'rayon',
#   'rekenhuur',
#   'relaties',
#   'renovatie',
#   'sanitair',
#   'situering',
#   'streefhuur',
#   'toegankelijkheidslabel',
#   'totaalInhoud',
#   'totaleOppervlakte',
#   'uitExploitatiedatum',
#   'uitExploitatieReden',
#   'verkoop',
#   'vertrekken',
#   'vertrekkenAantal',
#   'verwarmdeVertrekkenAantal',
#   'voorwaarden',
#   'vraagprijs',
#   'woonvertrekInhoud',
#   'woonvertrekkenTotaalOppervlakte',
#   'woonvorm',
#   'zelfstandig',
#   'zorgfaciliteitOmschrijving'],
#  'Publicaties-EenheidVoorwaarden': ['maximumAantalPersonen',
#   'maximuminkomen',
#   'maximunleeftijd',
#   'minimumAantalPersonen',
#   'minimuminkomen',
#   'minimumleeftijd'],
#  'Publicaties-Eenheidadres': ['allOf: Publicaties-Adres',
#   'geometrie',
#   'land',
#   'woonplaats'],
#  'Publicaties-Energieprestatie': ['begindatum', 'einddatum', 'index', 'label'],
#  'Publicaties-Gemeente': ['code', 'naam'],
#  'Publicaties-Geometrie': ['soort'],
#  'Publicaties-HuidigeGebruiker': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'Vertrekdatum',
#   'relatie'],
#  'Publicaties-NatuurlijkPersoon': ['allOf: Publicaties-Relatie',
#   'achternaam',
#   'initialen',
#   'tussenvoegsels',
#   'voornaam'],
#  'Publicaties-Pand': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'renovatie',
#   'kavelOppervlakte',
#   'liftAanwezig'],
#  'Publicaties-Prijscomponent': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'bedrag',
#   'btw'],
#  'Publicaties-Publicatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'status',
#   'begindatum',
#   'einddatum',
#   'opleverdatum',
#   'aantalEenheden',
#   'aantalEenhedenBeschikbaar',
#   'advertentieUrl',
#   'cluster',
#   'contractvorm',
#   'detailModel',
#   'detailStatus',
#   'eenheden',
#   'huidigeGebruiker',
#   'intakevorm',
#   'label',
#   'looptijd',
#   'model',
#   'modules',
#   'oplevering',
#   'reactieUrl',
#   'taal',
#   'wachttijd',
#   'wachttijdMetVoorrang',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Publicaties-Punt': ['allOf: Publicaties-Geometrie',
#   'lengtegraad',
#   'breedtegraad'],
#  'Publicaties-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'contactgegevens',
#   'rollen'],
#  'Publicaties-Relatierol': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Publicaties-Renovatie': ['omschrijving', 'datum'],
#  'Publicaties-Telefoonnummer': ['allOf: Publicaties-Contactgegeven',
#   'abonneenummer',
#   'dagdelen',
#   'extensie',
#   'landnummer',
#   'netnummer'],
#  'Publicaties-Vertrek': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'inhoud',
#   'oppervlakte'],
#  'Publicaties-Wijk': ['code', 'naam'],
#  'Publicaties-Woonplaats': ['code', 'naam'],
#  'Puntenberekeningen-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam'],
#  'Puntenberekeningen-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'detailSoort'],
#  'Puntenberekeningen-Puntenberekening': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'datum',
#   'begindatum',
#   'einddatum',
#   'inschrijving',
#   'puntenmutaties',
#   'situatiepunten',
#   'startpunten',
#   'zoekpunten',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Puntenberekeningen-Puntenmutatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'omschrijving',
#   'adressen'],
#  'Puntenberekeningen-Serviceovereenkomst': ['allOf: Puntenberekeningen-Overeenkomst',
#   'samenwerkingsverband'],
#  'Referentiedata': ['code', 'naam'],
#  'Relaties-Account': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'gebruikersnaam',
#   'status'],
#  'Relaties-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam'],
#  'Relaties-BuitenlandsAdres': ['allOf: Relaties-Adres',
#   'adresregel1',
#   'adresregel2',
#   'land',
#   'postbusnummer',
#   'provincie',
#   'woonplaats'],
#  'Relaties-Contactgegeven': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'status',
#   'vertrouwelijkheid',
#   'voorkeur',
#   'waarde'],
#  'Relaties-Eenheidadres': ['allOf: Relaties-Adres',
#   'land',
#   'provincie',
#   'woonplaats'],
#  'Relaties-Inkomen': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'controledatum',
#   'bron',
#   'brutoJaarinkomen',
#   'brutoMaandinkomen',
#   'inkomensverklaringsoort',
#   'nettoJaarinkomen',
#   'nettoMaandinkomen',
#   'relaties'],
#  'Relaties-NatuurlijkPersoon': ['allOf: Relaties-Relatie',
#   'voornaam',
#   'initialen',
#   'aanhef',
#   'account',
#   'achternaam',
#   'bsn',
#   'burgerlijkeStaat',
#   'geboortedatum',
#   'geslacht',
#   'inkomens',
#   'nationaliteit',
#   'opleiding',
#   'overlijdensdatum',
#   'roepnaam',
#   'tussenvoegsels',
#   'voorkeurstaal',
#   'voorletters'],
#  'Relaties-Opleiding': ['instelling', 'plaats', 'studentnummer'],
#  'Relaties-Postadres': ['allOf: Relaties-Adres',
#   'antwoordnummer',
#   'postbusnummer',
#   'woonplaats'],
#  'Relaties-Rechtspersoon': ['allOf: Relaties-Relatie',
#   'naam',
#   'btwNummer',
#   'globaalLocatienummer',
#   'kvkNummer',
#   'organisatievorm',
#   'relaties'],
#  'Relaties-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adressen',
#   'contactgegevens',
#   'groepen',
#   'rollen',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Relaties-RelatieAdres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'begindatum',
#   'einddatum',
#   'adres'],
#  'Relaties-Relatiegroep': ['allOf: Relaties-Relatie', 'naam', 'relaties'],
#  'Relaties-Relatierol': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam',
#   'omschrijving',
#   'begindatum',
#   'einddatum',
#   'contactgegevens',
#   'relatieAdressen',
#   'rolRelatie'],
#  'Relaties-Woonplaats': ['code', 'naam'],
#  'Sancties-Adres': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'adres',
#   'huisletter',
#   'huisnummer',
#   'huisnummerToevoeging',
#   'postcode',
#   'straatnaam'],
#  'Sancties-Gebeurtenis': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'datum',
#   'begindatum',
#   'einddatum',
#   'adres',
#   'contextId',
#   'vestiging'],
#  'Sancties-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'detailSoort',
#   'begindatum',
#   'einddatum'],
#  'Sancties-Sanctie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'soort',
#   'omschrijving',
#   'status',
#   'begindatum',
#   'einddatum',
#   'gebeurtenissen',
#   'inschrijving',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Sancties-Serviceovereenkomst': ['allOf: Sancties-Overeenkomst',
#   'bedrag',
#   'samenwerkingsverband'],
#  'Toewijzingen-Inkomen': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'nettoMaandinkomen',
#   'brutoMaandinkomen',
#   'bron',
#   'brutoJaarinkomen',
#   'controledatum',
#   'nettoJaarinkomen'],
#  'Toewijzingen-Kandidaat': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'status',
#   'detailStatus',
#   'aantalKinderen',
#   'aantalVolwassenen',
#   'positie',
#   'relatie',
#   'verzamelinkomen',
#   'verzamelinkomenEU'],
#  'Toewijzingen-NatuurlijkPersoon': ['allOf: Toewijzingen-Relatie',
#   'voornaam',
#   'achternaam',
#   'geboortedatum',
#   'geslacht',
#   'initialen',
#   'inkomens',
#   'opleiding',
#   'roepnaam',
#   'signaleringen',
#   'tussenvoegsels'],
#  'Toewijzingen-Opleiding': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'begindatum',
#   'einddatum',
#   'instelling',
#   'niveau',
#   'plaats',
#   'studentnummer'],
#  'Toewijzingen-Overeenkomst': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'begindatum',
#   'einddatum',
#   'prijscomponenten'],
#  'Toewijzingen-Relatie': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'rollen'],
#  'Toewijzingen-Relatierol': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'naam'],
#  'Toewijzingen-Signalering': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'status',
#   'detailStatus',
#   'begindatum',
#   'einddatum'],
#  'Toewijzingen-Toewijzing': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'datum',
#   'aanvullendeDoelgroep',
#   'doelgroep',
#   'eenheid',
#   'huishoudgrootte',
#   'kandidaat',
#   'overeenkomst',
#   'Rekenhuur',
#   'Rekeninkomen',
#   'voorrangsregelingen',
#   'extra-attributen',
#   'informatieobjecten'],
#  'Toewijzingen-Voorrangsregeling': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'soort',
#   'detailSoort',
#   'naam',
#   'begindatum',
#   'einddatum',
#   'profiel'],
#  'Toewijzingen-VoorrangsregelingProfiel': ['id',
#   'idExtern',
#   'idGegevensbeheerder',
#   'code',
#   'eenheidSoorten',
#   'huidigeOppervlakte',
#   'huidigeVerdieping',
#   'huurInkomenTabel',
#   'maximumBrutoHuur',
#   'maximumKamers',
#   'minimumBrutoHuur',
#   'minimumKamers',
#   'minimumOppervlakte',
#   'toegankelijkheidslabels']}

# %% [markdown]
# ## 4. Saving as plantuml, .csv and .json

# %% [markdown]
# ### 4a. Creating a plantuml file

# %%
textfile = open(API_name+"_API_plantuml.txt", "w")
textfile.write('@startuml\n')
for key, value in object_dict.items():
    textfile.write('class '+str(key) +'{\n')
    for i in range (len(value)):
        textfile.write(value[i] + "\n")
    textfile.write('}\n')
#textfile.write('}\n')
textfile.write('@enduml')
textfile.close()

# %%
import glob
my_txts = glob.glob('*.txt')
my_txts
# Out:
# ['VERA-Beheer_Financiele_Gegevens_API_plantuml.txt',
#  'VERA-Beheer_Overeenkomstgegevens_API_plantuml.txt',
#  'VERA-Beheer_Relatiegegevens_API_plantuml.txt',
#  'VERA-Beheer_Vastgoedegevens_API_plantuml.txt',
#  'VERA-Casemanagement_API_plantuml.txt',
#  'VERA-Incasso_API_plantuml.txt',
#  'VERA-Kwaliteitsmeting_API_plantuml.txt',
#  'VERA-Onderhoud_API_plantuml.txt',
#  'VERA-Verhuren_Eenheden_API_plantuml.txt',
#  'VERA-Woonruimteverdeling_API_plantuml.txt']

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA\\Ketenprocessen_api'

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA\\Ketenprocessen_api\VERA-Beheer_Financiele_Gegevens_API_plantuml.txt

# %%
#convert the txt file to an .png image using plantuml
# !python -m plantuml VERA-Woonruimteverdeling_API_plantuml.txt
# Out:
# [{'filename': 'VERA-Woonruimteverdeling_API_plantuml.txt', 'gen_success': True}]

# %%
#show the generated png
from IPython import display
display.Image(filename="VERA-Woonruimteverdeling_API_plantuml.png", width=1000, height=800)

# %% [markdown]
# ### 4b. Saving as a .csv file

# %%
with open(API_name+"_API_objecten.csv", mode="w") as my_csv:
    for key, value in object_dict.items():
        my_csv.write(str(key)+";")
        for i in range (len(value)-1):
            my_csv.write(value[i]+",")#write values + a comma  
        my_csv.write(value[-1]+"\n") #write last value (and no comma)

# %%
import glob
my_csvs=glob.glob('*.csv')
my_csvs
# Out:
# ['VERA-Beheer_Financiele_Gegevens_API_objecten.csv',
#  'VERA-Beheer_Overeenkomstgegevens_API_objecten.csv',
#  'VERA-Beheer_Relatiegegevens_API_objecten.csv',
#  'VERA-Beheer_Vastgoedegevens_API_objecten.csv',
#  'VERA-Casemanagement_API_objecten.csv',
#  'VERA-Incasso_API_objecten.csv',
#  'VERA-Kwaliteitsmeting_API_objecten.csv',
#  'VERA-Onderhoud_API_objecten.csv',
#  'VERA-Verhuren_Eenheden_API_objecten.csv',
#  'VERA-Woonruimteverdeling_API_objecten.csv']

# %%
#check the plantuml file manually
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\VERA\\VERA-Onderhoud_API_objecten.csv

# %% [markdown]
# ### 4c. Saving as a .json file

# %%
#converting the python dict to a JSON 
import json 
      
# Serializing json  
json_object = json.dumps(object_dict, indent = 4) 
print(json_object)
# Out:
# {
#     "Eenheden-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam"
#     ],
#     "Eenheden-BuitenlandsAdres": [
#         "allOf: Eenheden-Adres",
#         "land"
#     ],
#     "Eenheden-Buurt": [
#         "code",
#         "naam"
#     ],
#     "Eenheden-Cluster": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Eenheden-Contactgegeven": [
#         "soort",
#         "detailSoort",
#         "status",
#         "vertrouwelijkheid",
#         "voorkeur",
#         "waarde"
#     ],
#     "Eenheden-Eenheid": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "naam",
#         "omschrijving",
#         "kadastraalNummer",
#         "status",
#         "detailStatus",
#         "beginBouwdatum",
#         "opleverdatum",
#         "inExploitatiedatum",
#         "uitExploitatiedatum",
#         "aantalOnzelfstandigeEenheden",
#         "aanvullendeDoelgroep",
#         "adres",
#         "beoogdUitExploitatieDatum",
#         "bestemming",
#         "bouwnummer",
#         "brutohuur",
#         "buitenruimten",
#         "clusters",
#         "doelgroep",
#         "energieprestatie",
#         "energievoorzieningen",
#         "etage",
#         "inExploitatieReden",
#         "interieur",
#         "isolatie",
#         "kamersAantal",
#         "klimaatbeheersing",
#         "kwaliteitsniveau",
#         "ligging",
#         "liggingTuin",
#         "maatschappelijkLabel",
#         "monumenten",
#         "overigeVertrekkenTotaalOppervlakte",
#         "panden",
#         "prijscomponenten",
#         "prijsconditie",
#         "publicatieLabel",
#         "rekenhuur",
#         "relaties",
#         "renovatie",
#         "sanitair",
#         "situering",
#         "streefhuur",
#         "toegankelijkheidslabel",
#         "totaalInhoud",
#         "totaleOppervlakte",
#         "uitExploitatieReden",
#         "verkoop",
#         "vertrekken",
#         "vertrekkenAantal",
#         "verwarmdeVertrekkenAantal",
#         "voorwaarden",
#         "vraagprijs",
#         "woonvertrekInhoud",
#         "woonvertrekkenTotaalOppervlakte",
#         "woonvorm",
#         "zelfstandig",
#         "zorgfaciliteitOmschrijving",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Eenheden-EenheidVoorwaarden": [
#         "maximumAantalPersonen",
#         "maximuminkomen",
#         "maximunleeftijd",
#         "minimumAantalPersonen",
#         "minimuminkomen",
#         "minimumleeftijd"
#     ],
#     "Eenheden-Eenheidadres": [
#         "allOf: Eenheden-Adres",
#         "geometrie",
#         "land",
#         "woonplaats"
#     ],
#     "Eenheden-Energieprestatie": [
#         "begindatum",
#         "einddatum",
#         "index",
#         "label"
#     ],
#     "Eenheden-Gemeente": [
#         "code",
#         "naam"
#     ],
#     "Eenheden-Geometrie": [
#         "soort"
#     ],
#     "Eenheden-Pand": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "kavelOppervlakte",
#         "liftAanwezig",
#         "renovatie"
#     ],
#     "Eenheden-Postadres": [
#         "allOf: Eenheden-Adres",
#         "antwoordnummer",
#         "postbusnummer",
#         "woonplaats"
#     ],
#     "Eenheden-Prijscomponent": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "bedrag",
#         "btw"
#     ],
#     "Eenheden-Punt": [
#         "allOf: Eenheden-Geometrie",
#         "lengtegraad",
#         "breedtegraad"
#     ],
#     "Eenheden-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adressen",
#         "contactgegevens",
#         "rollen"
#     ],
#     "Eenheden-RelatieAdres": [
#         "soort",
#         "adres"
#     ],
#     "Eenheden-Relatierol": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Eenheden-Renovatie": [
#         "omschrijving",
#         "datum"
#     ],
#     "Eenheden-Telefoonnummer": [
#         "allOf: Eenheden-Contactgegeven",
#         "abonneenummer",
#         "dagdelen",
#         "extensie",
#         "landnummer",
#         "netnummer"
#     ],
#     "Eenheden-Vertrek": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "inhoud",
#         "oppervlakte"
#     ],
#     "Eenheden-Wijk": [
#         "code",
#         "naam"
#     ],
#     "Eenheden-Woonplaats": [
#         "code",
#         "naam"
#     ],
#     "ExtraAttribuut": [
#         "naam",
#         "waarde"
#     ],
#     "Foutbericht": [
#         "code",
#         "omschrijving"
#     ],
#     "Gebeurtenissen-Adres": [
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode"
#     ],
#     "Gebeurtenissen-Cluster": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "naam"
#     ],
#     "Gebeurtenissen-Eenheidadres": [
#         "allOf: Gebeurtenissen-Adres",
#         "gemeente",
#         "geometrie",
#         "land",
#         "woonplaats"
#     ],
#     "Gebeurtenissen-Gebeurtenis": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "datum",
#         "begindatum",
#         "einddatum",
#         "adres",
#         "cluster",
#         "contextId",
#         "inschrijving",
#         "vestiging",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Gebeurtenissen-Gemeente": [
#         "code",
#         "naam"
#     ],
#     "Gebeurtenissen-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "detailSoort"
#     ],
#     "Gebeurtenissen-Serviceovereenkomst": [
#         "allOf: Gebeurtenissen-Overeenkomst",
#         "samenwerkingsverband"
#     ],
#     "Informatieobject": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "onderwerp",
#         "subonderwerp",
#         "titel",
#         "beschrijving",
#         "bestand",
#         "bestandsgrootte",
#         "bestandslocatie",
#         "bestandsnaam",
#         "externePublicatie",
#         "externePublicatietekst",
#         "formaat",
#         "gebruiksrechten",
#         "taal",
#         "versie",
#         "vertrouwelijkheid"
#     ],
#     "Kandidaten-Contactgegeven": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "status",
#         "vertrouwelijkheid",
#         "voorkeur",
#         "waarde"
#     ],
#     "Kandidaten-Inkomen": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "nettoMaandinkomen",
#         "brutoMaandinkomen",
#         "bron",
#         "brutoJaarinkomen",
#         "controledatum",
#         "nettoJaarinkomen"
#     ],
#     "Kandidaten-Kandidaat": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "status",
#         "detailStatus",
#         "aantalKinderen",
#         "aantalVolwassenen",
#         "eenheid",
#         "positie",
#         "relatie",
#         "verzamelinkomen",
#         "verzamelinkomenEU",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Kandidaten-NatuurlijkPersoon": [
#         "allOf: Kandidaten-Relatie",
#         "voornaam",
#         "achternaam",
#         "geboortedatum",
#         "geslacht",
#         "initialen",
#         "inkomens",
#         "opleiding",
#         "roepnaam",
#         "signaleringen",
#         "tussenvoegsels"
#     ],
#     "Kandidaten-Opleiding": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "instelling",
#         "niveau",
#         "plaats",
#         "studentnummer"
#     ],
#     "Kandidaten-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "contactgegevens",
#         "rollen"
#     ],
#     "Kandidaten-Relatiegroep": [
#         "allOf: Kandidaten-Relatie",
#         "naam",
#         "relaties"
#     ],
#     "Kandidaten-Relatierol": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Kandidaten-Signalering": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "status",
#         "detailStatus",
#         "begindatum",
#         "einddatum"
#     ],
#     "Overeenkomsten-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "detailSoort",
#         "status",
#         "begindatum",
#         "einddatum",
#         "eindeDetailReden",
#         "eindeReden",
#         "relaties",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Overeenkomsten-Serviceovereenkomst": [
#         "allOf: Overeenkomsten-Overeenkomst",
#         "samenwerkingsverband",
#         "aantalPersonenHuishouden"
#     ],
#     "Overeenkomstkoppelingen-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam"
#     ],
#     "Overeenkomstkoppelingen-NatuurlijkPersoon": [
#         "allOf: Overeenkomstkoppelingen-Relatie",
#         "geboortedatum",
#         "voornaam",
#         "achternaam",
#         "initialen",
#         "roepnaam",
#         "tussenvoegsels",
#         "voorletters"
#     ],
#     "Overeenkomstkoppelingen-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "detailSoort",
#         "status",
#         "begindatum",
#         "einddatum",
#         "redenOpzegging",
#         "relaties"
#     ],
#     "Overeenkomstkoppelingen-Overeenkomstkoppeling": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "status",
#         "begindatum",
#         "einddatum",
#         "overeenkomsten",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Overeenkomstkoppelingen-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adressen",
#         "huishoudledenAantal",
#         "rollen"
#     ],
#     "Overeenkomstkoppelingen-RelatieAdres": [
#         "soort",
#         "adres"
#     ],
#     "Overeenkomstkoppelingen-Relatierol": [
#         "soort",
#         "naam"
#     ],
#     "Overeenkomstkoppelingen-Serviceovereenkomst": [
#         "allOf: Overeenkomstkoppelingen-Overeenkomst",
#         "samenwerkingsverband",
#         "aantalPersonenHuishouden"
#     ],
#     "Publicaties-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "buurt",
#         "gemeente",
#         "geometrie",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam",
#         "wijk",
#         "woonplaats"
#     ],
#     "Publicaties-Buurt": [
#         "code",
#         "naam"
#     ],
#     "Publicaties-Cluster": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Publicaties-Contactgegeven": [
#         "soort",
#         "detailSoort",
#         "status",
#         "vertrouwelijkheid",
#         "voorkeur",
#         "waarde"
#     ],
#     "Publicaties-Eenheid": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "naam",
#         "omschrijving",
#         "kadastraalNummer",
#         "bouwnummer",
#         "status",
#         "detailStatus",
#         "beginBouwdatum",
#         "opleverdatum",
#         "aantalOnzelfstandigeEenheden",
#         "aanvullendeDoelgroep",
#         "adres",
#         "beoogdUitExploitatieDatum",
#         "beschermdStadsgezicht",
#         "bewoonbareVertrekkenTotaalInhoud",
#         "brutohuur",
#         "buitenruimten",
#         "clusters",
#         "doelgroep",
#         "energieprestatie",
#         "energievoorzieningen",
#         "etage",
#         "inExploitatiedatum",
#         "inExploitatieReden",
#         "interieur",
#         "isolatie",
#         "kamersAantal",
#         "klimaatbeheersing",
#         "kwaliteitsniveau",
#         "ligging",
#         "liggingTuin",
#         "maatschappelijkLabel",
#         "monumenten",
#         "overigeVertrekkenTotaalOppervlakte",
#         "panden",
#         "prijscomponenten",
#         "prijsconditie",
#         "publicatieLabel",
#         "rayon",
#         "rekenhuur",
#         "relaties",
#         "renovatie",
#         "sanitair",
#         "situering",
#         "streefhuur",
#         "toegankelijkheidslabel",
#         "totaalInhoud",
#         "totaleOppervlakte",
#         "uitExploitatiedatum",
#         "uitExploitatieReden",
#         "verkoop",
#         "vertrekken",
#         "vertrekkenAantal",
#         "verwarmdeVertrekkenAantal",
#         "voorwaarden",
#         "vraagprijs",
#         "woonvertrekInhoud",
#         "woonvertrekkenTotaalOppervlakte",
#         "woonvorm",
#         "zelfstandig",
#         "zorgfaciliteitOmschrijving"
#     ],
#     "Publicaties-EenheidVoorwaarden": [
#         "maximumAantalPersonen",
#         "maximuminkomen",
#         "maximunleeftijd",
#         "minimumAantalPersonen",
#         "minimuminkomen",
#         "minimumleeftijd"
#     ],
#     "Publicaties-Eenheidadres": [
#         "allOf: Publicaties-Adres",
#         "geometrie",
#         "land",
#         "woonplaats"
#     ],
#     "Publicaties-Energieprestatie": [
#         "begindatum",
#         "einddatum",
#         "index",
#         "label"
#     ],
#     "Publicaties-Gemeente": [
#         "code",
#         "naam"
#     ],
#     "Publicaties-Geometrie": [
#         "soort"
#     ],
#     "Publicaties-HuidigeGebruiker": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "Vertrekdatum",
#         "relatie"
#     ],
#     "Publicaties-NatuurlijkPersoon": [
#         "allOf: Publicaties-Relatie",
#         "achternaam",
#         "initialen",
#         "tussenvoegsels",
#         "voornaam"
#     ],
#     "Publicaties-Pand": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "renovatie",
#         "kavelOppervlakte",
#         "liftAanwezig"
#     ],
#     "Publicaties-Prijscomponent": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "bedrag",
#         "btw"
#     ],
#     "Publicaties-Publicatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "status",
#         "begindatum",
#         "einddatum",
#         "opleverdatum",
#         "aantalEenheden",
#         "aantalEenhedenBeschikbaar",
#         "advertentieUrl",
#         "cluster",
#         "contractvorm",
#         "detailModel",
#         "detailStatus",
#         "eenheden",
#         "huidigeGebruiker",
#         "intakevorm",
#         "label",
#         "looptijd",
#         "model",
#         "modules",
#         "oplevering",
#         "reactieUrl",
#         "taal",
#         "wachttijd",
#         "wachttijdMetVoorrang",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Publicaties-Punt": [
#         "allOf: Publicaties-Geometrie",
#         "lengtegraad",
#         "breedtegraad"
#     ],
#     "Publicaties-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "contactgegevens",
#         "rollen"
#     ],
#     "Publicaties-Relatierol": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Publicaties-Renovatie": [
#         "omschrijving",
#         "datum"
#     ],
#     "Publicaties-Telefoonnummer": [
#         "allOf: Publicaties-Contactgegeven",
#         "abonneenummer",
#         "dagdelen",
#         "extensie",
#         "landnummer",
#         "netnummer"
#     ],
#     "Publicaties-Vertrek": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "inhoud",
#         "oppervlakte"
#     ],
#     "Publicaties-Wijk": [
#         "code",
#         "naam"
#     ],
#     "Publicaties-Woonplaats": [
#         "code",
#         "naam"
#     ],
#     "Puntenberekeningen-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam"
#     ],
#     "Puntenberekeningen-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "detailSoort"
#     ],
#     "Puntenberekeningen-Puntenberekening": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "datum",
#         "begindatum",
#         "einddatum",
#         "inschrijving",
#         "puntenmutaties",
#         "situatiepunten",
#         "startpunten",
#         "zoekpunten",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Puntenberekeningen-Puntenmutatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "omschrijving",
#         "adressen"
#     ],
#     "Puntenberekeningen-Serviceovereenkomst": [
#         "allOf: Puntenberekeningen-Overeenkomst",
#         "samenwerkingsverband"
#     ],
#     "Referentiedata": [
#         "code",
#         "naam"
#     ],
#     "Relaties-Account": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "gebruikersnaam",
#         "status"
#     ],
#     "Relaties-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam"
#     ],
#     "Relaties-BuitenlandsAdres": [
#         "allOf: Relaties-Adres",
#         "adresregel1",
#         "adresregel2",
#         "land",
#         "postbusnummer",
#         "provincie",
#         "woonplaats"
#     ],
#     "Relaties-Contactgegeven": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "status",
#         "vertrouwelijkheid",
#         "voorkeur",
#         "waarde"
#     ],
#     "Relaties-Eenheidadres": [
#         "allOf: Relaties-Adres",
#         "land",
#         "provincie",
#         "woonplaats"
#     ],
#     "Relaties-Inkomen": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "controledatum",
#         "bron",
#         "brutoJaarinkomen",
#         "brutoMaandinkomen",
#         "inkomensverklaringsoort",
#         "nettoJaarinkomen",
#         "nettoMaandinkomen",
#         "relaties"
#     ],
#     "Relaties-NatuurlijkPersoon": [
#         "allOf: Relaties-Relatie",
#         "voornaam",
#         "initialen",
#         "aanhef",
#         "account",
#         "achternaam",
#         "bsn",
#         "burgerlijkeStaat",
#         "geboortedatum",
#         "geslacht",
#         "inkomens",
#         "nationaliteit",
#         "opleiding",
#         "overlijdensdatum",
#         "roepnaam",
#         "tussenvoegsels",
#         "voorkeurstaal",
#         "voorletters"
#     ],
#     "Relaties-Opleiding": [
#         "instelling",
#         "plaats",
#         "studentnummer"
#     ],
#     "Relaties-Postadres": [
#         "allOf: Relaties-Adres",
#         "antwoordnummer",
#         "postbusnummer",
#         "woonplaats"
#     ],
#     "Relaties-Rechtspersoon": [
#         "allOf: Relaties-Relatie",
#         "naam",
#         "btwNummer",
#         "globaalLocatienummer",
#         "kvkNummer",
#         "organisatievorm",
#         "relaties"
#     ],
#     "Relaties-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adressen",
#         "contactgegevens",
#         "groepen",
#         "rollen",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Relaties-RelatieAdres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "begindatum",
#         "einddatum",
#         "adres"
#     ],
#     "Relaties-Relatiegroep": [
#         "allOf: Relaties-Relatie",
#         "naam",
#         "relaties"
#     ],
#     "Relaties-Relatierol": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam",
#         "omschrijving",
#         "begindatum",
#         "einddatum",
#         "contactgegevens",
#         "relatieAdressen",
#         "rolRelatie"
#     ],
#     "Relaties-Woonplaats": [
#         "code",
#         "naam"
#     ],
#     "Sancties-Adres": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "adres",
#         "huisletter",
#         "huisnummer",
#         "huisnummerToevoeging",
#         "postcode",
#         "straatnaam"
#     ],
#     "Sancties-Gebeurtenis": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "datum",
#         "begindatum",
#         "einddatum",
#         "adres",
#         "contextId",
#         "vestiging"
#     ],
#     "Sancties-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "detailSoort",
#         "begindatum",
#         "einddatum"
#     ],
#     "Sancties-Sanctie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "soort",
#         "omschrijving",
#         "status",
#         "begindatum",
#         "einddatum",
#         "gebeurtenissen",
#         "inschrijving",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Sancties-Serviceovereenkomst": [
#         "allOf: Sancties-Overeenkomst",
#         "bedrag",
#         "samenwerkingsverband"
#     ],
#     "Toewijzingen-Inkomen": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "nettoMaandinkomen",
#         "brutoMaandinkomen",
#         "bron",
#         "brutoJaarinkomen",
#         "controledatum",
#         "nettoJaarinkomen"
#     ],
#     "Toewijzingen-Kandidaat": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "status",
#         "detailStatus",
#         "aantalKinderen",
#         "aantalVolwassenen",
#         "positie",
#         "relatie",
#         "verzamelinkomen",
#         "verzamelinkomenEU"
#     ],
#     "Toewijzingen-NatuurlijkPersoon": [
#         "allOf: Toewijzingen-Relatie",
#         "voornaam",
#         "achternaam",
#         "geboortedatum",
#         "geslacht",
#         "initialen",
#         "inkomens",
#         "opleiding",
#         "roepnaam",
#         "signaleringen",
#         "tussenvoegsels"
#     ],
#     "Toewijzingen-Opleiding": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "begindatum",
#         "einddatum",
#         "instelling",
#         "niveau",
#         "plaats",
#         "studentnummer"
#     ],
#     "Toewijzingen-Overeenkomst": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "begindatum",
#         "einddatum",
#         "prijscomponenten"
#     ],
#     "Toewijzingen-Relatie": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "rollen"
#     ],
#     "Toewijzingen-Relatierol": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "naam"
#     ],
#     "Toewijzingen-Signalering": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "status",
#         "detailStatus",
#         "begindatum",
#         "einddatum"
#     ],
#     "Toewijzingen-Toewijzing": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "datum",
#         "aanvullendeDoelgroep",
#         "doelgroep",
#         "eenheid",
#         "huishoudgrootte",
#         "kandidaat",
#         "overeenkomst",
#         "Rekenhuur",
#         "Rekeninkomen",
#         "voorrangsregelingen",
#         "extra-attributen",
#         "informatieobjecten"
#     ],
#     "Toewijzingen-Voorrangsregeling": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "soort",
#         "detailSoort",
#         "naam",
#         "begindatum",
#         "einddatum",
#         "profiel"
#     ],
#     "Toewijzingen-VoorrangsregelingProfiel": [
#         "id",
#         "idExtern",
#         "idGegevensbeheerder",
#         "code",
#         "eenheidSoorten",
#         "huidigeOppervlakte",
#         "huidigeVerdieping",
#         "huurInkomenTabel",
#         "maximumBrutoHuur",
#         "maximumKamers",
#         "minimumBrutoHuur",
#         "minimumKamers",
#         "minimumOppervlakte",
#         "toegankelijkheidslabels"
#     ]
# }

# %%
#save as a .json file
import json
with open(API_name+'_API_objecten.json', 'w', encoding='utf-8') as f:
    json.dump(json_object, f, ensure_ascii=False, indent=4)

# %%
import glob
my_jsons = glob.glob('*.json')
my_jsons
# Out:
# ['VERA-Beheer_Financiele_Gegevens_API_objecten.json',
#  'VERA-Beheer_Overeenkomstgegevens_API_objecten.json',
#  'VERA-Beheer_Relatiegegevens_API_objecten.json',
#  'VERA-Beheer_Vastgoedegevens_API_objecten.json',
#  'VERA-Casemanagement_API_objecten.json',
#  'VERA-Incasso_API_objecten.json',
#  'VERA-Kwaliteitsmeting_API_objecten.json',
#  'VERA-Onderhoud_API_objecten.json',
#  'VERA-Verhuren_Eenheden_API_objecten.json',
#  'VERA-Woonruimteverdeling_API_objecten.json']
