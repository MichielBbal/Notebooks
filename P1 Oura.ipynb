# %% [markdown]
# # Jupyter Notebook for Oura Ring

# %% [markdown]
# Contents:
#
# 1. Installation and tokens
# 2. Your first API call

# %% [markdown]
# ## 1. Installation and tokens

# %%
# !pip install oura

# %%
# copy the PAT from the oura ring portal. 
PAT = 'MYDJP3SZNVLJKXGTBXJO3SRSV4UPNONY'

# %%
from oura import OuraClient
client = OuraClient(personal_access_token=PAT)

# or just these for make calls until token expires
oura = OuraClient('BZYMU6OTSH6FU3MF','23B72KJR3HLG5JLDM53BYNE6GG5DCZ4J', PAT)

# %% [markdown]
# ## First API call

# %%
# Sleep Summary
#oura.user_info()
oura.sleep_summary(start='2020-11-05', end='2020-11-24')
#oura.activity_summary(start='2018-12-25')
# Out:
# {'sleep': [{'awake': 2940,
#    'bedtime_end': '2020-11-06T06:46:29+01:00',
#    'bedtime_end_delta': 24389,
#    'bedtime_start': '2020-11-05T23:49:29+01:00',
#    'bedtime_start_delta': -631,
#    'breath_average': 15.25,
#    'deep': 5190,
#    'duration': 25020,
#    'efficiency': 88,
#    'hr_5min': [62,
#     61,
#     59,
#     59,
#     59,
#     58,
#     59,
#     60,
#     59,
#     59,
#     59,
#     58,
#     58,
#     58,
#     55,
#     55,
#     57,
#     55,
#     56,
#     55,
#     54,
#     53,
#     54,
#     54,
#     53,
#     54,
#     54,
#     54,
#     54,
#     54,
#     53,
#     54,
#     54,
#     57,
#     54,
#     52,
#     52,
#     52,
#     52,
#     51,
#     52,
#     52,
#     53,
#     52,
#     58,
#     54,
#     52,
#     52,
#     53,
#     52,
#     52,
#     56,
#     53,
#     53,
#     53,
#     53,
#     54,
#     52,
#     52,
#     54,
#     53,
#     54,
#     54,
#     54,
#     55,
#     55,
#     54,
#     54,
#     55,
# ...

# %% [markdown]
# ## Oura Pandas API Calls
#
# Check is this still valid or not?
