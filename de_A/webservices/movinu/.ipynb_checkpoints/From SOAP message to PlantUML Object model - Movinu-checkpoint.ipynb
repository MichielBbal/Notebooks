# %% [markdown]
# # From SOAP message to PlantUML Object model
#
# ### Description
# For movin'u two .wsdl files were found in the ESB code base:
#
# With this notebook, these files are reverse engineered and turned into a datamodel

# %% [markdown]
# ### 1. By using the xml part of the soap message via SOAP UI
#
# Manual steps:
# - Load the wsdl into SOAPUI
# - copy request / response message into an empty xml-file.
# N.B. this script uses full soap message

# %%
import glob
my_xmls = glob.glob('*.xml')
my_xmls
# Out:
# ['UpdateWosIntake.xml', 'UpdateWosWorkAssignment.xml', 'wip.xml']

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\webservices\\movinu'

# %%
# %pycat 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\webservices\\movinu\\wosintakeplanned.xml'

# %% [markdown]
# ### Getting the request data

# %%
#select the xml files manually
request_xml='wip.xml'
#response_xml= 'objectAfmeldenResponse.xml'
method_name = 'WosIntakePlanned'

# %%
#create a new file with the Postman body
import xml.etree.ElementTree as ET #import the library 
tree = ET.parse(request_xml) #parse the XML
print(request_xml)
ET.dump(tree) #print the xml file
# Out:
# wip.xml
# <ns0:Envelope xmlns:ns0="http://www.w3.org/2003/05/soap-envelope" xmlns:ns1="http://tempuri.org/" xmlns:ns2="http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax">
#    <ns0:Header />
#    <ns0:Body>
#       <ns1:WosIntakePlanned>
#
#          <ns1:wosIntakePlanned>
#
#             <ns2:WWS>
#
#                <ns2:atticWithFixedStairs>?</ns2:atticWithFixedStairs>
#
#                <ns2:carportPresent>?</ns2:carportPresent>
#
#                <ns2:extraQualityBathroom>?</ns2:extraQualityBathroom>
#
#                <ns2:extraQualityKitchen>?</ns2:extraQualityKitchen>
#
#                <ns2:extraQualityToilet>?</ns2:extraQualityToilet>
#
#                <ns2:heatingUtility>?</ns2:heatingUtility>
#
#                <ns2:lengthKitchenWorktop>?</ns2:lengthKitchenWorktop>
#
#                <ns2:numberOfAdditionalHeatedAreas>?</ns2:numberOfAdditionalHeatedAreas>
#
#                <ns2:numberOfAdditionalHeatedAreasWW>?</ns2:numberOfAdditionalHeatedAreasWW>
#
#                <ns2:numberOfHeatedRooms>?</ns2:numberOfHeatedRooms>
#
#                <ns2:numberOfHeatedRoomsWW>?</ns2:numberOfHeatedRoomsWW>
#
#                <ns2:numberOfSinks>?</ns2:numberOfSinks>
#
#                <ns2:numberOfToilets>?</ns2:numberOfToilets>
#
#                <ns2:privateOutsideArea>?</ns2:privateOutsideArea>
#
#                <ns2:provisionBathroom>?</ns2:provisionBathroom>
#
#                <ns2:provisionBathroom2>?</ns2:provisionBathroom2>
#
#                <ns2:sizeAttic>?</ns2:sizeAttic>
#
#                <ns2:sizeAtticWithFixedStairs>?</ns2:sizeAtticWithFixedStairs>
#
#                <ns2:sizeAtticwithoutfixedstairs>?</ns2:sizeAtticwithoutfixedstairs>
#
#                <ns2:sizeBathroom1>?</ns2:sizeBathroom1>
#
#                <ns2:sizeBathroom2>?</ns2:sizeBathroom2>
#
#                <ns2:sizeBedroom1>?</ns2:sizeBedroom1>
#
#                <ns2:sizeBedroom2>?</ns2:sizeBedroom2>
#
#                <ns2:sizeBedroom3>?</ns2:sizeBedroom3>
#
#                <ns2:sizeBedroom4>?</ns2:sizeBedroom4>
#
#                <ns2:sizeBedroom5>?</ns2:sizeBedroom5>
#
#                <ns2:sizeBedroom6>?</ns2:sizeBedroom6>
#
#                <ns2:sizeBedroom7>?</ns2:sizeBedroom7>
#
#                <ns2:sizeBedroomAttic>?</ns2:sizeBedroomAttic>
#
#                <ns2:sizeBedroomAttic2>?</ns2:sizeBedroomAttic2>
#
#                <ns2:sizeCellar>?</ns2:sizeCellar>
#
#                <ns2:sizeGarage>?</ns2:sizeGarage>
#
#                <ns2:sizeGreenery>?</ns2:sizeGreenery>
#
#                <ns2:sizeInsideStorage1>?</ns2:sizeInsideStorage1>
#
#                <ns2:sizeInsideStorage2>?</ns2:sizeInsideStorage2>
#
#                <ns2:sizeInsideStorage3>?</ns2:sizeInsideStorage3>
#
#                <ns2:sizeKitchen>?</ns2:sizeKitchen>
#
#                <ns2:sizeLaundryroom>?</ns2:sizeLaundryroom>
#
#                <ns2:sizeLivingRoom1>?</ns2:sizeLivingRoom1>
#
#                <ns2:sizeLivingRoom2>?</ns2:sizeLivingRoom2>
#
#                <ns2:sizeOutsideStorage1>?</ns2:sizeOutsideStorage1>
#
#                <ns2:sizeOutsideStorage2>?</ns2:sizeOutsideStorage2>
#
#                <ns2:sizeOutsideStorage3>?</ns2:sizeOutsideStorage3>
#
#                <ns2:sizeUtilityroom>?</ns2:sizeUtilityroom>
#
#                <ns2:toiletInBathroom>?</ns2:toiletInBathroom>
#             </ns2:WWS>
#
#             <ns2:changeType>?</ns2:changeType>
#
#             <ns2:contract>
#
#                <ns2:contractId>?</ns2:contractId>
#
#                <ns2:contractee>
#
#                   <ns2:contractee>
#
#                      <ns2:contracteeId>?</ns2:contracteeId>
#
#                      <ns2:contracteeType>?</ns2:contracteeType>
#
#                      <ns2:endDate>?</ns2:endDate>
#
#                      <ns2:person>
#
#                         <ns2:correspondenceAddress>
#
#                            <ns2:correspondenceAddress>
#
#                               <ns2:addressSecret>?</ns2:addressSecret>
#
#                               <ns2:city>?</ns2:city>
#
#                               <ns2:corrAddressId>?</ns2:corrAddressId>
#
#                               <ns2:country>?</ns2:country>
#
#                               <ns2:endDate>?</ns2:endDate>
#
#                               <ns2:houseNumber>?</ns2:houseNumber>
#
#                               <ns2:houseNumberSuffix>?</ns2:houseNumberSuffix>
#
#                               <ns2:postalCode>?</ns2:postalCode>
#
#                               <ns2:startDate>?</ns2:startDate>
#
#                               <ns2:street>?</ns2:street>
#                            </ns2:correspondenceAddress>
#                         </ns2:correspondenceAddress>
#
#                         <ns2:dateOfBirth>?</ns2:dateOfBirth>
#
#                         <ns2:deceased>?</ns2:deceased>
#
#                         <ns2:deceasedDate>?</ns2:deceasedDate>
#
#                         <ns2:email1>?</ns2:email1>
#
#                         <ns2:email2>?</ns2:email2>
#
#                         <ns2:gender>?</ns2:gender>
#
#                         <ns2:initials>?</ns2:initials>
#
#                         <ns2:media>
#
#                            <ns2:media>
#
#                               <ns2:attachmentType>?</ns2:attachmentType>
#
#                               <ns2:fileID>?</ns2:fileID>
#
#                               <ns2:hash>?</ns2:hash>
#
#                               <ns2:mimetype>?</ns2:mimetype>
#
#                               <ns2:pixelHeight>?</ns2:pixelHeight>
#
#                               <ns2:pixelWidth>?</ns2:pixelWidth>
#
#                               <ns2:size>?</ns2:size>
#
#                               <ns2:url>?</ns2:url>
#                            </ns2:media>
#                         </ns2:media>
#
#                         <ns2:paymentBalance>?</ns2:paymentBalance>
#
#                         <ns2:personId>?</ns2:personId>
#
#                         <ns2:phone1>?</ns2:phone1>
#
#                         <ns2:phone1Secret>?</ns2:phone1Secret>
#
#                         <ns2:phone2>?</ns2:phone2>
#
#                         <ns2:phone2Secret>?</ns2:phone2Secret>
#
#                         <ns2:phone3>?</ns2:phone3>
#
#                         <ns2:phone3Secret>?</ns2:phone3Secret>
#
#                         <ns2:signal>
#
#                            <ns2:signal>
#
#                               <ns2:description>?</ns2:description>
#
#                               <ns2:endDate>?</ns2:endDate>
#
#                               <ns2:kindOfSignal>?</ns2:kindOfSignal>
#
#                               <ns2:signalId>?</ns2:signalId>
#
#                               <ns2:startDate>?</ns2:startDate>
#                            </ns2:signal>
#                         </ns2:signal>
#
#                         <ns2:socialSecurityNr>?</ns2:socialSecurityNr>
#
#                         <ns2:surname>?</ns2:surname>
#
#                         <ns2:surnamePrefix>?</ns2:surnamePrefix>
#                      </ns2:person>
#                   </ns2:contractee>
#                </ns2:contractee>
#
#                <ns2:desctiption>?</ns2:desctiption>
#
#                <ns2:endDate>?</ns2:endDate>
#
#                <ns2:startDate>?</ns2:startDate>
#             </ns2:contract>
#
#             <ns2:intakePlanningList>
#
#                <ns2:IntakePlanning>
#
#                   <ns2:InspectorEmail>?</ns2:InspectorEmail>
#
#                   <ns2:InspectorName>?</ns2:InspectorName>
#
#                   <ns2:IntakeDate>?</ns2:IntakeDate>
#
#                   <ns2:IntakeId>?</ns2:IntakeId>
#
#                   <ns2:IntakeType>?</ns2:IntakeType>
#                </ns2:IntakePlanning>
#             </ns2:intakePlanningList>
#
#             <ns2:newContract>
#
#                <ns2:desctiption>?</ns2:desctiption>
#
#                <ns2:endDate>?</ns2:endDate>
#
#                <ns2:newContractId>?</ns2:newContractId>
#
#                <ns2:newContractee>
#
#                   <ns2:newContractee>
#
#                      <ns2:contracteeType>?</ns2:contracteeType>
#
#                      <ns2:endDate>?</ns2:endDate>
#
#                      <ns2:newContracteeId>?</ns2:newContracteeId>
#
#                      <ns2:person>
#
#                         <ns2:correspondenceAddress>
#
#                            <ns2:correspondenceAddress>
#
#                               <ns2:addressSecret>?</ns2:addressSecret>
#
#                               <ns2:city>?</ns2:city>
#
#                               <ns2:corrAddressId>?</ns2:corrAddressId>
#
#                               <ns2:country>?</ns2:country>
#
#                               <ns2:endDate>?</ns2:endDate>
#
#                               <ns2:houseNumber>?</ns2:houseNumber>
#
#                               <ns2:houseNumberSuffix>?</ns2:houseNumberSuffix>
#
#                               <ns2:postalCode>?</ns2:postalCode>
#
#                               <ns2:startDate>?</ns2:startDate>
#
#                               <ns2:street>?</ns2:street>
#                            </ns2:correspondenceAddress>
#                         </ns2:correspondenceAddress>
#
#                         <ns2:dateOfBirth>?</ns2:dateOfBirth>
#
#                         <ns2:deceased>?</ns2:deceased>
#
#                         <ns2:deceasedDate>?</ns2:deceasedDate>
#
#                         <ns2:email1>?</ns2:email1>
#
#                         <ns2:email2>?</ns2:email2>
#
#                         <ns2:gender>?</ns2:gender>
#
#                         <ns2:initials>?</ns2:initials>
#
#                         <ns2:media>
#
#                            <ns2:media>
#
#                               <ns2:attachmentType>?</ns2:attachmentType>
#
#                               <ns2:fileID>?</ns2:fileID>
#
#                               <ns2:hash>?</ns2:hash>
#
#                               <ns2:mimetype>?</ns2:mimetype>
#
#                               <ns2:pixelHeight>?</ns2:pixelHeight>
#
#                               <ns2:pixelWidth>?</ns2:pixelWidth>
#
#                               <ns2:size>?</ns2:size>
#
#                               <ns2:url>?</ns2:url>
#                            </ns2:media>
#                         </ns2:media>
#
#                         <ns2:paymentBalance>?</ns2:paymentBalance>
#
#                         <ns2:personId>?</ns2:personId>
#
#                         <ns2:phone1>?</ns2:phone1>
#
#                         <ns2:phone1Secret>?</ns2:phone1Secret>
#
#                         <ns2:phone2>?</ns2:phone2>
#
#                         <ns2:phone2Secret>?</ns2:phone2Secret>
#
#                         <ns2:phone3>?</ns2:phone3>
#
#                         <ns2:phone3Secret>?</ns2:phone3Secret>
#
#                         <ns2:signal>
#
#                            <ns2:signal>
#
#                               <ns2:description>?</ns2:description>
#
#                               <ns2:endDate>?</ns2:endDate>
#
#                               <ns2:kindOfSignal>?</ns2:kindOfSignal>
#
#                               <ns2:signalId>?</ns2:signalId>
#
#                               <ns2:startDate>?</ns2:startDate>
#                            </ns2:signal>
#                         </ns2:signal>
#
#                         <ns2:socialSecurityNr>?</ns2:socialSecurityNr>
#
#                         <ns2:surname>?</ns2:surname>
#
#                         <ns2:surnamePrefix>?</ns2:surnamePrefix>
#                      </ns2:person>
#                   </ns2:newContractee>
#                </ns2:newContractee>
#
#                <ns2:startDate>?</ns2:startDate>
#             </ns2:newContract>
#
#             <ns2:object>
#
#                <ns2:category>?</ns2:category>
#
#                <ns2:city>?</ns2:city>
#
#                <ns2:company>?</ns2:company>
#
#                <ns2:complexName>?</ns2:complexName>
#
#                <ns2:constructionYear>?</ns2:constructionYear>
#
#                <ns2:contractor>?</ns2:contractor>
#
#                <ns2:country>?</ns2:country>
#
#                <ns2:description>?</ns2:description>
#
#                <ns2:endOfLife>?</ns2:endOfLife>
#
#                <ns2:energyLabel>?</ns2:energyLabel>
#
#                <ns2:floor>?</ns2:floor>
#
#                <ns2:houseNumber>?</ns2:houseNumber>
#
#                <ns2:houseNumberSuffix>?</ns2:houseNumberSuffix>
#
#                <ns2:intendedUse>?</ns2:intendedUse>
#
#                <ns2:intendedUseDateFrom>?</ns2:intendedUseDateFrom>
#
#                <ns2:media>
#
#                   <ns2:media>
#
#                      <ns2:attachmentType>?</ns2:attachmentType>
#
#                      <ns2:fileID>?</ns2:fileID>
#
#                      <ns2:hash>?</ns2:hash>
#
#                      <ns2:mimetype>?</ns2:mimetype>
#
#                      <ns2:pixelHeight>?</ns2:pixelHeight>
#
#                      <ns2:pixelWidth>?</ns2:pixelWidth>
#
#                      <ns2:size>?</ns2:size>
#
#                      <ns2:url>?</ns2:url>
#                   </ns2:media>
#                </ns2:media>
#
#                <ns2:memo>?</ns2:memo>
#
#                <ns2:nickname>?</ns2:nickname>
#
#                <ns2:objectId>?</ns2:objectId>
#
#                <ns2:postalCode>?</ns2:postalCode>
#
#                <ns2:qualityLevel>?</ns2:qualityLevel>
#
#                <ns2:rentPolicy>?</ns2:rentPolicy>
#
#                <ns2:residenceType>?</ns2:residenceType>
#
#                <ns2:street>?</ns2:street>
#
#                <ns2:subComplexName>?</ns2:subComplexName>
#
#                <ns2:vheType>?</ns2:vheType>
#             </ns2:object>
#
#             <ns2:rentTermination>
#
#                <ns2:mutationType>?</ns2:mutationType>
#
#                <ns2:rentTerminationId>?</ns2:rentTerminationId>
#
#                <ns2:terminationDate>?</ns2:terminationDate>
#             </ns2:rentTermination>
#          </ns1:wosIntakePlanned>
#       </ns1:WosIntakePlanned>
#    </ns0:Body>
# </ns0:Envelope>

# %%
request_list =[]
for elem in tree.iter():
    request_list.append(elem.tag)
request_list
# Out:
# ['{http://www.w3.org/2003/05/soap-envelope}Envelope',
#  '{http://www.w3.org/2003/05/soap-envelope}Header',
#  '{http://www.w3.org/2003/05/soap-envelope}Body',
#  '{http://tempuri.org/}WosIntakePlanned',
#  '{http://tempuri.org/}wosIntakePlanned',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}WWS',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}atticWithFixedStairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}carportPresent',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityKitchen',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityToilet',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}heatingUtility',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}lengthKitchenWorktop',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfAdditionalHeatedAreas',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfAdditionalHeatedAreasWW',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfHeatedRooms',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfHeatedRoomsWW',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfSinks',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfToilets',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}privateOutsideArea',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}provisionBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}provisionBathroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAttic',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAtticWithFixedStairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAtticwithoutfixedstairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBathroom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBathroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom4',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom5',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom6',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom7',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroomAttic',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroomAttic2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeCellar',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeGarage',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeGreenery',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeKitchen',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLaundryroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLivingRoom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLivingRoom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeUtilityroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}toiletInBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}changeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contract',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}person',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}addressSecret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}corrAddressId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}dateOfBirth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceased',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceasedDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}gender',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}initials',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}paymentBalance',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}personId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}kindOfSignal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signalId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}socialSecurityNr',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surnamePrefix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}desctiption',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intakePlanningList',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakePlanning',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}InspectorEmail',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}InspectorName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContract',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}desctiption',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContracteeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}person',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}addressSecret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}corrAddressId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}dateOfBirth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceased',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceasedDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}gender',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}initials',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}paymentBalance',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}personId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}kindOfSignal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signalId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}socialSecurityNr',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surnamePrefix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}object',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}category',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}company',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}complexName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}constructionYear',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractor',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endOfLife',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}energyLabel',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}floor',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intendedUse',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intendedUseDateFrom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}memo',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}nickname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}objectId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}qualityLevel',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentPolicy',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}residenceType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}subComplexName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}vheType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentTermination',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mutationType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentTerminationId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}terminationDate']

# %%
#remove th soap headers
del request_list[0:4]
request_list
# Out:
# ['{http://tempuri.org/}wosIntakePlanned',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}WWS',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}atticWithFixedStairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}carportPresent',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityKitchen',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}extraQualityToilet',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}heatingUtility',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}lengthKitchenWorktop',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfAdditionalHeatedAreas',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfAdditionalHeatedAreasWW',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfHeatedRooms',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfHeatedRoomsWW',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfSinks',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}numberOfToilets',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}privateOutsideArea',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}provisionBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}provisionBathroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAttic',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAtticWithFixedStairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeAtticwithoutfixedstairs',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBathroom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBathroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom4',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom5',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom6',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroom7',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroomAttic',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeBedroomAttic2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeCellar',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeGarage',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeGreenery',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeInsideStorage3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeKitchen',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLaundryroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLivingRoom1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeLivingRoom2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeOutsideStorage3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}sizeUtilityroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}toiletInBathroom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}changeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contract',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}person',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}addressSecret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}corrAddressId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}dateOfBirth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceased',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceasedDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}gender',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}initials',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}paymentBalance',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}personId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}kindOfSignal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signalId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}socialSecurityNr',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surnamePrefix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}desctiption',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intakePlanningList',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakePlanning',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}InspectorEmail',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}InspectorName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}IntakeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContract',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}desctiption',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContractee',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contracteeType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}newContracteeId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}person',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}correspondenceAddress',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}addressSecret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}corrAddressId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}dateOfBirth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceased',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}deceasedDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}email2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}gender',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}initials',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}paymentBalance',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}personId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone1Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone2Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}phone3Secret',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}kindOfSignal',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}signalId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}socialSecurityNr',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}surnamePrefix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}startDate',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}object',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}category',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}city',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}company',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}complexName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}constructionYear',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}contractor',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}country',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}description',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}endOfLife',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}energyLabel',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}floor',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumber',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}houseNumberSuffix',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intendedUse',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}intendedUseDateFrom',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}media',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}attachmentType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}fileID',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}hash',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mimetype',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelHeight',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}pixelWidth',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}size',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}url',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}memo',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}nickname',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}objectId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}postalCode',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}qualityLevel',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentPolicy',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}residenceType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}street',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}subComplexName',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}vheType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentTermination',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}mutationType',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}rentTerminationId',
#  '{http://schemas.datacontract.org/2004/07/MovinU.Data.Erp.Ax}terminationDate']

# %%
attribute_list =[]
for i in range(len(request_list)):
    my_s = request_list[i]
    my_l = my_s.split('}')
    my_s2= my_l[1]
    attribute_list.append(my_s2)
    #print(my_s2)
attribute_list
# Out:
# ['wosIntakePlanned',
#  'WWS',
#  'atticWithFixedStairs',
#  'carportPresent',
#  'extraQualityBathroom',
#  'extraQualityKitchen',
#  'extraQualityToilet',
#  'heatingUtility',
#  'lengthKitchenWorktop',
#  'numberOfAdditionalHeatedAreas',
#  'numberOfAdditionalHeatedAreasWW',
#  'numberOfHeatedRooms',
#  'numberOfHeatedRoomsWW',
#  'numberOfSinks',
#  'numberOfToilets',
#  'privateOutsideArea',
#  'provisionBathroom',
#  'provisionBathroom2',
#  'sizeAttic',
#  'sizeAtticWithFixedStairs',
#  'sizeAtticwithoutfixedstairs',
#  'sizeBathroom1',
#  'sizeBathroom2',
#  'sizeBedroom1',
#  'sizeBedroom2',
#  'sizeBedroom3',
#  'sizeBedroom4',
#  'sizeBedroom5',
#  'sizeBedroom6',
#  'sizeBedroom7',
#  'sizeBedroomAttic',
#  'sizeBedroomAttic2',
#  'sizeCellar',
#  'sizeGarage',
#  'sizeGreenery',
#  'sizeInsideStorage1',
#  'sizeInsideStorage2',
#  'sizeInsideStorage3',
#  'sizeKitchen',
#  'sizeLaundryroom',
#  'sizeLivingRoom1',
#  'sizeLivingRoom2',
#  'sizeOutsideStorage1',
#  'sizeOutsideStorage2',
#  'sizeOutsideStorage3',
#  'sizeUtilityroom',
#  'toiletInBathroom',
#  'changeType',
#  'contract',
#  'contractId',
#  'contractee',
#  'contractee',
#  'contracteeId',
#  'contracteeType',
#  'endDate',
#  'person',
#  'correspondenceAddress',
#  'correspondenceAddress',
#  'addressSecret',
#  'city',
#  'corrAddressId',
#  'country',
#  'endDate',
#  'houseNumber',
#  'houseNumberSuffix',
#  'postalCode',
#  'startDate',
#  'street',
#  'dateOfBirth',
#  'deceased',
#  'deceasedDate',
#  'email1',
#  'email2',
#  'gender',
#  'initials',
#  'media',
#  'media',
#  'attachmentType',
#  'fileID',
#  'hash',
#  'mimetype',
#  'pixelHeight',
#  'pixelWidth',
#  'size',
#  'url',
#  'paymentBalance',
#  'personId',
#  'phone1',
#  'phone1Secret',
#  'phone2',
#  'phone2Secret',
#  'phone3',
#  'phone3Secret',
#  'signal',
#  'signal',
#  'description',
#  'endDate',
#  'kindOfSignal',
#  'signalId',
#  'startDate',
#  'socialSecurityNr',
#  'surname',
#  'surnamePrefix',
#  'desctiption',
#  'endDate',
#  'startDate',
#  'intakePlanningList',
#  'IntakePlanning',
#  'InspectorEmail',
#  'InspectorName',
#  'IntakeDate',
#  'IntakeId',
#  'IntakeType',
#  'newContract',
#  'desctiption',
#  'endDate',
#  'newContractId',
#  'newContractee',
#  'newContractee',
#  'contracteeType',
#  'endDate',
#  'newContracteeId',
#  'person',
#  'correspondenceAddress',
#  'correspondenceAddress',
#  'addressSecret',
#  'city',
#  'corrAddressId',
#  'country',
#  'endDate',
#  'houseNumber',
#  'houseNumberSuffix',
#  'postalCode',
#  'startDate',
#  'street',
#  'dateOfBirth',
#  'deceased',
#  'deceasedDate',
#  'email1',
#  'email2',
#  'gender',
#  'initials',
#  'media',
#  'media',
#  'attachmentType',
#  'fileID',
#  'hash',
#  'mimetype',
#  'pixelHeight',
#  'pixelWidth',
#  'size',
#  'url',
#  'paymentBalance',
#  'personId',
#  'phone1',
#  'phone1Secret',
#  'phone2',
#  'phone2Secret',
#  'phone3',
#  'phone3Secret',
#  'signal',
#  'signal',
#  'description',
#  'endDate',
#  'kindOfSignal',
#  'signalId',
#  'startDate',
#  'socialSecurityNr',
#  'surname',
#  'surnamePrefix',
#  'startDate',
#  'object',
#  'category',
#  'city',
#  'company',
#  'complexName',
#  'constructionYear',
#  'contractor',
#  'country',
#  'description',
#  'endOfLife',
#  'energyLabel',
#  'floor',
#  'houseNumber',
#  'houseNumberSuffix',
#  'intendedUse',
#  'intendedUseDateFrom',
#  'media',
#  'media',
#  'attachmentType',
#  'fileID',
#  'hash',
#  'mimetype',
#  'pixelHeight',
#  'pixelWidth',
#  'size',
#  'url',
#  'memo',
#  'nickname',
#  'objectId',
#  'postalCode',
#  'qualityLevel',
#  'rentPolicy',
#  'residenceType',
#  'street',
#  'subComplexName',
#  'vheType',
#  'rentTermination',
#  'mutationType',
#  'rentTerminationId',
#  'terminationDate']

# %%
#creating a plantUML .txt file based on the list above
textfile = open(str(method_name) + '_plantuml.txt', 'w')
textfile.write('@startuml\n')
textfile.write('title '+ str(method_name) + '\n')
textfile.write('object '+attribute_list[0] +'{\n')
for i in range (len(attribute_list)):
    try:
        textfile.write(attribute_list[i+1] + "\n")
    except:
        pass
textfile.write('}\n')
textfile.write('@enduml')
textfile.close() 
print('done')
# Out:
# done

# %%
#check the file
import glob
my_txts= glob.glob('*.txt')
my_txts
# Out:
# ['updatewosintake_plantuml.txt',
#  'UpdateWosWorkAssignment_plantuml.txt',
#  'WosIntakePlanned_plantuml.txt']

# %%
pwd
# Out:
# 'C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\webservices\\movinu'

# %%
# %pycat C:\\Users\\31653\\Documents\\GitHub\\Notebooks\\de_alliantie\\Webservices\\movinu\\WosIntakePlanned_plantuml.txt

# %%
#convert the txt file to an .png image using plantuml
# !python -m plantuml WosIntakePlanned_plantuml.txt
# Out:
# [{'filename': 'WosIntakePlanned_plantuml.txt', 'gen_success': True}]

# %%
from IPython import display
display.Image(filename='WosIntakePlanned_plantuml.png')
